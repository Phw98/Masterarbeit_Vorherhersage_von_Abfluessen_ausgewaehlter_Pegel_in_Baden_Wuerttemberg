# %% [markdown]
# # Verschiedene Ansätze für den Umgang mit Lücken
# Dieser Block wurde erstellt, als noch nicht klar war, welche Methoden des maschinellen Lernens in der vorliegenden Arbeit verwendet werden sollten. Aus diesem Grund wurden präventiv verschiedene Verfahren zum Umgang mit fehlenden Werten (Lücken) in den Niederschlagszeitreihen implementiert.

# %% [markdown]
# ### Interpolation kleiner Lücken und belassen von NaNs in großen Lücken
# 1. In der Funktion "interpolate_small_gaps" wird die Zeitreihe zunächst auf stündliche Frequenz gebracht ("asfreq("h")"). Fehlende Werte in "Wert in mm" werden zeitbasiert interpoliert ("method="time"") für maximal 6 aufeinanderfolgende Stundenwerte ("limit=6") innerhalb der Zeitreihe. Interpolierte Werte werden dabei in der Spalte "Interpoliert" markiert. Schließlich werden die durch die stündliche Frequenz entstandenen NaNs in Spalten mit konstanten Werten (z.B. "Stations ID") mit dem jeweiligen ersten Eintrag gefüllt.
# 2. Die Funktion "interpolate_and_big_gaps" wendet die in 1. definierte Interpolation an. Das daraus resultierende DataFrame wird als CSV-Datei gespeichert, wobei die bisherige Endung "_filtered_standardised.csv" durch "_interpolated_and_nan.csv" ersetzt wird.
#
# ### Interpolation kleiner Lücken und Maskierung großer Lücken
# 1. Die Funktion "mask_big_gaps(interpolated)" nutzt das Ergebnis der Funktion "interpolate_small_gaps" und ersetzt alle restlichen Lücken in "Wert in mm" durch den Fehlerwert -999.0. Diese maskierten Werte werden dabei in der Spalte "Maskiert" markiert. Das daraus resultierende DataFrame wird als CSV-Datei gespeichert, wobei die Endung "_filtered_standardised.csv" durch "_interpolated_and_masked.csv" ersetzt wird.
# 2. Die Funktion "interpolate_and_mask()" kombiniert beide Funktionen.
#
# ### Belassen aller NaNs
# Die Funktion "keep_nan()" füllt die aus "asfreq("h")" resultierenden NaNs in konstanten Metadatenspalten auf. Die fehlenden Werte innerhalb der Spalte "Wert in mm" werden nicht interpoliert und bleiben NaNs. Das daraus resultierende DataFrame wird als CSV-Datei gespeichert, wobei die Endung "_standardised.csv" durch "_just_nan.csv" ersetzt wird.
#
# ### Maskieren aller NaNs
# Die Funktion "mask_nans()" ersetzt alle NaNs in "Wert in mm" durch -999.0 und markiert diese in der Spalte "Maskiert". Das daraus resultierende DataFrame wird als CSV-Datei gespeichert, wobei die Endung "_standardised.csv" durch "_just_masked.csv" ersetzt wurde.
#
# In der vorliegenden Arbeit wurde letztlich nur die NaN-Variante ("..._just_nan.csv") verwendet, da XGBoost und Random Forest mit fehlenden Werten umgehen können.

# %%
from pathlib import Path
import pandas as pd
import glob


files=glob.glob("Datensätze/DWD/Filtered-Enhanced-Ba-Wü-Messnetze und Parameternetze-stündlich/*/*_standardised.csv")
print(f"Found {len(files)} files")

# interpolate every gap in the respective csv file
def interpolate_small_gaps():
    interpolated = []
    for p in files:
        p = Path(p)

        # read the respective file as a data frame.
        df = pd.read_csv(p, sep=",", encoding="utf-8")

        # store the data frame as a copy of the data frame to work with it without missunderstandings.
        df = df.copy()
        # define the column "Datum / Uhrzeit" as a real date time.
        df["Datum / Uhrzeit"] = pd.to_datetime(df["Datum / Uhrzeit"], errors="coerce")

        # convert the column "Wert in mm" to a real numeric value.
        df["Wert in mm"] = df["Wert in mm"].astype(float)

        # maybe "Datum / Uhrzeit" is by any case not sorted.
        df = df.sort_values("Datum / Uhrzeit")
        
        # set the column "Datum / Uhrzeit" as index and in hourly frequence. Now the gaps are rows with NaNs but the Index is a real date time.
        df = df.set_index("Datum / Uhrzeit").asfreq("h")

        # set marker for the interpolation marker. True if respective df["Wert in mm"] is nan false if not
        was_nan = df["Wert in mm"].isna()

        # The interpolation of the NaNs in the column "Wert in mm" but just inside the data frame.
        df["Wert in mm"] = df["Wert in mm"].interpolate(method="time", limit=6, limit_direction="both", limit_area="inside")

        # new column which marks interpolated values
        df["Interpoliert"] = was_nan & df["Wert in mm"].notna()

       
        for c in ("Stations ID", "Geographische Breite", "Geographische Länge", "Stationsname"):
            if c in df.columns and df[c].notna().any():
                df[c] = df[c].fillna(df[c].iloc[0])
                
        # reset the index and change the "index" back to "Datum / Uhrzeit" to avoid mistakes for repeated execution. 
        df = df.reset_index().rename(columns={"index": "Datum / Uhrzeit"})

        # create new data frame with the respective columns
        cols = [c for c in ("Stations ID", "Stationsname", "Geographische Breite", "Geographische Länge", "Datum / Uhrzeit", "Wert in mm", "Interpoliert") if c in df.columns]

        # store those as a data frame
        df = df[cols]
        
        interpolated.append({
            "Datei": p.name, "Pfad": p,  "Data Frame": df
        })

    print(f"\n Ready. interpolated {len(interpolated)} of {len(files)} files.")
    return interpolated

def mask_big_gaps(interpolated):
    masked = []
    for i in interpolated:
        df_masked = i["Data Frame"].copy()
        filename = i["Datei"]
        path = i["Pfad"]

        df_masked["Maskiert"] = df_masked["Wert in mm"].isna()
        df_masked["Wert in mm"] = df_masked["Wert in mm"].fillna(-999.0)

        cols = [c for c in ("Stations ID", "Stationsname", "Geographische Breite", "Geographische Länge", "Datum / Uhrzeit", "Wert in mm", "Interpoliert", "Maskiert") if c in df_masked.columns]

        df_masked = df_masked[cols]

        # replace old ending with new ending and store it as a csv file
        out_path = path.with_name(filename.replace("_filtered_standardised", "_interpolated_and_masked"))
        df_masked.to_csv(out_path, index=False, encoding="utf-8")

        print(f"masked: {filename} to {out_path.name} ({len(df_masked)} rows)")
        masked.append({
            "Datei": out_path.name, "Pfad": out_path, "Data Frame": df_masked
        })

    print(f"\n Ready. masked {len(masked)} of {len(interpolated)} files.")
    return masked

        
    
def interpolate_and_mask():
    interpolated = interpolate_small_gaps()
    masked = mask_big_gaps(interpolated)

    return masked

def interpolate_and_big_gaps():
    interpolated = interpolate_small_gaps()
    gaps = []
    for i in interpolated:
        df_gaps = i["Data Frame"].copy()
        filename = i["Datei"]
        path = i["Pfad"]


        cols = [c for c in ("Stations ID", "Stationsname", "Geographische Breite", "Geographische Länge", "Datum / Uhrzeit", "Wert in mm", "Interpoliert") if c in df_gaps.columns]

        df_gaps = df_gaps[cols]

        # replace old ending with new ending and store it as a csv file
        out_path = path.with_name(filename.replace("_filtered_standardised", "_interpolated_and_nan"))
        df_gaps.to_csv(out_path, index=False, encoding="utf-8")

        print(f"just interpolated: {filename} to {out_path.name} ({len(df_gaps)} rows)")
        gaps.append({
            "Datei": out_path.name, "Pfad": out_path, "Data Frame": df_gaps
        })

    print(f"\n Ready. Interpolated small gaps an kept NaNs in big gaps in {len(gaps)} of {len(interpolated)} files.")
    return gaps

def keep_nan():
    kept = []

    for f in files:
        path = Path(f)
        filename = path.name

        df_nan = pd.read_csv(path, encoding="utf-8")

        # store the data frame as a copy of the data frame to work with it without missunderstandings.
        df_nan = df_nan.copy()
        # define the column "Datum / Uhrzeit" as a real date time.
        df_nan["Datum / Uhrzeit"] = pd.to_datetime(df_nan["Datum / Uhrzeit"], errors="coerce")

        # convert the column "Wert in mm to a real numeric value.
        df_nan["Wert in mm"] = df_nan["Wert in mm"].astype(float)

        # maybe "Datum / Uhrzeit" is by any case not sorted.
        df_nan = df_nan.sort_values("Datum / Uhrzeit")
        
        # set the column "Datum / Uhrzeit" as index and in hourly frequence. Now the gaps are rows with NaNs but the Index is a real date time.
        df_nan = df_nan.set_index("Datum / Uhrzeit").asfreq("h")


        
        for c in ("Stations ID", "Geographische Breite", "Geographische Länge", "Stationsname"):
            if c in df_nan.columns and df_nan[c].notna().any():
                df_nan[c] = df_nan[c].fillna(df_nan[c].iloc[0])
                
        # reset the index and change the "index" back to "Datum / Uhrzeit" to avoid mistakes for repeated execution. 
        df_nan = df_nan.reset_index().rename(columns={"index": "Datum / Uhrzeit"})

        cols = [c for c in ("Stations ID", "Stationsname", "Geographische Breite", "Geographische Länge", "Datum / Uhrzeit", "Wert in mm") if c in df_nan.columns]

        df_nan = df_nan[cols]

        # replace old ending with new ending and store it as a csv file
        out_path = path.with_name(filename.replace("_standardised", "_just_nan"))
        df_nan.to_csv(out_path, index=False, encoding="utf-8")

        print(f"just kept all NaNs: {filename} to {out_path.name} ({len(df_nan)} rows)")
        kept.append({
            "Datei": out_path.name, "Pfad": out_path, "Data Frame": df_nan
        })

    print(f"\n Ready. Kept NaNs in {len(kept)} of {len(files)} files.")
    return kept

def mask_nans():
    mask = []

    for f in files:
        path = Path(f)
        filename = path.name

        df_mask = pd.read_csv(path, encoding="utf-8")

        # store the data frame as a copy of the data frame to work with it without missunderstandings.
        df_mask = df_mask.copy()
        # define the column "Datum / Uhrzeit" as a real date time.
        df_mask["Datum / Uhrzeit"] = pd.to_datetime(df_mask["Datum / Uhrzeit"], errors="coerce")

        # convert the column "Wert in mms to a real numeric value.
        df_mask["Wert in mm"] = df_mask["Wert in mm"].astype(float)

        # maybe "Datum / Uhrzeit" is by any case not sorted.
        df_mask = df_mask.sort_values("Datum / Uhrzeit")
        
        # set the column "Datum / Uhrzeit" as index and in hourly frequence. Now the gaps are rows with NaNs but the Index is a real date time.
        df_mask = df_mask.set_index("Datum / Uhrzeit").asfreq("h")


        
        for c in ("Stations ID", "Geographische Breite", "Geographische Länge", "Stationsname"):
            if c in df_mask.columns and df_mask[c].notna().any():
                df_mask[c] = df_mask[c].fillna(df_mask[c].iloc[0])
                
        

        df_mask["Maskiert"] = df_mask["Wert in mm"].isna()
        df_mask["Wert in mm"] = df_mask["Wert in mm"].fillna(-999.0)

        # reset the index and change the "index" back to "Datum / Uhrzeit" to avoid mistakes for repeated execution. 
        df_mask = df_mask.reset_index().rename(columns={"index": "Datum / Uhrzeit"})
        
        cols = [c for c in ("Stations ID", "Stationsname", "Geographische Breite", "Geographische Länge", "Datum / Uhrzeit", "Wert in mm", "Maskiert") if c in df_mask.columns]

        df_mask = df_mask[cols]

        # replace old ending with new ending and store it as a csv file
        out_path = path.with_name(filename.replace("_standardised", "_just_masked"))
        df_mask.to_csv(out_path, index=False, encoding="utf-8")

        print(f"masked: {filename} to {out_path.name} ({len(df_mask)} rows)")
        mask.append({
            "Datei": out_path.name, "Pfad": out_path, "Data Frame": df_mask
        })

    print(f"\n Ready. masked {len(mask)} of {len(files)} files.")
    return mask

    

interpolated_and_masked = interpolate_and_mask()
interpolated_and_nan = interpolate_and_big_gaps()
kept_all_nans = keep_nan()
masked_nans = mask_nans()
# Out:
# Found 128 files
#
#  Ready. interpolated 128 of 128 files.
# masked: produkt_rr_stunde_20040814_20241231_00020_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040814_20241231_00020_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_00257_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_00257_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_00259_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_00259_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060524_20241231_00269_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060524_20241231_00269_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061101_20241231_00279_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061101_20241231_00279_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060724_20241231_00498_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060724_20241231_00498_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050621_20241231_00684_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050621_20241231_00684_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20071201_20241231_00731_enhanced_filtered_standardised.csv to produkt_rr_stunde_20071201_20241231_00731_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_00755_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_00755_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_00757_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_00757_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041019_20241231_00931_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041019_20241231_00931_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060608_20241231_01089_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060608_20241231_01089_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041102_20241231_01176_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041102_20241231_01176_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_01197_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_01197_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040801_20241231_01214_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_01214_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050201_20241231_01216_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050201_20241231_01216_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021201_20241231_01224_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021201_20241231_01224_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021201_20241231_01255_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021201_20241231_01255_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20051101_20241231_01290_enhanced_filtered_standardised.csv to produkt_rr_stunde_20051101_20241231_01290_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_01443_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_01443_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_01468_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_01468_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_01602_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_01602_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070501_20241231_01711_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_01711_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050201_20241231_01937_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050201_20241231_01937_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061001_20241231_02050_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061001_20241231_02050_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_02074_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_02074_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050701_20241231_02159_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050701_20241231_02159_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050301_20241231_02388_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050301_20241231_02388_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070501_20241231_02546_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_02546_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060901_20241231_02575_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060901_20241231_02575_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_02638_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_02638_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061010_20241231_02677_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_02677_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_02712_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_02712_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050101_20241231_02787_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050101_20241231_02787_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19960327_20241231_02812_enhanced_filtered_standardised.csv to produkt_rr_stunde_19960327_20241231_02812_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_02814_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_02814_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061101_20241231_02850_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061101_20241231_02850_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050711_20241231_02880_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050711_20241231_02880_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070401_20241231_02953_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070401_20241231_02953_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070501_20241231_03247_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_03247_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20030105_20241231_03278_enhanced_filtered_standardised.csv to produkt_rr_stunde_20030105_20241231_03278_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_03362_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_03362_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_03402_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_03402_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070101_20241231_03418_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070101_20241231_03418_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_03440_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_03440_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050301_20241231_03519_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050301_20241231_03519_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061010_20241231_03690_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_03690_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_03734_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_03734_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_03761_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_03761_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_03925_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_03925_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_03927_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_03927_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_04094_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_04094_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_04160_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_04160_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_04169_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_04169_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_04175_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_04175_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20081101_20241231_04177_enhanced_filtered_standardised.csv to produkt_rr_stunde_20081101_20241231_04177_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040801_20241231_04189_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_04189_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041026_20241231_04294_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041026_20241231_04294_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_04300_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_04300_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_04315_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_04315_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_04349_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_04349_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_04703_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_04703_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070501_20241231_04710_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_04710_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060619_20241231_04712_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060619_20241231_04712_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041110_20241231_04881_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041110_20241231_04881_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_04887_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_04887_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19980601_20241231_04928_enhanced_filtered_standardised.csv to produkt_rr_stunde_19980601_20241231_04928_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19951004_20241231_04931_enhanced_filtered_standardised.csv to produkt_rr_stunde_19951004_20241231_04931_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041028_20241231_05059_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041028_20241231_05059_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061009_20241231_05174_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061009_20241231_05174_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040801_20241231_05229_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_05229_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_05275_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_05275_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061010_20241231_05435_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_05435_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050401_20241231_05453_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050401_20241231_05453_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20051001_20241231_05511_enhanced_filtered_standardised.csv to produkt_rr_stunde_20051001_20241231_05511_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20071201_20241231_05559_enhanced_filtered_standardised.csv to produkt_rr_stunde_20071201_20241231_05559_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_05562_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_05562_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_05664_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_05664_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070701_20241231_05711_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070701_20241231_05711_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070101_20241231_05724_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070101_20241231_05724_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040801_20241231_05731_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_05731_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060218_20241231_05840_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060218_20241231_05840_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_05906_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_05906_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20030105_20241231_06258_enhanced_filtered_standardised.csv to produkt_rr_stunde_20030105_20241231_06258_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_06259_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_06259_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021201_20241231_06260_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021201_20241231_06260_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_06262_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_06262_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_06263_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_06263_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_06275_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_06275_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050101_20241231_07104_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050101_20241231_07104_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050101_20241231_07138_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050101_20241231_07138_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041201_20241231_07187_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041201_20241231_07187_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050416_20241231_07224_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050416_20241231_07224_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050416_20241231_07226_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050416_20241231_07226_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07227_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07227_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07230_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07230_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050416_20241231_07233_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050416_20241231_07233_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07234_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07234_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07235_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07235_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07238_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07238_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07240_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07240_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050414_20241231_07241_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050414_20241231_07241_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07242_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07242_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07243_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07243_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_07322_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_07322_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_07331_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_07331_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060526_20241231_07380_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060526_20241231_07380_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061201_20241231_07382_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061201_20241231_07382_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070330_20241231_07403_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070330_20241231_07403_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061201_20241231_07429_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061201_20241231_07429_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061009_20241231_07434_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061009_20241231_07434_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061010_20241231_07436_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_07436_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07487_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07487_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07488_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07488_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07489_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07489_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07490_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07490_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07491_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07491_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07492_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07492_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07493_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07493_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07494_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07494_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07495_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07495_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07497_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07497_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07498_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07498_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070801_20241231_13674_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070801_20241231_13674_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20080101_20241231_13698_enhanced_filtered_standardised.csv to produkt_rr_stunde_20080101_20241231_13698_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20080301_20241231_13715_enhanced_filtered_standardised.csv to produkt_rr_stunde_20080301_20241231_13715_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20080901_20241231_13716_enhanced_filtered_standardised.csv to produkt_rr_stunde_20080901_20241231_13716_enhanced_interpolated_and_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20081201_20241231_13965_enhanced_filtered_standardised.csv to produkt_rr_stunde_20081201_20241231_13965_enhanced_interpolated_and_masked.csv (131496 rows)
#
#  Ready. masked 128 of 128 files.
#
#  Ready. interpolated 128 of 128 files.
# just interpolated: produkt_rr_stunde_20040814_20241231_00020_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040814_20241231_00020_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021101_20241231_00257_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_00257_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040701_20241231_00259_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_00259_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20060524_20241231_00269_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060524_20241231_00269_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061101_20241231_00279_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061101_20241231_00279_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20060724_20241231_00498_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060724_20241231_00498_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050621_20241231_00684_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050621_20241231_00684_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20071201_20241231_00731_enhanced_filtered_standardised.csv to produkt_rr_stunde_20071201_20241231_00731_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040601_20241231_00755_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_00755_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040601_20241231_00757_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_00757_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20041019_20241231_00931_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041019_20241231_00931_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20060608_20241231_01089_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060608_20241231_01089_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20041102_20241231_01176_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041102_20241231_01176_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021101_20241231_01197_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_01197_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040801_20241231_01214_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_01214_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050201_20241231_01216_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050201_20241231_01216_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021201_20241231_01224_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021201_20241231_01224_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021201_20241231_01255_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021201_20241231_01255_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20051101_20241231_01290_enhanced_filtered_standardised.csv to produkt_rr_stunde_20051101_20241231_01290_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19950901_20241231_01443_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_01443_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19950901_20241231_01468_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_01468_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040701_20241231_01602_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_01602_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070501_20241231_01711_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_01711_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050201_20241231_01937_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050201_20241231_01937_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061001_20241231_02050_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061001_20241231_02050_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040601_20241231_02074_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_02074_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050701_20241231_02159_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050701_20241231_02159_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050301_20241231_02388_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050301_20241231_02388_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070501_20241231_02546_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_02546_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20060901_20241231_02575_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060901_20241231_02575_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19950901_20241231_02638_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_02638_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061010_20241231_02677_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_02677_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19950901_20241231_02712_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_02712_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050101_20241231_02787_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050101_20241231_02787_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19960327_20241231_02812_enhanced_filtered_standardised.csv to produkt_rr_stunde_19960327_20241231_02812_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021101_20241231_02814_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_02814_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061101_20241231_02850_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061101_20241231_02850_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050711_20241231_02880_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050711_20241231_02880_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070401_20241231_02953_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070401_20241231_02953_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070501_20241231_03247_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_03247_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20030105_20241231_03278_enhanced_filtered_standardised.csv to produkt_rr_stunde_20030105_20241231_03278_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19950901_20241231_03362_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_03362_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021101_20241231_03402_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_03402_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070101_20241231_03418_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070101_20241231_03418_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050901_20241231_03440_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_03440_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050301_20241231_03519_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050301_20241231_03519_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061010_20241231_03690_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_03690_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040701_20241231_03734_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_03734_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19950901_20241231_03761_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_03761_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050901_20241231_03925_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_03925_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040701_20241231_03927_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_03927_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040601_20241231_04094_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_04094_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040701_20241231_04160_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_04160_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021101_20241231_04169_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_04169_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040601_20241231_04175_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_04175_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20081101_20241231_04177_enhanced_filtered_standardised.csv to produkt_rr_stunde_20081101_20241231_04177_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040801_20241231_04189_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_04189_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20041026_20241231_04294_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041026_20241231_04294_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040701_20241231_04300_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_04300_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050901_20241231_04315_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_04315_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040601_20241231_04349_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_04349_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021101_20241231_04703_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_04703_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070501_20241231_04710_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_04710_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20060619_20241231_04712_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060619_20241231_04712_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20041110_20241231_04881_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041110_20241231_04881_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19950901_20241231_04887_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_04887_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19980601_20241231_04928_enhanced_filtered_standardised.csv to produkt_rr_stunde_19980601_20241231_04928_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19951004_20241231_04931_enhanced_filtered_standardised.csv to produkt_rr_stunde_19951004_20241231_04931_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20041028_20241231_05059_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041028_20241231_05059_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061009_20241231_05174_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061009_20241231_05174_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040801_20241231_05229_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_05229_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040601_20241231_05275_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_05275_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061010_20241231_05435_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_05435_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050401_20241231_05453_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050401_20241231_05453_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20051001_20241231_05511_enhanced_filtered_standardised.csv to produkt_rr_stunde_20051001_20241231_05511_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20071201_20241231_05559_enhanced_filtered_standardised.csv to produkt_rr_stunde_20071201_20241231_05559_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040601_20241231_05562_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_05562_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040701_20241231_05664_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_05664_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070701_20241231_05711_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070701_20241231_05711_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070101_20241231_05724_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070101_20241231_05724_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040801_20241231_05731_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_05731_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20060218_20241231_05840_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060218_20241231_05840_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_19950901_20241231_05906_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_05906_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20030105_20241231_06258_enhanced_filtered_standardised.csv to produkt_rr_stunde_20030105_20241231_06258_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040601_20241231_06259_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_06259_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021201_20241231_06260_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021201_20241231_06260_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20021101_20241231_06262_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_06262_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040701_20241231_06263_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_06263_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20040701_20241231_06275_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_06275_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050101_20241231_07104_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050101_20241231_07104_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050101_20241231_07138_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050101_20241231_07138_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20041201_20241231_07187_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041201_20241231_07187_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050416_20241231_07224_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050416_20241231_07224_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050416_20241231_07226_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050416_20241231_07226_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050415_20241231_07227_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07227_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050415_20241231_07230_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07230_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050416_20241231_07233_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050416_20241231_07233_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050415_20241231_07234_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07234_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050415_20241231_07235_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07235_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050415_20241231_07238_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07238_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050415_20241231_07240_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07240_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050414_20241231_07241_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050414_20241231_07241_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050415_20241231_07242_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07242_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050415_20241231_07243_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07243_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050901_20241231_07322_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_07322_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20050901_20241231_07331_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_07331_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20060526_20241231_07380_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060526_20241231_07380_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061201_20241231_07382_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061201_20241231_07382_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070330_20241231_07403_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070330_20241231_07403_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061201_20241231_07429_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061201_20241231_07429_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061009_20241231_07434_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061009_20241231_07434_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061010_20241231_07436_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_07436_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07487_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07487_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07488_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07488_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07489_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07489_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07490_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07490_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07491_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07491_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07492_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07492_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07493_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07493_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07494_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07494_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07495_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07495_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07497_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07497_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20061126_20241231_07498_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07498_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20070801_20241231_13674_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070801_20241231_13674_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20080101_20241231_13698_enhanced_filtered_standardised.csv to produkt_rr_stunde_20080101_20241231_13698_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20080301_20241231_13715_enhanced_filtered_standardised.csv to produkt_rr_stunde_20080301_20241231_13715_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20080901_20241231_13716_enhanced_filtered_standardised.csv to produkt_rr_stunde_20080901_20241231_13716_enhanced_interpolated_and_nan.csv (131496 rows)
# just interpolated: produkt_rr_stunde_20081201_20241231_13965_enhanced_filtered_standardised.csv to produkt_rr_stunde_20081201_20241231_13965_enhanced_interpolated_and_nan.csv (131496 rows)
#
#  Ready. Interpolated small gaps an kept NaNs in big gaps in 128 of 128 files.
# just kept all NaNs: produkt_rr_stunde_20040814_20241231_00020_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040814_20241231_00020_enhanced_filtered_just_nan.csv (131496 rows)
# just kept all NaNs: produkt_rr_stunde_20021101_20241231_00257_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_00257_enhanced_filtered_just_nan.csv (131496 rows)
# ...
# masked: produkt_rr_stunde_20070501_20241231_03247_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_03247_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20030105_20241231_03278_enhanced_filtered_standardised.csv to produkt_rr_stunde_20030105_20241231_03278_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_03362_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_03362_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_03402_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_03402_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070101_20241231_03418_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070101_20241231_03418_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_03440_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_03440_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050301_20241231_03519_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050301_20241231_03519_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061010_20241231_03690_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_03690_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_03734_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_03734_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_03761_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_03761_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_03925_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_03925_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_03927_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_03927_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_04094_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_04094_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_04160_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_04160_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_04169_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_04169_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_04175_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_04175_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20081101_20241231_04177_enhanced_filtered_standardised.csv to produkt_rr_stunde_20081101_20241231_04177_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040801_20241231_04189_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_04189_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041026_20241231_04294_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041026_20241231_04294_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_04300_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_04300_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_04315_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_04315_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_04349_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_04349_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_04703_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_04703_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070501_20241231_04710_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070501_20241231_04710_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060619_20241231_04712_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060619_20241231_04712_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041110_20241231_04881_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041110_20241231_04881_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_04887_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_04887_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19980601_20241231_04928_enhanced_filtered_standardised.csv to produkt_rr_stunde_19980601_20241231_04928_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19951004_20241231_04931_enhanced_filtered_standardised.csv to produkt_rr_stunde_19951004_20241231_04931_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041028_20241231_05059_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041028_20241231_05059_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061009_20241231_05174_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061009_20241231_05174_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040801_20241231_05229_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_05229_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_05275_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_05275_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061010_20241231_05435_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_05435_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050401_20241231_05453_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050401_20241231_05453_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20051001_20241231_05511_enhanced_filtered_standardised.csv to produkt_rr_stunde_20051001_20241231_05511_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20071201_20241231_05559_enhanced_filtered_standardised.csv to produkt_rr_stunde_20071201_20241231_05559_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_05562_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_05562_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_05664_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_05664_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070701_20241231_05711_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070701_20241231_05711_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070101_20241231_05724_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070101_20241231_05724_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040801_20241231_05731_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040801_20241231_05731_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060218_20241231_05840_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060218_20241231_05840_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_19950901_20241231_05906_enhanced_filtered_standardised.csv to produkt_rr_stunde_19950901_20241231_05906_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20030105_20241231_06258_enhanced_filtered_standardised.csv to produkt_rr_stunde_20030105_20241231_06258_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040601_20241231_06259_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040601_20241231_06259_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021201_20241231_06260_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021201_20241231_06260_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20021101_20241231_06262_enhanced_filtered_standardised.csv to produkt_rr_stunde_20021101_20241231_06262_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_06263_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_06263_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20040701_20241231_06275_enhanced_filtered_standardised.csv to produkt_rr_stunde_20040701_20241231_06275_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050101_20241231_07104_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050101_20241231_07104_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050101_20241231_07138_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050101_20241231_07138_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20041201_20241231_07187_enhanced_filtered_standardised.csv to produkt_rr_stunde_20041201_20241231_07187_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050416_20241231_07224_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050416_20241231_07224_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050416_20241231_07226_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050416_20241231_07226_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07227_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07227_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07230_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07230_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050416_20241231_07233_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050416_20241231_07233_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07234_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07234_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07235_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07235_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07238_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07238_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07240_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07240_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050414_20241231_07241_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050414_20241231_07241_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07242_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07242_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050415_20241231_07243_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050415_20241231_07243_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_07322_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_07322_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20050901_20241231_07331_enhanced_filtered_standardised.csv to produkt_rr_stunde_20050901_20241231_07331_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20060526_20241231_07380_enhanced_filtered_standardised.csv to produkt_rr_stunde_20060526_20241231_07380_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061201_20241231_07382_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061201_20241231_07382_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070330_20241231_07403_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070330_20241231_07403_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061201_20241231_07429_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061201_20241231_07429_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061009_20241231_07434_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061009_20241231_07434_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061010_20241231_07436_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061010_20241231_07436_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07487_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07487_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07488_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07488_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07489_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07489_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07490_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07490_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07491_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07491_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07492_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07492_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07493_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07493_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07494_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07494_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07495_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07495_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07497_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07497_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20061126_20241231_07498_enhanced_filtered_standardised.csv to produkt_rr_stunde_20061126_20241231_07498_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20070801_20241231_13674_enhanced_filtered_standardised.csv to produkt_rr_stunde_20070801_20241231_13674_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20080101_20241231_13698_enhanced_filtered_standardised.csv to produkt_rr_stunde_20080101_20241231_13698_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20080301_20241231_13715_enhanced_filtered_standardised.csv to produkt_rr_stunde_20080301_20241231_13715_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20080901_20241231_13716_enhanced_filtered_standardised.csv to produkt_rr_stunde_20080901_20241231_13716_enhanced_filtered_just_masked.csv (131496 rows)
# masked: produkt_rr_stunde_20081201_20241231_13965_enhanced_filtered_standardised.csv to produkt_rr_stunde_20081201_20241231_13965_enhanced_filtered_just_masked.csv (131496 rows)
#
#  Ready. masked 128 of 128 files.
