# %% [markdown]
# # Random Forest - Anwendung (Lead Time 6 Stunde)

# %% [markdown]
# ### Feature Creation
# In diesem Block wird die Attributmatrix für die Modellierung erstellt. Dazu werden Zeitmerkmale aus dem Zeitindex abgeleitet ("Stunde", "Tage in einer Woche", "Monat", "Viertel Jahr", "Jahr", "Tage im Jahr"). Zusätzlich werden zyklische Zeitinformationen über Sinus und Cosinus ("Sinus Tag", "Cosinus Tag", "Sinus Jahr", "Cosinus Jahr") abgebildet, damit die Modelle periodische Muster lernen können.
# Darüber hinaus werden Lag-Features erzeugt (1, 3, 6, 12, 24, 48, 72, 168, 720, 8760 Stunden), um Informationen aus der Vergangenheit in die Vorhersage einzubeziehen (Von Bedeutung wegen Autokorrelation in Abflusszeitreihen). Diese gehen als Spalten "Abfluss in m^3/s_lag{lag}" in die Attributmatrix ein.
# Da Niederschlag häufig zeitverzögert auf den Abfluss wirkt, werden auch die zugeordneten Niederschlagszeitreihen um 0, 1, 3, 6, 12, 24, 36, 48 Stunden verschoben. Diese Merkmale werden als "{column}_lag{lag}" ergänzt. Die konstanten Spalten "Stationsname", "Gewässer", "Interpoliert" werden abschließend entfernt.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import glob

# Create new time series for all 25 stations which is enriched by feauters an which based on datetime index.
def feature_creation_nan():
    all_merged_files_nan=glob.glob("Datensätze/UDO-LUBW/Endgültige Auswahl Landespegel Hydrologie/Gewässer/*/*/*_merged_nan.csv")

    
    all_water_stations = []
    for a in all_merged_files_nan:
        p = Path(a)
        
        # read the respective file as a data frame.
        df_water_station = pd.read_csv(p, sep=",", index_col="Datum / Uhrzeit", parse_dates=["Datum / Uhrzeit"], encoding="utf-8")

        df_water_station = df_water_station.sort_index()
        
        # save "Stationsname" and "Gewässer" separately. I will drop them later on in the features.
        station_and_water = df_water_station[["Stationsname", "Gewässer"]]
        
        # defining time features by creating them from the datetime index
        df_water_station["Stunde"] = df_water_station.index.hour
        df_water_station["Tage in einer Woche"] = df_water_station.index.dayofweek
        df_water_station["Monat"] = df_water_station.index.month
        df_water_station["Viertel Jahr"] = df_water_station.index.quarter
        df_water_station["Jahr"] = df_water_station.index.year
        df_water_station["Tage im Jahr"] = df_water_station.index.dayofyear


        # defining cyclic features by calculating daily and yearly cycles (as sinus and cosinus).
        df_water_station["Sinus Tag"] = np.sin(2 * np.pi * df_water_station["Stunde"] / 24)
        df_water_station["Cosinus Tag"] = np.cos(2 * np.pi * df_water_station["Stunde"] / 24)
        df_water_station["Sinus Jahr"] = np.sin(2 * np.pi * df_water_station["Tage im Jahr"] / 365)
        df_water_station["Cosinus Jahr"] = np.cos(2 * np.pi * df_water_station["Tage im Jahr"] / 365)

        # defining lag features by shifting the original "Abfluss in m^3/s" to enable connecting with past surface runoff.
        # store them in a separate data frame to avoid warnings
        lags_water = {}
        for lag in [1, 3, 6, 12, 24, 48, 72, 168, 720, 8760]:
            lags_water[f"Abfluss in m^3/s_lag{lag}"] = df_water_station["Abfluss in m^3/s"].shift(lag)
        df_lags_water = pd.DataFrame(lags_water, index=df_water_station.index)

        # defining lag features for exogenous variables by shifting the original precipitation columns to capture their delayed impact on the surface runoff. 
        # store them in a separate data frame to avoid warnings
        lags_exogene = {}
        for column in df_water_station.filter(regex=r"^Niederschlag").columns:
            for lag in [0, 1, 3, 6, 12, 24, 36, 48]:
                lags_exogene[f"{column}_lag{lag}"] = df_water_station[column].shift(lag)
        df_lags_exogene = pd.DataFrame(lags_exogene, index=df_water_station.index)

        # Concatenate the data frames to one
        df_water_station = pd.concat([df_water_station, df_lags_water, df_lags_exogene], axis=1)
        

        # remove static columns or columns that are not used as features for the model
        df_water_station = df_water_station.drop(columns=["Stationsname", "Gewässer", "Interpoliert"])
                
        all_water_stations.append({
            "Stationsname": station_and_water["Stationsname"].iloc[0],
            "Gewässer": station_and_water["Gewässer"].iloc[0],
            "df": df_water_station
        })
        print(f"Create features for {p.name}.")

    return all_water_stations

feature_creation_nan()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# [{'Stationsname': 'Gießen Argen',
#   'Gewässer': 'Argen',
#   'df':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            78.308                      0.0
#   2010-01-01 01:00:00            75.247                      0.0
#   2010-01-01 02:00:00            73.206                      0.0
#   2010-01-01 03:00:00            69.861                      0.0
#   2010-01-01 04:00:00            67.697                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            11.832                      0.0
#   2024-12-31 20:00:00            11.037                      0.0
#   2024-12-31 21:00:00            10.951                      0.0
#   2024-12-31 22:00:00            10.797                      0.0
#   2024-12-31 23:00:00            10.783                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Blaubeuren Blau',
#   'Gewässer': 'Blau',
#   'df':                      Abfluss in m^3/s  Niederschlag 2814 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             5.580                      0.0
#   2010-01-01 01:00:00             5.555                      0.0
#   2010-01-01 02:00:00             5.562                      0.0
#   2010-01-01 03:00:00             5.568                      0.0
#   2010-01-01 04:00:00             5.597                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             2.573                      0.0
#   2024-12-31 20:00:00             2.635                      0.0
#   2024-12-31 21:00:00             2.450                      0.0
#   2024-12-31 22:00:00             2.488                      0.0
#   2024-12-31 23:00:00             2.428                      0.0
#
#                        Niederschlag 5511 in mm  Niederschlag 3418 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3418 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3418 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 57 columns]},
#  {'Stationsname': 'Bolheim Brenz',
#   'Gewässer': 'Brenz',
#   'df':                      Abfluss in m^3/s  Niederschlag 3440 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             4.161                      0.0
#   2010-01-01 01:00:00             4.161                      0.0
#   2010-01-01 02:00:00             3.967                      0.0
#   2010-01-01 03:00:00             3.967                      0.0
#   2010-01-01 04:00:00             3.967                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             4.098                      0.0
#   2024-12-31 20:00:00             4.040                      0.0
#   2024-12-31 21:00:00             3.962                      0.0
#   2024-12-31 22:00:00             3.871                      0.0
#   2024-12-31 23:00:00             3.982                      0.0
#
#                        Niederschlag 7331 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 7331 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 7331 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Beuron Donau',
#   'Gewässer': 'Donau',
#   'df':                      Abfluss in m^3/s  Niederschlag 2638 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            74.509                      0.0
#   2010-01-01 01:00:00            74.509                      0.0
#   2010-01-01 02:00:00            75.483                      0.0
#   2010-01-01 03:00:00            75.483                      0.0
#   2010-01-01 04:00:00            75.483                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            14.078                      0.0
#   2024-12-31 20:00:00            14.012                      0.0
#   2024-12-31 21:00:00            13.903                      0.0
#   2024-12-31 22:00:00            13.838                      0.0
#   2024-12-31 23:00:00            13.765                      0.0
#
#                        Niederschlag 4703 in mm  Niederschlag 3519 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3519 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3519 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
# ...
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Hausen Zaber',
#   'Gewässer': 'Zaber',
#   'df':                      Abfluss in m^3/s  Niederschlag 4349 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             1.417                      0.0
#   2010-01-01 01:00:00             1.417                      0.0
#   2010-01-01 02:00:00             1.334                      0.0
#   2010-01-01 03:00:00             1.334                      0.0
#   2010-01-01 04:00:00             1.334                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             0.486                      0.0
#   2024-12-31 20:00:00             0.487                      0.0
#   2024-12-31 21:00:00             0.487                      0.0
#   2024-12-31 22:00:00             0.486                      0.0
#   2024-12-31 23:00:00             0.485                      0.0
#
#                        Niederschlag 3734 in mm  Niederschlag 7238 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag 7498 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  ...  \
#   Datum / Uhrzeit                                                        ...
#   2010-01-01 00:00:00       0                    4      1             1  ...
#   2010-01-01 01:00:00       1                    4      1             1  ...
#   2010-01-01 02:00:00       2                    4      1             1  ...
#   2010-01-01 03:00:00       3                    4      1             1  ...
#   2010-01-01 04:00:00       4                    4      1             1  ...
#   ...                     ...                  ...    ...           ...  ...
#   2024-12-31 19:00:00      19                    1     12             4  ...
#   2024-12-31 20:00:00      20                    1     12             4  ...
#   2024-12-31 21:00:00      21                    1     12             4  ...
#   2024-12-31 22:00:00      22                    1     12             4  ...
#   2024-12-31 23:00:00      23                    1     12             4  ...
#
#                        Niederschlag 7498 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 7498 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 66 columns]}]

# %% [markdown]
# ## Hyperparameter Tuning mit Cross Validation

# %% [markdown]
# ### Teilung in Trainings- und Testset
# In diesem Block werden alle Zeitreihen zeitbasiert in Trainings- und Testsets aufgeteilt. Das Trainingsset umfasst alle Einträge von 2010 bis einschließlich 2021 (Zeitstempel vor dem 0.01.2022). Die späteren Einträge werden dem Testset zugeordnet.

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import glob

# split the stations time series in train and test sets
def train_and_test_nan():
    # create the features for every station
    water_stations = feature_creation_nan()
    train_test_nan = []

    # defining the timestamp separating the train and test data
    split_train_test = pd.Timestamp("2022-01-01")
    for a in water_stations:
        
        # defining important information to identify the correct train and test set for the respective station
        water = a["Gewässer"]
        station = a["Stationsname"]
        df_water_station = a["df"]

        # splitting the respective time series into train and test data (ratio: 80% train set, 20% test set)
        # (train set until 2021-12-31, test set from 2022-01-01)
        train_data = df_water_station[df_water_station.index < split_train_test]
        test_data = df_water_station[df_water_station.index >= split_train_test]

        # store the respective split with the meta data in train_test_nan
        train_test_nan.append({
            "Gewässer": water, "Stationsname": station, "Trainingsset": train_data, "Testset": test_data
        })

        print(f"Created train ({len(train_data)} rows) and test data ({len(test_data)} rows) for {station}.")

    return train_test_nan



train_and_test_nan()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# [{'Gewässer': 'Argen',
#   'Stationsname': 'Gießen Argen',
#   'Trainingsset':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            78.308                      0.0
#   2010-01-01 01:00:00            75.247                      0.0
#   2010-01-01 02:00:00            73.206                      0.0
#   2010-01-01 03:00:00            69.861                      0.0
#   2010-01-01 04:00:00            67.697                      0.0
#   ...                               ...                      ...
#   2021-12-31 19:00:00            49.543                      0.0
#   2021-12-31 20:00:00            48.711                      0.0
#   2021-12-31 21:00:00            47.784                      0.0
#   2021-12-31 22:00:00            47.063                      0.0
#   2021-12-31 23:00:00            46.322                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2021-12-31 19:00:00                      0.0                              0.0
#   2021-12-31 20:00:00                      0.0                              0.0
#   2021-12-31 21:00:00                      0.0                              0.0
#   2021-12-31 22:00:00                      0.0                              0.0
#   2021-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2021-12-31 19:00:00      19                    4     12             4  2021
#   2021-12-31 20:00:00      20                    4     12             4  2021
#   2021-12-31 21:00:00      21                    4     12             4  2021
#   2021-12-31 22:00:00      22                    4     12             4  2021
#   2021-12-31 23:00:00      23                    4     12             4  2021
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2021-12-31 19:00:00           365  ...                            0.1
#   2021-12-31 20:00:00           365  ...                            0.0
#   2021-12-31 21:00:00           365  ...                            0.0
#   2021-12-31 22:00:00           365  ...                            0.0
#   2021-12-31 23:00:00           365  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2021-12-31 19:00:00                            3.1
#   2021-12-31 20:00:00                            0.3
#   2021-12-31 21:00:00                            0.1
#   2021-12-31 22:00:00                            0.1
#   2021-12-31 23:00:00                            0.4
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                   0.05
#   2021-12-31 20:00:00                                   0.05
#   2021-12-31 21:00:00                                   0.00
#   2021-12-31 22:00:00                                   0.00
#   2021-12-31 23:00:00                                   0.00
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                   2.45
#   2021-12-31 20:00:00                                   0.50
#   2021-12-31 21:00:00                                   0.40
#   2021-12-31 22:00:00                                   0.65
#   2021-12-31 23:00:00                                   0.90
#
#   [105192 rows x 48 columns],
#   'Testset':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00            45.612                      0.0
#   2022-01-01 01:00:00            44.763                      0.0
#   2022-01-01 02:00:00            44.163                      0.0
#   2022-01-01 03:00:00            43.402                      0.0
#   2022-01-01 04:00:00            42.720                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            11.832                      0.0
#   2024-12-31 20:00:00            11.037                      0.0
#   2024-12-31 21:00:00            10.951                      0.0
#   2024-12-31 22:00:00            10.797                      0.0
#   2024-12-31 23:00:00            10.783                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.0                              0.0
#   2022-01-01 01:00:00                      0.0                              0.0
#   2022-01-01 02:00:00                      0.0                              0.0
#   2022-01-01 03:00:00                      0.0                              0.0
#   2022-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00       0                    5      1             1  2022
#   2022-01-01 01:00:00       1                    5      1             1  2022
#   2022-01-01 02:00:00       2                    5      1             1  2022
#   2022-01-01 03:00:00       3                    5      1             1  2022
#   2022-01-01 04:00:00       4                    5      1             1  2022
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2022-01-01 00:00:00             1  ...                            0.0
#   2022-01-01 01:00:00             1  ...                            0.0
#   2022-01-01 02:00:00             1  ...                            0.0
#   2022-01-01 03:00:00             1  ...                            0.0
#   2022-01-01 04:00:00             1  ...                            0.0
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.3
#   2022-01-01 01:00:00                            0.2
#   2022-01-01 02:00:00                            0.1
#   2022-01-01 03:00:00                            0.2
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.45
#   2022-01-01 01:00:00                                   0.15
#   2022-01-01 02:00:00                                   0.05
#   2022-01-01 03:00:00                                   0.10
#   2022-01-01 04:00:00                                   0.00
#   ...                                                    ...
#   2024-12-31 19:00:00                                   0.00
#   2024-12-31 20:00:00                                   0.00
#   2024-12-31 21:00:00                                   0.00
#   2024-12-31 22:00:00                                   0.00
#   2024-12-31 23:00:00                                   0.00
#
#   [26304 rows x 48 columns]},
#  {'Gewässer': 'Blau',
#   'Stationsname': 'Blaubeuren Blau',
#   'Trainingsset':                      Abfluss in m^3/s  Niederschlag 2814 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             5.580                      0.0
#   2010-01-01 01:00:00             5.555                      0.0
#   2010-01-01 02:00:00             5.562                      0.0
#   2010-01-01 03:00:00             5.568                      0.0
#   2010-01-01 04:00:00             5.597                      0.0
#   ...                               ...                      ...
#   2021-12-31 19:00:00             5.165                      0.0
#   2021-12-31 20:00:00             5.158                      0.0
#   2021-12-31 21:00:00             5.068                      0.0
#   2021-12-31 22:00:00             5.168                      0.0
#   2021-12-31 23:00:00             5.085                      0.0
#
#                        Niederschlag 5511 in mm  Niederschlag 3418 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2021-12-31 19:00:00                      0.0                      0.0
#   2021-12-31 20:00:00                      0.0                      0.0
#   2021-12-31 21:00:00                      0.0                      0.0
#   2021-12-31 22:00:00                      0.0                      0.0
#   2021-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2021-12-31 19:00:00                              0.0      19
#   2021-12-31 20:00:00                              0.0      20
#   2021-12-31 21:00:00                              0.0      21
#   2021-12-31 22:00:00                              0.0      22
#   2021-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2021-12-31 19:00:00                    4     12             4  2021  ...
#   2021-12-31 20:00:00                    4     12             4  2021  ...
#   2021-12-31 21:00:00                    4     12             4  2021  ...
#   2021-12-31 22:00:00                    4     12             4  2021  ...
#   2021-12-31 23:00:00                    4     12             4  2021  ...
#
#                        Niederschlag 3418 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2021-12-31 19:00:00                            0.0
#   2021-12-31 20:00:00                            0.0
#   2021-12-31 21:00:00                            0.1
#   2021-12-31 22:00:00                            0.0
#   2021-12-31 23:00:00                            0.0
#
#                        Niederschlag 3418 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2021-12-31 19:00:00                            4.0
#   2021-12-31 20:00:00                            0.2
#   2021-12-31 21:00:00                            0.2
#   2021-12-31 22:00:00                            0.0
#   2021-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                               0.333333
#   2021-12-31 20:00:00                               0.033333
#   2021-12-31 21:00:00                               0.000000
#   2021-12-31 22:00:00                               0.000000
#   2021-12-31 23:00:00                               0.000000
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                               0.100000
#   2021-12-31 20:00:00                               0.900000
#   2021-12-31 21:00:00                               0.533333
#   2021-12-31 22:00:00                               0.000000
#   2021-12-31 23:00:00                               0.000000
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                               3.433333
#   2021-12-31 20:00:00                               1.700000
#   2021-12-31 21:00:00                               0.333333
#   2021-12-31 22:00:00                               0.000000
#   2021-12-31 23:00:00                               0.000000
#
#   [105192 rows x 57 columns],
#   'Testset':                      Abfluss in m^3/s  Niederschlag 2814 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00             5.010                      0.0
#   2022-01-01 01:00:00             5.038                      0.0
#   2022-01-01 02:00:00             5.068                      0.0
#   2022-01-01 03:00:00             4.945                      0.0
#   2022-01-01 04:00:00             4.870                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             2.573                      0.0
#   2024-12-31 20:00:00             2.635                      0.0
#   2024-12-31 21:00:00             2.450                      0.0
#   2024-12-31 22:00:00             2.488                      0.0
#   2024-12-31 23:00:00             2.428                      0.0
#
#                        Niederschlag 5511 in mm  Niederschlag 3418 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.0                      0.0
#   2022-01-01 01:00:00                      0.0                      0.0
#   2022-01-01 02:00:00                      0.0                      0.0
#   2022-01-01 03:00:00                      0.0                      0.0
#   2022-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                              0.0       0
#   2022-01-01 01:00:00                              0.0       1
#   2022-01-01 02:00:00                              0.0       2
#   2022-01-01 03:00:00                              0.0       3
#   2022-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2022-01-01 00:00:00                    5      1             1  2022  ...
#   2022-01-01 01:00:00                    5      1             1  2022  ...
#   2022-01-01 02:00:00                    5      1             1  2022  ...
#   2022-01-01 03:00:00                    5      1             1  2022  ...
#   2022-01-01 04:00:00                    5      1             1  2022  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3418 in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.0
#   2022-01-01 01:00:00                            0.0
#   2022-01-01 02:00:00                            0.0
#   2022-01-01 03:00:00                            0.0
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3418 in mm_lag48  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.5
#   2022-01-01 01:00:00                            0.8
#   2022-01-01 02:00:00                            0.9
#   2022-01-01 03:00:00                            0.1
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
# ...
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                   0.25
#   2021-12-31 20:00:00                                   0.00
#   2021-12-31 21:00:00                                   0.00
#   2021-12-31 22:00:00                                   0.00
#   2021-12-31 23:00:00                                   0.00
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                  1.125
#   2021-12-31 20:00:00                                  0.350
#   2021-12-31 21:00:00                                  0.025
#   2021-12-31 22:00:00                                  0.000
#   2021-12-31 23:00:00                                  0.000
#
#   [105192 rows x 66 columns],
#   'Testset':                      Abfluss in m^3/s  Niederschlag 4349 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00             0.541                      0.0
#   2022-01-01 01:00:00             0.536                      0.0
#   2022-01-01 02:00:00             0.524                      0.0
#   2022-01-01 03:00:00             0.531                      0.0
#   2022-01-01 04:00:00             0.520                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             0.486                      0.0
#   2024-12-31 20:00:00             0.487                      0.0
#   2024-12-31 21:00:00             0.487                      0.0
#   2024-12-31 22:00:00             0.486                      0.0
#   2024-12-31 23:00:00             0.485                      0.0
#
#                        Niederschlag 3734 in mm  Niederschlag 7238 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.1                      0.0
#   2022-01-01 01:00:00                      0.0                      0.0
#   2022-01-01 02:00:00                      0.1                      0.0
#   2022-01-01 03:00:00                      0.0                      0.0
#   2022-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag 7498 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.0                            0.025
#   2022-01-01 01:00:00                      0.1                            0.025
#   2022-01-01 02:00:00                      0.1                            0.050
#   2022-01-01 03:00:00                      0.0                            0.000
#   2022-01-01 04:00:00                      0.0                            0.000
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                            0.000
#   2024-12-31 20:00:00                      0.0                            0.000
#   2024-12-31 21:00:00                      0.0                            0.000
#   2024-12-31 22:00:00                      0.0                            0.000
#   2024-12-31 23:00:00                      0.0                            0.000
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  ...  \
#   Datum / Uhrzeit                                                        ...
#   2022-01-01 00:00:00       0                    5      1             1  ...
#   2022-01-01 01:00:00       1                    5      1             1  ...
#   2022-01-01 02:00:00       2                    5      1             1  ...
#   2022-01-01 03:00:00       3                    5      1             1  ...
#   2022-01-01 04:00:00       4                    5      1             1  ...
#   ...                     ...                  ...    ...           ...  ...
#   2024-12-31 19:00:00      19                    1     12             4  ...
#   2024-12-31 20:00:00      20                    1     12             4  ...
#   2024-12-31 21:00:00      21                    1     12             4  ...
#   2024-12-31 22:00:00      22                    1     12             4  ...
#   2024-12-31 23:00:00      23                    1     12             4  ...
#
#                        Niederschlag 7498 in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.0
#   2022-01-01 01:00:00                            0.0
#   2022-01-01 02:00:00                            0.1
#   2022-01-01 03:00:00                            0.4
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 7498 in mm_lag48  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.0
#   2022-01-01 01:00:00                            0.0
#   2022-01-01 02:00:00                            0.0
#   2022-01-01 03:00:00                            0.0
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                 0.025
#   2022-01-01 01:00:00                                 0.025
#   2022-01-01 02:00:00                                 0.050
#   2022-01-01 03:00:00                                 0.000
#   2022-01-01 04:00:00                                 0.000
#   ...                                                   ...
#   2024-12-31 19:00:00                                 0.000
#   2024-12-31 20:00:00                                 0.000
#   2024-12-31 21:00:00                                 0.000
#   2024-12-31 22:00:00                                 0.000
#   2024-12-31 23:00:00                                 0.000
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                 0.000
#   2022-01-01 01:00:00                                 0.025
#   2022-01-01 02:00:00                                 0.025
#   2022-01-01 03:00:00                                 0.050
#   2022-01-01 04:00:00                                 0.000
#   ...                                                   ...
#   2024-12-31 19:00:00                                 0.000
#   2024-12-31 20:00:00                                 0.000
#   2024-12-31 21:00:00                                 0.000
#   2024-12-31 22:00:00                                 0.000
#   2024-12-31 23:00:00                                 0.000
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                 0.000
#   2022-01-01 01:00:00                                 0.000
#   2022-01-01 02:00:00                                 0.000
#   2022-01-01 03:00:00                                 0.025
#   2022-01-01 04:00:00                                 0.025
#   ...                                                   ...
#   2024-12-31 19:00:00                                 0.000
#   2024-12-31 20:00:00                                 0.000
#   2024-12-31 21:00:00                                 0.000
#   2024-12-31 22:00:00                                 0.000
#   2024-12-31 23:00:00                                 0.000
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                  0.000
#   2022-01-01 01:00:00                                  0.000
#   2022-01-01 02:00:00                                  0.025
#   2022-01-01 03:00:00                                  0.100
#   2022-01-01 04:00:00                                  0.050
#   ...                                                    ...
#   2024-12-31 19:00:00                                  0.000
#   2024-12-31 20:00:00                                  0.000
#   2024-12-31 21:00:00                                  0.000
#   2024-12-31 22:00:00                                  0.000
#   2024-12-31 23:00:00                                  0.000
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                  0.025
#   2022-01-01 01:00:00                                  0.000
#   2022-01-01 02:00:00                                  0.000
#   2022-01-01 03:00:00                                  0.000
#   2022-01-01 04:00:00                                  0.000
#   ...                                                    ...
#   2024-12-31 19:00:00                                  0.000
#   2024-12-31 20:00:00                                  0.000
#   2024-12-31 21:00:00                                  0.000
#   2024-12-31 22:00:00                                  0.000
#   2024-12-31 23:00:00                                  0.000
#
#   [26304 rows x 66 columns]}]

# %% [markdown]
# ### Hyperparameter-Optimierung
# In diesem Abschnitt werden die Hyperparameter des Random Forest für die spätere Vorhersage der Testsets aller 25 Zeitreihen optimiert. Für das Tuning werden drei repräsentative Zeitreihen verwendet, die anhand des Variationskoeffizienten (hoch, mittel, niedrig) ausgewählt wurden ("Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein").
# Es wird eine Grid-Search mit TimeSeriesSplit-Cross-Validation durchgeführt. Pro Station werden 7 Folds verwendet. Das Validierungsset umfasst dabei jeweils 720 Stunden. Zur Vermeidung von Leakage wird eine Lücke von 6 Stunde ("gap=6") zwischen trainingsset und Validierungsset gesetzt. Die Zielgröße ist dabei eine 6-Stunden-Vorhersage (y=Abfluss(t+6)).
# Bewertet werden hier RMSE, MAE und NSE. Der Output zeigt dabei die Hyperparameterkombination mit dem niedrigsten mittleren RMSE und MAE sowie der höchsten mittleren NSE über alle Folds und repräsentativen Stationen.
# Als primäres Auswahlkriterium wurde die NSE verwendet. Darüber hinaus wurde die Diferenz zwischen Trainings-NSE und Validierungs-NSE ("nse gap") betrachtet, um ggfs. ein mögliches Overfitting zu erkennen und diesem später entgegenwirken zu können.
# Randbemerkung: Mit horizon ist die Lead Time der Vorhersage gemeint, also t --> Q(t+6)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from itertools import product
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


def hyper_parameter_tuning_cross_validation():
    train_test = train_and_test_nan()

    # define possible parameters
    params = {
                "n_estimators": [100, 200, 300, 500],
                "max_features": ["sqrt", "log2", 1.0],
                "max_depth": [10, 20],
                "min_samples_split": [5, 10],
                "min_samples_leaf": [1, 4],
                "max_samples": np.linspace(0.5, 1.0, 3),
            }
    keys = params.keys()
    values = params.values()
    params_columns = list(keys)

    # create all hyperparameter combinations a list of dictionaries. Each of them containing one hyper parameter combination.
    dict_all_combination = []
    all_combination = list(product(*values))
    for c in all_combination:
        dict_combination = dict(zip(keys, c))
        dict_all_combination.append(dict_combination)
            
    pred = []
    scores = []

    # try every hyperparameter combination of the grid.
    for d in dict_all_combination:
        selected_stations = ["Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein"]
        selected_train_test = [t for t in train_test if t["Stationsname"] in selected_stations]

        
        for t in selected_train_test:
            train_water = t["Trainingsset"].copy()
            train_water = train_water.sort_index()
            # define forecast horizon to forecast six hour in the future.
            train_water["y"] = train_water["Abfluss in m^3/s"].shift(-6)
    
            # the last 6 rows of y are NaN due to the shift by six hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
            train_water = train_water.dropna(subset=["y"])
    
            # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast. We keep "Abfluss in m^3/s" as current value and the last knon runoff which is important for the prediction. 
            x = train_water.drop(columns=["y"])
            y = train_water["y"]
            
            station = t["Stationsname"]
    
            # define Time Series Split for the Cross validation. We evaluate the model on 720 hour validation windows using six hour forecasts. 
            # To avoid leakage between train and validation I use a gap of six hours.
            tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=6)
            fold = 0

            # split the train set into seven folds for the cross validation and use RandomForestRegressor with the respective hyperparameter combination.
            for train_idx, validation_idx in tss.split(x):
                fold += 1
                x_train = x.iloc[train_idx]
                x_validation = x.iloc[validation_idx]
                y_train = y.iloc[train_idx]
                y_validation = y.iloc[validation_idx]
                
                model = RandomForestRegressor(
                    **d,
                    n_jobs = -1, 
                    random_state=42
                )
                    
                model.fit(x_train, y_train)
                
                
                # this is needed to predict the validation set    
                y_pred_validation = model.predict(x_validation)
                pred.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold, 
                    "Vorhersage": y_pred_validation
                 })

                # this is needed to check for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting
                y_pred_train = model.predict(x_train)

                # calculate the evaluation metrics for the validation set forecast in the cross validation
                rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
                mae_validation = mean_absolute_error(y_validation, y_pred_validation)
                nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

                # calculate the evaluation metrics for the training set forecast in the cross validation to compare them with the claculated metrics in the validation set forecast.
                rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
                mae_train = mean_absolute_error(y_train, y_pred_train)
                nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)

                # store information about the respective hyperparameter, station and fold with the corresponding metrics
                scores.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold,
                    "rmse validation": rmse_validation,
                    "mae validation": mae_validation,
                    "nse validation": nse_validation,
                    "rmse train": rmse_train,
                    "mae train": mae_train,
                    "nse train": nse_train,
                })
                print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
                print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
                print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station and hyperparameter combination
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby(["Stationsname"] + params_columns)[["rmse validation", "mae validation", "nse validation", "rmse train", "mae train", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "rmse train": "mean_rmse_train", "mae train": "mean_mae_train", "nse train": "mean_nse_train"})

    # calculate the mean evaluation metrics of all stations with the same hyperparameter configurations to find the best hyper parameter combination for all stations. We also want to calculate the evaluation metrics in the train set to identify if the model realy learns to regularize ore just to memorize if the metrics in the train set are much betterthan the metrics in the validation set.
    mean_per_hyper_parameter = mean_per_station.groupby(params_columns)[["mean_rmse_validation", "mean_mae_validation", "mean_nse_validation", "mean_rmse_train", "mean_mae_train", "mean_nse_train"]].mean()
    mean_per_hyper_parameter = mean_per_hyper_parameter.reset_index()
    mean_per_hyper_parameter["nse gap"] = mean_per_hyper_parameter["mean_nse_train"] - mean_per_hyper_parameter["mean_nse_validation"]

    # sort the evaluation metrics to show the best hyperparameter for the best metric
    sorted_rmse = mean_per_hyper_parameter.sort_values("mean_rmse_validation")
    sorted_mae = mean_per_hyper_parameter.sort_values("mean_mae_validation")
    sorted_nse = mean_per_hyper_parameter.sort_values("mean_nse_validation", ascending=False)

    # define the best hyperparameters per evaluation metric
    best_hp_rmse = sorted_rmse[params_columns].iloc[0]
    best_hp_mae = sorted_mae[params_columns].iloc[0]
    best_hp_nse = sorted_nse[params_columns].iloc[0]

    print(f"Best Hyperparameter combination with lowest mean rmse for all stations are {best_hp_rmse} with mean rmse {sorted_rmse['mean_rmse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_rmse['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean mae for all stations are {best_hp_mae} with mean mae {sorted_mae['mean_mae_validation'].iloc[0]} with nse gap between train and validation of: {sorted_mae['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean nse for all stations are {best_hp_nse} with mean nse {sorted_nse['mean_nse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_nse['nse gap'].iloc[0]}.")

    return best_hp_rmse, best_hp_mae, best_hp_nse

hyper_parameter_tuning_cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.0015261186582975.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.724850508065178.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8368297063987828.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.124856847778166.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9742191193558187.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9249894552551131.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.0039113393425518.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5944953884008546.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7800481438056552.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4275578746660756.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.308905959966647.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4555364803183245.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7646458579632575.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5122256713918177.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.6945014319482004.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8342611613546331.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.523878101004835.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7169252170911302.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.7334840900263004.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.826272622843621.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9445030563136624.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.159102868727646.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06821577329452339.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8897926688316099.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28801225457657714.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1252495129554567.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9219547318160735.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11564997560596063.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.054328644405779294.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8842680531055266.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04302204431315491.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.026781053822737825.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9439085692151994.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03742528657342447.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.025114893000928035.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7023802398246325.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01386555821783225.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.01087373332096937.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8460360524456358.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.061754181982637484.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.039942204999365294.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9685840701781008.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.797658465773.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.196663360372006.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9925014858538039.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.06594946724367.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.067497757972223.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9783989345989471.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.554665759761062.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.5742360942292026.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9940617429819163.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 5.541654022870887.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.964256434817745.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9958888849046672.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.7621201803478246.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.243645858349152.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9884535178406986.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.5389331292224204.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.2174174730430298.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9457140466291194.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7699488537484451.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.3983993846196918.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9695943753690441.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.103391490423625.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.775967511192775.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8255664693892946.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.004143769397116.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9350220419969058.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9279170420360864.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.0871824628897249.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6035976382774183.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.742046284012214.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.42057371770302665.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3061405941195312.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.47317882079005535.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7154459227100459.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.48881340181817357.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7325502943320897.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8115745609508969.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.49964052688591304.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7321115542435815.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.9998493559349737.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9322727342758084.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9363017169095366.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1514491674253162.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06480753367107787.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9001407625920705.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2861306687346983.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11846091975077415.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9229711412710254.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11949536897537047.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05598194291945555.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8764438642223168.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0434015707997039.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0272802445288211.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9429145633417063.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0368785465111032.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.024121508621942143.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.711012481872122.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.014099760332426272.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.010851997001342697.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.840790938793747.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06134294196168505.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03871364607318276.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.969001093602629.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.961139315012312.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.4247520130168914.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9918420011552026.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 7.599191865854277.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.38774979482785.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9848230884397617.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.037503905264903.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.9937936192397583.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9953337083729548.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.128700705679733.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.690152132457422.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.997718042131791.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.167859563071959.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7744126327788554.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9928874253714245.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.3291210280660553.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.9730769485534156.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9595072726318893.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.650421601853262.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.250335465922161.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9735623837175285.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.0156883822758123.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.7512905126364273.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8352862832528711.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 5.885248481651709.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9464296231790368.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9307435794064387.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.034623319840951.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6010862445721825.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7663846163101352.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.43854447137823127.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3132314105090732.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4271957286139588.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7938998324303496.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5129103532409429.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.6706786259050319.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8125274285109371.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5115558401129122.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7314821307172539.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.795828942525225.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.8580627118033664.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9426341117840288.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.16368765302942626.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06888087947917226.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8833495795842994.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28923179990297726.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12422336303480609.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9212923901773324.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11745360110342154.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05536138271569203.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8806300968583021.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04364776492451774.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.026953573527542903.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.942265095611.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.037119521746523165.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.024254830737307536.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7072234846307746.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.014287378974469094.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.01123284982277465.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.836525713876994.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.062175645067732994.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03909166964800227.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.968153788793926.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.999720157011352.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.1613722535035076.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9916823121318737.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.723053555188631.
# Calculated CV MAE for Konstanz Rhein with MAE: 6.435605582055979.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9800020415612397.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.0912293605151735.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.183340041790492.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.995208697167334.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.2844743857797125.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.9796181113326297.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9975425996241382.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.1050319560256465.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7292190259576474.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9932937161195665.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.513636927718872.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.2087078066856956.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9474840289287406.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.880962790625057.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.4775843602598684.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9656605839992293.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.0670873111232493.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.795072487042603.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8296237246252665.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.103875318189668.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9284952760594716.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9255024926398426.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.1331454552805416.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6092511761308279.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7197741245614933.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4220272019560019.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3095595433094947.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4695311870269404.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7422180792817766.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5012903917649952.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.71215972823054.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8348494083761948.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5189736835000632.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7165258778614685.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.903775654563148.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.8925792886284765.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9393249477287865.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1556081463891008.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06656972668496344.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8945809438293943.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2986358780146758.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1259235878714423.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9160909877755743.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12053388990568543.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05644646479461611.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8742869066329113.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04318156496962953.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.026736486357234416.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9434918372542129.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03720187117454056.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02362424186507927.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7059229979132393.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.014092424279448401.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.010602498670826653.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.840956567462011.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06109208823091039.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03755644273410724.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9692541069478.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.983773912861962.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.291244642157701.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9870860211605049.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.28645953848604.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.361875650327462.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.972191316576863.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.417576216681976.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.6816304046091717.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9944138310220733.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.669594113336501.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.2805313902951605.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9970809664647449.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.554410449990397.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.2045206059853033.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9963432441769255.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.665205709042746.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.2672014765046242.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9364400197348595.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.5261299029313253.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.1158628137176796.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9773944280256375.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.0416970418767098.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.741124890498112.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8324329005767787.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.284047557198157.
# Calculated CV MAE for Elpershofen Jagst with MAE: 2.0110498867625646.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9210395962695906.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.1868927330814814.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6104406085869514.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.6925603665610937.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.429030166995529.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.31233606797130853.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.45178031218597614.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7895171252390893.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5280184474384376.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.6743046129358674.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8165541260785557.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5022128786503536.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7288141113961097.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.847091088994215.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.8867316832129326.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9410742124981609.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.15225878574964427.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06452499897262685.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8990702520244791.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2968460101892952.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12541362294581737.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9170937873976617.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11690694405150115.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.055479581860746405.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8817386630319168.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.043385752525865816.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.027329338253537817.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9429561668366369.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03666251326161516.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.023402276124944776.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7143883228110228.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.013960398373178381.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.010784575896996213.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8439226282250674.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.062252676688731926.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03883720656799249.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9680748291007498.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.668452170291905.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.962718296930358.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9930030442460078.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 7.443988042517835.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.481307543715998.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9854366959250435.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.602897742113136.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.571505107582311.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9939353098147399.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 5.379904880457481.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.900605599437727.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.996125371995011.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.991515637656545.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.637352537094252.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9939975024856403.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.0009565763806023.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.8003824025072884.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.977034365648475.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7118150872194091.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.350190405406659.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9715589126803365.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.0024460666717188.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.7432224613205316.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8367296698273197.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 5.998043639533287.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9414403347875413.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9280634382747308.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.1489852941791192.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6056094155781115.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7118850112310333.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.42154116463816116.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3062854959006722.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4707523366177767.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7847457357819779.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5165783740765341.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.6782293504352523.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8183414573486225.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5109506109477275.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7276256304983791.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.7174310563714656.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.8101176157267553.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9449792758306845.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1614933127226588.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0668363222670786.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8864561668797633.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.3024542120107506.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13362973055683597.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9139315627717919.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11732992839595646.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05525728258116411.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8808813454659562.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04320912902346002.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.026872800849745224.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9434196726085008.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03722953249502137.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02421626215594067.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7054855154880328.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.014162819201933107.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.011015015627977286.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8393636814099692.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.060746202941444366.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.037647818582043135.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9696012696520022.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.097791407006852.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.3455781897316808.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9912694199180878.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.27835092005927.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.2930810589700945.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9773749174726695.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.733145425507082.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.53884834538782.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9935872300112428.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.603427178178939.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.224566767230401.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9971631042700332.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.8109150764453994.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.150178215604619.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9880419601371816.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.2409506109963475.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.9785095884805531.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9647014418677429.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7828046776293542.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.3616277160486112.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9691510756151703.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.0034823219620352.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.7663178138557358.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8366169491079745.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.168833770617414.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.990352435859053.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9239084257410316.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.1072764237895363.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6123617729472293.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7324228535261681.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4259342502384495.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.31027155020340874.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.45966376154586375.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7723452064015665.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5081437682486014.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.6883182245312768.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8327213987382857.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.520388792203553.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7179691725248635.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.9317027414237273.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9330340556285648.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9384537201595711.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.16578091462491176.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06987952304638635.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8803470177617906.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2944450711492082.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12496414911387238.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9184294817985427.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12128605660060354.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.056071294609058624.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8727130383323745.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.043655527142939715.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02689919684753154.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9422445588990614.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03863614296661545.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02665612987689062.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6828103393937859.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.013993368097423001.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0106353618207059.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8431845541214055.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06215565349781573.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03853009983189479.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9681742647666021.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 6.25981993374087.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.635843152655473.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9796264322916026.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.802970782970828.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.733944905184197.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9693285020461623.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.9016105570169306.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.0527290990949028.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9956425360601936.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.7281630587580805.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.380929782740934.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9970072825922783.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.595543118153454.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.2319964357759017.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9961471541161501.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.3704979215299686.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.0730671143147772.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9569468696726859.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.6759085238494582.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.200167061687652.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9727395440214548.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.0493980051337495.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.7970735794295012.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8315833342920814.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.111221754219469.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9840944472806854.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9253230589210855.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.0140183155871318.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6063466250272588.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7755970763135702.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.42351751717097985.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.30842153089706265.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4657780563677488.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7559270206042191.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.508815644857104.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7014285775265798.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.81884486637442.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.509790844618354.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.727290421060647.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.8864961306733368.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.8991645399899495.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.939860898423283.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1647744803804699.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07452106693966226.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8817954031001765.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2873775702662263.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12672927581759919.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9222983250346571.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11715098980258755.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05468935716125072.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8812444015284313.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04408278126638985.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.027586520927648867.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9411085285036616.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03856675729711491.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02611824609201082.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.683948582142283.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.014391475237085893.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.011272998863599086.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.834134924850364.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.05902189568625509.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03708550874001255.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9713025386269363.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.8182364595181486.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.3321558389677826.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9924200027844474.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 7.983216321945906.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.708620131430184.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9832504023583788.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.8538450043523618.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.847457980902527.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9957485756617315.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.134923519170797.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.6618328501597874.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9977111581745598.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.062679161554878.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.692780501302638.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9935608593825296.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.061091652531685.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.8662533960639948.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9741920346249475.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7251820792544397.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.2977079831787186.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9711130045822607.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.981031785688995.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.746946013410214.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8390503432363384.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.080008394695503.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9287633934030586.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9260839429685068.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.0914212009268993.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6037675348098016.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7400309282622777.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4258685302594737.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3101129808377868.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4598304921932169.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7597171382023357.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5015826559179218.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.6984270769323955.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8156196868775379.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5141373945384631.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7294344296863242.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.900126955663199.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9063630802450267.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.939438315686539.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1767978405761081.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07180377134052886.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8639155892318657.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.29501950403057225.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1258272363686293.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9181108994967585.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12011198465660386.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05746915071014464.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8751654344507167.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0438757056989047.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.027224688541071164.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9416605055802435.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04315429988428739.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03250781527624711.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6042876143086068.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.015213633311006253.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.011798860905556232.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8146424804471214.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.062126831739829864.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03939181276693339.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9682037732961012.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.828412018680004.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.8957379936436194.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9878786204562315.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.670209798824155.
# Calculated CV MAE for Konstanz Rhein with MAE: 6.466653525931744.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9802436006252281.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.085379839278807.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.327515426815848.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9952223883047543.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.875075818513217.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.492804446321038.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9968184147286995.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.9870867954894702.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.61831268975183.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9940241701692765.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.2282596429194605.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.9746962423968971.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9654197334796375.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7114293672585792.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.2644554149702825.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9715717283859711.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.091240929560618.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.791887283041865.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8269296980480942.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.130252817232682.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9900368262537516.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9248572291764614.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.1095424235722622.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6080302729708932.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.731326559667987.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.41852298436680635.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3022362550884627.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.47830389516916805.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7325500112207111.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5066887205455818.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7196096537272832.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8123362104858953.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5071081256881251.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7316085003956183.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.9760960215046417.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.920510187760286.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9370560222993883.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.16841080974593342.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06875403465353756.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8765206334666416.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.30550122628320264.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1273401259978009.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9121886691533437.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11931353401084067.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.055252098173519414.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8768196065122793.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04341631535191431.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.026811564761833998.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9428757701755406.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0375172554357296.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.024713691808373427.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7009157015453744.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.013549478163769594.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.010544790502422898.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8529755853258216.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06147390468492507.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.038349725579779365.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9688685914873792.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.8223961571628062.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.1534680655646374.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9924034780500484.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.36642749385844.
# Calculated CV MAE for Konstanz Rhein with MAE: 6.412632528147938.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9816037760824688.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.559722533144782.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.7097850421105565.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9940485498779653.
# ...
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.6442333037410846.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.9211323448998554.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.997998546484094.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.960249923317609.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.3844400845458553.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9994855967428327.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.0018428704112667.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.7412870398330896.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9984809790245934.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8803647052848101.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.64471020658982.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9822346725335119.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.268812694044987.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.9053925543155701.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9843747301586974.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.686521773574601.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3696658011001739.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8692813449454901.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.614000170546983.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.5238664081132094.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9574317646981632.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.0574679352081917.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5955844626985497.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7559542061579461.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4451918857248265.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3480942672345933.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.40969909733978505.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7236700269244036.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.46493088572414265.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7263662457928928.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6673971198931.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4270568266481809.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8188385500808241.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.5551609462178275.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3141578007542734.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9740057687341538.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.14703137576362507.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06289336134583928.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9058816062839277.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28041010774689923.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11548886708512758.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9260204011328234.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12717735042699763.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.057950443801420726.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8600471607031615.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.044826076941178065.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.026570112637435524.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9391058046513919.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0375891827799968.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02385744604312071.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6997678051672047.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.011241980625775331.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.008498971982254274.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8987884711066672.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06015090961263264.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.034938974156029166.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9701941459871914.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.739505022801048.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.0678481922952616.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9960979969227607.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.6241045058270163.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.5155389028726693.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9965481651502658.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.3420408670031096.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7637562180177946.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9984298725572813.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7436884566753614.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.3154434719399606.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9995929773253912.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8929165809419806.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.67949215723583.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9987933360935927.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.787775782304487.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.5862243278632734.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.985774968961858.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.0891520448221292.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.7962750316927893.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9884864429148665.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.754712112871416.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3913294313927826.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8625612240405303.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.63312812629016.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.5385572206694422.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9570780884657679.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.0599885259318758.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5930665271151346.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.754789399793814.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.46928342910548704.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.363910874596406.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.34408221724037213.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7118786138812834.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.45752574945351554.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7352107249578306.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6666118820619084.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4253259430002301.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8192645966836143.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.555996320388729.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3312490675901396.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9739887690542571.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.14705799404080386.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0628666520707842.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9058475251736459.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.285173875515833.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11731160101606479.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9234854340312756.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1278514470645831.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05897463314358087.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8585596039219774.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04649593963147794.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.027954084928925493.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9344844352335854.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.039806342173655467.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0256563601622228.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6633054883965794.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.011452368363432336.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.008651667479671693.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8949647828875378.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.060822792629440334.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03561202338221164.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9695245670140586.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.962072661727682.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.2470039147019003.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9954382149119708.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.815369040737186.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.7436314035936222.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9961742050768431.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.4186477330386786.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7937761150874052.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9983254766586219.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.8248993865573897.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.3300370749463573.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.999554180901685.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8972785471350533.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6839170103078314.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9987815180057621.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8340019335245635.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6206265245362906.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9840565579949581.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.1410992466310166.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.8434721020420975.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9873619714098966.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.743587821253494.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3767704295565155.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8636690145329671.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.708315449286995.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.5483776354980383.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9556736941879683.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.0478014014939276.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.591607938917891.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7603955597162576.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4971229707474295.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3817496448333161.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.2639511651063441.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7311529403806675.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.46204283801122126.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.720678117680496.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6669432628659707.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.42760352008927965.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8190848605238976.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.558372287125083.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3334212201503668.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.97394038827731.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.15146524461904945.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06509309541040877.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.900119560210475.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28869667373907015.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11887571491689053.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.92158336467093.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12979158774853095.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06025784297944524.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8542343282056808.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04766569300901592.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.028790360355208842.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9311464630019431.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04107082739364622.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02626448182772564.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6415749145625833.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.011899003818809067.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.008898002357786011.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8866124090958516.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06151545860304081.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.036091007496445414.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9688264900712183.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.1117643488974878.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.3660229467543488.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9949654946448208.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.814076450206367.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.7546709254283552.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9961767968830667.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.5176897699209055.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8350860158752798.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9981855274731872.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.892837206266333.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.348185755986408.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9995203688876894.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.9108658284624233.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6969013324320071.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9987443362221092.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8590134710183477.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6362474897432632.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9830859379179985.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.1933688592659633.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.8913823061601361.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9861776496120885.
# Best Hyperparameter combination with lowest mean rmse for all stations are n_estimators         200
# max_features         1.0
# max_depth             20
# min_samples_split      5
# min_samples_leaf       4
# max_samples          0.5
# Name: 87, dtype: object with mean rmse 1.268157277129224 with nse gap between train and validation of: 0.10298996575601904.
# Best Hyperparameter combination with lowest mean mae for all stations are n_estimators         100
# max_features         1.0
# max_depth             20
# min_samples_split     10
# min_samples_leaf       4
# max_samples          0.5
# Name: 21, dtype: object with mean mae 0.7641784626749608 with nse gap between train and validation of: 0.1029498754497381.
# Best Hyperparameter combination with lowest mean nse for all stations are n_estimators         300
# max_features         1.0
# max_depth             20
# min_samples_split      5
# min_samples_leaf       4
# max_samples          0.5
# Name: 159, dtype: object with mean nse 0.8897974683163339 with nse gap between train and validation of: 0.10199613492443016.
# (n_estimators         200
#  max_features         1.0
#  max_depth             20
#  min_samples_split      5
#  min_samples_leaf       4
#  max_samples          0.5
#  Name: 87, dtype: object,
#  n_estimators         100
#  max_features         1.0
#  max_depth             20
#  min_samples_split     10
#  min_samples_leaf       4
#  max_samples          0.5
#  Name: 21, dtype: object,
#  n_estimators         300
#  max_features         1.0
#  max_depth             20
#  min_samples_split      5
#  min_samples_leaf       4
#  max_samples          0.5
#  Name: 159, dtype: object)

# %% [markdown]
# ### Hyperparameter-Tuning mit höherem min_samples_leaf
# Mit der nun in der vorherigen Optimierung ausgewählten Kombination wird hier zusätzlich der Hyperparameter "min_samples_leaf" mit etwas höheren Werten in einer erneuten Cross-Validation variiert, während die übrigen Hyperparameter fixiert bleiben. Ziel ist es, zu überprüfen, ob sich dadurch die Validierungsleistung verbessern oder die Differenz zwischen Trainings- und Validierungs-NSE reduzieren lässt. Tatsächlich wird min_samples_leaf=10 gewählt, da die NSE-Leistung damit am besten ist.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from itertools import product
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


def hyper_parameter_tuning_cross_validation():
    train_test = train_and_test_nan()

    # define possible parameters
    params = {
                "min_samples_leaf": [6, 8, 10]
            }
    keys = params.keys()
    values = params.values()
    params_columns = list(keys)

    # create all hyperparameter combinations a list of dictionaries. Each of them containing one hyper parameter combination.
    dict_all_combination = []
    all_combination = list(product(*values))
    for c in all_combination:
        dict_combination = dict(zip(keys, c))
        dict_all_combination.append(dict_combination)
            
    pred = []
    scores = []

    # try every hyperparameter combination of the grid.
    for d in dict_all_combination:
        selected_stations = ["Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein"]
        selected_train_test = [t for t in train_test if t["Stationsname"] in selected_stations]

       
        for t in selected_train_test:
            train_water = t["Trainingsset"].copy()
            train_water = train_water.sort_index()
            # define forecast horizon to forecast one hour in the future.
            train_water["y"] = train_water["Abfluss in m^3/s"].shift(-6)
    
            # the last 6 rows of y are NaNs due to the shift by six hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
            train_water = train_water.dropna(subset=["y"])
    
            # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast. We keep "Abfluss in m^3/s" as current value and the last knon runoff which is important for the prediction. 
            x = train_water.drop(columns=["y"])
            y = train_water["y"]
            
            station = t["Stationsname"]
    
            # define Time Series Spliit for the Cross validation. We evaluate the model on 720 hour validation windows using six hour forecasts. 
            # To avoid leakage between train and validation I use a gap of six hours.
            tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=6)
            fold = 0

            # split the train set into seven folds for the cross validation and use XGBoostRegressor with the respective hyperparameter combination.
            for train_idx, validation_idx in tss.split(x):
                fold += 1
                x_train = x.iloc[train_idx]
                x_validation = x.iloc[validation_idx]
                y_train = y.iloc[train_idx]
                y_validation = y.iloc[validation_idx]
                
                model = RandomForestRegressor(
                    **d,
                    n_estimators=300,
                    max_depth=20,
                    min_samples_split=5,
                    max_features=1.0,
                    max_samples=0.5,
                    n_jobs = -1, 
                    random_state=42
                )
                    
                model.fit(x_train, y_train)
                
                
                # this is needed to predict the validation set    
                y_pred_validation = model.predict(x_validation)
                pred.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold, 
                    "Vorhersage": y_pred_validation
                 })

                # this is needed to check for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting
                y_pred_train = model.predict(x_train)

                # calculate the evaluation metrics for the validation set forecast in the cross validation
                rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
                mae_validation = mean_absolute_error(y_validation, y_pred_validation)
                nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

                # calculate the evaluation metrics for the training set forecast in the cross validation to compare them with the claculated metrics in the validation set forecast.
                rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
                mae_train = mean_absolute_error(y_train, y_pred_train)
                nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)

                # store information about the respective hyperparameter, station and fold with the corresponding metrics
                scores.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold,
                    "rmse validation": rmse_validation,
                    "mae validation": mae_validation,
                    "nse validation": nse_validation,
                    "rmse train": rmse_train,
                    "mae train": mae_train,
                    "nse train": nse_train,
                })
                print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
                print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
                print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station and hyperparameter combination
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby(["Stationsname"] + params_columns)[["rmse validation", "mae validation", "nse validation", "rmse train", "mae train", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "rmse train": "mean_rmse_train", "mae train": "mean_mae_train", "nse train": "mean_nse_train"})

    # calculate the mean evaluation metrics of all stations with the same hyperparameter configurations to find the best hyper parameter combination for all stations. We also want to calculate the evaluation metrics in the train set to identify if the model realy learns to regularize ore just to memorize if the metrics in the train set are much betterthan the metrics in the validation set.
    mean_per_hyper_parameter = mean_per_station.groupby(params_columns)[["mean_rmse_validation", "mean_mae_validation", "mean_nse_validation", "mean_rmse_train", "mean_mae_train", "mean_nse_train"]].mean()
    mean_per_hyper_parameter = mean_per_hyper_parameter.reset_index()
    mean_per_hyper_parameter["nse gap"] = mean_per_hyper_parameter["mean_nse_train"] - mean_per_hyper_parameter["mean_nse_validation"]

    # sort the evaluation metrics to show the best hyperparameter for the best metric
    sorted_rmse = mean_per_hyper_parameter.sort_values("mean_rmse_validation")
    sorted_mae = mean_per_hyper_parameter.sort_values("mean_mae_validation")
    sorted_nse = mean_per_hyper_parameter.sort_values("mean_nse_validation", ascending=False)

    # define the best hyperparameters per evaluation metric
    best_hp_rmse = sorted_rmse[params_columns].iloc[0]
    best_hp_mae = sorted_mae[params_columns].iloc[0]
    best_hp_nse = sorted_nse[params_columns].iloc[0]

    print(f"Best Hyperparameter combination with lowest mean rmse for all stations are {best_hp_rmse} with mean rmse {sorted_rmse['mean_rmse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_rmse['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean mae for all stations are {best_hp_mae} with mean mae {sorted_mae['mean_mae_validation'].iloc[0]} with nse gap between train and validation of: {sorted_mae['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean nse for all stations are {best_hp_nse} with mean nse {sorted_nse['mean_nse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_nse['nse gap'].iloc[0]}.")

    return best_hp_rmse, best_hp_mae, best_hp_nse

hyper_parameter_tuning_cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.6369123834361337.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3601569386735015.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8740644796995644.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.666481040532452.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.5421529337745947.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9564578925273345.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.9187190614850853.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5847211872038266.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8157945962248058.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4306539480604304.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3333430879791298.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.44762268693020546.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7219670917597851.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.46472984279950413.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7276525565530432.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6667774854380605.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4253398136729108.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8191747869711834.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.6090555511034643.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3261200782301357.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9728976400684548.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1412366498928681.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0602048955170976.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.913154108029817.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28129527335175053.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11627589024725135.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9255526037819752.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12423675519884327.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05586869889220331.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8664443183961341.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.043619438884280236.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.025254521771747043.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9423400076054824.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03620963295076419.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.022762319893069396.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7214008812551789.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.011108257667933507.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.008448441709362488.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.901181965709071.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.05973476929365106.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.034574738544214.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9706051293811672.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.686913437466049.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.012072395067547.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9962463760968859.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.6694260173091093.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.5286976595876802.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9964612909591639.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.3214511317149924.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7618455137597449.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9984573583309196.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.747112617190317.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.3184957169538627.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9995913771778274.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8874916780168989.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6738594262185212.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9988079536951053.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.7856908074037532.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.5859359768459319.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9858501669684845.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.0729294216227792.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.7830816021474536.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9888268711953808.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.640543905761456.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.364928223953411.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8737173672386362.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.713010609317113.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.558230545284042.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9555852452000562.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8930340033766659.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5781220313552267.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8259504507019843.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4270434994053582.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3281716469108116.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.45684573045107646.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7294997352844294.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.46750869585478155.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7219398353708043.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.665915828113727.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.42475440995737457.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8196418354203369.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.655630496150841.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3421705544155864.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.971921380540708.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.13873669100682526.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05907628316295139.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9162013294388073.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2814358674885343.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11675006243253444.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9254781661065474.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12362273748234803.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05466551212707306.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8677612057487308.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04331185467152072.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.025121734643436353.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.943150323979143.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03566299174307231.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0220411598541554.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7297491681516699.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.011144392213422425.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.00846613364005551.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9005380208926378.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0592086045432681.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03394242109736634.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9711206893330885.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.557514790565717.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.9182586524427572.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.996599210794423.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.7512481151353163.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.557183134073217.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9963017168037313.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.3201403198923205.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7677581881456963.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9984590999502159.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.75551816287401.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.3272270985313817.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9995874358633242.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8905259566731768.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6718867300360434.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9987997886972811.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.7857655939304943.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.5882715713497931.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9858474731168575.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.0553727646746147.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.7675889668939956.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9891895378369715.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.6552282129434572.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3719661767159002.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8723089232158978.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.790448237840514.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.5682550072698764.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9541137319499405.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8771996515366173.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5774393907350615.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8320678636203884.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.42248910035491144.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.32295573647419495.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.46836938143760354.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7437362606231693.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.47202181697547546.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7109809893399839.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6626158639468578.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.42425471378261254.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.821424945990876.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.713539686535708.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3666656365839913.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9706834533008956.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.13783620599385596.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.058282226450378796.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9172856072557614.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28092095853048815.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11697414833568452.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.925750603716801.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12287250060595872.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.054165235928699436.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8693613867474022.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.043256055793366076.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.024848824002529503.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9432967090657356.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03530643344612744.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02176578194942317.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.735126085092279.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.011184788393091236.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.008521821137936715.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8998156547174907.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.05908387713476247.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03377637894209019.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9712422340855789.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.513899074737464.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8795418736775693.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9967142154611416.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.7183313088130197.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.460674751711213.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9963663361299612.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.354574526612727.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7954880967901448.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9984130222098637.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7947462209654592.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.3513434233779569.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9995687918963838.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8908290743552092.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6713761410512012.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9987989715011479.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.7808634330486258.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.5830700584186812.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9860235092014749.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.0467363263077385.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.7568786692636863.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9893657445397696.
# Best Hyperparameter combination with lowest mean rmse for all stations are min_samples_leaf    6
# Name: 0, dtype: int64 with mean rmse 1.2628105928466382 with nse gap between train and validation of: 0.09335024337643183.
# Best Hyperparameter combination with lowest mean mae for all stations are min_samples_leaf    10
# Name: 2, dtype: int64 with mean mae 0.7581079004559194 with nse gap between train and validation of: 0.08752400590488052.
# Best Hyperparameter combination with lowest mean nse for all stations are min_samples_leaf    10
# Name: 2, dtype: int64 with mean nse 0.8979561028798274 with nse gap between train and validation of: 0.08752400590488052.
# (min_samples_leaf    6
#  Name: 0, dtype: int64,
#  min_samples_leaf    10
#  Name: 2, dtype: int64,
#  min_samples_leaf    10
#  Name: 2, dtype: int64)

# %% [markdown]
# ### Cross Validation mit optimierten Hyperparametern
# In den folgenden zwei Blöcken wird eine zeitbasierte Cross-Validation mit der ermittelten Hyperparameter-Kombination für alle 25 Zeitreihen durchgeführt. Ziel ist es, die Validierungsleistung pro Station und über alle Stationen im Mittel zu quantifizieren. Zusätzlich soll ermöglicht werden, eine mögliche Überanpassung über die Differenz zwischen Trainings- und Validierungs-NSE zu beurteilen.
# Im ersten Block wird der Niederschlag als exogene Variable verwendet, im zweiten Block werden alle Niderschlagsdaten entfernt. Durch den Vergleich der Metriken soll die Bedeutung der Niederschlagsdaten für die Vorhersageleistung bewertet werden.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Cross Validation with exogene features
def cross_validation():
    train_test = train_and_test_nan()
    
    pred = []
    scores = []

    # Cross Validation for every of the 25 stations in Baden-Württemberg with the best hyper parameter from the hyper parameter tuning.
    for t in train_test:
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()

        # defining forecast horizon to forecast six hours in the future (Q(t)--> Q(t+6)).
        train_water["y"] = train_water["Abfluss in m^3/s"].shift(-6)

        # the last six rows of y are NaN due to the shift by six hour. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train_water = train_water.dropna(subset=["y"])

        # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast.
        # We keep "Abfluss in m^3/s" as current value and the last known runoff which is important for the prediction.
        x = train_water.drop(columns=["y"])
        y = train_water["y"]
        
        station = t["Stationsname"]

        # define Time Series Spliit for the Cross validation. I evaluate the model on 720 hour validation windows using six hour ahead forecasts. 
        # To avoid leakage between train and validation I use a gap of six hour.
        tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=6)
        fold = 0

        # split the train set into seven folds for the cross validation and use RandomForestRegressor with the respective hyperparameter combination.
        for train_idx, validation_idx in tss.split(x):
            fold += 1
            x_train = x.iloc[train_idx]
            x_validation = x.iloc[validation_idx]
            y_train = y.iloc[train_idx]
            y_validation = y.iloc[validation_idx]

            # Define Random Forest model with the best hyperparameter combination identified in the hyperparameter tuning
            model = RandomForestRegressor(
                 n_estimators=300, 
                max_features=1.0,
                max_depth=20, 
                min_samples_split=5,
                min_samples_leaf=10,
                max_samples=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # Predict the respective validation set per fold
            y_pred_validation = model.predict(x_validation)
            pred.append({
                "Stationsname": station,
                "Fold": fold, 
                "Vorhersage": y_pred_validation
            })

            # Predict the respective validation set per fold to ceck for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting.
            y_pred_train = model.predict(x_train)

            # Calculate the evaluation metrics "RMSE", "MAE" and "NSE" for the prediction of the validation set per fold.
            rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
            mae_validation = mean_absolute_error(y_validation, y_pred_validation)
            nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

            # Calculate "NSE" and "NSE gap" per fold to identify potential model overfitting.
            nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)
            nse_gap = nse_train - nse_validation

            # store evaluation metrics for this station and fold in score
            scores.append({
                "Stationsname": station,
                "Fold": fold,
                "rmse validation": rmse_validation,
                "mae validation": mae_validation,
                "nse validation": nse_validation,
                "nse train": nse_train,
                "nse gap": nse_gap
            })
            print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
            print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
            print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station. This enables to compare the scores with the other cv, to identify the importance of the exogene features.
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby("Stationsname")[["rmse validation", "mae validation", "nse validation", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "nse train": "mean_nse_train"})

    overall_mean_nse = mean_per_station["mean_nse_validation"].mean()
    overall_mean_nse_train = mean_per_station["mean_nse_train"].mean()
    overall_nse_gap = overall_mean_nse_train - overall_mean_nse
    
    return scores_df, mean_per_station, overall_mean_nse, overall_mean_nse_train, overall_nse_gap

cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Gießen Argen with RMSE: 4.371778247484489.
# Calculated CV MAE for Gießen Argen with MAE: 1.6572973653137713.
# Calculated CV NSE for Gießen Argen with NSE: 0.8930694547448222.
# Calculated CV RMSE for Gießen Argen with RMSE: 10.012508641404466.
# Calculated CV MAE for Gießen Argen with MAE: 3.7088771395669036.
# Calculated CV NSE for Gießen Argen with NSE: 0.8627918788623428.
# Calculated CV RMSE for Gießen Argen with RMSE: 7.830376006464277.
# Calculated CV MAE for Gießen Argen with MAE: 2.7827714019470227.
# Calculated CV NSE for Gießen Argen with NSE: 0.9309875477550003.
# Calculated CV RMSE for Gießen Argen with RMSE: 2.3595635543057445.
# Calculated CV MAE for Gießen Argen with MAE: 0.7023974560025172.
# Calculated CV NSE for Gießen Argen with NSE: 0.8004750441821668.
# Calculated CV RMSE for Gießen Argen with RMSE: 0.4754736089826341.
# Calculated CV MAE for Gießen Argen with MAE: 0.2595556169395061.
# Calculated CV NSE for Gießen Argen with NSE: 0.797495307552045.
# Calculated CV RMSE for Gießen Argen with RMSE: 1.2253718270647185.
# Calculated CV MAE for Gießen Argen with MAE: 0.5502397466517336.
# Calculated CV NSE for Gießen Argen with NSE: 0.9536493647010313.
# Calculated CV RMSE for Gießen Argen with RMSE: 4.556349397607647.
# Calculated CV MAE for Gießen Argen with MAE: 2.1126671112593476.
# Calculated CV NSE for Gießen Argen with NSE: 0.9612019509891305.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.210086981999981.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.11952936428302938.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.6666221914826863.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 1.5322871970413463.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.4776008535044791.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9079852550505526.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.09643028863603872.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.07584820402155487.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9314953728046227.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.09602506249003583.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.0767927872515321.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9270847089473655.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.07654302821506806.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.061194878814637525.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.7838627289275835.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.06249631585277858.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.046416436214847125.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.651627129135722.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.13010009793715874.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.09508865563181226.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.980549321720447.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.6061572322509805.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.29281807015885736.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.22725617800033993.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.9177161156668695.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.3977006138099606.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.6391190061280994.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.503268682654971.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.2225546754894949.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.26224134508716634.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.17516029381131487.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.12239944386096775.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.3830395009037604.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.2850067445843473.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.15777183281047646.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.3653578244559459.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.23798246108189902.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.11489221915938279.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.4912173490833994.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.330917224027493.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.1923096756036984.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.8592212996377313.
# Calculated CV RMSE for Beuron Donau with RMSE: 2.4031309955197764.
# Calculated CV MAE for Beuron Donau with MAE: 1.1414098730575615.
# Calculated CV NSE for Beuron Donau with NSE: 0.9666632380986249.
# Calculated CV RMSE for Beuron Donau with RMSE: 1.685642395204757.
# Calculated CV MAE for Beuron Donau with MAE: 0.9827332285887999.
# Calculated CV NSE for Beuron Donau with NSE: 0.9785271391841835.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.5056584843744434.
# Calculated CV MAE for Beuron Donau with MAE: 0.33991345427203234.
# Calculated CV NSE for Beuron Donau with NSE: 0.9637873681901739.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.19326095653158876.
# Calculated CV MAE for Beuron Donau with MAE: 0.10247152365323957.
# Calculated CV NSE for Beuron Donau with NSE: 0.9061478393059138.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.0933565957666974.
# Calculated CV MAE for Beuron Donau with MAE: 0.05454562857422051.
# Calculated CV NSE for Beuron Donau with NSE: 0.914659810702673.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.0739311561690475.
# Calculated CV MAE for Beuron Donau with MAE: 0.047532970598912386.
# Calculated CV NSE for Beuron Donau with NSE: 0.9009301149120059.
# Calculated CV RMSE for Beuron Donau with RMSE: 1.6492941201148843.
# Calculated CV MAE for Beuron Donau with MAE: 0.6194908040542725.
# Calculated CV NSE for Beuron Donau with NSE: 0.969565331669751.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 3.318577932361865.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.7612546204281974.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9767606112499743.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 3.4968599987926052.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.8519974881490202.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9757657832554028.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.6950255647056783.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.49302468424698553.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9838465882155959.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.4564358508277327.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.33444531791784293.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9291900792548757.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.6293424145394536.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.4990236610654035.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.6652708544853547.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.653186704417176.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.5230958381740837.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.4334925437522945.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 2.2395997931696936.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.942352902580639.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9572086494515125.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 6.904879448424279.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.2916110587013419.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.10180790354513491.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 1.654661122406156.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.7207825182515728.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.5278509630838325.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.9189416456222135.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.5837546365118633.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.23280777952633191.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.3053312020371896.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.18800039086603537.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.5419544845239141.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.34682895331885694.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.17121715054722708.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.013073603715945348.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.23287283338746506.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.14253225846650455.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.5732257868823201.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.5001058741657827.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.26943010131557665.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.5766011289230617.
# Calculated CV RMSE for Eutingen Enz with RMSE: 7.33736917815202.
# Calculated CV MAE for Eutingen Enz with MAE: 2.835723778103184.
# Calculated CV NSE for Eutingen Enz with NSE: 0.461058648710968.
# Calculated CV RMSE for Eutingen Enz with RMSE: 3.7193163804873954.
# Calculated CV MAE for Eutingen Enz with MAE: 1.7585545331849914.
# Calculated CV NSE for Eutingen Enz with NSE: 0.9009246183931677.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.6894444047501271.
# Calculated CV MAE for Eutingen Enz with MAE: 1.035942193369683.
# Calculated CV NSE for Eutingen Enz with NSE: 0.6888537818806901.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.0414153220676206.
# Calculated CV MAE for Eutingen Enz with MAE: 0.4913944729627613.
# Calculated CV NSE for Eutingen Enz with NSE: 0.5786182666993347.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.341040086224324.
# Calculated CV MAE for Eutingen Enz with MAE: 0.5811207155826656.
# Calculated CV NSE for Eutingen Enz with NSE: 0.37232153023786896.
# Calculated CV RMSE for Eutingen Enz with RMSE: 0.6266547808500622.
# Calculated CV MAE for Eutingen Enz with MAE: 0.4893430497075028.
# Calculated CV NSE for Eutingen Enz with NSE: 0.5772090426039679.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.7609973106556054.
# Calculated CV MAE for Eutingen Enz with MAE: 0.822853945599314.
# Calculated CV NSE for Eutingen Enz with NSE: 0.9429046552947391.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.6552282129434572.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3719661767159004.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8723089232158978.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.790448237840515.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.568255007269877.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9541137319499405.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8771996515366173.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5774393907350615.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8320678636203884.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4224891003549115.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.32295573647419495.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4683693814376034.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7437362606231693.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.47202181697547546.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7109809893399837.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6626158639468577.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.42425471378261254.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8214249459908761.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.7135396865357087.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.3666656365839913.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9706834533008954.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 2.7730094812937263.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.4073558085487068.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.8063575354315358.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 3.4068668561893274.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.2458757139534455.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.8909977446848567.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.6707520367276008.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.3621255619173414.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.8215929645876754.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.4273515281188613.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.2186468083750945.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.5629827076878575.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.6356992303641382.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.27229918802692055.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.6919661341960947.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 1.0839048264277447.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.38773855450820033.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.7847452507546102.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 4.501258757491982.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.78376954097031.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.9283143188328948.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 1.3929636690270812.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.415691447604429.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.06739986054735958.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 2.135515426932439.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.537191308668308.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.5545683267153607.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.35785242544768053.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.18908422592449753.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.38871887752593914.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.1383320908143146.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.07455287427247005.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.08746862949158563.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.20030395234793943.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.08632116754824408.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.10843474472189829.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.12102995427290286.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.06178280352940687.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.5372991519529149.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.4749369295531193.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.22102682153264924.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.8230570049320625.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.13783620599385596.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05828222645037881.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9172856072557614.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28092095853048815.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11697414833568448.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.925750603716801.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12287250060595872.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05416523592869944.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8693613867474022.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.043256055793366076.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.024848824002529503.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9432967090657356.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03530643344612744.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.021765781949423173.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7351260850922788.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.011184788393091234.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.008521821137936716.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8998156547174907.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.05908387713476247.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0337763789420902.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9712422340855789.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.5032420038022187.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.1926382128548281.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.21593207790904012.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.2904553062069626.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.10874449821534692.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.592338420355711.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.08292371307542327.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.0381334225033806.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.3675204895510469.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.07121270613967041.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.028462481898265966.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.4479313453159601.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.11754626135970514.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.04541629412831681.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.4934162032037597.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.0519324606885629.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.027259935566644033.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.6748972057681719.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.11621470592656637.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.0465429461122792.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.7955994756292601.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 4.139551200742387.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.9592780335019007.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.863814323457821.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 4.085776408705256.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.7943563675042646.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.9754214928557146.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 1.0486728286208196.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 0.5476595327140523.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.8808355430743302.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 0.5635844372624781.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 0.27498313794673307.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.8706787381581325.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 0.9629015749120992.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 0.3076537514314285.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.8260660742911273.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 0.7544957755630074.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 0.3412636534771321.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.9128120023982134.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 4.026297897376697.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.6268517722952562.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.9445751019264795.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 7.088615689139453.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 3.3794333286066136.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.5431102992690088.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 3.936453519541763.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 2.0567664190400947.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.8153467852791954.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 3.2686329668180893.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.6104127996408881.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.022734967490082192.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.025084729896741.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.6441454516028252.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.6643931977276931.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.8150514859450841.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.6745775201412565.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -0.4594633140667541.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.1417032781272431.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.7877736065960689.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.7441689021750177.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 10.319218747499747.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 3.8280209248410553.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.8539275937750452.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.3516780320467185.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.5471150088285494.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.7951752222391822.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.8337498943398105.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.31047416443518955.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.8658263548565303.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.2727457762314239.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.1469844030395678.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.3822118193665214.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.10645560733450543.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.05069698640372554.
# Calculated CV NSE for Baiersbronn Murg with NSE: -0.7342004423499398.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.2600430317367449.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.11349359326138087.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.39876342419425737.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.41726156850348806.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.16100514228424118.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.8286746519584383.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 3.7359023090953087.
# Calculated CV MAE for Baiersbronn Murg with MAE: 1.348898249240362.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.8221552635000882.
# Calculated CV RMSE for Horb Neckar with RMSE: 4.9043584427911595.
# Calculated CV MAE for Horb Neckar with MAE: 2.3518199882664237.
# Calculated CV NSE for Horb Neckar with NSE: 0.8660720714676152.
# Calculated CV RMSE for Horb Neckar with RMSE: 4.091329221171484.
# Calculated CV MAE for Horb Neckar with MAE: 2.0310181248932526.
# Calculated CV NSE for Horb Neckar with NSE: 0.9031771665254702.
# Calculated CV RMSE for Horb Neckar with RMSE: 3.541472104204468.
# Calculated CV MAE for Horb Neckar with MAE: 1.2108924123977791.
# Calculated CV NSE for Horb Neckar with NSE: 0.4358224682973041.
# Calculated CV RMSE for Horb Neckar with RMSE: 1.5423333008443534.
# Calculated CV MAE for Horb Neckar with MAE: 0.6319691596925041.
# Calculated CV NSE for Horb Neckar with NSE: 0.7322288036545554.
# Calculated CV RMSE for Horb Neckar with RMSE: 0.4666522463241172.
# Calculated CV MAE for Horb Neckar with MAE: 0.30285091587303364.
# Calculated CV NSE for Horb Neckar with NSE: 0.8460771245534124.
# Calculated CV RMSE for Horb Neckar with RMSE: 0.7391017044393753.
# Calculated CV MAE for Horb Neckar with MAE: 0.35531100391810055.
# Calculated CV NSE for Horb Neckar with NSE: 0.6794584424565987.
# Calculated CV RMSE for Horb Neckar with RMSE: 2.8642212315947018.
# Calculated CV MAE for Horb Neckar with MAE: 1.2225691792282989.
# Calculated CV NSE for Horb Neckar with NSE: 0.9240150056184243.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.9147133378254555.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.3945439708005891.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8924262239193992.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 1.5813450872951342.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.709265590962399.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8319940046123153.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.3371242056096563.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.24436926380940777.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9905978025291172.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.37816162998620517.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.2410335050282692.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.5607098285854832.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.21053822780104778.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.12534295719052457.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.902396859407018.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.3424725408244335.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.19255065434987476.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.803406662106619.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.38626721198819797.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.24496804260976207.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9630420776622084.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.513899074737472.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8795418736775682.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9967142154611415.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.7183313088130205.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.4606747517112133.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9963663361299612.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.354574526612715.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7954880967901374.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9984130222098637.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.794746220965463.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.35134342337796.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9995687918963838.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8908290743552097.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6713761410511985.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9987989715011479.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.7808634330486277.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.583070058418682.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9860235092014749.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.0467363263077398.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.7568786692636921.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9893657445397696.
# Calculated CV RMSE for Binnrot Rot with RMSE: 2.803485648283508.
# Calculated CV MAE for Binnrot Rot with MAE: 0.6390138879881042.
# Calculated CV NSE for Binnrot Rot with NSE: 0.48365848971840264.
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.5074017746893071.
# Calculated CV MAE for Binnrot Rot with MAE: 0.3815599232719448.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7894555605010336.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.5574870184010424.
# Calculated CV MAE for Binnrot Rot with MAE: 0.20110674090448777.
# Calculated CV NSE for Binnrot Rot with NSE: 0.8308268720882167.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.10946844951770268.
# Calculated CV MAE for Binnrot Rot with MAE: 0.05143274325192233.
# Calculated CV NSE for Binnrot Rot with NSE: 0.5621086993316359.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.11661830856911203.
# Calculated CV MAE for Binnrot Rot with MAE: 0.06691147707487957.
# Calculated CV NSE for Binnrot Rot with NSE: 0.049526003216374126.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.0758015636853385.
# Calculated CV MAE for Binnrot Rot with MAE: 0.04336961039007503.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7770227866507389.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.39931211599545213.
# Calculated CV MAE for Binnrot Rot with MAE: 0.1699056359165161.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7829244056065675.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.976903323595647.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.0223384028329208.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.5862637307847827.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 5.312824780125423.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.763265689554926.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.9200576687057846.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.5549756665525585.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.35238317757867255.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.8614584771482814.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.25079579069060093.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.17647664261638804.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.6426685021591336.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.35693994507106264.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.22396237578327174.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.812223286658842.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.3754632424452049.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.18781776431196096.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.6892631824544656.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.7498250339166197.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.9530527128826153.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.9679346970242971.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.6535090258420442.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.5891730279431858.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.8272246683244469.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 4.61549026491771.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.4099669829944408.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.6908595967192406.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 3.1581394810119927.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.0506502782914109.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.8834376336809642.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.4076402027478632.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.3196898824124677.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.5695772035779533.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.3204448623266776.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.09540511035127355.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.12086146097631567.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.33597508445599766.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.15067138187686788.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.9168167198757442.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.5529616114142475.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.0276687919833516.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.9112643893838112.
# Calculated CV RMSE for Zell Wiese with RMSE: 1.5212649374711054.
# Calculated CV MAE for Zell Wiese with MAE: 0.7038975880899925.
# Calculated CV NSE for Zell Wiese with NSE: 0.5858772558047767.
# Calculated CV RMSE for Zell Wiese with RMSE: 2.6766778114509386.
# Calculated CV MAE for Zell Wiese with MAE: 0.9995771128009551.
# Calculated CV NSE for Zell Wiese with NSE: 0.9275894843964803.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.3332379322894594.
# Calculated CV MAE for Zell Wiese with MAE: 0.16653788621960963.
# Calculated CV NSE for Zell Wiese with NSE: 0.9244045096210836.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.36391345588420076.
# Calculated CV MAE for Zell Wiese with MAE: 0.1544561844983301.
# Calculated CV NSE for Zell Wiese with NSE: 0.30983301705873756.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.32013757334772186.
# Calculated CV MAE for Zell Wiese with MAE: 0.14133862942192496.
# Calculated CV NSE for Zell Wiese with NSE: 0.6335353480897756.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.582021871192293.
# Calculated CV MAE for Zell Wiese with MAE: 0.24901684626169135.
# Calculated CV NSE for Zell Wiese with NSE: 0.7319098214164816.
# Calculated CV RMSE for Zell Wiese with RMSE: 2.4276907811978212.
# Calculated CV MAE for Zell Wiese with MAE: 1.1001785729681839.
# Calculated CV NSE for Zell Wiese with NSE: 0.9647055249930384.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 2.610035023782726.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.9180078426299108.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.53008734238372.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 1.3535946613557894.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.5572115515724096.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.9156671582501397.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.17000386401450215.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.08931390992188164.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.9759518142593963.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.12278961464011008.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.07259610581733962.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.7972991579412897.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.09834892426948312.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.0436168664015897.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.8369363123414949.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.12921341974278916.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.06269998186341286.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.8297411270126348.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 1.1935267734558963.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.4951199372627668.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.9582896068082479.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 3.222452398812974.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 1.4399439224674218.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.5902649467356696.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 7.8709075082818565.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 2.237953046227637.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.48509279235322966.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.44931142528603674.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.25233850090630744.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.9566686792451717.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.2878308832948145.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.17453308415677782.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.6157598728827778.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.25232873112101184.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.16296735575774446.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.4380087349191327.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.21006224428883088.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.13943806441770354.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.7544664006912049.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 1.5190365727903832.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.6511097027846289.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.9511119262254549.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.2984851453030991.
# Calculated CV MAE for Hausen Zaber with MAE: 0.10524225739358882.
# Calculated CV NSE for Hausen Zaber with NSE: 0.36560097857257023.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.3522902079664881.
# Calculated CV MAE for Hausen Zaber with MAE: 0.11351371680754428.
# Calculated CV NSE for Hausen Zaber with NSE: 0.5101374412934756.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.23643858753738614.
# Calculated CV MAE for Hausen Zaber with MAE: 0.07405566957043921.
# Calculated CV NSE for Hausen Zaber with NSE: 0.3379360021194281.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.0637671660579745.
# Calculated CV MAE for Hausen Zaber with MAE: 0.03417327487751504.
# Calculated CV NSE for Hausen Zaber with NSE: 0.29340450597924683.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.1913235164090437.
# Calculated CV MAE for Hausen Zaber with MAE: 0.04868156656280464.
# Calculated CV NSE for Hausen Zaber with NSE: 0.4461789513721015.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.06132024146946519.
# Calculated CV MAE for Hausen Zaber with MAE: 0.02926042638247338.
# Calculated CV NSE for Hausen Zaber with NSE: 0.7102911213757569.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.14825363654032553.
# Calculated CV MAE for Hausen Zaber with MAE: 0.060140732931622524.
# Calculated CV NSE for Hausen Zaber with NSE: 0.49817509349724287.
# (     Stationsname  Fold  rmse validation  mae validation  nse validation  \
#  0    Gießen Argen     1         4.371778        1.657297        0.893069
#  1    Gießen Argen     2        10.012509        3.708877        0.862792
#  2    Gießen Argen     3         7.830376        2.782771        0.930988
#  3    Gießen Argen     4         2.359564        0.702397        0.800475
#  4    Gießen Argen     5         0.475474        0.259556        0.797495
#  ..            ...   ...              ...             ...             ...
#  170  Hausen Zaber     3         0.236439        0.074056        0.337936
#  171  Hausen Zaber     4         0.063767        0.034173        0.293405
#  172  Hausen Zaber     5         0.191324        0.048682        0.446179
#  173  Hausen Zaber     6         0.061320        0.029260        0.710291
#  174  Hausen Zaber     7         0.148254        0.060141        0.498175
#
#       nse train   nse gap
#  0     0.959290  0.066220
#  1     0.959191  0.096399
#  2     0.958721  0.027734
#  3     0.958863  0.158388
#  4     0.958912  0.161417
#  ..         ...       ...
#  170   0.854697  0.516761
#  171   0.854722  0.561317
#  172   0.855154  0.408975
#  173   0.855192  0.144901
#  174   0.855408  0.357233
#
#  [175 rows x 7 columns],
#                       Stationsname  mean_rmse_validation  mean_mae_validation  \
#  0              Bad Rotenfels Murg              4.084966             1.854447
#  1                Baiersbronn Murg              0.996834             0.382667
#  2                    Beuron Donau              0.943468             0.469728
#  3                     Binnrot Rot              0.795654             0.221900
#  4                 Blaubeuren Blau              0.314853             0.136067
#  5                   Bolheim Brenz              0.436601             0.214350
#  6               Elpershofen Jagst              1.837894             0.871937
#  7                    Eutingen Enz              2.502320             1.144990
#  8               Ewattingen Wutach              0.811073             0.319795
#  9                    Gießen Argen              4.404489             1.681972
#  10                 Hausach Kinzig              1.928406             0.811116
#  11                   Hausen Zaber              0.193126             0.066438
#  12                    Horb Neckar              2.592781             1.158062
#  13             Hundersingen Donau              1.641290             0.915028
#  14              Hüttlingen Kocher              0.688705             0.226522
#  15                 Konstanz Rhein              1.871426             1.356910
#  16           Mägerkingen Lauchert              0.098637             0.045476
#  17         Oberlauchringen Wutach              1.973133             0.722612
#  18           Rengers Untere Argen              2.006309             0.663318
#  19           Riegel Leopoldskanal              2.225897             0.978864
#  20  Rielasingen Radolfzeller Aach              0.592946             0.307439
#  21      Tauberbischofsheim Tauber              1.511104             0.668471
#  22                 Wannweil Echaz              1.551946             0.481047
#  23              Wiesloch Leimbach              0.176218             0.069600
#  24                     Zell Wiese              1.174992             0.502143
#
#      mean_nse_validation  mean_nse_train
#  0              0.454888        0.930952
#  1              0.479801        0.870120
#  2              0.942897        0.995174
#  3              0.610789        0.929110
#  4              0.835604        0.995746
#  5              0.461065        0.961499
#  6              0.804278        0.979700
#  7              0.645984        0.974245
#  8              0.834853        0.973286
#  9              0.885667        0.959023
#  10             0.783851        0.968204
#  11             0.451675        0.855365
#  12             0.769550        0.972448
#  13             0.845934        0.997157
#  14             0.347450        0.861194
#  15             0.995036        0.999897
#  16             0.894554        0.976843
#  17             0.684482        0.971908
#  18             0.668331        0.933289
#  19             0.896315        0.982074
#  20             0.849225        0.990939
#  21             0.782839        0.985897
#  22             0.202981        0.788493
#  23             0.407513        0.787209
#  24             0.725408        0.976605  ,
#  np.float64(0.6904388048311884),
#  np.float64(0.9446550611844772),
#  np.float64(0.2542162563532888))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Cross Validation without exogene features
def cross_validation():
    train_test = train_and_test_nan()
    
    pred = []
    scores = []

    # Cross Validation for every of the 25 stations in Baden-Württemberg with the best hyper parameter from the hyper parameter tuning.
    for t in train_test:
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()

        # define all exogene precipitation data
        exogene_features = train_water.filter(regex=r"^Niederschlag").columns

        # defining forecast horizon to forecast six hours in the future (Q(t)--> Q(t+6)).
        train_water["y"] = train_water["Abfluss in m^3/s"].shift(-6)

        # the last six rows of y are NaN due to the shift by six hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train_water = train_water.dropna(subset=["y"])

        # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast.
        # We keep "Abfluss in m^3/s" as current value and the last known runoff which is important for the prediction.
        x = train_water.drop(columns=["y", *exogene_features])
        y = train_water["y"]
        
        station = t["Stationsname"]

        # define Time Series Spliit for the Cross validation. I evaluate the model on 720 hour validation windows using six hour ahead forecasts. 
        # To avoid leakage between train and validation I use a gap of six hours.
        tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=6)
        fold = 0

        # split the train set into seven folds for the cross validation and use RandomForestRegressor with the respective hyperparameter combination.
        for train_idx, validation_idx in tss.split(x):
            fold += 1
            x_train = x.iloc[train_idx]
            x_validation = x.iloc[validation_idx]
            y_train = y.iloc[train_idx]
            y_validation = y.iloc[validation_idx]

            # Define Random Forest model with the best hyperparameter combination identified in the hyperparameter tuning
            model = RandomForestRegressor(
                 n_estimators=300, 
                max_features=1.0,
                max_depth=20, 
                min_samples_split=5,
                min_samples_leaf=10,
                max_samples=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # Predict the respective validation set per fold
            y_pred_validation = model.predict(x_validation)
            pred.append({
                "Stationsname": station,
                "Fold": fold, 
                "Vorhersage": y_pred_validation
            })

            # Predict the respective validation set per fold to ceck for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting.
            y_pred_train = model.predict(x_train)

            # Calculate the evaluation metrics "RMSE", "MAE" and "NSE" for the prediction of the validation set per fold.
            rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
            mae_validation = mean_absolute_error(y_validation, y_pred_validation)
            nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

            # Calculate "NSE" and "NSE gap" per fold to identify potential model overfitting.
            nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)
            nse_gap = nse_train - nse_validation

            # store evaluation metrics for this station and fold in score
            scores.append({
                "Stationsname": station,
                "Fold": fold,
                "rmse validation": rmse_validation,
                "mae validation": mae_validation,
                "nse validation": nse_validation,
                "nse train": nse_train,
                "nse gap": nse_gap
            })
            print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
            print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
            print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")
            

    # calculate the mean evaluation metrics over the folds with the same station. This enables to compare the scores with the other cv, to identify the importance of the exogene features.
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby("Stationsname")[["rmse validation", "mae validation", "nse validation", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "nse train": "mean_nse_train"})

    overall_mean_nse = mean_per_station["mean_nse_validation"].mean()
    overall_mean_nse_train = mean_per_station["mean_nse_train"].mean()
    overall_nse_gap = overall_mean_nse_train - overall_mean_nse
    
    return scores_df, mean_per_station, overall_mean_nse, overall_mean_nse_train, overall_nse_gap

cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Gießen Argen with RMSE: 5.183557356724415.
# Calculated CV MAE for Gießen Argen with MAE: 1.9514896355124929.
# Calculated CV NSE for Gießen Argen with NSE: 0.8496714915191295.
# Calculated CV RMSE for Gießen Argen with RMSE: 11.60450696442203.
# Calculated CV MAE for Gießen Argen with MAE: 4.062253017117739.
# Calculated CV NSE for Gießen Argen with NSE: 0.8156906376803649.
# Calculated CV RMSE for Gießen Argen with RMSE: 8.308047297367427.
# Calculated CV MAE for Gießen Argen with MAE: 3.2651643465315208.
# Calculated CV NSE for Gießen Argen with NSE: 0.9223108899781884.
# Calculated CV RMSE for Gießen Argen with RMSE: 2.684201493599654.
# Calculated CV MAE for Gießen Argen with MAE: 0.8572466536758965.
# Calculated CV NSE for Gießen Argen with NSE: 0.7417953306378569.
# Calculated CV RMSE for Gießen Argen with RMSE: 0.811181350596604.
# Calculated CV MAE for Gießen Argen with MAE: 0.3698162608177355.
# Calculated CV NSE for Gießen Argen with NSE: 0.41058908642229164.
# Calculated CV RMSE for Gießen Argen with RMSE: 1.70936194317443.
# Calculated CV MAE for Gießen Argen with MAE: 0.7250516494773028.
# Calculated CV NSE for Gießen Argen with NSE: 0.9098038562016099.
# Calculated CV RMSE for Gießen Argen with RMSE: 5.717125697951776.
# Calculated CV MAE for Gießen Argen with MAE: 2.3828362059165777.
# Calculated CV NSE for Gießen Argen with NSE: 0.9389154570140713.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.22377607744481642.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.12463430180049287.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.621761513912424.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 1.536907048724276.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.4811048438882494.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9074295690070311.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.09867095110513899.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.07673767111945169.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9282748272790503.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.09824570148086707.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.0781020525392894.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9236732918175135.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.08227695707997784.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.06466937887081367.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.7502676368090573.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.06324248374282761.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.04724214229772188.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.6432587497611783.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.13384524410448326.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.09804110739759528.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9794133637110826.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.6203682911037375.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.3102174893753047.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.19059824380869606.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.934816422686085.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.40832517331445517.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.6255447185340735.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.5003988103717457.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.23434921591546135.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.27063144107285.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.17408565245666874.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.13254050252658442.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.39058661563741415.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.3051961899680573.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.16774386211178344.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.2722589547730805.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.26189764864936793.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.1291102230516167.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.3838228494758642.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.3468384704393004.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.20263449648215726.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.8453490004841872.
# Calculated CV RMSE for Beuron Donau with RMSE: 2.597824793651195.
# Calculated CV MAE for Beuron Donau with MAE: 1.1930170722086035.
# Calculated CV NSE for Beuron Donau with NSE: 0.9610427548735764.
# Calculated CV RMSE for Beuron Donau with RMSE: 1.9551669567848111.
# Calculated CV MAE for Beuron Donau with MAE: 1.1071666999724035.
# Calculated CV NSE for Beuron Donau with NSE: 0.9711113853625871.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.6661478079014861.
# Calculated CV MAE for Beuron Donau with MAE: 0.396804082880604.
# Calculated CV NSE for Beuron Donau with NSE: 0.9371526893786365.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.20864063303644806.
# Calculated CV MAE for Beuron Donau with MAE: 0.13305503643841732.
# Calculated CV NSE for Beuron Donau with NSE: 0.8906159977833876.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.09647914451729198.
# Calculated CV MAE for Beuron Donau with MAE: 0.06228572287671141.
# Calculated CV NSE for Beuron Donau with NSE: 0.90885549807757.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.09851819958641785.
# Calculated CV MAE for Beuron Donau with MAE: 0.062279419359188716.
# Calculated CV NSE for Beuron Donau with NSE: 0.8240782257482744.
# Calculated CV RMSE for Beuron Donau with RMSE: 1.647361760252218.
# Calculated CV MAE for Beuron Donau with MAE: 0.6435136741296488.
# Calculated CV NSE for Beuron Donau with NSE: 0.9696366061363678.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 3.3262050559951994.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.8498527766859063.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9766536658159843.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 3.7176438171122936.
# Calculated CV MAE for Hundersingen Donau with MAE: 2.042132105976858.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9726089895283272.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.7906407763184962.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.5465790673606459.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9790963982221825.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.4914204224486135.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.3558139871641695.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9179193073726725.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.7185693913912581.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.5595315421280279.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.5636279233221636.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.6920762043335289.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.5661584857702694.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.36402683282217174.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 2.295888130572701.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.9773433126005061.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9550306508723827.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 6.9197689056959035.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.345982181101025.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.0979300626264028.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 1.7495652063874796.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.7975864667191133.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.4721369668749752.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 1.0208497076915808.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.6833276809828718.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.053213754145331804.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.35102746469267804.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.2559947122796748.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.3945915820759458.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.3565741919570784.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.1919028229686605.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.043167114556571295.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.23545151288860763.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.15973294279695233.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.608260414456324.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.5415254858222983.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.2868259654492512.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.5035636366281796.
# Calculated CV RMSE for Eutingen Enz with RMSE: 8.299359739722377.
# Calculated CV MAE for Eutingen Enz with MAE: 3.2187609121156475.
# Calculated CV NSE for Eutingen Enz with NSE: 0.31047511547180884.
# Calculated CV RMSE for Eutingen Enz with RMSE: 4.585604943821806.
# Calculated CV MAE for Eutingen Enz with MAE: 1.9834306958765209.
# Calculated CV NSE for Eutingen Enz with NSE: 0.8493972916579718.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.882844116135194.
# Calculated CV MAE for Eutingen Enz with MAE: 1.1877498987244908.
# Calculated CV NSE for Eutingen Enz with NSE: 0.6135392004760213.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.2798382134788158.
# Calculated CV MAE for Eutingen Enz with MAE: 0.613291103730339.
# Calculated CV NSE for Eutingen Enz with NSE: 0.36358863660452934.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.2044604598222108.
# Calculated CV MAE for Eutingen Enz with MAE: 0.5862848907639971.
# Calculated CV NSE for Eutingen Enz with NSE: 0.49366399914204984.
# Calculated CV RMSE for Eutingen Enz with RMSE: 0.5551078099973181.
# Calculated CV MAE for Eutingen Enz with MAE: 0.40795249904684117.
# Calculated CV NSE for Eutingen Enz with NSE: 0.6682402839311947.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.7755071519987504.
# Calculated CV MAE for Eutingen Enz with MAE: 0.9517333152260553.
# Calculated CV NSE for Eutingen Enz with NSE: 0.9419598981434092.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.034110762383561.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.6049537869499124.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8332677145458779.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.05493200011234.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9979532520130796.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.926692404570445.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.9816132145891691.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6289647192477006.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7897104437498546.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.5340752757975423.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.39385036296699744.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.15045983981813016.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.9991159190676743.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.525008825588303.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4784208098331688.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6957897379473041.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4347321687333189.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8030966206088255.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.781025557126878.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.7852063071834932.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9430806827151458.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 3.184417121050739.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.661186439011922.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.7446371051528948.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 4.133859587509334.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.668359819368604.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.8395142029239115.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.9013500098792528.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.5062189289492043.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.6778375553691383.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.558499181483263.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.31391426678877954.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.25359733507534155.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.696358080060616.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.3260761964233071.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.6303758546011733.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.9150604930805438.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.39324904514526043.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.8465842127647314.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 5.317618386128192.
# Calculated CV MAE for Hausach Kinzig with MAE: 2.1662762516649954.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.8999542158750679.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 1.3998771106701877.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.43682664041189695.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.07802141405872542.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 2.2262501178986436.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.572558381546494.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.5159128217573709.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.3801950408907873.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.23626788189193823.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.31000499067042564.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.13156484748544142.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.08793742494735216.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.1745673292397799.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.22327660025713592.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.09584705238504022.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.10779785358743665.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.1297150722475701.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.06346751539525243.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.46850958003961285.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.48433595202363233.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.2465173262807883.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.8159842868276022.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1435889997730094.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05907005438659898.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9102371144110655.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.29448627427785107.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12383063543349344.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9184066510838048.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.13601072059221966.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.060065558849888095.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8399305505725121.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.05050637183064888.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.030927981454688065.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9226951440812239.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.038698542209539326.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.023324816025272192.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.681784958700872.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.014206151624909246.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.011263859549628929.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.838379215063117.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06859471805027528.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03947401652467542.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9612386832233402.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.5246880822262874.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.2245541701262255.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.14768070566706015.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.3368256683239204.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.13369780714492208.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.4517842434295183.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.09649423953717466.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.06316671654169284.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.851736287206168.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.08599377043212875.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.03650571254759011.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.1949699486988553.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.1265334094304574.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.050032994076731126.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.41299192731571654.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.05240996286116715.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.02497285055358984.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.6688912909000324.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.14302864754153655.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.059019094005541846.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.6903964765897983.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 5.515487124231387.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 2.5731413362245665.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.7582354248915947.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 7.183228664327044.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 2.986102787269283.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.9240293764044022.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 1.3117421673167196.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 0.7397000477512624.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.8135494510344312.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 0.8378668225262138.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 0.3769288546932406.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.7141738648449794.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 1.5143075805092194.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 0.3921175294300205.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.569821502974673.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 0.828219061000497.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 0.43608115562531774.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.8949409374497571.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 4.845098124508528.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 2.101085981983775.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.9197401676086097.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 7.972680875765473.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 3.9311075119917094.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.4220406863120033.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 3.651248378719225.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.980509170384388.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.8411345813370668.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 2.896176934427194.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.5719699997986103.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.23276178330856445.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.2012856719599607.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.7628986284785074.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.5391030641466841.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.625414808321945.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.6652240870532649.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -0.17042532257150045.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.3137893983808382.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.8689175918308831.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.6612351480231524.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 12.486565556346447.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 4.751784249992171.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.7861247406846595.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.5018195810731434.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.6194530066079191.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.7471450231252643.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.0608279172913877.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.4386717941412001.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.7827871492318349.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.2905302788578681.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.16686223859862875.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.2990188661529304.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.08776939492096136.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.06099612771360663.
# Calculated CV NSE for Baiersbronn Murg with NSE: -0.1788225023987804.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.26739836579787823.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.11933995601733152.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.3642703766558454.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.4631610977132723.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.18225962350892067.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.7889093489535648.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 3.9540297069422916.
# Calculated CV MAE for Baiersbronn Murg with MAE: 1.4768580986691806.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.8007814156927351.
# Calculated CV RMSE for Horb Neckar with RMSE: 5.476045864880292.
# Calculated CV MAE for Horb Neckar with MAE: 2.6146154165830846.
# Calculated CV NSE for Horb Neckar with NSE: 0.8330290577572109.
# Calculated CV RMSE for Horb Neckar with RMSE: 5.394957959630145.
# Calculated CV MAE for Horb Neckar with MAE: 2.633172980796854.
# Calculated CV NSE for Horb Neckar with NSE: 0.8316453710070537.
# Calculated CV RMSE for Horb Neckar with RMSE: 4.1257221858554365.
# Calculated CV MAE for Horb Neckar with MAE: 1.4221701679995047.
# Calculated CV NSE for Horb Neckar with NSE: 0.23431860068341015.
# Calculated CV RMSE for Horb Neckar with RMSE: 1.7122647036041705.
# Calculated CV MAE for Horb Neckar with MAE: 0.7851507767843009.
# Calculated CV NSE for Horb Neckar with NSE: 0.6699732092628572.
# Calculated CV RMSE for Horb Neckar with RMSE: 0.5509057933040792.
# Calculated CV MAE for Horb Neckar with MAE: 0.34501132713456.
# Calculated CV NSE for Horb Neckar with NSE: 0.7854783517062561.
# Calculated CV RMSE for Horb Neckar with RMSE: 0.7508491078782069.
# Calculated CV MAE for Horb Neckar with MAE: 0.2766933817161585.
# Calculated CV NSE for Horb Neckar with NSE: 0.6691879858861502.
# Calculated CV RMSE for Horb Neckar with RMSE: 3.4527899321972515.
# Calculated CV MAE for Horb Neckar with MAE: 1.4483493343580482.
# Calculated CV NSE for Horb Neckar with NSE: 0.889578147302315.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.9376730636845354.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.412012052497766.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8869581462783818.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 1.695626129384581.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.7815378242019451.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8068335611584223.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.36638085063957226.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.26570121936643426.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9888950903530302.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.39831327148046.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.2590217441431127.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.5126442234150193.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.2149855055548553.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.12738460439494184.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8982298938755213.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.3547111113190179.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.2002570333869285.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.7891047148010137.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.37209879005424906.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.23107158877738862.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9657036127462507.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.611748360046635.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.957749309977113.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9964534501646622.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.758046093077209.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.5042192013858653.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9962883006676468.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.3642369732825426.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.79900501697258.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9983999705512554.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.8983690806851305.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.391704441014081.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9995175613179871.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.9058975105362524.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6842152062394845.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9987579969010193.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8073434693602384.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.5982267283929216.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9850595167641267.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.0839036946269343.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.7989473190605292.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9885971374467453.
# Calculated CV RMSE for Binnrot Rot with RMSE: 2.9737395600209178.
# Calculated CV MAE for Binnrot Rot with MAE: 0.6787484617079981.
# Calculated CV NSE for Binnrot Rot with NSE: 0.4190400060122168.
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.731913046026391.
# Calculated CV MAE for Binnrot Rot with MAE: 0.4497988843616582.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7220684183090491.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.6330203524876589.
# Calculated CV MAE for Binnrot Rot with MAE: 0.25777351734701315.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7818791365139585.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.1485766180743357.
# Calculated CV MAE for Binnrot Rot with MAE: 0.062440793724444096.
# Calculated CV NSE for Binnrot Rot with NSE: 0.19334223099742742.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.16131756461902164.
# Calculated CV MAE for Binnrot Rot with MAE: 0.08287074306215679.
# Calculated CV NSE for Binnrot Rot with NSE: -0.8187377344344084.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.09325045638348771.
# Calculated CV MAE for Binnrot Rot with MAE: 0.05330983333365288.
# Calculated CV NSE for Binnrot Rot with NSE: 0.662552600005225.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.3663421130033644.
# Calculated CV MAE for Binnrot Rot with MAE: 0.18079928378611024.
# Calculated CV NSE for Binnrot Rot with NSE: 0.8172910948135698.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 2.0818343378835773.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.0826977293799387.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.5411771207231838.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 5.599323429986642.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.9128376511582235.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.9112032784605125.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.6417986738598728.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.3977554338415465.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.8147195038927523.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.28345531486889664.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.1988814877401148.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.5435428411679699.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.41037188415366094.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.2525996368002088.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.7517972294911104.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.41207697988309033.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.21575738073972953.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.6257045319446661.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.9316803899613768.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.0318905147677124.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.9609234117499672.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.503285845594039.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.799261916239916.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.6040052000153506.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 5.230753105909993.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.6027743285082958.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.6029469524399347.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 3.7233497012142585.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.2807279560146339.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.8379819515689139.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.5617802869161856.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.4519382315525485.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.47015137164906173.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.3111649785372428.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.09954141430332118.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.0568825657374854.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.5515472030759295.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.22143053944047775.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.775824952052274.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.862311697396079.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.0395291553767454.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.888456768007645.
# Calculated CV RMSE for Zell Wiese with RMSE: 1.5776634525357998.
# Calculated CV MAE for Zell Wiese with MAE: 0.7989026292699628.
# Calculated CV NSE for Zell Wiese with NSE: 0.5546021648020554.
# Calculated CV RMSE for Zell Wiese with RMSE: 3.1103322574542314.
# Calculated CV MAE for Zell Wiese with MAE: 1.2110020811245392.
# Calculated CV NSE for Zell Wiese with NSE: 0.9022260836558897.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.47427447698677255.
# Calculated CV MAE for Zell Wiese with MAE: 0.2519028205492032.
# Calculated CV NSE for Zell Wiese with NSE: 0.8468748475568613.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.5108791619774644.
# Calculated CV MAE for Zell Wiese with MAE: 0.26232466170503677.
# Calculated CV NSE for Zell Wiese with NSE: -0.3601735599368281.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.5057737091479346.
# Calculated CV MAE for Zell Wiese with MAE: 0.20575668046927997.
# Calculated CV NSE for Zell Wiese with NSE: 0.08531555495853127.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.6338762323918685.
# Calculated CV MAE for Zell Wiese with MAE: 0.28557188090254165.
# Calculated CV NSE for Zell Wiese with NSE: 0.6820116346881209.
# Calculated CV RMSE for Zell Wiese with RMSE: 2.421661819894998.
# Calculated CV MAE for Zell Wiese with MAE: 1.1683378821141792.
# Calculated CV NSE for Zell Wiese with NSE: 0.9648806089073857.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 2.9753746955722633.
# Calculated CV MAE for Ewattingen Wutach with MAE: 1.1113255787229135.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.38932828695273913.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 2.0032528004980352.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.850507946728935.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.8152897541422386.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.2723184291376905.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.1398862740031466.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.9382952213296795.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.19549902233689206.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.10478248919125066.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.4861676303314154.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.14039729736407228.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.06225517740268667.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.667696032082449.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.13552023655420548.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.07166983726896109.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.8127150776761515.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 1.7489352665625584.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.6833095480569282.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.9104372493886502.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 3.383665054944571.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 1.5555317878052601.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.548243062429147.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 7.8671613138769585.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 2.209975518588406.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.48558282058791524.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.46777892072025945.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.2535729790121997.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.9530334891661227.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.3521665976619155.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.2053125634661592.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.4247928715540801.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.2750679481769925.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.17027807754151902.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.3321543004861349.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.21722870616909143.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.13889221369046395.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.7374274275578705.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 1.9791433704296482.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.8120116464570291.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.9170109147605974.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.34756432111765495.
# Calculated CV MAE for Hausen Zaber with MAE: 0.12318114433413895.
# Calculated CV NSE for Hausen Zaber with NSE: 0.13982377348518749.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.4257559851201118.
# Calculated CV MAE for Hausen Zaber with MAE: 0.14514041104684836.
# Calculated CV NSE for Hausen Zaber with NSE: 0.2845247314558105.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.2500112771116663.
# Calculated CV MAE for Hausen Zaber with MAE: 0.09742668927972768.
# Calculated CV NSE for Hausen Zaber with NSE: 0.2597431124809927.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.08987300968151335.
# Calculated CV MAE for Hausen Zaber with MAE: 0.057299644071229394.
# Calculated CV NSE for Hausen Zaber with NSE: -0.40357363559699455.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.22093695790044732.
# Calculated CV MAE for Hausen Zaber with MAE: 0.06643489108109815.
# Calculated CV NSE for Hausen Zaber with NSE: 0.2614677092307094.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.07182266051990832.
# Calculated CV MAE for Hausen Zaber with MAE: 0.04363857658201343.
# Calculated CV NSE for Hausen Zaber with NSE: 0.6025549708743361.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.15454956680158402.
# Calculated CV MAE for Hausen Zaber with MAE: 0.09163442708152147.
# Calculated CV NSE for Hausen Zaber with NSE: 0.4546477787063973.
# (     Stationsname  Fold  rmse validation  mae validation  nse validation  \
#  0    Gießen Argen     1         5.183557        1.951490        0.849671
#  1    Gießen Argen     2        11.604507        4.062253        0.815691
#  2    Gießen Argen     3         8.308047        3.265164        0.922311
#  3    Gießen Argen     4         2.684201        0.857247        0.741795
#  4    Gießen Argen     5         0.811181        0.369816        0.410589
#  ..            ...   ...              ...             ...             ...
#  170  Hausen Zaber     3         0.250011        0.097427        0.259743
#  171  Hausen Zaber     4         0.089873        0.057300       -0.403574
#  172  Hausen Zaber     5         0.220937        0.066435        0.261468
#  173  Hausen Zaber     6         0.071823        0.043639        0.602555
#  174  Hausen Zaber     7         0.154550        0.091634        0.454648
#
#       nse train   nse gap
#  0     0.944893  0.095222
#  1     0.944811  0.129120
#  2     0.944067  0.021756
#  3     0.944116  0.202321
#  4     0.944116  0.533527
#  ..         ...       ...
#  170   0.825487  0.565744
#  171   0.825287  1.228861
#  172   0.825710  0.564243
#  173   0.825576  0.223021
#  174   0.825783  0.371135
#
#  [175 rows x 7 columns],
#                       Stationsname  mean_rmse_validation  mean_mae_validation  \
#  0              Bad Rotenfels Murg              4.449595             2.076059
#  1                Baiersbronn Murg              1.089362             0.437777
#  2                    Beuron Donau              1.038591             0.514017
#  3                     Binnrot Rot              0.872594             0.252249
#  4                 Blaubeuren Blau              0.319566             0.138647
#  5                   Bolheim Brenz              0.449086             0.226417
#  6               Elpershofen Jagst              2.297237             1.052953
#  7                    Eutingen Enz              2.797532             1.278458
#  8               Ewattingen Wutach              1.067328             0.431962
#  9                    Gießen Argen              5.145426             1.944837
#  10                 Hausach Kinzig              2.243880             1.005040
#  11                   Hausen Zaber              0.222931             0.089251
#  12                    Horb Neckar              3.066219             1.360738
#  13             Hundersingen Donau              1.718921             0.985344
#  14              Hüttlingen Kocher              0.710745             0.248489
#  15                 Konstanz Rhein              1.918506             1.390581
#  16           Mägerkingen Lauchert              0.106585             0.049708
#  17         Oberlauchringen Wutach              2.077459             0.763654
#  18           Rengers Untere Argen              2.392028             0.785029
#  19           Riegel Leopoldskanal              3.147993             1.372165
#  20  Rielasingen Radolfzeller Aach              0.619970             0.325284
#  21      Tauberbischofsheim Tauber              1.622934             0.727489
#  22                 Wannweil Echaz              1.596395             0.531622
#  23              Wiesloch Leimbach              0.195139             0.084564
#  24                     Zell Wiese              1.319209             0.597686
#
#      mean_nse_validation  mean_nse_train
#  0              0.473139        0.895084
#  1              0.514870        0.840186
#  2              0.923213        0.994755
#  3              0.396777        0.909908
#  4              0.822011        0.995350
#  5              0.425542        0.957937
#  6              0.703533        0.973939
#  7              0.605838        0.967506
#  8              0.717133        0.958103
#  9              0.798397        0.944374
#  10             0.698929        0.957050
#  11             0.228455        0.826174
#  12             0.701887        0.963298
#  13             0.818423        0.996868
#  14             0.299880        0.853337
#  15             0.994725        0.999895
#  16             0.867525        0.974162
#  17             0.628321        0.962400
#  18             0.588926        0.902296
#  19             0.799213        0.972187
#  20             0.835481        0.990682
#  21             0.735581        0.984701
#  22             0.124287        0.778031
#  23             0.244997        0.745965
#  24             0.525105        0.970538  ,
#  np.float64(0.6188875080451809),
#  np.float64(0.9325891693580948),
#  np.float64(0.3137016613129139))

# %% [markdown]
# ### Final model fitting und Evaluation
# In diesem Abschnitt wird schließlich das finale Modell mit der gewählten Hyperparameter-Kombination für jede Station separat trainiert und auf dem Testzeitraum evaluiert. Die Zielvariable wird als 6-Stunden-Vorhersage definiert (Lead Time 6h), das heißt es wird Q(t+6) auf Basis der Merkmale zu Zeitpunkt t vorhergesagt (y = Abfluss.shift(-6)).
# Die Vorhersage erfolgt als Expanding-Window. Das Modell wird zunächst auf dem Trainingsset trainiert und sagt anschließend den Testdatensatz blockweise in Fenster von 720 Stunden voraus. Nach jeder Blockvorhersage werden die tatsächlichen Beobachtungen dieses Blocks an den Trainingssatz angehängt und das Modell wird für den nächsten Block erneut trainiert. Die vorhersagen werden zeitlich korrekt um plus 6 Stunden verschoben, sodass der Vorhersagezeitpunkt dem tatsächlichen Zielzeitpunkt am Abfluss Q(t+6) entspricht.
#
# Die Vorhersagegüte wird auf mehreren Ebenen ausgewertet:
# - Es wird der stündliche absoute Fehler berechnet
# - Pro Block (720 Stunden) werden RMSE, MAE und NSE berechnet
# - Die Vorhersagegüte der Wochen um die zehn höchsten Abflussspitzen pro Station werden berechnet (RMSE, MAE und NSE), wobei die Peaks mindestens 7 Tage auseinanderliegen.
# - Die Gesamtmetriken werden über den gesamten vorhergesagten Testzeitraum pro Station berechnet (RMSE, MAE und NSE)
#
# Alle Auswertungen und Ergebnisse werden als CSV-Dateien im Ordner "Evaluation" gespeichert.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error


def final_model_fitting():
    
    train_test = train_and_test_nan()

    results = []
    all_forecasts = {}
    all_hourly_eval_list = []
    all_evaluate_max_week_list = []
    overall_max_week_metrics = []
    all_monthly_eval_list = []
    week = 168
    month = 720
    horizon = 6
    
    
    for t in train_test:
        
        station = t["Stationsname"]
        
        
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()
        
        test_water = t["Testset"].copy()
        test_water = test_water.sort_index()

        train = train_water.copy()
        test = test_water.copy()
        train["y"] = train_water["Abfluss in m^3/s"].shift(-horizon)
        test["y"] = test_water["Abfluss in m^3/s"].shift(-horizon)
        
        
        # the last 6 rows of y are NaNs due to the shift by six hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train = train.dropna(subset=["y"])
        test = test.dropna(subset=["y"])

        # define current_train to enrich it later in the expanding window forecast.
        current_train = train.copy()

        
        
        forecast_blocks = []
        # expanding window forecast: predicting a window of one month and cancatenate the actual runoff of this month to the train data.
        for i in range(0, len(test), month):
            end = i + month
            # defining x and y for final evaluation
            x_train = current_train.drop(columns=["y"])
            y_train = current_train["y"]
        
            x_test = test.drop(columns=["y"])
            y_test = test["y"]

            # defining the test block (one month). if the block is empty, the time series is at the end
            x_test_block = x_test.iloc[i:end]
            if len(x_test_block) == 0:
                break

            # defining the model with the best hyperparamters due to hyperparameter tuning.
            model = RandomForestRegressor(
                n_estimators=300, 
                max_features=1.0,
                max_depth=20, 
                min_samples_split=5,
                min_samples_leaf=10,
                max_samples=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # predicting the respective month and store the forecast in forecast_blocks but shift the forecast six hours ahead because that is the actual date for the forecast due to the horizon (shift(-1)). 
            y_block_pred = model.predict(x_test_block)
            forecast_blocks.append(pd.Series(y_block_pred, index=test.index[i:i + len(x_test_block)] + pd.Timedelta(hours=horizon)))

            # enriching the train set by the actual values of the month which was forecasted in this loop.
            current_train = pd.concat([current_train, test.iloc[i:i + len(x_test_block)]])

            
        # concatenate the forecast on forecast_series with the corresponding station and store every forecast as a data frame in all_forecasts[station]   
        forecast_series = pd.concat(forecast_blocks).sort_index()
        all_forecasts[station] = pd.DataFrame({
            "Forecast": forecast_series
        })

        # defining the actual surface runoff to calculate the absolute error per hour.
        all_truth = test_water["Abfluss in m^3/s"].reindex(forecast_series.index) 

        # calculate the absolute error per hour.
        absolute_error_hourly = abs(all_truth - forecast_series)

        # store the information in the data frame evaluate_hourly_df.
        evaluate_hourly_df = pd.DataFrame({
            "Stationsname": station,
            "Datum / Uhrzeit": forecast_series.index,
            "Abfluss in m^3/s": all_truth.values,
            "Forecast": forecast_series.values,
            "Absolutfehler pro Stunde": absolute_error_hourly.values,
            
        })
        # append the respective data frame to a list.
        all_hourly_eval_list.append(evaluate_hourly_df)

        # calculate the 10 highest peaks which are minimum 7 days apart from each Peak
        true_runoff = evaluate_hourly_df["Abfluss in m^3/s"]
        forecast_runoff = evaluate_hourly_df["Forecast"]
        maximum_runoff = (true_runoff > true_runoff.shift(1)) & (true_runoff > true_runoff.shift(-1))
        local_maxima = true_runoff[maximum_runoff]
        local_maxima = local_maxima.sort_values(ascending=False)
        maximum_times = local_maxima.index

        # check if the sorted local maxima are more than a week apart.
        all_selected_maxima = []
        for maxima in maximum_times:
            if len(all_selected_maxima) >= 10:
                break
                
            distance_ok = True
            for selected in all_selected_maxima:
                if abs(maxima - selected) <= week:
                    distance_ok = False
                    break
            if distance_ok:
                all_selected_maxima.append(maxima)
                
        # define the week around the selected local maxima
        evaluate_maximum_weeks = []
        for selected_maxima in all_selected_maxima:
            start = selected_maxima - (week // 2)
            end = selected_maxima + (week // 2)
            
            start = max(start, true_runoff.index.min())
            end = min(end, true_runoff.index.max())

            # define the actual week around the local maxima and the forecast week to calculate the evaluation metrics of the forecast of this week.
            true_max_week = true_runoff.iloc[start:end]
            forecast_max_week = forecast_runoff.iloc[start:end]

            mae_max_week = mean_absolute_error(true_max_week, forecast_max_week)
            rmse_max_week = np.sqrt(mean_squared_error(true_max_week, forecast_max_week))

            squared_diff = (true_max_week - forecast_max_week)**2
            sum_squared_diff = np.sum(squared_diff)
            squared_diff2 = (true_max_week - true_max_week.mean())**2
            sum_squared_diff2 = np.sum(squared_diff2)

            if sum_squared_diff2 == 0:
                nse_max_week = np.nan
            else:
                nse_max_week = 1 - (sum_squared_diff / sum_squared_diff2)

            # store all maximum weeks of a time series and station in evaluate_maximum_weeks
            evaluate_maximum_weeks.append({
                "Stationsname": station,
                "Wochenstart": true_max_week.index[0],
                "Wochenende": true_max_week.index[-1],
                "Peak": selected_maxima,
                "MAE_MAX_WEEK": mae_max_week,
                "RMSE_MAX_WEEK": rmse_max_week,
                "NSE_MAX_WEEK": nse_max_week
            })
        evaluate_max_week_df = pd.DataFrame(evaluate_maximum_weeks)
        all_evaluate_max_week_list.append(evaluate_max_week_df)

        # calculate the evaluation metrics per station to identify how good the model is forecasting weeks with maximum peaks.
        all_mae_max_week = evaluate_max_week_df["MAE_MAX_WEEK"].mean()
        all_rmse_max_week = evaluate_max_week_df["RMSE_MAX_WEEK"].mean()
        all_nse_max_week = evaluate_max_week_df["NSE_MAX_WEEK"].mean()

        # store them in overall_max_week_metrics
        overall_max_week_metrics.append({
            "Stationsname": station,
            "All_MAE": all_mae_max_week,
            "All_RMSE": all_rmse_max_week,
            "All_NSE": all_nse_max_week
        })
                
        # Calculate the evaluation metrics per month block
        evaluate_monthly = []
        for i in range(0, len(forecast_series), month):
            end = i + month
            pred_block = forecast_series.iloc[i:end]
            truth_block = all_truth.iloc[i:end]

            if len(pred_block) == 0:
                break
          
            mae_block = mean_absolute_error(truth_block, pred_block)
            rmse_block = np.sqrt(mean_squared_error(truth_block, pred_block))

            squared_diff = (truth_block - pred_block)**2
            sum_squared_diff = np.sum(squared_diff)
            squared_diff2 = (truth_block - truth_block.mean())**2
            sum_squared_diff2 = np.sum(squared_diff2)

            if sum_squared_diff2 == 0:
                nse_block = np.nan
            else:
                nse_block = 1 - (sum_squared_diff / sum_squared_diff2)

            evaluate_monthly.append({
                "Stationsname": station,
                "Block Index": i // month,
                "Block Start": pred_block.index[0],
                "Block Ende": pred_block.index[-1],
                "MAE Block": mae_block,
                "RMSE Block": rmse_block,
                "NSE Block": nse_block
            })

        evaluate_monthly_df = pd.DataFrame(evaluate_monthly)
        all_monthly_eval_list.append(evaluate_monthly_df)

        
        # Calculate evaluation metrics for the whole test set per station    
        rmse = np.sqrt(mean_squared_error(test_water["Abfluss in m^3/s"].reindex(forecast_series.index), forecast_series))
        mae = mean_absolute_error(test_water["Abfluss in m^3/s"].reindex(forecast_series.index), forecast_series)
        nse = 1 - np.sum((test_water["Abfluss in m^3/s"].reindex(forecast_series.index) - forecast_series)**2) / np.sum((test_water["Abfluss in m^3/s"].reindex(forecast_series.index) - np.mean(test_water["Abfluss in m^3/s"].reindex(forecast_series.index)))**2)
        results.append({
            "Stationsname": station,
            "RMSE": rmse,
            "MAE": mae,
            "NSE": nse
        })

            
        print(f"{station}: Finished forecasting. Forecasting months {i // 720 + 1}")
        print(forecast_series.describe())

    # create a data frame for every evaluation metric an sort them.
    results_rmse_df = pd.DataFrame(results).sort_values(by="RMSE")
    results_mae_df = pd.DataFrame(results).sort_values(by="MAE")
    results_nse_df = pd.DataFrame(results).sort_values(by="NSE", ascending=False)

    # concatenate hourly and monthly evaluation metrics and for every station and the metrics for every maximum week individually and overall.  
    all_hourly_eval_df = pd.concat(all_hourly_eval_list, ignore_index=True)
    all_monthly_eval_df = pd.concat(all_monthly_eval_list, ignore_index=True)
    all_evaluate_max_week_df = pd.concat(all_evaluate_max_week_list, ignore_index=True)
    overall_max_week_metrics_df = pd.DataFrame(overall_max_week_metrics)

    

    # store the different evaluation metrics and times as csv file.
    results_rmse_df.to_csv("Evaluation/Random_Forest_Gesamtmetriken_RMSE_H6.csv", index=False)
    results_mae_df.to_csv("Evaluation/Random_Forest_Gesamtmetriken_MAE_H6.csv", index=False)
    results_nse_df.to_csv("Evaluation/Random_Forest_Gesamtmetriken_NSE_H6.csv", index=False)
    all_hourly_eval_df.to_csv("Evaluation/Random_Forest_Metriken_stündlich_H6.csv", index=False)
    all_monthly_eval_df.to_csv("Evaluation/Random_Forest_Metriken_monatlich_H6.csv", index=False)
    all_evaluate_max_week_df.to_csv("Evaluation/Random_Forest_Metriken_maximum_wochen_H6.csv", index=False)
    overall_max_week_metrics_df.to_csv("Evaluation/Random_Forest_Metriken_durchschnittlich_über_maximum_wochen_H6.csv", index=False)
    
    return results_rmse_df, results_mae_df, results_nse_df, all_forecasts, all_hourly_eval_df, all_monthly_eval_df

final_model_fitting()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Gießen Argen: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        19.948624
# std         21.140731
# min          3.103528
# 25%          8.089929
# 50%         13.829418
# 75%         24.810998
# max        313.149804
# dtype: float64
# Blaubeuren Blau: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         2.433491
# std          1.711371
# min          0.670830
# 25%          1.318765
# 50%          2.023582
# 75%          2.943141
# max         16.418994
# dtype: float64
# Bolheim Brenz: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         4.445871
# std          1.863250
# min          1.942072
# 25%          3.206240
# 50%          4.021319
# 75%          5.163191
# max         15.445550
# dtype: float64
# Beuron Donau: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        11.742314
# std         16.273322
# min          0.524909
# 25%          2.194137
# 50%          5.349908
# 75%         16.309327
# max        185.638972
# dtype: float64
# Hundersingen Donau: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        24.061090
# std         23.055230
# min          4.460569
# 25%          9.776966
# 50%         16.345398
# 75%         30.965568
# max        224.022282
# dtype: float64
# Wannweil Echaz: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         2.720763
# std          2.390452
# min          0.541848
# 25%          1.509580
# 50%          2.167976
# 75%          3.192967
# max         39.084943
# dtype: float64
# Eutingen Enz: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        16.128870
# std         11.855813
# min          3.966636
# 25%          8.095141
# 50%         12.888087
# 75%         20.545702
# max        145.895996
# dtype: float64
# Elpershofen Jagst: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         7.901019
# std         11.748058
# min          0.952701
# 25%          2.198241
# 50%          4.347220
# 75%          8.573318
# max        142.340794
# dtype: float64
# Hausach Kinzig: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        15.817390
# std         17.683339
# min          1.904043
# 25%          5.117862
# 50%         10.545197
# 75%         20.055516
# max        230.443290
# dtype: float64
# Hüttlingen Kocher: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         2.032671
# std          1.674811
# min          0.546316
# 25%          0.950917
# 50%          1.471993
# 75%          2.503410
# max         21.473865
# dtype: float64
# Mägerkingen Lauchert: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         0.673652
# std          0.684524
# min          0.060310
# 25%          0.244743
# 50%          0.503107
# 75%          0.883660
# max          8.223001
# dtype: float64
# Wiesloch Leimbach: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         0.614566
# std          0.325881
# min          0.225006
# 25%          0.427320
# 50%          0.550601
# 75%          0.714765
# max          6.363782
# dtype: float64
# Riegel Leopoldskanal: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        11.811711
# std         17.197911
# min          0.208636
# 25%          0.656481
# 50%          4.857466
# 75%         17.648475
# max        181.433522
# dtype: float64
# Bad Rotenfels Murg: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        16.072542
# std         16.113694
# min          1.978615
# 25%          5.795124
# 50%         11.748090
# 75%         20.150500
# max        255.930779
# dtype: float64
# Baiersbronn Murg: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         2.934900
# std          3.632806
# min          0.470586
# 25%          0.907657
# 50%          1.874095
# 75%          3.314196
# max         52.295269
# dtype: float64
# Horb Neckar: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        13.877863
# std         14.109628
# min          2.687865
# 25%          5.667860
# 50%          9.730570
# 75%         17.265237
# max        171.314801
# dtype: float64
# Rielasingen Radolfzeller Aach: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         9.275734
# std          4.347375
# min          2.356107
# 25%          6.191860
# 50%          9.126169
# 75%         11.759397
# max         26.524885
# dtype: float64
# Konstanz Rhein: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean       321.285916
# std        132.406465
# min        168.611566
# 25%        226.978605
# 50%        291.651594
# 75%        364.569708
# max        817.205225
# dtype: float64
# Binnrot Rot: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         1.906038
# std          1.482636
# min          0.785939
# 25%          1.143420
# 50%          1.500630
# 75%          2.040129
# max         19.647341
# dtype: float64
# Tauberbischofsheim Tauber: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         8.754313
# std          8.969167
# min          2.233456
# 25%          3.912704
# 50%          6.386457
# 75%         10.205793
# max        151.162717
# dtype: float64
# Rengers Untere Argen: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         4.565170
# std          6.250016
# min          0.340304
# 25%          1.287232
# 50%          2.613447
# 75%          5.445246
# max         83.013587
# dtype: float64
# Zell Wiese: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         7.275091
# std          7.486702
# min          0.779039
# 25%          2.568298
# 50%          5.075449
# 75%          8.926413
# max         88.502879
# dtype: float64
# Ewattingen Wutach: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         5.721442
# std          5.885020
# min          0.678317
# 25%          2.067300
# 50%          3.976191
# 75%          7.575295
# max         89.387249
# dtype: float64
# Oberlauchringen Wutach: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         9.000349
# std          8.181126
# min          1.648061
# 25%          3.776007
# 50%          6.341532
# 75%         12.049712
# max        114.334869
# dtype: float64
# Hausen Zaber: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         0.507886
# std          0.408515
# min          0.153326
# 25%          0.306291
# 50%          0.424309
# 75%          0.595208
# max          8.573546
# dtype: float64
# (                     Stationsname      RMSE       MAE       NSE
#  10           Mägerkingen Lauchert  0.086174  0.032506  0.984806
#  1                 Blaubeuren Blau  0.129463  0.081696  0.994318
#  11              Wiesloch Leimbach  0.265849  0.071015  0.587382
#  24                   Hausen Zaber  0.290424  0.072944  0.649859
#  2                   Bolheim Brenz  0.408405  0.201841  0.954765
#  16  Rielasingen Radolfzeller Aach  0.530838  0.246289  0.985412
#  18                    Binnrot Rot  0.729943  0.159770  0.845922
#  9               Hüttlingen Kocher  0.910608  0.256220  0.797960
#  22              Ewattingen Wutach  1.016052  0.265414  0.970273
#  5                  Wannweil Echaz  1.221487  0.369245  0.798619
#  21                     Zell Wiese  1.406458  0.449220  0.965197
#  23         Oberlauchringen Wutach  1.527675  0.461426  0.965627
#  19      Tauberbischofsheim Tauber  1.543922  0.469622  0.971468
#  3                    Beuron Donau  1.561746  0.530215  0.990676
#  4              Hundersingen Donau  1.564797  0.792479  0.995382
#  14               Baiersbronn Murg  1.613618  0.423732  0.809607
#  7               Elpershofen Jagst  1.891235  0.656210  0.975324
#  17                 Konstanz Rhein  1.964979  1.186710  0.999780
#  6                    Eutingen Enz  2.094986  0.904859  0.968923
#  20           Rengers Untere Argen  2.417238  0.690720  0.862183
#  12           Riegel Leopoldskanal  2.784642  0.892942  0.974092
#  15                    Horb Neckar  3.113146  0.962026  0.953945
#  8                  Hausach Kinzig  4.145889  1.093539  0.944791
#  0                    Gießen Argen  5.182225  1.665363  0.941945
#  13             Bad Rotenfels Murg  5.589964  2.383085  0.872583,
#                       Stationsname      RMSE       MAE       NSE
#  10           Mägerkingen Lauchert  0.086174  0.032506  0.984806
#  11              Wiesloch Leimbach  0.265849  0.071015  0.587382
#  24                   Hausen Zaber  0.290424  0.072944  0.649859
#  1                 Blaubeuren Blau  0.129463  0.081696  0.994318
#  18                    Binnrot Rot  0.729943  0.159770  0.845922
#  2                   Bolheim Brenz  0.408405  0.201841  0.954765
#  16  Rielasingen Radolfzeller Aach  0.530838  0.246289  0.985412
#  9               Hüttlingen Kocher  0.910608  0.256220  0.797960
#  22              Ewattingen Wutach  1.016052  0.265414  0.970273
#  5                  Wannweil Echaz  1.221487  0.369245  0.798619
#  14               Baiersbronn Murg  1.613618  0.423732  0.809607
#  21                     Zell Wiese  1.406458  0.449220  0.965197
#  23         Oberlauchringen Wutach  1.527675  0.461426  0.965627
#  19      Tauberbischofsheim Tauber  1.543922  0.469622  0.971468
#  3                    Beuron Donau  1.561746  0.530215  0.990676
#  7               Elpershofen Jagst  1.891235  0.656210  0.975324
#  20           Rengers Untere Argen  2.417238  0.690720  0.862183
#  4              Hundersingen Donau  1.564797  0.792479  0.995382
#  12           Riegel Leopoldskanal  2.784642  0.892942  0.974092
#  6                    Eutingen Enz  2.094986  0.904859  0.968923
#  15                    Horb Neckar  3.113146  0.962026  0.953945
#  8                  Hausach Kinzig  4.145889  1.093539  0.944791
#  17                 Konstanz Rhein  1.964979  1.186710  0.999780
#  0                    Gießen Argen  5.182225  1.665363  0.941945
#  13             Bad Rotenfels Murg  5.589964  2.383085  0.872583,
#                       Stationsname      RMSE       MAE       NSE
#  17                 Konstanz Rhein  1.964979  1.186710  0.999780
#  4              Hundersingen Donau  1.564797  0.792479  0.995382
#  1                 Blaubeuren Blau  0.129463  0.081696  0.994318
#  3                    Beuron Donau  1.561746  0.530215  0.990676
#  16  Rielasingen Radolfzeller Aach  0.530838  0.246289  0.985412
#  10           Mägerkingen Lauchert  0.086174  0.032506  0.984806
#  7               Elpershofen Jagst  1.891235  0.656210  0.975324
#  12           Riegel Leopoldskanal  2.784642  0.892942  0.974092
#  19      Tauberbischofsheim Tauber  1.543922  0.469622  0.971468
#  22              Ewattingen Wutach  1.016052  0.265414  0.970273
#  6                    Eutingen Enz  2.094986  0.904859  0.968923
#  23         Oberlauchringen Wutach  1.527675  0.461426  0.965627
#  21                     Zell Wiese  1.406458  0.449220  0.965197
#  2                   Bolheim Brenz  0.408405  0.201841  0.954765
#  15                    Horb Neckar  3.113146  0.962026  0.953945
#  8                  Hausach Kinzig  4.145889  1.093539  0.944791
#  0                    Gießen Argen  5.182225  1.665363  0.941945
#  13             Bad Rotenfels Murg  5.589964  2.383085  0.872583
#  20           Rengers Untere Argen  2.417238  0.690720  0.862183
#  18                    Binnrot Rot  0.729943  0.159770  0.845922
#  14               Baiersbronn Murg  1.613618  0.423732  0.809607
#  5                  Wannweil Echaz  1.221487  0.369245  0.798619
#  9               Hüttlingen Kocher  0.910608  0.256220  0.797960
#  24                   Hausen Zaber  0.290424  0.072944  0.649859
#  11              Wiesloch Leimbach  0.265849  0.071015  0.587382,
#  {'Gießen Argen':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  42.447049
#   2022-01-01 07:00:00  41.916585
#   2022-01-01 08:00:00  41.417098
#   2022-01-01 09:00:00  41.127296
#   2022-01-01 10:00:00  40.838625
#   ...                        ...
#   2024-12-31 19:00:00  10.962965
#   2024-12-31 20:00:00  10.891963
#   2024-12-31 21:00:00  10.887644
#   2024-12-31 22:00:00  10.758992
#   2024-12-31 23:00:00  10.270706
#
#   [26298 rows x 1 columns],
#   'Blaubeuren Blau':                      Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  4.934700
#   2022-01-01 07:00:00  4.972115
#   2022-01-01 08:00:00  4.983265
#   2022-01-01 09:00:00  4.845703
#   2022-01-01 10:00:00  4.749486
#   ...                       ...
#   2024-12-31 19:00:00  2.479578
#   2024-12-31 20:00:00  2.460012
#   2024-12-31 21:00:00  2.491845
#   2024-12-31 22:00:00  2.521721
#   2024-12-31 23:00:00  2.488234
#
#   [26298 rows x 1 columns],
#   'Bolheim Brenz':                      Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  4.809136
#   2022-01-01 07:00:00  4.710942
#   2022-01-01 08:00:00  4.750518
#   2022-01-01 09:00:00  4.796556
#   2022-01-01 10:00:00  4.885793
#   ...                       ...
#   2024-12-31 19:00:00  3.993274
#   2024-12-31 20:00:00  4.008026
#   2024-12-31 21:00:00  4.025793
#   2024-12-31 22:00:00  4.007458
#   2024-12-31 23:00:00  3.993597
#
#   [26298 rows x 1 columns],
#   'Beuron Donau':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  31.392671
#   2022-01-01 07:00:00  30.891314
#   2022-01-01 08:00:00  30.830207
#   2022-01-01 09:00:00  30.648087
#   2022-01-01 10:00:00  30.573704
#   ...                        ...
#   2024-12-31 19:00:00  14.026612
#   2024-12-31 20:00:00  14.017697
#   2024-12-31 21:00:00  14.019647
#   2024-12-31 22:00:00  14.014243
#   2024-12-31 23:00:00  14.038883
#
#   [26298 rows x 1 columns],
#   'Hundersingen Donau':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  47.839356
#   2022-01-01 07:00:00  47.370920
#   2022-01-01 08:00:00  47.088207
#   2022-01-01 09:00:00  46.993320
#   2022-01-01 10:00:00  46.579336
#   ...                        ...
#   2024-12-31 19:00:00  27.552434
#   2024-12-31 20:00:00  25.520371
#   2024-12-31 21:00:00  27.212598
#   2024-12-31 22:00:00  27.415720
#   2024-12-31 23:00:00  27.722570
#
#   [26298 rows x 1 columns],
#   'Wannweil Echaz':                      Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  3.081245
#   2022-01-01 07:00:00  2.919312
#   2022-01-01 08:00:00  2.937214
#   2022-01-01 09:00:00  2.979480
#   2022-01-01 10:00:00  2.996092
#   ...                       ...
#   2024-12-31 19:00:00  2.015203
#   2024-12-31 20:00:00  1.993180
#   2024-12-31 21:00:00  2.003375
#   2024-12-31 22:00:00  2.034887
#   2024-12-31 23:00:00  1.961290
#
#   [26298 rows x 1 columns],
#   'Eutingen Enz':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  23.338752
#   2022-01-01 07:00:00  23.432194
#   2022-01-01 08:00:00  23.481222
#   2022-01-01 09:00:00  23.354865
#   2022-01-01 10:00:00  23.365647
#   ...                        ...
#   2024-12-31 19:00:00  12.127144
#   2024-12-31 20:00:00  12.123231
#   2024-12-31 21:00:00  12.126993
#   2024-12-31 22:00:00  12.141607
#   2024-12-31 23:00:00  12.100148
#
#   [26298 rows x 1 columns],
#   'Elpershofen Jagst':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  23.761768
#   2022-01-01 07:00:00  23.041465
#   2022-01-01 08:00:00  22.399479
#   2022-01-01 09:00:00  22.301726
#   2022-01-01 10:00:00  21.744458
#   ...                        ...
#   2024-12-31 19:00:00   4.636977
#   2024-12-31 20:00:00   4.589377
#   2024-12-31 21:00:00   4.559094
#   2024-12-31 22:00:00   4.551417
#   2024-12-31 23:00:00   4.576601
#
#   [26298 rows x 1 columns],
#   'Hausach Kinzig':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  41.494621
#   2022-01-01 07:00:00  40.922456
#   2022-01-01 08:00:00  40.414409
#   2022-01-01 09:00:00  40.254165
#   2022-01-01 10:00:00  39.964538
#   ...                        ...
#   2024-12-31 19:00:00  14.947308
#   2024-12-31 20:00:00  14.939456
#   2024-12-31 21:00:00  14.944133
#   2024-12-31 22:00:00  14.786168
#   2024-12-31 23:00:00  14.813262
#
#   [26298 rows x 1 columns],
#   'Hüttlingen Kocher':                      Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  2.960906
#   2022-01-01 07:00:00  3.042804
#   2022-01-01 08:00:00  2.974263
#   2022-01-01 09:00:00  3.010025
#   2022-01-01 10:00:00  2.984709
#   ...                       ...
#   2024-12-31 19:00:00  1.171258
#   2024-12-31 20:00:00  1.129064
#   2024-12-31 21:00:00  1.149832
#   2024-12-31 22:00:00  1.101072
#   2024-12-31 23:00:00  1.099377
#
#   [26298 rows x 1 columns],
#   'Mägerkingen Lauchert':                      Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  1.375213
#   2022-01-01 07:00:00  1.376435
#   2022-01-01 08:00:00  1.400947
#   2022-01-01 09:00:00  1.390641
#   2022-01-01 10:00:00  1.371504
#   ...                       ...
#   2024-12-31 19:00:00  0.482057
#   2024-12-31 20:00:00  0.481035
#   2024-12-31 21:00:00  0.481370
#   2024-12-31 22:00:00  0.482884
#   2024-12-31 23:00:00  0.483080
#
#   [26298 rows x 1 columns],
#   'Wiesloch Leimbach':                      Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  0.678124
#   2022-01-01 07:00:00  0.696289
#   2022-01-01 08:00:00  0.671691
#   2022-01-01 09:00:00  0.623165
#   2022-01-01 10:00:00  0.614217
#   ...                       ...
#   2024-12-31 19:00:00  0.657861
#   2024-12-31 20:00:00  0.657430
#   2024-12-31 21:00:00  0.656261
#   2024-12-31 22:00:00  0.656306
#   2024-12-31 23:00:00  0.656886
#
#   [26298 rows x 1 columns],
#   'Riegel Leopoldskanal':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  41.753659
#   2022-01-01 07:00:00  41.122612
#   2022-01-01 08:00:00  40.779452
#   2022-01-01 09:00:00  40.184348
#   2022-01-01 10:00:00  39.828355
#   ...                        ...
#   2024-12-31 19:00:00  11.097722
#   2024-12-31 20:00:00  11.165215
#   2024-12-31 21:00:00  11.061622
#   2024-12-31 22:00:00  11.051994
#   2024-12-31 23:00:00  11.031319
#
#   [26298 rows x 1 columns],
#   'Bad Rotenfels Murg':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  39.408548
#   2022-01-01 07:00:00  38.519457
#   2022-01-01 08:00:00  37.433668
#   2022-01-01 09:00:00  37.369101
#   2022-01-01 10:00:00  40.227922
#   ...                        ...
#   2024-12-31 19:00:00  17.651971
#   2024-12-31 20:00:00  18.758096
#   2024-12-31 21:00:00  18.592435
#   2024-12-31 22:00:00  17.745481
#   2024-12-31 23:00:00  14.272359
#
#   [26298 rows x 1 columns],
#   'Baiersbronn Murg':                      Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  8.738696
#   2022-01-01 07:00:00  8.751213
#   2022-01-01 08:00:00  8.650358
#   2022-01-01 09:00:00  8.508249
#   2022-01-01 10:00:00  8.166081
#   ...                       ...
#   2024-12-31 19:00:00  1.995042
#   2024-12-31 20:00:00  1.990688
#   2024-12-31 21:00:00  1.991198
#   2024-12-31 22:00:00  1.991796
#   2024-12-31 23:00:00  1.979518
#
#   [26298 rows x 1 columns],
#   'Horb Neckar':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  21.693227
#   2022-01-01 07:00:00  21.220885
#   2022-01-01 08:00:00  21.038272
#   2022-01-01 09:00:00  20.696878
#   2022-01-01 10:00:00  20.628417
#   ...                        ...
#   2024-12-31 19:00:00  13.289832
#   2024-12-31 20:00:00  13.231750
#   2024-12-31 21:00:00  13.193269
#   2024-12-31 22:00:00  13.185723
#   2024-12-31 23:00:00  13.209505
#
#   [26298 rows x 1 columns],
#   'Rielasingen Radolfzeller Aach':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  13.017546
#   2022-01-01 07:00:00  13.017839
#   2022-01-01 08:00:00  12.958188
#   2022-01-01 09:00:00  12.959559
#   2022-01-01 10:00:00  12.955143
#   ...                        ...
#   2024-12-31 19:00:00   9.319644
#   2024-12-31 20:00:00   9.296477
#   2024-12-31 21:00:00   9.239735
#   2024-12-31 22:00:00   9.180098
#   2024-12-31 23:00:00   9.190885
#
#   [26298 rows x 1 columns],
#   'Konstanz Rhein':                        Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  256.064439
#   2022-01-01 07:00:00  256.143941
#   2022-01-01 08:00:00  256.178021
#   2022-01-01 09:00:00  256.407140
#   2022-01-01 10:00:00  256.434265
#   ...                         ...
#   2024-12-31 19:00:00  210.628799
#   2024-12-31 20:00:00  210.613135
#   2024-12-31 21:00:00  210.625715
#   2024-12-31 22:00:00  210.619631
#   2024-12-31 23:00:00  210.616854
#
#   [26298 rows x 1 columns],
#   'Binnrot Rot':                      Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  2.309007
#   2022-01-01 07:00:00  2.301692
#   2022-01-01 08:00:00  2.353509
#   2022-01-01 09:00:00  2.283781
#   2022-01-01 10:00:00  2.207777
#   ...                       ...
#   2024-12-31 19:00:00  1.350970
#   2024-12-31 20:00:00  1.369985
#   2024-12-31 21:00:00  1.364792
#   2024-12-31 22:00:00  1.333848
#   2024-12-31 23:00:00  1.343933
#
#   [26298 rows x 1 columns],
#   'Tauberbischofsheim Tauber':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  21.072891
#   2022-01-01 07:00:00  20.611665
#   2022-01-01 08:00:00  20.403620
#   2022-01-01 09:00:00  20.128195
#   2022-01-01 10:00:00  19.867285
#   ...                        ...
#   2024-12-31 19:00:00   6.826965
#   2024-12-31 20:00:00   6.799315
#   2024-12-31 21:00:00   6.766021
#   2024-12-31 22:00:00   6.775889
#   2024-12-31 23:00:00   6.780747
#
#   [26298 rows x 1 columns],
#   'Rengers Untere Argen':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  11.445578
#   2022-01-01 07:00:00  11.214703
#   2022-01-01 08:00:00  11.142857
#   2022-01-01 09:00:00  10.802425
#   2022-01-01 10:00:00  10.667969
#   ...                        ...
#   2024-12-31 19:00:00   1.761422
#   2024-12-31 20:00:00   1.862898
#   2024-12-31 21:00:00   1.932976
#   2024-12-31 22:00:00   2.137883
#   2024-12-31 23:00:00   1.980753
#
#   [26298 rows x 1 columns],
#   'Zell Wiese':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  31.203748
#   2022-01-01 07:00:00  30.260638
#   2022-01-01 08:00:00  29.947880
#   2022-01-01 09:00:00  29.523512
#   2022-01-01 10:00:00  29.097745
#   ...                        ...
#   2024-12-31 19:00:00   5.152592
#   2024-12-31 20:00:00   5.146324
#   2024-12-31 21:00:00   5.126248
#   2024-12-31 22:00:00   5.146292
#   2024-12-31 23:00:00   5.140485
#
#   [26298 rows x 1 columns],
#   'Ewattingen Wutach':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  14.811504
#   2022-01-01 07:00:00  14.735552
#   2022-01-01 08:00:00  14.585892
#   2022-01-01 09:00:00  14.526939
#   2022-01-01 10:00:00  13.965995
#   ...                        ...
#   2024-12-31 19:00:00   5.845203
#   2024-12-31 20:00:00   5.846289
#   2024-12-31 21:00:00   5.843740
#   2024-12-31 22:00:00   5.833602
#   2024-12-31 23:00:00   5.820884
#
#   [26298 rows x 1 columns],
#   'Oberlauchringen Wutach':                       Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  20.239078
#   2022-01-01 07:00:00  20.012918
#   2022-01-01 08:00:00  19.835036
#   2022-01-01 09:00:00  19.744453
#   2022-01-01 10:00:00  19.506101
#   ...                        ...
#   2024-12-31 19:00:00   9.228267
#   2024-12-31 20:00:00   9.201758
#   2024-12-31 21:00:00   9.152129
#   2024-12-31 22:00:00   9.127169
#   2024-12-31 23:00:00   9.120562
#
#   [26298 rows x 1 columns],
#   'Hausen Zaber':                      Forecast
#   Datum / Uhrzeit
#   2022-01-01 06:00:00  0.533434
#   2022-01-01 07:00:00  0.547344
#   2022-01-01 08:00:00  0.561041
#   2022-01-01 09:00:00  0.535089
#   2022-01-01 10:00:00  0.525670
#   ...                       ...
#   2024-12-31 19:00:00  0.479101
#   2024-12-31 20:00:00  0.478764
#   2024-12-31 21:00:00  0.482656
#   2024-12-31 22:00:00  0.480740
#   2024-12-31 23:00:00  0.479011
#
#   [26298 rows x 1 columns]},
#          Stationsname     Datum / Uhrzeit  Abfluss in m^3/s   Forecast  \
#  0       Gießen Argen 2022-01-01 06:00:00            41.398  42.447049
#  1       Gießen Argen 2022-01-01 07:00:00            40.873  41.916585
#  2       Gießen Argen 2022-01-01 08:00:00            40.260  41.417098
#  3       Gießen Argen 2022-01-01 09:00:00            39.653  41.127296
#  4       Gießen Argen 2022-01-01 10:00:00            39.118  40.838625
#  ...              ...                 ...               ...        ...
#  657445  Hausen Zaber 2024-12-31 19:00:00             0.486   0.479101
#  657446  Hausen Zaber 2024-12-31 20:00:00             0.487   0.478764
#  657447  Hausen Zaber 2024-12-31 21:00:00             0.487   0.482656
#  657448  Hausen Zaber 2024-12-31 22:00:00             0.486   0.480740
#  657449  Hausen Zaber 2024-12-31 23:00:00             0.485   0.479011
#
#          Absolutfehler pro Stunde
#  0                       1.049049
#  1                       1.043585
#  2                       1.157098
#  3                       1.474296
#  4                       1.720625
#  ...                          ...
#  657445                  0.006899
#  657446                  0.008236
#  657447                  0.004344
#  657448                  0.005260
#  657449                  0.005989
#
#  [657450 rows x 5 columns],
#       Stationsname  Block Index         Block Start          Block Ende  \
#  0    Gießen Argen            0 2022-01-01 06:00:00 2022-01-31 05:00:00
#  1    Gießen Argen            1 2022-01-31 06:00:00 2022-03-02 05:00:00
#  2    Gießen Argen            2 2022-03-02 06:00:00 2022-04-01 05:00:00
#  3    Gießen Argen            3 2022-04-01 06:00:00 2022-05-01 05:00:00
#  4    Gießen Argen            4 2022-05-01 06:00:00 2022-05-31 05:00:00
#  ..            ...          ...                 ...                 ...
#  920  Hausen Zaber           32 2024-08-18 06:00:00 2024-09-17 05:00:00
#  921  Hausen Zaber           33 2024-09-17 06:00:00 2024-10-17 05:00:00
#  922  Hausen Zaber           34 2024-10-17 06:00:00 2024-11-16 05:00:00
#  923  Hausen Zaber           35 2024-11-16 06:00:00 2024-12-16 05:00:00
#  924  Hausen Zaber           36 2024-12-16 06:00:00 2024-12-31 23:00:00
#
#       MAE Block  RMSE Block  NSE Block
#  0     0.653053    1.644745   0.963856
#  1     1.994743    4.439730   0.879324
#  2     0.244229    0.346368   0.971832
#  3     1.090514    3.676197   0.754930
#  4     1.396920    4.593609   0.321160
#  ..         ...         ...        ...
#  920   0.068438    0.203814   0.112288
#  921   0.095669    0.254517   0.566447
#  922   0.019432    0.040207  -0.204830
#  923   0.049252    0.193244   0.628270
#  924   0.038294    0.107731   0.634637
#
#  [925 rows x 7 columns])
