# %% [markdown]
# # Random Forest - Anwendung (Lead Time 72 Stunde)

# %% [markdown]
# ### Feature Creation
# In diesem Block wird die Attributmatrix für die Modellierung erstellt. Dazu werden Zeitmerkmale aus dem Zeitindex abgeleitet ("Stunde", "Tage in einer Woche", "Monat", "Viertel Jahr", "Jahr", "Tage im Jahr"). Zusätzlich werden zyklische Zeitinformationen über Sinus und Cosinus ("Sinus Tag", "Cosinus Tag", "Sinus Jahr", "Cosinus Jahr") abgebildet, damit die Modelle periodische Muster lernen können.
# Darüber hinaus werden Lag-Features erzeugt (1, 3, 6, 12, 24, 48, 72, 168, 720, 8760 Stunden), um Informationen aus der Vergangenheit in die Vorhersage einzubeziehen (Von Bedeutung wegen Autokorrelation in Abflusszeitreihen). Diese gehen als Spalten "Abfluss in m^3/s_lag{lag}" in die Attributmatrix ein.
# Da Niederschlag häufig zeitverzögert auf den Abfluss wirkt, werden auch die zugeordneten Niederschlagszeitreihen um 0, 1, 3, 6, 12, 24, 36, 48 Stunden verschoben. Diese Merkmale werden als "{column}_lag{lag}" ergänzt. Die konstanten Spalten "Stationsname", "Gewässer", "Interpoliert" werden abschließend entfernt.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import glob

# Create new time series for all 25 stations which is enriched by feauters an which based on datetime index.
def feature_creation_nan():
    all_merged_files_nan=glob.glob("Datensätze/UDO-LUBW/Endgültige Auswahl Landespegel Hydrologie/Gewässer/*/*/*_merged_nan.csv")

    
    all_water_stations = []
    for a in all_merged_files_nan:
        p = Path(a)
        
        # read the respective file as a data frame.
        df_water_station = pd.read_csv(p, sep=",", index_col="Datum / Uhrzeit", parse_dates=["Datum / Uhrzeit"], encoding="utf-8")

        df_water_station = df_water_station.sort_index()
        
        # save "Stationsname" and "Gewässer" separately. I will drop them later on in the features.
        station_and_water = df_water_station[["Stationsname", "Gewässer"]]
        
        # defining time features by creating them from the datetime index
        df_water_station["Stunde"] = df_water_station.index.hour
        df_water_station["Tage in einer Woche"] = df_water_station.index.dayofweek
        df_water_station["Monat"] = df_water_station.index.month
        df_water_station["Viertel Jahr"] = df_water_station.index.quarter
        df_water_station["Jahr"] = df_water_station.index.year
        df_water_station["Tage im Jahr"] = df_water_station.index.dayofyear


        # defining cyclic features by calculating daily and yearly cycles (as sinus and cosinus).
        df_water_station["Sinus Tag"] = np.sin(2 * np.pi * df_water_station["Stunde"] / 24)
        df_water_station["Cosinus Tag"] = np.cos(2 * np.pi * df_water_station["Stunde"] / 24)
        df_water_station["Sinus Jahr"] = np.sin(2 * np.pi * df_water_station["Tage im Jahr"] / 365)
        df_water_station["Cosinus Jahr"] = np.cos(2 * np.pi * df_water_station["Tage im Jahr"] / 365)

        # defining lag features by shifting the original "Abfluss in m^3/s" to enable connecting with past surface runoff.
        # store them in a separate data frame to avoid warnings
        lags_water = {}
        for lag in [1, 3, 6, 12, 24, 48, 72, 168, 720, 8760]:
            lags_water[f"Abfluss in m^3/s_lag{lag}"] = df_water_station["Abfluss in m^3/s"].shift(lag)
        df_lags_water = pd.DataFrame(lags_water, index=df_water_station.index)

        # defining lag features for exogenous variables by shifting the original precipitation columns to capture their delayed impact on the surface runoff. 
        # store them in a separate data frame to avoid warnings
        lags_exogene = {}
        for column in df_water_station.filter(regex=r"^Niederschlag").columns:
            for lag in [0, 1, 3, 6, 12, 24, 36, 48]:
                lags_exogene[f"{column}_lag{lag}"] = df_water_station[column].shift(lag)
        df_lags_exogene = pd.DataFrame(lags_exogene, index=df_water_station.index)

        # Concatenate the data frames to one
        df_water_station = pd.concat([df_water_station, df_lags_water, df_lags_exogene], axis=1)
        

        # remove static columns or columns that are not used as features for the model
        df_water_station = df_water_station.drop(columns=["Stationsname", "Gewässer", "Interpoliert"])
                
        all_water_stations.append({
            "Stationsname": station_and_water["Stationsname"].iloc[0],
            "Gewässer": station_and_water["Gewässer"].iloc[0],
            "df": df_water_station
        })
        print(f"Create features for {p.name}.")

    return all_water_stations

feature_creation_nan()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# [{'Stationsname': 'Gießen Argen',
#   'Gewässer': 'Argen',
#   'df':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            78.308                      0.0
#   2010-01-01 01:00:00            75.247                      0.0
#   2010-01-01 02:00:00            73.206                      0.0
#   2010-01-01 03:00:00            69.861                      0.0
#   2010-01-01 04:00:00            67.697                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            11.832                      0.0
#   2024-12-31 20:00:00            11.037                      0.0
#   2024-12-31 21:00:00            10.951                      0.0
#   2024-12-31 22:00:00            10.797                      0.0
#   2024-12-31 23:00:00            10.783                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Blaubeuren Blau',
#   'Gewässer': 'Blau',
#   'df':                      Abfluss in m^3/s  Niederschlag 2814 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             5.580                      0.0
#   2010-01-01 01:00:00             5.555                      0.0
#   2010-01-01 02:00:00             5.562                      0.0
#   2010-01-01 03:00:00             5.568                      0.0
#   2010-01-01 04:00:00             5.597                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             2.573                      0.0
#   2024-12-31 20:00:00             2.635                      0.0
#   2024-12-31 21:00:00             2.450                      0.0
#   2024-12-31 22:00:00             2.488                      0.0
#   2024-12-31 23:00:00             2.428                      0.0
#
#                        Niederschlag 5511 in mm  Niederschlag 3418 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3418 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3418 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 57 columns]},
#  {'Stationsname': 'Bolheim Brenz',
#   'Gewässer': 'Brenz',
#   'df':                      Abfluss in m^3/s  Niederschlag 3440 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             4.161                      0.0
#   2010-01-01 01:00:00             4.161                      0.0
#   2010-01-01 02:00:00             3.967                      0.0
#   2010-01-01 03:00:00             3.967                      0.0
#   2010-01-01 04:00:00             3.967                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             4.098                      0.0
#   2024-12-31 20:00:00             4.040                      0.0
#   2024-12-31 21:00:00             3.962                      0.0
#   2024-12-31 22:00:00             3.871                      0.0
#   2024-12-31 23:00:00             3.982                      0.0
#
#                        Niederschlag 7331 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 7331 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 7331 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Beuron Donau',
#   'Gewässer': 'Donau',
#   'df':                      Abfluss in m^3/s  Niederschlag 2638 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            74.509                      0.0
#   2010-01-01 01:00:00            74.509                      0.0
#   2010-01-01 02:00:00            75.483                      0.0
#   2010-01-01 03:00:00            75.483                      0.0
#   2010-01-01 04:00:00            75.483                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            14.078                      0.0
#   2024-12-31 20:00:00            14.012                      0.0
#   2024-12-31 21:00:00            13.903                      0.0
#   2024-12-31 22:00:00            13.838                      0.0
#   2024-12-31 23:00:00            13.765                      0.0
#
#                        Niederschlag 4703 in mm  Niederschlag 3519 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3519 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3519 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
# ...
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Hausen Zaber',
#   'Gewässer': 'Zaber',
#   'df':                      Abfluss in m^3/s  Niederschlag 4349 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             1.417                      0.0
#   2010-01-01 01:00:00             1.417                      0.0
#   2010-01-01 02:00:00             1.334                      0.0
#   2010-01-01 03:00:00             1.334                      0.0
#   2010-01-01 04:00:00             1.334                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             0.486                      0.0
#   2024-12-31 20:00:00             0.487                      0.0
#   2024-12-31 21:00:00             0.487                      0.0
#   2024-12-31 22:00:00             0.486                      0.0
#   2024-12-31 23:00:00             0.485                      0.0
#
#                        Niederschlag 3734 in mm  Niederschlag 7238 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag 7498 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  ...  \
#   Datum / Uhrzeit                                                        ...
#   2010-01-01 00:00:00       0                    4      1             1  ...
#   2010-01-01 01:00:00       1                    4      1             1  ...
#   2010-01-01 02:00:00       2                    4      1             1  ...
#   2010-01-01 03:00:00       3                    4      1             1  ...
#   2010-01-01 04:00:00       4                    4      1             1  ...
#   ...                     ...                  ...    ...           ...  ...
#   2024-12-31 19:00:00      19                    1     12             4  ...
#   2024-12-31 20:00:00      20                    1     12             4  ...
#   2024-12-31 21:00:00      21                    1     12             4  ...
#   2024-12-31 22:00:00      22                    1     12             4  ...
#   2024-12-31 23:00:00      23                    1     12             4  ...
#
#                        Niederschlag 7498 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 7498 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 66 columns]}]

# %% [markdown]
# ## Hyperparameter Tuning mit Cross Validation

# %% [markdown]
# ### Teilung in Trainings- und Testset
# In diesem Block werden alle Zeitreihen zeitbasiert in Trainings- und Testsets aufgeteilt. Das Trainingsset umfasst alle Einträge von 2010 bis einschließlich 2021 (Zeitstempel vor dem 0.01.2022). Die späteren Einträge werden dem Testset zugeordnet.

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import glob

# split the stations time series in train and test sets
def train_and_test_nan():
    # create the features for every station
    water_stations = feature_creation_nan()
    train_test_nan = []

    # defining the timestamp separating the train and test data
    split_train_test = pd.Timestamp("2022-01-01")
    for a in water_stations:
        
        # defining important information to identify the correct train and test set for the respective station
        water = a["Gewässer"]
        station = a["Stationsname"]
        df_water_station = a["df"]

        # splitting the respective time series into train and test data (ratio: 80% train set, 20% test set)
        # (train set until 2021-12-31, test set from 2022-01-01)
        train_data = df_water_station[df_water_station.index < split_train_test]
        test_data = df_water_station[df_water_station.index >= split_train_test]

        # store the respective split with the meta data in train_test_nan
        train_test_nan.append({
            "Gewässer": water, "Stationsname": station, "Trainingsset": train_data, "Testset": test_data
        })

        print(f"Created train ({len(train_data)} rows) and test data ({len(test_data)} rows) for {station}.")

    return train_test_nan



train_and_test_nan()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# [{'Gewässer': 'Argen',
#   'Stationsname': 'Gießen Argen',
#   'Trainingsset':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            78.308                      0.0
#   2010-01-01 01:00:00            75.247                      0.0
#   2010-01-01 02:00:00            73.206                      0.0
#   2010-01-01 03:00:00            69.861                      0.0
#   2010-01-01 04:00:00            67.697                      0.0
#   ...                               ...                      ...
#   2021-12-31 19:00:00            49.543                      0.0
#   2021-12-31 20:00:00            48.711                      0.0
#   2021-12-31 21:00:00            47.784                      0.0
#   2021-12-31 22:00:00            47.063                      0.0
#   2021-12-31 23:00:00            46.322                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2021-12-31 19:00:00                      0.0                              0.0
#   2021-12-31 20:00:00                      0.0                              0.0
#   2021-12-31 21:00:00                      0.0                              0.0
#   2021-12-31 22:00:00                      0.0                              0.0
#   2021-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2021-12-31 19:00:00      19                    4     12             4  2021
#   2021-12-31 20:00:00      20                    4     12             4  2021
#   2021-12-31 21:00:00      21                    4     12             4  2021
#   2021-12-31 22:00:00      22                    4     12             4  2021
#   2021-12-31 23:00:00      23                    4     12             4  2021
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2021-12-31 19:00:00           365  ...                            0.1
#   2021-12-31 20:00:00           365  ...                            0.0
#   2021-12-31 21:00:00           365  ...                            0.0
#   2021-12-31 22:00:00           365  ...                            0.0
#   2021-12-31 23:00:00           365  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2021-12-31 19:00:00                            3.1
#   2021-12-31 20:00:00                            0.3
#   2021-12-31 21:00:00                            0.1
#   2021-12-31 22:00:00                            0.1
#   2021-12-31 23:00:00                            0.4
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                   0.05
#   2021-12-31 20:00:00                                   0.05
#   2021-12-31 21:00:00                                   0.00
#   2021-12-31 22:00:00                                   0.00
#   2021-12-31 23:00:00                                   0.00
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                
\
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                  0.000
#   2022-01-01 01:00:00                                  0.000
#   2022-01-01 02:00:00                                  0.025
#   2022-01-01 03:00:00                                  0.100
#   2022-01-01 04:00:00                                  0.050
#   ...                                                    ...
#   2024-12-31 19:00:00                                  0.000
#   2024-12-31 20:00:00                                  0.000
#   2024-12-31 21:00:00                                  0.000
#   2024-12-31 22:00:00                                  0.000
#   2024-12-31 23:00:00                                  0.000
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                  0.025
#   2022-01-01 01:00:00                                  0.000
#   2022-01-01 02:00:00                                  0.000
#   2022-01-01 03:00:00                                  0.000
#   2022-01-01 04:00:00                                  0.000
#   ...                                                    ...
#   2024-12-31 19:00:00                                  0.000
#   2024-12-31 20:00:00                                  0.000
#   2024-12-31 21:00:00                                  0.000
#   2024-12-31 22:00:00                                  0.000
#   2024-12-31 23:00:00                                  0.000
#
#   [26304 rows x 66 columns]}]

# %% [markdown]
# ### Hyperparameter-Optimierung
# In diesem Abschnitt werden die Hyperparameter des Random Forest für die spätere Vorhersage der Testsets aller 25 Zeitreihen optimiert. Für das Tuning werden drei repräsentative Zeitreihen verwendet, die anhand des Variationskoeffizienten (hoch, mittel, niedrig) ausgewählt wurden ("Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein").
# Es wird eine Grid-Search mit TimeSeriesSplit-Cross-Validation durchgeführt. Pro Station werden 7 Folds verwendet. Das Validierungsset umfasst dabei jeweils 720 Stunden. Zur Vermeidung von Leakage wird eine Lücke von 72 Stunde ("gap=72") zwischen trainingsset und Validierungsset gesetzt. Die Zielgröße ist dabei eine 72-Stunden-Vorhersage (y=Abfluss(t+72)).
# Bewertet werden hier RMSE, MAE und NSE. Der Output zeigt dabei die Hyperparameterkombination mit dem niedrigsten mittleren RMSE und MAE sowie der höchsten mittleren NSE über alle Folds und repräsentativen Stationen.
# Als primäres Auswahlkriterium wurde die NSE verwendet. Darüber hinaus wurde die Diferenz zwischen Trainings-NSE und Validierungs-NSE ("nse gap") betrachtet, um ggfs. ein mögliches Overfitting zu erkennen und diesem später entgegenwirken zu können.
# Randbemerkung: Mit horizon ist die Lead Time der Vorhersage gemeint, also t --> Q(t+72)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from itertools import product
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


def hyper_parameter_tuning_cross_validation():
    train_test = train_and_test_nan()

    # define possible parameters
    params = {
                "n_estimators": [100, 200, 300, 500],
                "max_features": ["sqrt", "log2", 1.0],
                "max_depth": [10, 20],
                "min_samples_split": [5, 10],
                "min_samples_leaf": [1, 4],
                "max_samples": np.linspace(0.5, 1.0, 3),
            }
    keys = params.keys()
    values = params.values()
    params_columns = list(keys)

    # create all hyperparameter combinations a list of dictionaries. Each of them containing one hyper parameter combination.
    dict_all_combination = []
    all_combination = list(product(*values))
    for c in all_combination:
        dict_combination = dict(zip(keys, c))
        dict_all_combination.append(dict_combination)
            
    pred = []
    scores = []

    # try every hyperparameter combination of the grid.
    for d in dict_all_combination:
        selected_stations = ["Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein"]
        selected_train_test = [t for t in train_test if t["Stationsname"] in selected_stations]

# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.6106815326258757.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.11481294422153754.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.42364527192679363.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.2801471171704623.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.5529836940690545.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.21360142506727284.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1546957256891549.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.38268331843029446.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.19787625997806554.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12885485484152803.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -7.319914818055706.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.047290220994847344.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.031059736263205236.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.7909646235009626.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.298429067512159.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.21406632965825712.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.26633227321354846.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 52.55362375072426.
# Calculated CV MAE for Konstanz Rhein with MAE: 47.61440346796893.
# Calculated CV NSE for Konstanz Rhein with NSE: -0.4359811547429564.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 48.296611066242704.
# Calculated CV MAE for Konstanz Rhein with MAE: 34.17362105034316.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.38696975856695104.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 24.88677198366376.
# Calculated CV MAE for Konstanz Rhein with MAE: 17.69539462058193.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.822710463802716.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 32.05535239277471.
# Calculated CV MAE for Konstanz Rhein with MAE: 24.395619193378504.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8624432425499342.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 26.21760426533641.
# Calculated CV MAE for Konstanz Rhein with MAE: 16.58992252924998.
# Calculated CV NSE for Konstanz Rhein with NSE: -0.04028073239523411.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 14.986130473322866.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.992287097602118.
# Calculated CV NSE for Konstanz Rhein with NSE: -4.1478631134781185.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.33962794861459.
# Calculated CV MAE for Konstanz Rhein with MAE: 15.330443797141099.
# Calculated CV NSE for Konstanz Rhein with NSE: -2.264476437052947.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 11.513991967927467.
# Calculated CV MAE for Elpershofen Jagst with MAE: 7.960611454782778.
# Calculated CV NSE for Elpershofen Jagst with NSE: -1.4010913633421933.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 23.310953565260785.
# Calculated CV MAE for Elpershofen Jagst with MAE: 10.392333842708448.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.08655199268747227.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.0231615183219542.
# Calculated CV MAE for Elpershofen Jagst with MAE: 2.3592923212046415.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.9946174477113761.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.4517479806996603.
# Calculated CV MAE for Elpershofen Jagst with MAE: 2.235256059983974.
# Calculated CV NSE for Elpershofen Jagst with NSE: -16.90319820450132.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.5451804289526696.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4936952688973033.
# Calculated CV NSE for Elpershofen Jagst with NSE: -2.384742608113606.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.666321844096338.
# Calculated CV MAE for Elpershofen Jagst with MAE: 2.352973208719241.
# Calculated CV NSE for Elpershofen Jagst with NSE: -7.8561815436928875.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 25.455184979099513.
# Calculated CV MAE for Elpershofen Jagst with MAE: 21.166436302394377.
# Calculated CV NSE for Elpershofen Jagst with NSE: -1.5798411824742313.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.4866999489156297.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3099682144080577.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.03128111775466147.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 1.1099305251444398.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.6305187127235683.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.15908753263714082.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.426502993423889.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.28044411516614126.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.5740058253019482.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.19921217626958726.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14654822943201065.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.20266920685914647.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.19946503158516854.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12758412000440128.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -7.454054311648189.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.046072672757907454.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.030933468967332654.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.699930377279538.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.307895535419672.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.2228389894092281.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.219048695554785.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 54.0245704657551.
# Calculated CV MAE for Konstanz Rhein with MAE: 48.59344408990161.
# Calculated CV NSE for Konstanz Rhein with NSE: -0.5174907438401943.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 48.484291502167785.
# Calculated CV MAE for Konstanz Rhein with MAE: 34.21531644329661.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.38219603512462985.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 26.115963609006283.
# Calculated CV MAE for Konstanz Rhein with MAE: 18.429326657824802.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.804764820563347.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 31.336600222109304.
# Calculated CV MAE for Konstanz Rhein with MAE: 24.05214983731887.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.868542740887645.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 26.9107436172808.
# Calculated CV MAE for Konstanz Rhein with MAE: 17.188195794846987.
# Calculated CV NSE for Konstanz Rhein with NSE: -0.09601360318214991.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 15.760833581819078.
# Calculated CV MAE for Konstanz Rhein with MAE: 9.344299624268066.
# Calculated CV NSE for Konstanz Rhein with NSE: -4.693854146325595.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 19.095469831240077.
# Calculated CV MAE for Konstanz Rhein with MAE: 16.202714327342772.
# Calculated CV NSE for Konstanz Rhein with NSE: -2.539102923989909.
# Best Hyperparameter combination with lowest mean rmse for all stations are n_estimators          100
# max_features         log2
# max_depth              10
# min_samples_split      10
# min_samples_leaf        4
# max_samples           1.0
# Name: 35, dtype: object with mean rmse 10.366911946500514 with nse gap between train and validation of: 1.2813266413444702.
# Best Hyperparameter combination with lowest mean mae for all stations are n_estimators          100
# max_features         sqrt
# max_depth              10
# min_samples_split      10
# min_samples_leaf        4
# max_samples           1.0
# Name: 59, dtype: object with mean mae 7.857229732286715 with nse gap between train and validation of: 1.3164307695076993.
# Best Hyperparameter combination with lowest mean nse for all stations are n_estimators          200
# max_features         log2
# max_depth              10
# min_samples_split      10
# min_samples_leaf        4
# max_samples           0.5
# Name: 105, dtype: object with mean nse -0.35630383213117917 with nse gap between train and validation of: 1.1857330017274.
# (n_estimators          100
#  max_features         log2
#  max_depth              10
#  min_samples_split      10
#  min_samples_leaf        4
#  max_samples           1.0
#  Name: 35, dtype: object,
#  n_estimators          100
#  max_features         sqrt
#  max_depth              10
#  min_samples_split      10
#  min_samples_leaf        4
#  max_samples           1.0
#  Name: 59, dtype: object,
#  n_estimators          200
#  max_features         log2
#  max_depth              10
#  min_samples_split      10
#  min_samples_leaf        4
#  max_samples           0.5
#  Name: 105, dtype: object)

# %% [markdown]
# ### Hyperparameter-Tuning mit höherem min_samples_leaf
# Mit der nun in der vorherigen Optimierung ausgewählten Kombination wird hier zusätzlich der Hyperparameter "min_samples_leaf" mit etwas höheren Werten in einer erneuten Cross-Validation variiert, während die übrigen Hyperparameter fixiert bleiben. Ziel ist es, zu überprüfen, ob sich dadurch die Validierungsleistung verbessern oder die Differenz zwischen Trainings- und Validierungs-NSE reduzieren lässt. Tatsächlich wird min_samples_leaf=36 gewählt, da die NSE-Leistung damit am besten ist.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from itertools import product
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


def hyper_parameter_tuning_cross_validation():
    train_test = train_and_test_nan()

    # define possible parameters
    params = {
                "min_samples_leaf": [6, 8, 10, 12, 24, 30, 36, 48]
            }
    keys = params.keys()
    values = params.values()
    params_columns = list(keys)

    # create all hyperparameter combinations a list of dictionaries. Each of them containing one hyper parameter combination.
    dict_all_combination = []
    all_combination = list(product(*values))
    for c in all_combination:
        dict_combination = dict(zip(keys, c))
        dict_all_combination.append(dict_combination)
            
    pred = []
    scores = []

    # try every hyperparameter combination of the grid.
    for d in dict_all_combination:
        selected_stations = ["Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein"]
        selected_train_test = [t for t in train_test if t["Stationsname"] in selected_stations]

        
        for t in selected_train_test:
            train_water = t["Trainingsset"].copy()
            train_water = train_water.sort_index()
            # define forecast horizon to forecast 72 hour in the future.
            train_water["y"] = train_water["Abfluss in m^3/s"].shift(-72)
    
            # the last 72 rows of y are NaNs due to the shift by 72 hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
            train_water = train_water.dropna(subset=["y"])
    
            # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast. We keep "Abfluss in m^3/s" as current value and the last knon runoff which is important for the prediction. 
            x = train_water.drop(columns=["y"])
            y = train_water["y"]
            
            station = t["Stationsname"]
    
            # define Time Series Spliit for the Cross validation. We evaluate the model on 720 hour validation windows using 72 hour forecasts. 
            # To avoid leakage between train and validation I use a gap of 72 hours.
            tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=72)
            fold = 0

            # split the train set into seven folds for the cross validation and use RandomForestRegressor with the respective hyperparameter combination.
            for train_idx, validation_idx in tss.split(x):
                fold += 1
                x_train = x.iloc[train_idx]
                x_validation = x.iloc[validation_idx]
                y_train = y.iloc[train_idx]
                y_validation = y.iloc[validation_idx]
                
                model = RandomForestRegressor(
                    **d,
                    n_estimators=200,
                    max_depth=10,
                    min_samples_split=10,
                    max_features="log2",
                    max_samples=0.5,
                    n_jobs = -1, 
                    random_state=42
                )
                    
                model.fit(x_train, y_train)
                
                
                # this is needed to predict the validation set    
                y_pred_validation = model.predict(x_validation)
                pred.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold, 
                    "Vorhersage": y_pred_validation
                 })

                # this is needed to check for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting
                y_pred_train = model.predict(x_train)

                # calculate the evaluation metrics for the validation set forecast in the cross validation
                rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
                mae_validation = mean_absolute_error(y_validation, y_pred_validation)
                nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

                # calculate the evaluation metrics for the training set forecast in the cross validation to compare them with the claculated metrics in the validation set forecast.
                rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
                mae_train = mean_absolute_error(y_train, y_pred_train)
                nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)

                # store information about the respective hyperparameter, station and fold with the corresponding metrics
                scores.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold,
                    "rmse validation": rmse_validation,
                    "mae validation": mae_validation,
                    "nse validation": nse_validation,
                    "rmse train": rmse_train,
                    "mae train": mae_train,
                    "nse train": nse_train,
                })
                print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
                print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
                print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station and hyperparameter combination
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby(["Stationsname"] + params_columns)[["rmse validation", "mae validation", "nse validation", "rmse train", "mae train", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "rmse train": "mean_rmse_train", "mae train": "mean_mae_train", "nse train": "mean_nse_train"})

    # calculate the mean evaluation metrics of all stations with the same hyperparameter configurations to find the best hyper parameter combination for all stations. We also want to calculate the evaluation metrics in the train set to identify if the model realy learns to regularize ore just to memorize if the metrics in the train set are much betterthan the metrics in the validation set.
    mean_per_hyper_parameter = mean_per_station.groupby(params_columns)[["mean_rmse_validation", "mean_mae_validation", "mean_nse_validation", "mean_rmse_train", "mean_mae_train", "mean_nse_train"]].mean()
    mean_per_hyper_parameter = mean_per_hyper_parameter.reset_index()
    mean_per_hyper_parameter["nse gap"] = mean_per_hyper_parameter["mean_nse_train"] - mean_per_hyper_parameter["mean_nse_validation"]

    # sort the evaluation metrics to show the best hyperparameter for the best metric
    sorted_rmse = mean_per_hyper_parameter.sort_values("mean_rmse_validation")
    sorted_mae = mean_per_hyper_parameter.sort_values("mean_mae_validation")
    sorted_nse = mean_per_hyper_parameter.sort_values("mean_nse_validation", ascending=False)

    # define the best hyperparameters per evaluation metric
    best_hp_rmse = sorted_rmse[params_columns].iloc[0]
    best_hp_mae = sorted_mae[params_columns].iloc[0]
    best_hp_nse = sorted_nse[params_columns].iloc[0]

    print(f"Best Hyperparameter combination with lowest mean rmse for all stations are {best_hp_rmse} with mean rmse {sorted_rmse['mean_rmse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_rmse['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean mae for all stations are {best_hp_mae} with mean mae {sorted_mae['mean_mae_validation'].iloc[0]} with nse gap between train and validation of: {sorted_mae['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean nse for all stations are {best_hp_nse} with mean nse {sorted_nse['mean_nse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_nse['nse gap'].iloc[0]}.")

    return best_hp_rmse, best_hp_mae, best_hp_nse

hyper_parameter_tuning_cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 9.181471084696133.
# Calculated CV MAE for Elpershofen Jagst with MAE: 6.940113289217463.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.5267972988646388.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 23.121520985633573.
# Calculated CV MAE for Elpershofen Jagst with MAE: 9

# Calculated CV RMSE for Konstanz Rhein with RMSE: 31.64072794743044.
# Calculated CV MAE for Konstanz Rhein with MAE: 27.407757835850695.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.4794812973255307.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 48.86747134958908.
# Calculated CV MAE for Konstanz Rhein with MAE: 36.71633343188314.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.37239222110264025.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 26.229636404874284.
# Calculated CV MAE for Konstanz Rhein with MAE: 19.137293026826836.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8030615537266796.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 25.079941512271382.
# Calculated CV MAE for Konstanz Rhein with MAE: 23.76373648318725.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.915795779953844.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 12.958930614083581.
# Calculated CV MAE for Konstanz Rhein with MAE: 11.585498288904718.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.7458425314764443.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 6.939648738966297.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.647986143838178.
# Calculated CV NSE for Konstanz Rhein with NSE: -0.10388275403013814.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.097268484622106.
# Calculated CV MAE for Konstanz Rhein with MAE: 6.849400716485943.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.3636301792833402.
# Best Hyperparameter combination with lowest mean rmse for all stations are min_samples_leaf    30
# Name: 5, dtype: int64 with mean rmse 10.171587154965142 with nse gap between train and validation of: 1.09474997859626.
# Best Hyperparameter combination with lowest mean mae for all stations are min_samples_leaf    30
# Name: 5, dtype: int64 with mean mae 7.6903888059228835 with nse gap between train and validation of: 1.09474997859626.
# Best Hyperparameter combination with lowest mean nse for all stations are min_samples_leaf    36
# Name: 6, dtype: int64 with mean nse -0.34897506836884046 with nse gap between train and validation of: 1.0795249829949845.
# (min_samples_leaf    30
#  Name: 5, dtype: int64,
#  min_samples_leaf    30
#  Name: 5, dtype: int64,
#  min_samples_leaf    36
#  Name: 6, dtype: int64)

# %% [markdown]
# ### Cross Validation mit optimierten Hyperparametern
# In den folgenden zwei Blöcken wird eine zeitbasierte Cross-Validation mit der ermittelten Hyperparameter-Kombination für alle 25 Zeitreihen durchgeführt. Ziel ist es, die Validierungsleistung pro Station und über alle Stationen im Mittel zu quantifizieren. Zusätzlich soll ermöglicht werden, eine mögliche Überanpassung über die Differenz zwischen Trainings- und Validierungs-NSE zu beurteilen.
# Im ersten Block wird der Niederschlag als exogene Variable verwendet, im zweiten Block werden alle Niderschlagsdaten entfernt. Durch den Vergleich der Metriken soll die Bedeutung der Niederschlagsdaten für die Vorhersageleistung bewertet werden.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Cross Validation with exogene features
def cross_validation():
    train_test = train_and_test_nan()
    
    pred = []
    scores = []

    # Cross Validation for every of the 25 stations in Baden-Württemberg with the best hyper parameter from the hyper parameter tuning.
    for t in train_test:
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()

        # defining forecast horizon to forecast 72 hours in the future (Q(t)--> Q(t+72)).
        train_water["y"] = train_water["Abfluss in m^3/s"].shift(-72)

        # the last 72 rows of y are NaN due to the shift by 72 hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train_water = train_water.dropna(subset=["y"])

        # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast.
        # We keep "Abfluss in m^3/s" as current value and the last known runoff which is important for the prediction.
        x = train_water.drop(columns=["y"])
        y = train_water["y"]
        
        station = t["Stationsname"]

        # define Time Series Spliit for the Cross validation. I evaluate the model on 720 hour validation windows using 72 hour ahead forecasts. 
        # To avoid leakage between train and validation I use a gap of 72 hours.
        tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=72)
        fold = 0

        # split the train set into seven folds for the cross validation and use RandomForestRegressor with the respective hyperparameter combination.
        for train_idx, validation_idx in tss.split(x):
            fold += 1
            x_train = x.iloc[train_idx]
            x_validation = x.iloc[validation_idx]
            y_train = y.iloc[train_idx]
            y_validation = y.iloc[validation_idx]

            # Define Random Forest model with the best hyperparameter combination identified in the hyperparameter tuning
            model = RandomForestRegressor(
                n_estimators=200, 
                max_features="log2",
                max_depth=10, 
                min_samples_split=10,
                min_samples_leaf=36,
                max_samples=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # Predict the respective validation set per fold
            y_pred_validation = model.predict(x_validation)
            pred.append({
                "Stationsname": station,
                "Fold": fold, 
                "Vorhersage": y_pred_validation
            })

            # Predict the respective validation set per fold to ceck for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting.
            y_pred_train = model.predict(x_train)

            # Calculate the evaluation metrics "RMSE", "MAE" and "NSE" for the prediction of the validation set per fold.
            rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
            mae_validation = mean_absolute_error(y_validation, y_pred_validation)
            nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

            # Calculate "NSE" and "NSE gap" per fold to identify potential model overfitting.
            nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)
            nse_gap = nse_train - nse_validation

            # store evaluation metrics for this station and fold in score
            scores.append({
                "Stationsname": station,
                "Fold": fold,
                "rmse validation": rmse_validation,
                "mae validation": mae_validation,
                "nse validation": nse_validation,
                "nse train": nse_train,
                "nse gap": nse_gap
            })
            print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
            print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
            print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station. This enables to compare the scores with the other cv, to identify the importance of the exogene features.
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby("Stationsname")[["rmse validation", "mae validation", "nse validation", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "nse train": "mean_nse_train"})

    overall_mean_nse = mean_per_station["mean_nse_validation"].mean()
    overall_mean_nse_train = mean_per_station["mean_nse_train"].mean()
    overall_nse_gap = overall_mean_nse_train - overall_mean_nse
    
    return scores_df, mean_per_station, overall_mean_nse, overall_mean_nse_train, overall_nse_gap

cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Gießen Argen with RMSE: 13.531736367505955.
# Calculated CV MAE for Gießen Argen with MAE: 9.246426629865772.
# Calculated CV NSE for Gießen Argen with NSE: -0.024454295502694956.
# Calculated CV RMSE for Gießen Argen with RMSE: 28.913205334304955.
# Calculated CV MAE for Gießen Argen with MAE: 16.365690093451434.
# Calculated CV NSE for Gießen Argen with NSE: -0.14415928807316258.
# Calculated CV RMSE for Gießen Argen with RMSE: 30.660561350119387.
# Calculated CV MAE for Gießen Argen with MAE: 15.193582706298942.
# Calculated CV NSE for Gießen Argen with NSE: -0.05808956063326365.
# Calculated CV RMSE for Gießen Argen with RMSE: 7.816002254220467.
# Calculated CV MAE for Gießen Argen with MAE: 7.025461498658052.

# Calculated CV NSE for Hundersingen Donau with NSE: 0.3712482432144044.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 2.229892607454487.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.9280135889722705.
# Calculated CV NSE for Hundersingen Donau with NSE: -0.6900614907894631.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 1.6048200121969143.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.3579299715096071.
# Calculated CV NSE for Hundersingen Donau with NSE: -1.1765677380972521.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 1.4540926838358426.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.2149790880381792.
# Calculated CV NSE for Hundersingen Donau with NSE: -1.8074700812600173.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 10.042267027569.
# Calculated CV MAE for Hundersingen Donau with MAE: 7.107411294360499.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.1396430196411369.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 7.486194212586147.
# Calculated CV MAE for Wannweil Echaz with MAE: 2.2837799060002184.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.05579404303015578.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 2.328877009768337.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.3918182901858884.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.06469320485206131.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 1.2206003504023426.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.8939998983517623.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.35355311695687375.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.5345492067351413.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.5008206342470222.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.4039176673550129.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.42519603082911117.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.33761743825472845.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.48331188919961443.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.2444522668975198.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.21754543843526292.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.7335706264790682.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.7834716209706395.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.5309725273755327.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.039135840664754395.
# Calculated CV RMSE for Eutingen Enz with RMSE: 10.526178135363011.
# Calculated CV MAE for Eutingen Enz with MAE: 5.797738325627123.
# Calculated CV NSE for Eutingen Enz with NSE: -0.10918042253614058.
# Calculated CV RMSE for Eutingen Enz with RMSE: 12.823526845248885.
# Calculated CV MAE for Eutingen Enz with MAE: 6.846937671428814.
# Calculated CV NSE for Eutingen Enz with NSE: -0.17775370396620382.
# Calculated CV RMSE for Eutingen Enz with RMSE: 3.8920287475829825.
# Calculated CV MAE for Eutingen Enz with MAE: 3.2111429476247855.
# Calculated CV NSE for Eutingen Enz with NSE: -0.6513107030966334.
# Calculated CV RMSE for Eutingen Enz with RMSE: 2.1021070672158664.
# Calculated CV MAE for Eutingen Enz with MAE: 1.5734188313864883.
# Calculated CV NSE for Eutingen Enz with NSE: -0.7168701254959824.
# Calculated CV RMSE for Eutingen Enz with RMSE: 2.0833367843059922.
# Calculated CV MAE for Eutingen Enz with MAE: 1.5642627262175877.
# Calculated CV NSE for Eutingen Enz with NSE: -0.5148606209645514.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.6341024892511835.
# Calculated CV MAE for Eutingen Enz with MAE: 1.3992847894697271.
# Calculated CV NSE for Eutingen Enz with NSE: -1.8749318787179527.
# Calculated CV RMSE for Eutingen Enz with RMSE: 6.675368055282844.
# Calculated CV MAE for Eutingen Enz with MAE: 4.117779462110026.
# Calculated CV NSE for Eutingen Enz with NSE: 0.17958470931095916.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 8.934318804969251.
# Calculated CV MAE for Elpershofen Jagst with MAE: 6.802629234890594.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.44570516342986344.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 23.062046977950573.
# Calculated CV MAE for Elpershofen Jagst with MAE: 9.417278078823793.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.06347219369868418.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.7255785313415877.
# Calculated CV MAE for Elpershofen Jagst with MAE: 2.293543451136734.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.6212661359451881.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.7952433436952404.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4773122780423535.
# Calculated CV NSE for Elpershofen Jagst with NSE: -8.598991728930713.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.8058566493748935.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.2372009029417412.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.7039429247609139.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.025923912972493.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.5340022361650503.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.6693345918446238.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 15.396327884082984.
# Calculated CV MAE for Elpershofen Jagst with MAE: 10.319396601575406.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.056211330363413525.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 6.202004548582613.
# Calculated CV MAE for Hausach Kinzig with MAE: 4.26071520801115.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.03136077166183204.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 10.314749758225686.
# Calculated CV MAE for Hausach Kinzig with MAE: 5.651469194496499.
# Calculated CV NSE for Hausach Kinzig with NSE: 0

# Calculated CV RMSE for Baiersbronn Murg with RMSE: 8.828395638493472.
# Calculated CV MAE for Baiersbronn Murg with MAE: 4.707230854632412.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.006852922650898208.
# Calculated CV RMSE for Horb Neckar with RMSE: 13.825685145237996.
# Calculated CV MAE for Horb Neckar with MAE: 8.503130719375006.
# Calculated CV NSE for Horb Neckar with NSE: -0.06433922750014442.
# Calculated CV RMSE for Horb Neckar with RMSE: 13.565104068095916.
# Calculated CV MAE for Horb Neckar with MAE: 7.992832096743395.
# Calculated CV NSE for Horb Neckar with NSE: -0.06437629153260183.
# Calculated CV RMSE for Horb Neckar with RMSE: 4.8675892631168125.
# Calculated CV MAE for Horb Neckar with MAE: 3.567583813199067.
# Calculated CV NSE for Horb Neckar with NSE: -0.06580066006294505.
# Calculated CV RMSE for Horb Neckar with RMSE: 3.4043626675754703.
# Calculated CV MAE for Horb Neckar with MAE: 2.4556452515488445.
# Calculated CV NSE for Horb Neckar with NSE: -0.3046049632183221.
# Calculated CV RMSE for Horb Neckar with RMSE: 2.0361804930283545.
# Calculated CV MAE for Horb Neckar with MAE: 1.8279753681931683.
# Calculated CV NSE for Horb Neckar with NSE: -1.9305490273718027.
# Calculated CV RMSE for Horb Neckar with RMSE: 2.5522652905284375.
# Calculated CV MAE for Horb Neckar with MAE: 2.309170247601459.
# Calculated CV NSE for Horb Neckar with NSE: -2.8223245862752675.
# Calculated CV RMSE for Horb Neckar with RMSE: 11.508625646007784.
# Calculated CV MAE for Horb Neckar with MAE: 9.41911599178042.
# Calculated CV NSE for Horb Neckar with NSE: -0.22676575241944263.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 2.867233587996346.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 1.9033989904723077.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.05696970849571881.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 4.6382135484716365.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 3.168293018334416.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.44534975422545786.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 1.2508308772090906.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 1.070053351419476.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8705665036195485.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.88375354454637.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.7043937937046817.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -1.3991582841530228.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.7047375279124131.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.618385019257197.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.09359537215045455.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.6615415345304898.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.5686074660329384.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.26644696639650267.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 2.2455297831564605.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 1.641645979404344.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.2490203028002389.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 30.795372297837094.
# Calculated CV MAE for Konstanz Rhein with MAE: 26.983756235004016.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.5069234789367172.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 50.4550370898876.
# Calculated CV MAE for Konstanz Rhein with MAE: 38.544414338299255.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.33095143535189875.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 26.040224477426595.
# Calculated CV MAE for Konstanz Rhein with MAE: 19.8696310776164.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8058955849720386.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 22.382541430130782.
# Calculated CV MAE for Konstanz Rhein with MAE: 21.14529943264552.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9329344311133299.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 11.38070236239186.
# Calculated CV MAE for Konstanz Rhein with MAE: 9.843178354115333.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8039789649781313.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 7.069311698606793.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.787145253015775.
# Calculated CV NSE for Konstanz Rhein with NSE: -0.14551883175542302.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.1452486659793.
# Calculated CV MAE for Konstanz Rhein with MAE: 6.903769521379388.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.35606624554937727.
# Calculated CV RMSE for Binnrot Rot with RMSE: 4.181268417341582.
# Calculated CV MAE for Binnrot Rot with MAE: 1.5517344735239347.
# Calculated CV NSE for Binnrot Rot with NSE: -0.14856733923426302.
# Calculated CV RMSE for Binnrot Rot with RMSE: 3.46405487246546.
# Calculated CV MAE for Binnrot Rot with MAE: 1.4354956551688647.
# Calculated CV NSE for Binnrot Rot with NSE: -0.11187318725880857.
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.3648822200361772.
# Calculated CV MAE for Binnrot Rot with MAE: 0.89986191563629.
# Calculated CV NSE for Binnrot Rot with NSE: -0.014033293177012185.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.5040592767192315.
# Calculated CV MAE for Binnrot Rot with MAE: 0.4497543576569011.
# Calculated CV NSE for Binnrot Rot with NSE: -8.284352210257435.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.24378522102409908.
# Calculated CV MAE for Binnrot Rot with MAE: 0.20788844518804703.
# Calculated CV NSE for Binnrot Rot with NSE: -3.153569783321408.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.26985714277896816.
# Calculated CV MAE for Binnrot Rot with MAE: 0.24056520957881986.
# Calculated CV NSE for Binnrot Rot with NSE: -1.8259989090453383.
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.0138329893731162.
# Calculated CV MAE for Binnrot Rot with MAE: 0.7793514803615595.
# Calculated CV NSE for Binnrot Rot with NSE: -0.39932586186447994.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 3.1747985387044264.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 2.4427400173704226.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.06705074739967931.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 20.152444033575286.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 8.390967480474878.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.15022094274724251.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 2.0058935763559997.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.7237077906151406.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.8098719503750265.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.114227750878487.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.9864995252800871.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -6.053079110986769.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.0376173098098238.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.7716968309743114.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.5868133467368835.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.9462947228220107.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.7632528211330705.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.9738343256210014.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 9.559261405129579.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 5.615026022987337.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.04303782403896983.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 3.874402699586171.
# Calculated CV MAE for Rengers Untere Argen with MAE: 2.654895747162996.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.051410937403061685.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 8.446758063457118.
# Calculated CV MAE for Rengers Untere Argen with MAE: 3.8796483911665987.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.035381022911981974.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 9.474806571699043.
# Calculated CV MAE for Rengers Untere Argen with MAE: 4.343921350100313.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.04914725024168387.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.501974248776945.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.9111481706148765.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.35980806223881.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.3077064125083218.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.1653126247772296.
# Calculated CV NSE for Rengers Untere Argen with NSE: -17.666625637463326.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.7545444523316418.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.4332190176131046.
# Calculated CV NSE for Rengers Untere Argen with NSE: -1.2685619822421899.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 8.283210323382235.
# Calculated CV MAE for Rengers Untere Argen with MAE: 4.77291303940715.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.06587122330975759.
# Calculated CV RMSE for Zell Wiese with RMSE: 2.934772509769235.
# Calculated CV MAE for Zell Wiese with MAE: 2.2682206792945485.
# Calculated CV NSE for Zell Wiese with NSE: -0.5412328485460534.
# Calculated CV RMSE for Zell Wiese with RMSE: 9.564238877428856.
# Calculated CV MAE for Zell Wiese with MAE: 5.2239869714009295.
# Calculated CV NSE for Zell Wiese with NSE: 0.07549285611989887.
# Calculated CV RMSE for Zell Wiese with RMSE: 1.7801008320524803.
# Calculated CV MAE for Zell Wiese with MAE: 1.4789460427198347.
# Calculated CV NSE for Zell Wiese with NSE: -1.1571295733978944.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.6743179191197156.
# Calculated CV MAE for Zell Wiese with MAE: 0.5385306152016791.
# Calculated CV NSE for Zell Wiese with NSE: -1.3696671720666775.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.9851337700676459.
# Calculated CV MAE for Zell Wiese with MAE: 0.7767668404616416.
# Calculated CV NSE for Zell Wiese with NSE: -2.4701576596682884.
# Calculated CV RMSE for Zell Wiese with RMSE: 2.7305926357017047.
# Calculated CV MAE for Zell Wiese with MAE: 2.0344864940712726.
# Calculated CV NSE for Zell Wiese with NSE: -4.900871040415536.
# Calculated CV RMSE for Zell Wiese with RMSE: 11.364788917484514.
# Calculated CV MAE for Zell Wiese with MAE: 7.7823936185022475.
# Calculated CV NSE for Zell Wiese with NSE: 0.22653131449187336.
# Calculated CV RMSE for Ewattingen Wutach with RMSE:
#
#  [175 rows x 7 columns],
#                       Stationsname  mean_rmse_validation  mean_mae_validation  \
#  0              Bad Rotenfels Murg              8.423228             5.168536
#  1                Baiersbronn Murg              2.509960             1.464243
#  2                    Beuron Donau              5.771356             4.026197
#  3                     Binnrot Rot              1.577391             0.794950
#  4                 Blaubeuren Blau              1.110158             0.542218
#  5                   Bolheim Brenz              0.696562             0.438350
#  6               Elpershofen Jagst              7.963614             4.725909
#  7                    Eutingen Enz              5.676664             3.501509
#  8               Ewattingen Wutach              2.433245             1.674052
#  9                    Gießen Argen             16.372784            10.286728
#  10                 Hausach Kinzig              6.206896             4.476132
#  11                   Hausen Zaber              0.278398             0.155403
#  12                    Horb Neckar              7.394259             5.153636
#  13             Hundersingen Donau              8.960068             5.974967
#  14              Hüttlingen Kocher              1.016938             0.520698
#  15                 Konstanz Rhein             22.324063            18.439599
#  16           Mägerkingen Lauchert              0.323160             0.192867
#  17         Oberlauchringen Wutach              4.121931             2.662711
#  18           Rengers Untere Argen              5.091915             2.880151
#  19           Riegel Leopoldskanal             10.062398             6.789694
#  20  Rielasingen Radolfzeller Aach              1.893120             1.382111
#  21      Tauberbischofsheim Tauber              5.427220             2.956270
#  22                 Wannweil Echaz              1.860477             0.879508
#  23              Wiesloch Leimbach              0.257830             0.139930
#  24                     Zell Wiese              4.290564             2.871904
#
#      mean_nse_validation  mean_nse_train
#  0             -0.967272        0.506020
#  1             -5.852705        0.338497
#  2             -1.200654        0.725727
#  3             -1.991103        0.401289
#  4             -0.247181        0.814271
#  5             -0.167037        0.857288
#  6             -1.578072        0.523046
#  7             -0.552189        0.656425
#  8             -0.781741        0.616760
#  9             -1.843837        0.375117
#  10            -1.506009        0.576560
#  11            -0.303955        0.440928
#  12            -0.782680        0.555272
#  13            -0.437230        0.735179
#  14            -0.659562        0.563164
#  15             0.513033        0.992011
#  16             0.018113        0.676593
#  17            -2.705188        0.646314
#  18            -2.751749        0.344172
#  19            -1.047038        0.583045
#  20            -0.158154        0.817419
#  21            -1.228262        0.618772
#  22            -0.286370        0.446898
#  23            -0.269989        0.364598
#  24            -1.448148        0.613256  ,
#  np.float64(-1.129399154633008),
#  np.float64(0.5915448263082606),
#  np.float64(1.7209439809412685))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Cross Validation without exogene features
def cross_validation():
    train_test = train_and_test_nan()
    
    pred = []
    scores = []

    # Cross Validation for every of the 25 stations in Baden-Württemberg with the best hyper parameter from the hyper parameter tuning.
    for t in train_test:
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()

        # define all exogene precipitation data
        exogene_features = train_water.filter(regex=r"^Niederschlag").columns

        # defining forecast horizon to forecast 72 hours in the future (Q(t)--> Q(t+72)).
        train_water["y"] = train_water["Abfluss in m^3/s"].shift(-72)

        # the last 72 rows of y are NaN due to the shift by 72 hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train_water = train_water.dropna(subset=["y"])

        # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast.
        # We keep "Abfluss in m^3/s" as current value and the last known runoff which is important for the prediction.
        x = train_water.drop(columns=["y", *exogene_features])
        y = train_water["y"]
        
        station = t["Stationsname"]

        # define Time Series Spliit for the Cross validation. I evaluate the model on 720 hour validation windows using 72 hour ahead forecasts. 
        # To avoid leakage between train and validation I use a gap of 72 hours.
        tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=72)
        fold = 0

        # split the train set into seven folds for the cross validation and use RandomForestRegressor with the respective hyperparameter combination.
        for train_idx, validation_idx in tss.split(x):
            fold += 1
            x_train = x.iloc[train_idx]
            x_validation = x.iloc[validation_idx]
            y_train = y.iloc[train_idx]
            y_validation = y.iloc[validation_idx]

            # Define Random Forest model with the best hyperparameter combination identified in the hyperparameter tuning
            model = RandomForestRegressor(
                n_estimators=200, 
                max_features="log2",
                max_depth=10, 
                min_samples_split=10,
                min_samples_leaf=36,
                max_samples=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # Predict the respective validation set per fold
            y_pred_validation = model.predict(x_validation)
            pred.append({
                "Stationsname": station,
                "Fold": fold, 
                "Vorhersage": y_pred_validation
            })

            # Predict the respective validation set per fold to ceck for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting.
            y_pred_train = model.predict(x_train)

            # Calculate the evaluation metrics "RMSE", "MAE" and "NSE" for the prediction of the validation set per fold.
            rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
            mae_validation = mean_absolute_error(y_validation, y_pred_validation)
            nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

            # Calculate "NSE" and "NSE gap" per fold to identify potential model overfitting.
            nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)
            nse_gap = nse_train - nse_validation

            # store evaluation metrics for this station and fold in score
            scores.append({
                "Stationsname": station,
                "Fold": fold,
                "rmse validation": rmse_validation,
                "mae validation": mae_validation,
                "nse validation": nse_validation,
                "nse train": nse_train,
                "nse gap": nse_gap
            })
            print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
            print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
            print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")
            

    # calculate the mean evaluation metrics over the folds with the same station. This enables to compare the scores with the other cv, to identify the importance of the exogene features.
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby("Stationsname")[["rmse validation", "mae validation", "nse validation", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "nse train": "mean_nse_train"})

    overall_mean_nse = mean_per_station["mean_nse_validation"].mean()
    overall_mean_nse_train = mean_per_station["mean_nse_train"].mean()
    overall_nse_gap = overall_mean_nse_train - overall_mean_nse
    
    return scores_df, mean_per_station, overall_mean_nse, overall_mean_nse_train, overall_nse_gap

cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Gießen Argen with RMSE: 13.51672570411185.
# Calculated CV MAE for Gießen Argen with MAE: 9.396257026875453.
# Calculated CV NSE for Gießen Argen with NSE: -0.022182715719516688.
# Calculated CV RMSE for Gießen Argen with RMSE: 29.891497996803817.
# Calculated CV MAE for Gießen Argen with MAE: 16.857499618042674.
# Calculated CV NSE for Gießen Argen with NSE: -0.22289556388559717.
# Calculated CV RMSE for Gießen Argen with RMSE: 30.81623378459245.
# Calculated CV MAE for Gießen Argen with MAE: 15.458116563319598.
# Calculated CV NSE for Gießen Argen with NSE: -0.06886128326662111.
# Calculated CV RMSE for Gießen Argen with RMSE: 7.8839670499896535.
# Calculated CV MAE for Gießen Argen with MAE: 7.106736429957189.
# Calculated CV NSE for Gießen Argen with NSE: -1.2275295061113534.
# Calculated CV RMSE for Gießen Argen with RMSE: 3.749809933866979.
# Calculated CV MAE for Gießen Argen with MAE: 3.1830387790444497.
# Calculated CV NSE for Gießen Argen with NSE: -11.595075307831193.
# Calculated CV RMSE for Gießen Argen with RMSE: 7.045064493222209.
# Calculated CV MAE for Gießen Argen with MAE: 5.2162001152504125.
# Calculated CV NSE for Gießen Argen with NSE: -0.532109675595692.
# Calculated CV RMSE for Gießen Argen with RMSE: 23.930043472534027.
# Calculated CV MAE for Gießen Argen with MAE: 17.787940901047534.
# Calculated CV NSE for Gießen Argen with NSE: -0.07019476567704697.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.5216983767203967.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.4253148164262486.
# Calculated CV NSE for Blaubeuren Blau with NSE: -1.055783488856687.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 5.59263568145495.
# Calculated CV MAE for Blaubeuren Blau with MAE: 2.1393879732855496.
# Calculated CV NSE for Blaubeuren Blau with NSE: -0.22577324942262944.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 1.0690318001666976.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.9391300226211011.
# Calculated CV NSE for Blaubeuren Blau with NSE: -7.419265832492366.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.43686761560411286.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.30908464469740915.
# Calculated CV NSE for Blaubeuren Blau with NSE: -0.5092080786119619.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.29772241516133674.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.2472266205779024.
# Calculated CV NSE for Blaubeuren Blau with NSE: -2.269952550631712.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.16358923423883204.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.09918542080160452.
# Calculated CV NSE for Blaubeuren Blau with NSE: -1.3869588574497396.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.8846879718447752.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.6770746244842546.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.10058578144796815.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.735667299496198.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.46685127174299007.
# Calculated CV NSE for Bolheim Brenz with NSE: -0.1382243263677443.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 1.7885915238089252.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.9476168420599971.
# Calculated CV NSE for Bolheim Brenz with NSE: -0.3707859050938025.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.6222115127887553.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.40800136255137415.
# Calculated CV NSE for Bolheim Brenz with NSE: -0.1276922252610495.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.3320469561481634.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.290444701100503.
# Calculated CV NSE for Bolheim Brenz with NSE: -1.2170987448951558.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.38323219784560203.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.3066836999651596.
# Calculated CV NSE for Bolheim Brenz with NSE: -0.14747342076670322.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.3497034990769812.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.24837750472846326.
# Calculated CV NSE for Bolheim Brenz with NSE: -0.09860696115408984.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.752453493804019.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.5483113001470722.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.2721237772162346.
# Calculated CV RMSE for Beuron Donau with RMSE: 14.669531491023141.
# Calculated CV MAE for Beuron Donau with MAE: 9.641425742425671.
# Calculated CV NSE for Beuron Donau with NSE: -0.24222713240185123.
# Calculated CV RMSE for Beuron Donau with RMSE: 12.012587945112495.
# Calculated CV MAE for Beuron Donau with MAE: 8.254779323473802.
# Calculated CV NSE for Beuron Donau with NSE: -0.09051634248202012.
# Calculated CV RMSE for Beuron Donau with RMSE: 3.602284431232981.
# Calculated CV MAE for Beuron Donau with MAE: 2.884881064008478.
# Calculated CV NSE for Beuron Donau with NSE: -0.8378137395661001.
# Calculated CV RMSE for Beuron Donau with RMSE: 1.089977399101706.
# Calculated CV MAE for Beuron Donau with MAE: 0.8729214004835323.
# Calculated CV NSE for Beuron Donau with NSE: -1.9853208338111665.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.4833253500121323.
# Calculated CV MAE for Beuron Donau with MAE: 0.41073084314039693.
# Calculated CV NSE for Beuron Donau with NSE: -1.2874032635408752.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.3377651601824153.
# Calculated CV MAE for Beuron Donau with MAE: 0.3125837767718223.
# Calculated CV NSE for Beuron Donau with NSE: -1.06783730121245.
# Calculated CV RMSE for Beuron Donau with RMSE: 9.576473019789296.
# Calculated CV MAE for Beuron Donau with MAE: 7.743020377255746.
# Calculated CV NSE for Beuron Donau with NSE: -0.026085453540786396.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 22.89758678920732.
# Calculated CV MAE for Hundersingen Donau with MAE: 14.09243797832281.
# Calculated CV NSE for Hundersingen Donau with NSE: -0.10636922460329612.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 23.685137192997203.
# Calculated CV MAE for Hundersingen Donau with MAE: 16.39586014457815.
# Calculated CV NSE for Hundersingen Donau with NSE: -0.11179395110384704.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 3.703507186705241.
# Calculated CV MAE for Hundersingen Donau with MAE: 3.1160701697905084.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.5413418772071602.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 2.479961919306955.
# Calculated CV MAE for Hundersingen Donau with MAE: 2.0302828281340783.
# Calculated CV NSE for Hundersingen Donau with NSE: -1.090377080086466.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 1.3539834264536763.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.1375595807031378.
# Calculated CV NSE for Hundersingen Donau with NSE: -0.5493381740426966.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 1.0889447933274827.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.8943574843139915.
# Calculated CV NSE for Hundersingen Donau with NSE: -0.5745000672628511.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 10.16392822287907.
# Calculated CV MAE for Hundersingen Donau with MAE: 8.036572831980601.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.11867044346940547.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 7.469473495661053.
# Calculated CV MAE for Wannweil Echaz with MAE: 2.2989991562775907.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.05108299285628082.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 2.30270129975173.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.45554940491236.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.08560004816678768.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 1.2675465370398948.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.9428158138554533.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.4596749294862359.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.6138920152559433.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.5689115253855068.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.8516130367959989.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.4472619415771424.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.3667146991264663.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.6412621862325136.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.26289538161940085.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.238686682320619.
# Calculated CV NSE for Wannweil Echaz with NSE: -1.0050227986568214.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.79392438520195.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.5463087446983067.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.06704827252363144.
# Calculated CV RMSE for Eutingen Enz with RMSE: 10.488089123722075.
# Calculated CV MAE for Eutingen Enz with MAE: 5.636892362332109.
# Calculated CV NSE for Eutingen Enz with NSE: -0.10116779934732612.
# Calculated CV RMSE for Eutingen Enz with RMSE: 13.3695588827314.
# Calculated CV MAE for Eutingen Enz with MAE: 7.79359542152023.
# Calculated CV NSE for Eutingen Enz with NSE: -0.2801877429703272.
# Calculated CV RMSE for Eutingen Enz with RMSE: 3.9475404448111187.
# Calculated CV MAE for Eutingen Enz with MAE: 3.3135748042374162.
# Calculated CV NSE for Eutingen Enz with NSE: -0.6987516578108255.
# Calculated CV RMSE for Eutingen Enz with RMSE: 2.4687182839204693.
# Calculated CV MAE for Eutingen Enz with MAE: 1.89017131440674.
# Calculated CV NSE for Eutingen Enz with NSE: -1.367940830879757.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.964573259961747.
# Calculated CV MAE for Eutingen Enz with MAE: 1.422179172825828.
# Calculated CV NSE for Eutingen Enz with NSE: -0.3470700152600623.
# Calculated CV RMSE for Eutingen Enz with RMSE: 2.6828520127770896.
# Calculated CV MAE for Eutingen Enz with MAE: 1.9604247974030722.
# Calculated CV NSE for Eutingen Enz with NSE: -6.74929886261954.
# Calculated CV RMSE for Eutingen Enz with RMSE: 8.049986105479888.
# Calculated CV MAE for Eutingen Enz with MAE: 6.447977507878573.
# Calculated CV NSE for Eutingen Enz with NSE: -0.19309101571313025.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 9.4951488356667.
# Calculated CV MAE for Elpershofen Jagst with MAE: 7.305364513548193.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.632903028832541.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 23.79030516404663.
# Calculated CV MAE for Elpershofen Jagst with MAE: 9.493366412078359.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.13169776922853904.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.136245656929525.
# Calculated CV MAE for Elpershofen Jagst with MAE: 2.6642968884227973.
# Calculated CV NSE for Elpershofen Jagst with NSE: -1.1466293244570016.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.206649431911356.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9087500986310992.
# Calculated CV NSE for Elpershofen Jagst with NSE: -13.502592782939082.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.7809037336242917.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.19562777707353.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.6571788697478869.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.2931439288537194.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.8710821040685326.
# Calculated CV NSE for Elpershofen Jagst with NSE: -1.1387487051169973.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.525722406809777.
# Calculated CV MAE for Elpershofen Jagst with MAE: 12.185557897677088.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.08732998153862614.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 6.282260888095889.
# Calculated CV MAE for Hausach Kinzig with MAE: 4.286047236085856.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.0061294364130611845.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 10.364029443148489.
# Calculated CV MAE for Hausach Kinzig with MAE: 5.381473487088361.
# Calculated CV NSE for Hausach Kinzig with NSE: -0.008747421377674147.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 3.3922778735147414.
# Calculated CV MAE for Hausach Kinzig with MAE: 2.8691772775454396.
# Calculated CV NSE for Hausach Kinzig with NSE: -3.5632137845213343.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 1.43232662466158.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.1419511333849715.
# Calculated CV NSE for Hausach Kinzig with NSE: -3.909216995689869.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 3.0939146323120177.
# Calculated CV MAE for Hausach Kinzig with MAE: 2.539813655120677.
# Calculated CV NSE for Hausach Kinzig with NSE: -6.296452302929812.
# Calculated CV RMSE for Hausach Kinzig with RMSE:

# Calculated CV RMSE for Baiersbronn Murg with RMSE: 3.029730308007199.
# Calculated CV MAE for Baiersbronn Murg with MAE: 1.4144268947542378.
# Calculated CV NSE for Baiersbronn Murg with NSE: -0.029067645812638432.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 2.213523874392145.
# Calculated CV MAE for Baiersbronn Murg with MAE: 1.035596813091817.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.054276772229743364.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.6831279623603798.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.5737021415881963.
# Calculated CV NSE for Baiersbronn Murg with NSE: -2.8754992115118045.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.5483603864700056.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.43262426059440945.
# Calculated CV NSE for Baiersbronn Murg with NSE: -45.01446282431224.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.3250152791002174.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.9972296026184122.
# Calculated CV NSE for Baiersbronn Murg with NSE: -14.609777902785414.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.424474352365907.
# Calculated CV MAE for Baiersbronn Murg with MAE: 1.2098391440157765.
# Calculated CV NSE for Baiersbronn Murg with NSE: -0.9967059798937616.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 8.964926746642893.
# Calculated CV MAE for Baiersbronn Murg with MAE: 5.067025600539688.
# Calculated CV NSE for Baiersbronn Murg with NSE: -0.024102636743447814.
# Calculated CV RMSE for Horb Neckar with RMSE: 13.816872473155284.
# Calculated CV MAE for Horb Neckar with MAE: 8.220200035229913.
# Calculated CV NSE for Horb Neckar with NSE: -0.06298281251811888.
# Calculated CV RMSE for Horb Neckar with RMSE: 14.03507980365596.
# Calculated CV MAE for Horb Neckar with MAE: 8.312287159289733.
# Calculated CV NSE for Horb Neckar with NSE: -0.1394065329898544.
# Calculated CV RMSE for Horb Neckar with RMSE: 5.128515351387185.
# Calculated CV MAE for Horb Neckar with MAE: 4.012759943208165.
# Calculated CV NSE for Horb Neckar with NSE: -0.18312724562675453.
# Calculated CV RMSE for Horb Neckar with RMSE: 3.430986674467514.
# Calculated CV MAE for Horb Neckar with MAE: 2.5150034730599455.
# Calculated CV NSE for Horb Neckar with NSE: -0.32509022509312135.
# Calculated CV RMSE for Horb Neckar with RMSE: 1.8870121752025533.
# Calculated CV MAE for Horb Neckar with MAE: 1.6538148089876459.
# Calculated CV NSE for Horb Neckar with NSE: -1.5168993637600807.
# Calculated CV RMSE for Horb Neckar with RMSE: 3.7283396804262496.
# Calculated CV MAE for Horb Neckar with MAE: 3.033373768161126.
# Calculated CV NSE for Horb Neckar with NSE: -7.156557110541458.
# Calculated CV RMSE for Horb Neckar with RMSE: 14.203254916891789.
# Calculated CV MAE for Horb Neckar with MAE: 12.075911033426294.
# Calculated CV NSE for Horb Neckar with NSE: -0.8684887173420086.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 2.8697321591890637.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 1.914964380035281.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.05881264501260697.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 4.440703511246274.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 2.9250126989346756.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.32487537640542574.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 1.3956395287769594.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 1.2045425819296747.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8388627234903596.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.9615293947750742.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.7615024160214514.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -1.8400219402801588.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.8964389095931788.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.7752512766705599.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.769470243501291.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.819779349907996.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.6955676643872665.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.12644822091452435.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 2.2820962216141996.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 1.8391853666814582.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.2900298587475423.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 28.66135555515648.
# Calculated CV MAE for Konstanz Rhein with MAE: 24.763296928439214.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.5728928331055687.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 47.801249670410314.
# Calculated CV MAE for Konstanz Rhein with MAE: 34.15820368753161.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.399480540723802.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 25.89148269925287.
# Calculated CV MAE for Konstanz Rhein with MAE: 19.115243627188956.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8081067010119923.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 23.38636967395753.
# Calculated CV MAE for Konstanz Rhein with MAE: 20.965524051005023.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9267839256327615.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 12.875427195222011.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.09295891877648.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.7491074058455529.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.114658982323695.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.926973801725007.
# Calculated CV NSE for Konstanz Rhein with NSE: -0.5093449919576358.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.301987693650736.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.082923407903333.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.33104536565881104.
# Calculated CV RMSE for Binnrot Rot with RMSE: 4.183441300160645.
# Calculated CV MAE for Binnrot Rot with MAE: 1.5561524970623957.
# Calculated CV NSE for Binnrot Rot with NSE: -0.14976140307350816.
# Calculated CV RMSE for Binnrot Rot with RMSE: 3.503031152667861.
# Calculated CV MAE for Binnrot Rot with MAE: 1.4969898078385704.
# Calculated CV NSE for Binnrot Rot with NSE: -0.13703473160676283.
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.4672798532728981.
# Calculated CV MAE for Binnrot Rot with MAE: 1.1604594090775566.
# Calculated CV NSE for Binnrot Rot with NSE: -0.171892487823188.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.7394363207698503.
# Calculated CV MAE for Binnrot Rot with MAE: 0.6523850278214525.
# Calculated CV NSE for Binnrot Rot with NSE: -18.97974503517282.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.21816409517185945.
# Calculated CV MAE for Binnrot Rot with MAE: 0.18858815702638637.
# Calculated CV NSE for Binnrot Rot with NSE: -2.3263911610279924.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.2800711446600955.
# Calculated CV MAE for Binnrot Rot with MAE: 0.24327494289319912.
# Calculated CV NSE for Binnrot Rot with NSE: -2.0439736385872362.
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.053713289005126.
# Calculated CV MAE for Binnrot Rot with MAE: 0.8542440016571659.
# Calculated CV NSE for Binnrot Rot with NSE: -0.5115793060739322.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 3.3045825619573974.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 2.461313694864226.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.15607482625030378.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 20.55574716104581.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 9.077291898895531.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.19671947225473496.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 2.487297880580609.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 2.2263344226692117.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -1.7828363896462478.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.0571977241707256.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.9002164446239171.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -5.349554463521624.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.9774949530683702.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.6877831022642448.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.40825232164756575.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.1690711217482708.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.9790780690383565.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -2.0125878927359193.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 10.315447823646734.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 6.54724357518076.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.11435167510430388.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 4.142075166342128.
# Calculated CV MAE for Rengers Untere Argen with MAE: 3.040062223311684.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.0841878776988838.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 8.590227089213922.
# Calculated CV MAE for Rengers Untere Argen with MAE: 3.9232278745029223.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.07085182300441373.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 9.353769139895224.
# Calculated CV MAE for Rengers Untere Argen with MAE: 4.179354093029288.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.022513463947684276.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.557056480019513.
# Calculated CV MAE for Rengers Untere Argen with MAE: 2.010100008397087.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.42034086491810196.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.4279767032153141.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.264996030607546.
# Calculated CV NSE for Rengers Untere Argen with NSE: -21.258072636751724.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.0965118793455604.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.7303572591545746.
# Calculated CV NSE for Rengers Untere Argen with NSE: -2.2390418045442.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 8.057051831832998.
# Calculated CV MAE for Rengers Untere Argen with MAE: 4.500385882970965.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.11618434823349422.
# Calculated CV RMSE for Zell Wiese with RMSE: 3.0597613451668866.
# Calculated CV MAE for Zell Wiese with MAE: 2.2919040588766113.
# Calculated CV NSE for Zell Wiese with NSE: -0.6753072944079141.
# Calculated CV RMSE for Zell Wiese with RMSE: 9.71448802645713.
# Calculated CV MAE for Zell Wiese with MAE: 4.9673369833883125.
# Calculated CV NSE for Zell Wiese with NSE: 0.046217659908321496.
# Calculated CV RMSE for Zell Wiese with RMSE: 2.015624934311824.
# Calculated CV MAE for Zell Wiese with MAE: 1.521439950557751.
# Calculated CV NSE for Zell Wiese with NSE: -1.7657089227529625.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.6425763518209546.
# Calculated CV MAE for Zell Wiese with MAE: 0.5220190101979314.
# Calculated CV NSE for Zell Wiese with NSE: -1.1518273737733251.
# Calculated CV RMSE for Zell Wiese with RMSE: 1.2491193433682146.
# Calculated CV MAE for Zell Wiese with MAE: 0.9411521738857551.
# Calculated CV NSE for Zell Wiese with NSE: -4.579132303458812.
# Calculated CV RMSE for Zell Wiese with RMSE: 3.929705795033365.
# Calculated CV MAE for Zell Wiese with MAE: 2.753946383443053.
# Calculated CV NSE for Zell Wiese with NSE: -11.221439688097712.
# Calculated CV RMSE for Zell Wiese with RMSE: 11.774365631289694.
# Calculated CV MAE for Zell Wiese with MAE: 8.536087880108388.
# Calculated CV NSE for Zell Wiese with NSE: 0.1697764969336557.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 4.507814376067617.
# Calculated CV MAE for Ewattingen Wutach with MAE: 3.043800611784055.
# Calculated CV NSE for Ewattingen Wutach with NSE: -0.4017046744101396.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 4.572417157401666.
# Calculated CV MAE for Ewattingen Wutach with MAE: 2.1731866199949983.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.037698504523066556.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 1.348415620557211.
# Calculated CV MAE for Ewattingen Wutach with MAE: 1.1684486597154975.
# Calculated CV NSE for Ewattingen Wutach with NSE: -0.5129071742004991.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.43413941923329386.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.3199969811358496.
# Calculated CV NSE for Ewattingen Wutach with NSE: -1.5339072956808675.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.5530602737336326.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.4688606691058585.
# Calculated CV NSE for Ewattingen Wutach with NSE: -4.1565942510029945.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.5231868731649838.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.41236304325354356.
# Calculated CV NSE for Ewattingen Wutach with NSE: -1.7913107680584743.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 5.61349595348429.
# Calculated CV MAE for Ewattingen Wutach with MAE: 4.388849086051711.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.07732919195366983.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 6.13426112667742.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 4.555380289285165.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -0.4847543863464516.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 11.541027279973934.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 5.070334261799103.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -0.10705268168869941.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 1.861695791145503.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 1.343473169723456.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.25608308072595976.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.7815783830872093.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.6842179964599956.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -1.8331724804815739.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.5572119248836324.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.45474038640303377.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -1.7405451555962363.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 2.3024953197740814.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 1.623407938256712.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -28.499349556746306.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 6.8420640811258675.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 5.6175121360437155.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.008162006503092956.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.3874185040921551.
# Calculated CV MAE for Hausen Zaber with MAE: 0.1868333850366578.
# Calculated CV NSE for Hausen Zaber with NSE: -0.06875406406801998.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.5221931182443197.
# Calculated CV MAE for Hausen Zaber with MAE: 0.2511571661670901.
# Calculated CV NSE for Hausen Zaber with NSE: -0.07630508217492715.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.301675630654736.
# Calculated CV MAE for Hausen Zaber with MAE: 0.13453075503440623.
# Calculated CV NSE for Hausen Zaber with NSE: -0.07781374646365569.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.1260518209670012.
# Calculated CV MAE for Hausen Zaber with MAE: 0.11363532974729615.
# Calculated CV NSE for Hausen Zaber with NSE: -1.7610538600174386.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.26686480953857894.
# Calculated CV MAE for Hausen Zaber with MAE: 0.1151275951542791.
# Calculated CV NSE for Hausen Zaber with NSE: -0.07749525539458402.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.1332786659681414.
# Calculated CV MAE for Hausen Zaber with MAE: 0.09764669162898068.
# Calculated CV NSE for Hausen Zaber with NSE: -0.368596315707596.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.27435450273092776.
# Calculated CV MAE for Hausen Zaber with MAE: 0.22550220642914334.
# Calculated CV NSE for Hausen Zaber with NSE: -0.7185639078607347.
# (     Stationsname  Fold  rmse validation  mae validation  nse validation  \
#  0    Gießen Argen     1        13.516726        9.396257       -0.022183
#  1    Gießen Argen     2        29.891498       16.857500       -0.222896
#  2    Gießen Argen     3        30.816234       15.458117       -0.068861
#  3    Gießen Argen     4         7.883967        7.106736       -1.227530
#  4    Gießen Argen     5         3.749810        3.183039      -11.595075
#  ..            ...   ...              ...             ...             ...
#  170  Hausen Zaber     3         0.301676        0.134531       -0.077814
#  171  Hausen Zaber     4         0.126052        0.113635       -1.761054
#  172  Hausen Zaber     5         0.266865        0.115128       -0.077495
#  173  Hausen Zaber     6         0.133279        0.097647       -0.368596
#  174  Hausen Zaber     7         0.274355        0.225502       -0.718564
#
#       nse train    nse gap
#  0     0.512354   0.534537
#  1     0.507061   0.729956
#  2     0.505626   0.574488
#  3     0.501506   1.729036
#  4     0.502982  12.098058
#  ..         ...        ...
#  170   0.520087   0.597901
#  171   0.521391   2.282445
#  172   0.521543   0.599038
#  173   0.521697   0.890293
#  174   0.520368   1.238932
#
#  [175 rows x 7 columns],
#                       Stationsname  mean_rmse_validation  mean_mae_validation  \
#  0              Bad Rotenfels Murg              8.548550             5.546286
#  1                Baiersbronn Murg              2.598451             1.532921
#  2                    Beuron Donau              5.967421             4.302906
#  3                     Binnrot Rot              1.635020             0.878871
#  4                 Blaubeuren Blau              1.280890             0.690915
#  5                   Bolheim Brenz              0.709129             0.459470
#  6               Elpershofen Jagst              8.461160             5.232007
#  7                    Eutingen Enz              6.138760             4.066402
#  8               Ewattingen Wutach              2.507504             1.710787
#  9                    Gießen Argen             16.690477            10.715113
#  10                 Hausach Kinzig              6.641959             4.958406
#  11                   Hausen Zaber              0.287405             0.160633
#  12                    Horb Neckar              8.032866             5.689050
#  13             Hundersingen Donau              9.339007             6.529020
#  14              Hüttlingen Kocher              1.040393             0.540954
#  15                 Konstanz Rhein             22.147504            17.443589
#  16           Mägerkingen Lauchert              0.339682             0.208267
#  17         Oberlauchringen Wutach              4.288619             2.764152
#  18           Rengers Untere Argen              5.174953             2.949783
#  19           Riegel Leopoldskanal             11.515627             7.638140
#  20  Rielasingen Radolfzeller Aach              1.952274             1.445147
#  21      Tauberbischofsheim Tauber              5.695263             3.268466
#  22                 Wannweil Echaz              1.879671             0.916855
#  23              Wiesloch Leimbach              0.259772             0.140612
#  24                     Zell Wiese              4.626520             3.076269
#
#      mean_nse_validation  mean_nse_train
#  0             -0.994415        0.586221
#  1             -9.070763        0.497535
#  2             -0.791029        0.829409
#  3             -3.474340        0.496771
#  4             -1.823765        0.870808
#  5             -0.261108        0.868144
#  6             -2.471011        0.672405
#  7             -1.391073        0.748305
#  8             -1.183057        0.745225
#  9             -1.962693        0.504322
#  10            -2.264822        0.702885
#  11            -0.449797        0.520907
#  12            -1.464650        0.657486
#  13            -0.253195        0.845389
#  14            -0.733995        0.628294
#  15             0.468296        0.993906
#  16            -0.111430        0.774104
#  17            -4.628661        0.737234
#  18            -3.425546        0.470057
#  19            -3.734299        0.708854
#  20            -0.367257        0.860812
#  21            -1.431482        0.728038
#  22            -0.427158        0.515450
#  23            -0.284296        0.441861
#  24            -2.739632        0.738427  ,
#  np.float64(-1.8108471445421128),
#  np.float64(0.6857139113523746),
#  np.float64(2.4965610558944875))

# %% [markdown]
# ### Final model fitting und Evaluation
# In diesem Abschnitt wird schließlich das finale Modell mit der gewählten Hyperparameter-Kombination für jede Station separat trainiert und auf dem Testzeitraum evaluiert. Die Zielvariable wird als 72-Stunden-Vorhersage definiert (Lead Time 72h), das heißt es wird Q(t+72) auf Basis der Merkmale zu Zeitpunkt t vorhergesagt (y = Abfluss.shift(-72)).
# Die Vorhersage erfolgt als Expanding-Window. Das Modell wird zunächst auf dem Trainingsset trainiert und sagt anschließend den Testdatensatz blockweise in Fenster von 720 Stunden voraus. Nach jeder Blockvorhersage werden die tatsächlichen Beobachtungen dieses Blocks an den Trainingssatz angehängt und das Modell wird für den nächsten Block erneut trainiert. Die vorhersagen werden zeitlich korrekt um plus 72 Stunden verschoben, sodass der Vorhersagezeitpunkt dem tatsächlichen Zielzeitpunkt am Abfluss Q(t+72) entspricht.
#
# Die Vorhersagegüte wird auf mehreren Ebenen ausgewertet:
# - Es wird der stündliche absoute Fehler berechnet
# - Pro Block (720 Stunden) werden RMSE, MAE und NSE berechnet
# - Die Vorhersagegüte der Wochen um die zehn höchsten Abflussspitzen pro Station werden berechnet (RMSE, MAE und NSE), wobei die Peaks mindestens 7 Tage auseinanderliegen.
# - Die Gesamtmetriken werden über den gesamten vorhergesagten Testzeitraum pro Station berechnet (RMSE, MAE und NSE)
#
# Alle Auswertungen und Ergebnisse werden als CSV-Dateien im Ordner "Evaluation" gespeichert.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error


def final_model_fitting():
    
    train_test = train_and_test_nan()

    results = []
    all_forecasts = {}
    all_hourly_eval_list = []
    all_evaluate_max_week_list = []
    overall_max_week_metrics = []
    all_monthly_eval_list = []
    week = 168
    month = 720
    horizon = 72
    
    
    for t in train_test:
        
        station = t["Stationsname"]
        
        
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()
        
        test_water = t["Testset"].copy()
        test_water = test_water.sort_index()

        train = train_water.copy()
        test = test_water.copy()
        train["y"] = train_water["Abfluss in m^3/s"].shift(-horizon)
        test["y"] = test_water["Abfluss in m^3/s"].shift(-horizon)
        
        
        # the last 72 rows of y are NaNs due to the shift by 72 hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train = train.dropna(subset=["y"])
        test = test.dropna(subset=["y"])

        # define current_train to enrich it later in the expanding window forecast.
        current_train = train.copy()

        
        
        forecast_blocks = []
        # expanding window forecast: predicting a window of one month (720 hours) and cancatenate the actual runoff of this month to the train data.
        for i in range(0, len(test), month):
            end = i + month
            # defining x and y for final evaluation
            x_train = current_train.drop(columns=["y"])
            y_train = current_train["y"]
        
            x_test = test.drop(columns=["y"])
            y_test = test["y"]

            # defining the test block (one month). if the block is empty, the time series is at the end
            x_test_block = x_test.iloc[i:end]
            if len(x_test_block) == 0:
                break

            # defining the model with the best hyperparamters due to hyperparameter tuning.
            model = RandomForestRegressor(
                n_estimators=200, 
                max_features="log2",
                max_depth=10, 
                min_samples_split=10,
                min_samples_leaf=36,
                max_samples=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # predicting the respective month and store the forecast in forecast_blocks but shift the forecast 72 hours ahead because that is the actual date for the forecast due to the horizon (shift(-72)). 
            y_block_pred = model.predict(x_test_block)
            forecast_blocks.append(pd.Series(y_block_pred, index=test.index[i:i + len(x_test_block)] + pd.Timedelta(hours=horizon)))

            # enriching the train set by the actual values of the month which was forecasted in this loop.
            current_train = pd.concat([current_train, test.iloc[i:i + len(x_test_block)]])

            
        # concatenate the forecast on forecast_series with the corresponding station and store every forecast as a data frame in all_forecasts[station]   
        forecast_series = pd.concat(forecast_blocks).sort_index()
        all_forecasts[station] = pd.DataFrame({
            "Forecast": forecast_series
        })

        # defining the actual surface runoff to calculate the absolute error per hour.
        all_truth = test_water["Abfluss in m^3/s"].reindex(forecast_series.index) 

        # calculate the absolute error per hour.
        absolute_error_hourly = abs(all_truth - forecast_series)

        # store the information in the data frame evaluate_hourly_df.
        evaluate_hourly_df = pd.DataFrame({
            "Stationsname": station,
            "Datum / Uhrzeit": forecast_series.index,
            "Abfluss in m^3/s": all_truth.values,
            "Forecast": forecast_series.values,
            "Absolutfehler pro Stunde": absolute_error_hourly.values,
            
        })
        # append the respective data frame to a list.
        all_hourly_eval_list.append(evaluate_hourly_df)

        # calculate the 10 highest peaks which are minimum 7 days apart from each Peak
        true_runoff = evaluate_hourly_df["Abfluss in m^3/s"]
        forecast_runoff = evaluate_hourly_df["Forecast"]
        maximum_runoff = (true_runoff > true_runoff.shift(1)) & (true_runoff > true_runoff.shift(-1))
        local_maxima = true_runoff[maximum_runoff]
        local_maxima = local_maxima.sort_values(ascending=False)
        maximum_times = local_maxima.index

        # check if the sorted local maxima are more than a week apart.
        all_selected_maxima = []
        for maxima in maximum_times:
            if len(all_selected_maxima) >= 10:
                break
                
            distance_ok = True
            for selected in all_selected_maxima:
                if abs(maxima - selected) <= week:
                    distance_ok = False
                    break
            if distance_ok:
                all_selected_maxima.append(maxima)
                
        # define the week around the selected local maxima
        evaluate_maximum_weeks = []
        for selected_maxima in all_selected_maxima:
            start = selected_maxima - (week // 2)
            end = selected_maxima + (week // 2)
            
            start = max(start, true_runoff.index.min())
            end = min(end, true_runoff.index.max())

            # define the actual week around the local maxima and the forecast week to calculate the evaluation metrics of the forecast of this week.
            true_max_week = true_runoff.iloc[start:end]
            forecast_max_week = forecast_runoff.iloc[start:end]

            mae_max_week = mean_absolute_error(true_max_week, forecast_max_week)
            rmse_max_week = np.sqrt(mean_squared_error(true_max_week, forecast_max_week))

            squared_diff = (true_max_week - forecast_max_week)**2
            sum_squared_diff = np.sum(squared_diff)
            squared_diff2 = (true_max_week - true_max_week.mean())**2
            sum_squared_diff2 = np.sum(squared_diff2)

            if sum_squared_diff2 == 0:
                nse_max_week = np.nan
            else:
                nse_max_week = 1 - (sum_squared_diff / sum_squared_diff2)

            # store all maximum weeks of a time series and station in evaluate_maximum_weeks
            evaluate_maximum_weeks.append({
                "Stationsname": station,
                "Wochenstart": true_max_week.index[0],
                "Wochenende": true_max_week.index[-1],
                "Peak": selected_maxima,
                "MAE_MAX_WEEK": mae_max_week,
                "RMSE_MAX_WEEK": rmse_max_week,
                "NSE_MAX_WEEK": nse_max_week
            })
        evaluate_max_week_df = pd.DataFrame(evaluate_maximum_weeks)
        all_evaluate_max_week_list.append(evaluate_max_week_df)

        # calculate the evaluation metrics per station to identify how good the model is forecasting weeks with maximum peaks.
        all_mae_max_week = evaluate_max_week_df["MAE_MAX_WEEK"].mean()
        all_rmse_max_week = evaluate_max_week_df["RMSE_MAX_WEEK"].mean()
        all_nse_max_week = evaluate_max_week_df["NSE_MAX_WEEK"].mean()

        # store them in overall_max_week_metrics
        overall_max_week_metrics.append({
            "Stationsname": station,
            "All_MAE": all_mae_max_week,
            "All_RMSE": all_rmse_max_week,
            "All_NSE": all_nse_max_week
        })
                
        # Calculate the evaluation metrics per month block
        evaluate_monthly = []
        for i in range(0, len(forecast_series), month):
            end = i + month
            pred_block = forecast_series.iloc[i:end]
            truth_block = all_truth.iloc[i:end]

            if len(pred_block) == 0:
                break
          
            mae_block = mean_absolute_error(truth_block, pred_block)
            rmse_block = np.sqrt(mean_squared_error(truth_block, pred_block))

            squared_diff = (truth_block - pred_block)**2
            sum_squared_diff = np.sum(squared_diff)
            squared_diff2 = (truth_block - truth_block.mean())**2
            sum_squared_diff2 = np.sum(squared_diff2)

            if sum_squared_diff2 == 0:
                nse_block = np.nan
            else:
                nse_block = 1 - (sum_squared_diff / sum_squared_diff2)

            evaluate_monthly.append({
                "Stationsname": station,
                "Block Index": i // month,
                "Block Start": pred_block.index[0],
                "Block Ende": pred_block.index[-1],
                "MAE Block": mae_block,
                "RMSE Block": rmse_block,
                "NSE Block": nse_block
            })

        evaluate_monthly_df = pd.DataFrame(evaluate_monthly)
        all_monthly_eval_list.append(evaluate_monthly_df)

        
        # Calculate evaluation metrics for the whole test set per station    
        rmse = np.sqrt(mean_squared_error(test_water["Abfluss in m^3/s"].reindex(forecast_series.index), forecast_series))
        mae = mean_absolute_error(test_water["Abfluss in m^3/s"].reindex(forecast_series.index), forecast_series)
        nse = 1 - np.sum((test_water["Abfluss in m^3/s"].reindex(forecast_series.index) - forecast_series)**2) / np.sum((test_water["Abfluss in m^3/s"].reindex(forecast_series.index) - np.mean(test_water["Abfluss in m^3/s"].reindex(forecast_series.index)))**2)
        results.append({
            "Stationsname": station,
            "RMSE": rmse,
            "MAE": mae,
            "NSE": nse
        })

            
        print(f"{station}: Finished forecasting. Forecasting months {i // 720 + 1}")
        print(forecast_series.describe())

    # create a data frame for every evaluation metric an sort them.
    results_rmse_df = pd.DataFrame(results).sort_values(by="RMSE")
    results_mae_df = pd.DataFrame(results).sort_values(by="MAE")
    results_nse_df = pd.DataFrame(results).sort_values(by="NSE", ascending=False)

    # concatenate hourly and monthly evaluation metrics and for every station and the metrics for every maximum week individually and overall.  
    all_hourly_eval_df = pd.concat(all_hourly_eval_list, ignore_index=True)
    all_monthly_eval_df = pd.concat(all_monthly_eval_list, ignore_index=True)
    all_evaluate_max_week_df = pd.concat(all_evaluate_max_week_list, ignore_index=True)
    overall_max_week_metrics_df = pd.DataFrame(overall_max_week_metrics)

    

    # store the different evaluation metrics and times as csv file.
    results_rmse_df.to_csv("Evaluation/Random_Forest_Gesamtmetriken_RMSE_72h.csv", index=False)
    results_mae_df.to_csv("Evaluation/Random_Forest_Gesamtmetriken_MAE_72h.csv", index=False)
    results_nse_df.to_csv("Evaluation/Random_Forest_Gesamtmetriken_NSE_72h.csv", index=False)
    all_hourly_eval_df.to_csv("Evaluation/Random_Forest_Metriken_stündlich_72h.csv", index=False)
    all_monthly_eval_df.to_csv("Evaluation/Random_Forest_Metriken_monatlich_72h.csv", index=False)
    all_evaluate_max_week_df.to_csv("Evaluation/Random_Forest_Metriken_maximum_wochen_72h.csv", index=False)
    overall_max_week_metrics_df.to_csv("Evaluation/Random_Forest_Metriken_durchschnittlich_über_maximum_wochen_72h.csv", index=False)
    
    return results_rmse_df, results_mae_df, results_nse_df, all_forecasts, all_hourly_eval_df, all_monthly_eval_df

final_model_fitting()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Gießen Argen: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean        19.883943
# std          9.807463
# min          5.651118
# 25%         12.531161
# 50%         17.905842
# 75%         26.113426
# max         60.508589
# dtype: float64
# Blaubeuren Blau: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         2.508638
# std          1.476970
# min          0.760527
# 25%          1.338528
# 50%          2.246235
# 75%          3.057753
# max         10.119200
# dtype: float64
# Bolheim Brenz: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         4.403670
# std          1.600583
# min          2.158091
# 25%          3.357734
# 50%          4.031530
# 75%          5.152789
# max         10.439558
# dtype: float64
# Beuron Donau: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean        11.928497
# std         12.047137
# min          1.029266
# 25%          2.726972
# 50%          6.680116
# 75%         18.418969
# max         73.864970
# dtype: float64
# Hundersingen Donau: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean        24.326956
# std         17.212343
# min          6.531856
# 25%         11.019585
# 50%         18.107765
# 75%         33.539187
# max        103.864803
# dtype: float64
# Wannweil Echaz: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         2.596336
# std          1.296831
# min          0.708868
# 25%          1.623332
# 50%          2.317876
# 75%          3.269489
# max         10.259946
# dtype: float64
# Eutingen Enz: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean        16.352507
# std          9.068775
# min          5.271557
# 25%          8.817492
# 50%         14.658580
# 75%         21.394351
# max         67.681174
# dtype: float64
# Elpershofen Jagst: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         8.085982
# std          6.604714
# min          1.453841
# 25%          3.057966
# 50%          5.734527
# 75%         11.601611
# max         44.110687
# dtype: float64
# Hausach Kinzig: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean        15.609101
# std         11.778624
# min          3.052649
# 25%          6.319974
# 50%         12.439396
# 75%         21.386197
# max         73.009342
# dtype: float64
# Hüttlingen Kocher: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         2.004641
# std          1.124433
# min          0.659621
# 25%          1.078466
# 50%          1.712773
# 75%          2.588396
# max          6.444938
# dtype: float64
# Mägerkingen Lauchert: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         0.702833
# std          0.549858
# min          0.079141
# 25%          0.267644
# 50%          0.590780
# 75%          0.971636
# max          4.178186
# dtype: float64
# Wiesloch Leimbach: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         0.605472
# std          0.184358
# min          0.289330
# 25%          0.468432
# 50%          0.587279
# 75%          0.728361
# max          1.327381
# dtype: float64
# Riegel Leopoldskanal: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean        12.449351
# std         12.458508
# min          1.038213
# 25%          2.190361
# 50%          8.686544
# 75%         18.905473
# max         72.093974
# dtype: float64
# Bad Rotenfels Murg: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean        15.886550
# std         10.872616
# min          2.782994
# 25%          7.423100
# 50%         13.605570
# 75%         20.801156
# max         69.133023
# dtype: float64
# Baiersbronn Murg: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         2.875377
# std          1.838328
# min          0.675372
# 25%          1.381691
# 50%          2.538712
# 75%          3.738177
# max         11.928560
# dtype: float64
# Horb Neckar: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean        13.816584
# std          8.685365
# min          3.562619
# 25%          6.777721
# 50%         11.234542
# 75%         18.942827
# max         61.356107
# dtype: float64
# Rielasingen Radolfzeller Aach: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         9.206069
# std          3.694001
# min          3.058635
# 25%          6.353244
# 50%          9.328497
# 75%         11.423051
# max         21.354704
# dtype: float64
# Konstanz Rhein: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean       322.672956
# std        127.806838
# min        173.404816
# 25%        227.673706
# 50%        294.950699
# 75%        367.720235
# max        782.514911
# dtype: float64
# Binnrot Rot: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         1.945931
# std          0.727338
# min          0.898500
# 25%          1.323861
# 50%          1.806590
# 75%          2.400262
# max          5.032292
# dtype: float64
# Tauberbischofsheim Tauber: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         8.955692
# std          5.843109
# min          2.593178
# 25%          4.354309
# 50%          7.787356
# 75%         11.190714
# max         43.656208
# dtype: float64
# Rengers Untere Argen: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         4.448377
# std          2.531738
# min          0.770573
# 25%          2.528278
# 50%          3.848401
# 75%          5.930917
# max         17.200991
# dtype: float64
# Zell Wiese: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         7.516464
# std          5.595965
# min          1.207060
# 25%          2.957604
# 50%          6.403478
# 75%          9.905197
# max         37.768587
# dtype: float64
# Ewattingen Wutach: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         5.758703
# std          4.134818
# min          1.104281
# 25%          2.229873
# 50%          4.696940
# 75%          7.920009
# max         27.982130
# dtype: float64
# Oberlauchringen Wutach: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         9.035462
# std          6.058296
# min          1.994940
# 25%          4.000385
# 50%          7.330407
# 75%         12.752228
# max         40.392681
# dtype: float64
# Hausen Zaber: Finished forecasting. Forecasting months 37
# count    26232.000000
# mean         0.530227
# std          0.230915
# min          0.204634
# 25%          0.358929
# 50%          0.475559
# 75%          0.654775
# max          1.924084
# dtype: float64
# (                     Stationsname       RMSE        MAE       NSE
#  11              Wiesloch Leimbach   0.377616   0.157165  0.169566
#  10           Mägerkingen Lauchert   0.451832   0.185157  0.582659
