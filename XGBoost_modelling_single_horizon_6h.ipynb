# %% [markdown]
# # XGBoost - Anwendung (Lead Time 6 Stunden)

# %% [markdown]
# ### Feature Creation
# In diesem Block wird die Attributmatrix für die Modellierung erstellt. Dazu werden Zeitmerkmale aus dem Zeitindex abgeleitet ("Stunde", "Tage in einer Woche", "Monat", "Viertel Jahr", "Jahr", "Tage im Jahr"). Zusätzlich werden zyklische Zeitinformationen über Sinus und Cosinus ("Sinus Tag", "Cosinus Tag", "Sinus Jahr", "Cosinus Jahr") abgebildet, damit die Modelle periodische Muster lernen können.
# Darüber hinaus werden Lag-Features erzeugt (1, 3, 6, 12, 24, 48, 72, 168, 720, 8760 Stunden), um Informationen aus der Vergangenheit in die Vorhersage einzubeziehen (Von Bedeutung wegen Autokorrelation in Abflusszeitreihen). Diese gehen als Spalten "Abfluss in m^3/s_lag{lag}" in die Attributmatrix ein.
# Da Niederschlag häufig zeitverzögert auf den Abfluss wirkt, werden auch die zugeordneten Niederschlagszeitreihen um 0, 1, 3, 6, 12, 24, 36, 48 Stunden verschoben. Diese Merkmale werden als "{column}_lag{lag}" ergänzt. Die konstanten Spalten "Stationsname", "Gewässer", "Interpoliert" werden abschließend entfernt.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import glob

# Create new time series for all 25 stations which is enriched by feauters an which based on datetime index.
def feature_creation_nan():
    all_merged_files_nan=glob.glob("Datensätze/UDO-LUBW/Endgültige Auswahl Landespegel Hydrologie/Gewässer/*/*/*_merged_nan.csv")

    
    all_water_stations = []
    for a in all_merged_files_nan:
        p = Path(a)
        
        # read the respective file as a data frame.
        df_water_station = pd.read_csv(p, sep=",", index_col="Datum / Uhrzeit", parse_dates=["Datum / Uhrzeit"], encoding="utf-8")

        df_water_station = df_water_station.sort_index()
        
        # save "Stationsname" and "Gewässer" separately. I will drop them later on in the features.
        station_and_water = df_water_station[["Stationsname", "Gewässer"]]
        
        # defining time features by creating them from the datetime index
        df_water_station["Stunde"] = df_water_station.index.hour
        df_water_station["Tage in einer Woche"] = df_water_station.index.dayofweek
        df_water_station["Monat"] = df_water_station.index.month
        df_water_station["Viertel Jahr"] = df_water_station.index.quarter
        df_water_station["Jahr"] = df_water_station.index.year
        df_water_station["Tage im Jahr"] = df_water_station.index.dayofyear


        # defining cyclic features by calculating daily and yearly cycles (as sinus and cosinus).
        df_water_station["Sinus Tag"] = np.sin(2 * np.pi * df_water_station["Stunde"] / 24)
        df_water_station["Cosinus Tag"] = np.cos(2 * np.pi * df_water_station["Stunde"] / 24)
        df_water_station["Sinus Jahr"] = np.sin(2 * np.pi * df_water_station["Tage im Jahr"] / 365)
        df_water_station["Cosinus Jahr"] = np.cos(2 * np.pi * df_water_station["Tage im Jahr"] / 365)

        # defining lag features by shifting the original "Abfluss in m^3/s" to enable connecting with past surface runoff.
        # store them in a separate data frame to avoid warnings
        lags_water = {}
        for lag in [1, 3, 6, 12, 24, 48, 72, 168, 720, 8760]:
            lags_water[f"Abfluss in m^3/s_lag{lag}"] = df_water_station["Abfluss in m^3/s"].shift(lag)
        df_lags_water = pd.DataFrame(lags_water, index=df_water_station.index)

        # defining lag features for exogenous variables by shifting the original precipitation columns to capture their delayed impact on the surface runoff. 
        # store them in a separate data frame to avoid warnings
        lags_exogene = {}
        for column in df_water_station.filter(regex=r"^Niederschlag").columns:
            for lag in [0, 1, 3, 6, 12, 24, 36, 48]:
                lags_exogene[f"{column}_lag{lag}"] = df_water_station[column].shift(lag)
        df_lags_exogene = pd.DataFrame(lags_exogene, index=df_water_station.index)

        # Concatenate the data frames to one
        df_water_station = pd.concat([df_water_station, df_lags_water, df_lags_exogene], axis=1)
        

        # remove static columns or columns that are not used as features for the model
        df_water_station = df_water_station.drop(columns=["Stationsname", "Gewässer", "Interpoliert"])
                
        all_water_stations.append({
            "Stationsname": station_and_water["Stationsname"].iloc[0],
            "Gewässer": station_and_water["Gewässer"].iloc[0],
            "df": df_water_station
        })
        print(f"Create features for {p.name}.")

    return all_water_stations

feature_creation_nan()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# [{'Stationsname': 'Gießen Argen',
#   'Gewässer': 'Argen',
#   'df':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            78.308                      0.0
#   2010-01-01 01:00:00            75.247                      0.0
#   2010-01-01 02:00:00            73.206                      0.0
#   2010-01-01 03:00:00            69.861                      0.0
#   2010-01-01 04:00:00            67.697                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            11.832                      0.0
#   2024-12-31 20:00:00            11.037                      0.0
#   2024-12-31 21:00:00            10.951                      0.0
#   2024-12-31 22:00:00            10.797                      0.0
#   2024-12-31 23:00:00            10.783                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Blaubeuren Blau',
#   'Gewässer': 'Blau',
#   'df':                      Abfluss in m^3/s  Niederschlag 2814 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             5.580                      0.0
#   2010-01-01 01:00:00             5.555                      0.0
#   2010-01-01 02:00:00             5.562                      0.0
#   2010-01-01 03:00:00             5.568                      0.0
#   2010-01-01 04:00:00             5.597                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             2.573                      0.0
#   2024-12-31 20:00:00             2.635                      0.0
#   2024-12-31 21:00:00             2.450                      0.0
#   2024-12-31 22:00:00             2.488                      0.0
#   2024-12-31 23:00:00             2.428                      0.0
#
#                        Niederschlag 5511 in mm  Niederschlag 3418 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3418 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3418 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 57 columns]},
#  {'Stationsname': 'Bolheim Brenz',
#   'Gewässer': 'Brenz',
#   'df':                      Abfluss in m^3/s  Niederschlag 3440 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             4.161                      0.0
#   2010-01-01 01:00:00             4.161                      0.0
#   2010-01-01 02:00:00             3.967                      0.0
#   2010-01-01 03:00:00             3.967                      0.0
#   2010-01-01 04:00:00             3.967                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             4.098                      0.0
#   2024-12-31 20:00:00             4.040                      0.0
#   2024-12-31 21:00:00             3.962                      0.0
#   2024-12-31 22:00:00             3.871                      0.0
#   2024-12-31 23:00:00             3.982                      0.0
#
#                        Niederschlag 7331 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 7331 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 7331 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Beuron Donau',
#   'Gewässer': 'Donau',
#   'df':                      Abfluss in m^3/s  Niederschlag 2638 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            74.509                      0.0
#   2010-01-01 01:00:00            74.509                      0.0
#   2010-01-01 02:00:00            75.483                      0.0
#   2010-01-01 03:00:00            75.483                      0.0
#   2010-01-01 04:00:00            75.483                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            14.078                      0.0
#   2024-12-31 20:00:00            14.012                      0.0
#   2024-12-31 21:00:00            13.903                      0.0
#   2024-12-31 22:00:00            13.838                      0.0
#   2024-12-31 23:00:00            13.765                      0.0
#
#                        Niederschlag 4703 in mm  Niederschlag 3519 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3519 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3519 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
# ...
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Hausen Zaber',
#   'Gewässer': 'Zaber',
#   'df':                      Abfluss in m^3/s  Niederschlag 4349 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             1.417                      0.0
#   2010-01-01 01:00:00             1.417                      0.0
#   2010-01-01 02:00:00             1.334                      0.0
#   2010-01-01 03:00:00             1.334                      0.0
#   2010-01-01 04:00:00             1.334                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             0.486                      0.0
#   2024-12-31 20:00:00             0.487                      0.0
#   2024-12-31 21:00:00             0.487                      0.0
#   2024-12-31 22:00:00             0.486                      0.0
#   2024-12-31 23:00:00             0.485                      0.0
#
#                        Niederschlag 3734 in mm  Niederschlag 7238 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag 7498 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  ...  \
#   Datum / Uhrzeit                                                        ...
#   2010-01-01 00:00:00       0                    4      1             1  ...
#   2010-01-01 01:00:00       1                    4      1             1  ...
#   2010-01-01 02:00:00       2                    4      1             1  ...
#   2010-01-01 03:00:00       3                    4      1             1  ...
#   2010-01-01 04:00:00       4                    4      1             1  ...
#   ...                     ...                  ...    ...           ...  ...
#   2024-12-31 19:00:00      19                    1     12             4  ...
#   2024-12-31 20:00:00      20                    1     12             4  ...
#   2024-12-31 21:00:00      21                    1     12             4  ...
#   2024-12-31 22:00:00      22                    1     12             4  ...
#   2024-12-31 23:00:00      23                    1     12             4  ...
#
#                        Niederschlag 7498 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 7498 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 66 columns]}]

# %% [markdown]
# ## Hyperparameter Tuning mit Cross Validation

# %% [markdown]
# ### Teilung in Trainings- und Testset
# In diesem Block werden alle Zeitreihen zeitbasiert in Trainings- und Testsets aufgeteilt. Das Trainingsset umfasst alle Einträge von 2010 bis einschließlich 2021 (Zeitstempel vor dem 0.01.2022). Die späteren Einträge werden dem Testset zugeordnet.

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import glob

# split the stations time series in train and test sets
def train_and_test_nan():
    # create the features for every station
    water_stations = feature_creation_nan()
    train_test_nan = []

    # defining the timestamp separating the train and test data
    split_train_test = pd.Timestamp("2022-01-01")
    for a in water_stations:
        
        # defining important information to identify the correct train and test set for the respective station
        water = a["Gewässer"]
        station = a["Stationsname"]
        df_water_station = a["df"]

        # splitting the respective time series into train and test data (ratio: 80% train set, 20% test set)
        # (train set until 2021-12-31, test set from 2022-01-01)
        train_data = df_water_station[df_water_station.index < split_train_test]
        test_data = df_water_station[df_water_station.index >= split_train_test]

        # store the respective split with the meta data in train_test_nan
        train_test_nan.append({
            "Gewässer": water, "Stationsname": station, "Trainingsset": train_data, "Testset": test_data
        })

        print(f"Created train ({len(train_data)} rows) and test data ({len(test_data)} rows) for {station}.")

    return train_test_nan



train_and_test_nan()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# [{'Gewässer': 'Argen',
#   'Stationsname': 'Gießen Argen',
#   'Trainingsset':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            78.308                      0.0
#   2010-01-01 01:00:00            75.247                      0.0
#   2010-01-01 02:00:00            73.206                      0.0
#   2010-01-01 03:00:00            69.861                      0.0
#   2010-01-01 04:00:00            67.697                      0.0
#   ...                               ...                      ...
#   2021-12-31 19:00:00            49.543                      0.0
#   2021-12-31 20:00:00            48.711                      0.0
#   2021-12-31 21:00:00            47.784                      0.0
#   2021-12-31 22:00:00            47.063                      0.0
#   2021-12-31 23:00:00            46.322                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2021-12-31 19:00:00                      0.0                              0.0
#   2021-12-31 20:00:00                      0.0                              0.0
#   2021-12-31 21:00:00                      0.0                              0.0
#   2021-12-31 22:00:00                      0.0                              0.0
#   2021-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2021-12-31 19:00:00      19                    4     12             4  2021
#   2021-12-31 20:00:00      20                    4     12             4  2021
#   2021-12-31 21:00:00      21                    4     12             4  2021
#   2021-12-31 22:00:00      22                    4     12             4  2021
#   2021-12-31 23:00:00      23                    4     12             4  2021
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2021-12-31 19:00:00           365  ...                            0.1
#   2021-12-31 20:00:00           365  ...                            0.0
#   2021-12-31 21:00:00           365  ...                            0.0
#   2021-12-31 22:00:00           365  ...                            0.0
#   2021-12-31 23:00:00           365  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2021-12-31 19:00:00                            3.1
#   2021-12-31 20:00:00                            0.3
#   2021-12-31 21:00:00                            0.1
#   2021-12-31 22:00:00                            0.1
#   2021-12-31 23:00:00                            0.4
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                   0.05
#   2021-12-31 20:00:00                                   0.05
#   2021-12-31 21:00:00                                   0.00
#   2021-12-31 22:00:00                                   0.00
#   2021-12-31 23:00:00                                   0.00
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                   2.45
#   2021-12-31 20:00:00                                   0.50
#   2021-12-31 21:00:00                                   0.40
#   2021-12-31 22:00:00                                   0.65
#   2021-12-31 23:00:00                                   0.90
#
#   [105192 rows x 48 columns],
#   'Testset':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00            45.612                      0.0
#   2022-01-01 01:00:00            44.763                      0.0
#   2022-01-01 02:00:00            44.163                      0.0
#   2022-01-01 03:00:00            43.402                      0.0
#   2022-01-01 04:00:00            42.720                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            11.832                      0.0
#   2024-12-31 20:00:00            11.037                      0.0
#   2024-12-31 21:00:00            10.951                      0.0
#   2024-12-31 22:00:00            10.797                      0.0
#   2024-12-31 23:00:00            10.783                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.0                              0.0
#   2022-01-01 01:00:00                      0.0                              0.0
#   2022-01-01 02:00:00                      0.0                              0.0
#   2022-01-01 03:00:00                      0.0                              0.0
#   2022-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00       0                    5      1             1  2022
#   2022-01-01 01:00:00       1                    5      1             1  2022
#   2022-01-01 02:00:00       2                    5      1             1  2022
#   2022-01-01 03:00:00       3                    5      1             1  2022
#   2022-01-01 04:00:00       4                    5      1             1  2022
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2022-01-01 00:00:00             1  ...                            0.0
#   2022-01-01 01:00:00             1  ...                            0.0
#   2022-01-01 02:00:00             1  ...                            0.0
#   2022-01-01 03:00:00             1  ...                            0.0
#   2022-01-01 04:00:00             1  ...                            0.0
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.3
#   2022-01-01 01:00:00                            0.2
#   2022-01-01 02:00:00                            0.1
#   2022-01-01 03:00:00                            0
      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             0.486                      0.0
#   2024-12-31 20:00:00             0.487                      0.0
#   2024-12-31 21:00:00             0.487                      0.0
#   2024-12-31 22:00:00             0.486                      0.0
#   2024-12-31 23:00:00             0.485                      0.0
#
#                        Niederschlag 3734 in mm  Niederschlag 7238 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.1                      0.0
#   2022-01-01 01:00:00                      0.0                      0.0
#   2022-01-01 02:00:00                      0.1                      0.0
#   2022-01-01 03:00:00                      0.0                      0.0
#   2022-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag 7498 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.0                            0.025
#   2022-01-01 01:00:00                      0.1                            0.025
#   2022-01-01 02:00:00                      0.1                            0.050
#   2022-01-01 03:00:00                      0.0                            0.000
#   2022-01-01 04:00:00                      0.0                            0.000
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                            0.000
#   2024-12-31 20:00:00                      0.0                            0.000
#   2024-12-31 21:00:00                      0.0                            0.000
#   2024-12-31 22:00:00                      0.0                            0.000
#   2024-12-31 23:00:00                      0.0                            0.000
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  ...  \
#   Datum / Uhrzeit                                                        ...
#   2022-01-01 00:00:00       0                    5      1             1  ...
#   2022-01-01 01:00:00       1                    5      1             1  ...
#   2022-01-01 02:00:00       2                    5      1             1  ...
#   2022-01-01 03:00:00       3                    5      1             1  ...
#   2022-01-01 04:00:00       4                    5      1             1  ...
#   ...                     ...                  ...    ...           ...  ...
#   2024-12-31 19:00:00      19                    1     12             4  ...
#   2024-12-31 20:00:00      20                    1     12             4  ...
#   2024-12-31 21:00:00      21                    1     12             4  ...
#   2024-12-31 22:00:00      22                    1     12             4  ...
#   2024-12-31 23:00:00      23                    1     12             4  ...
#
#                        Niederschlag 7498 in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.0
#   2022-01-01 01:00:00                            0.0
#   2022-01-01 02:00:00                            0.1
#   2022-01-01 03:00:00                            0.4
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 7498 in mm_lag48  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.0
#   2022-01-01 01:00:00                            0.0
#   2022-01-01 02:00:00                            0.0
#   2022-01-01 03:00:00                            0.0
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                 0.025
#   2022-01-01 01:00:00                                 0.025
#   2022-01-01 02:00:00                                 0.050
#   2022-01-01 03:00:00                                 0.000
#   2022-01-01 04:00:00                                 0.000
#   ...                                                   ...
#   2024-12-31 19:00:00                                 0.000
#   2024-12-31 20:00:00                                 0.000
#   2024-12-31 21:00:00                                 0.000
#   2024-12-31 22:00:00                                 0.000
#   2024-12-31 23:00:00                                 0.000
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                 0.000
#   2022-01-01 01:00:00                                 0.025
#   2022-01-01 02:00:00                                 0.025
#   2022-01-01 03:00:00                                 0.050
#   2022-01-01 04:00:00                                 0.000
#   ...                                                   ...
#   2024-12-31 19:00:00                                 0.000
#   2024-12-31 20:00:00                                 0.000
#   2024-12-31 21:00:00                                 0.000
#   2024-12-31 22:00:00                                 0.000
#   2024-12-31 23:00:00                                 0.000
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                 0.000
#   2022-01-01 01:00:00                                 0.000
#   2022-01-01 02:00:00                                 0.000
#   2022-01-01 03:00:00                                 0.025
#   2022-01-01 04:00:00                                 0.025
#   ...                                                   ...
#   2024-12-31 19:00:00                                 0.000
#   2024-12-31 20:00:00                                 0.000
#   2024-12-31 21:00:00                                 0.000
#   2024-12-31 22:00:00                                 0.000
#   2024-12-31 23:00:00                                 0.000
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                  0.000
#   2022-01-01 01:00:00                                  0.000
#   2022-01-01 02:00:00                                  0.025
#   2022-01-01 03:00:00                                  0.100
#   2022-01-01 04:00:00                                  0.050
#   ...                                                    ...
#   2024-12-31 19:00:00                                  0.000
#   2024-12-31 20:00:00                                  0.000
#   2024-12-31 21:00:00                                  0.000
#   2024-12-31 22:00:00                                  0.000
#   2024-12-31 23:00:00                                  0.000
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                  0.025
#   2022-01-01 01:00:00                                  0.000
#   2022-01-01 02:00:00                                  0.000
#   2022-01-01 03:00:00                                  0.000
#   2022-01-01 04:00:00                                  0.000
#   ...                                                    ...
#   2024-12-31 19:00:00                                  0.000
#   2024-12-31 20:00:00                                  0.000
#   2024-12-31 21:00:00                                  0.000
#   2024-12-31 22:00:00                                  0.000
#   2024-12-31 23:00:00                                  0.000
#
#   [26304 rows x 66 columns]}]

# %% [markdown]
# ### Hyperparameter-Optimierung
# In diesem Abschnitt werden die Hyperparameter des XGBoost für die spätere Vorhersage der Testsets aller 25 Zeitreihen optimiert. Für das Tuning werden drei repräsentative Zeitreihen verwendet, die anhand des Variationskoeffizienten (hoch, mittel, niedrig) ausgewählt wurden ("Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein").
# Es wird eine Grid-Search mit TimeSeriesSplit-Cross-Validation durchgeführt. Pro Station werden 7 Folds verwendet. Das Validierungsset umfasst dabei jeweils 720 Stunden. Zur Vermeidung von Leakage wird eine Lücke von 6 Stunden ("gap=6") zwischen trainingsset und Validierungsset gesetzt. Die Zielgröße ist dabei eine 6-Stunden-Vorhersage (y=Abfluss(t+6)).
# Bewertet werden hier RMSE, MAE und NSE. Der Output zeigt dabei die Hyperparameterkombination mit dem niedrigsten mittleren RMSE und MAE sowie der höchsten mittleren NSE über alle Folds und repräsentativen Stationen.
# Als primäres Auswahlkriterium wurde die NSE verwendet. Darüber hinaus wurde die Diferenz zwischen Trainings-NSE und Validierungs-NSE ("nse gap") betrachtet, um ggfs. ein mögliches Overfitting zu erkennen und diesem später entgegenwirken zu können. Randbemerkung: Mit horizon ist die Lead Time der Vorhersage gemeint, also t --> Q(t+6)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
from itertools import product
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


def hyper_parameter_tuning_cross_validation():
    train_test = train_and_test_nan()

    # define possible parameters
    params = {
                "n_estimators": [100, 200, 300, 500],
                "max_depth": [3, 6, 8],
                "learning_rate": [0.05, 0.1],
                "subsample": np.linspace(0.5, 1.0, 3),
                "colsample_bytree": np.linspace(0.5, 1.0, 3),
            }
    keys = params.keys()
    values = params.values()
    params_columns = list(keys)

    # create all hyperparameter combinations a list of dictionaries. Each of them containing one hyper parameter combination.
    dict_all_combination = []
    all_combination = list(product(*values))
    for c in all_combination:
        dict_combination = dict(zip(keys, c))
        dict_all_combination.append(dict_combination)
            
    pred = []
    scores = []

    # try every hyperparameter combination of the grid.
    for d in dict_all_combination:
        selected_stations = ["Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein"]
        selected_train_test = [t for t in train_test if t["Stationsname"] in selected_stations]

       
        for t in selected_train_test:
            train_water = t["Trainingsset"].copy()
            train_water = train_water.sort_index()
            # define lead time to forecast six hour in the future: Q(t) --> Q(t+6).
            train_water["y"] = train_water["Abfluss in m^3/s"].shift(-6)
    
            # the last six rows of y are NaNs due to the shift by six hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
            train_water = train_water.dropna(subset=["y"])
    
            # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast. We keep "Abfluss in m^3/s" as current value and the last known runoff which is important for the prediction. 
            x = train_water.drop(columns=["y"])
            y = train_water["y"]
            
            station = t["Stationsname"]
    
            # define Time Series Spliit for the Cross validation. We evaluate the model on 720 hour validation windows using six hour forecasts. 
            # To avoid leakage between train and validation I use a gap of six hours.
            tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=6)
            fold = 0

            # split the train set into seven folds for the cross validation and use XGBoostRegressor with the respective hyperparameter combination.
            for train_idx, validation_idx in tss.split(x):
                fold += 1
                x_train = x.iloc[train_idx]
                x_validation = x.iloc[validation_idx]
                y_train = y.iloc[train_idx]
                y_validation = y.iloc[validation_idx]
                
                model = xgb.XGBRegressor(
                    **d,
                    base_score=0.5, 
                    tree_method="hist", 
                    n_jobs = -1, 
                    random_state=42,
                    eval_metric="rmse"
                )
                    
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_validation, y_validation)],
                    verbose=100
                )
                
                
                # this is needed to predict the validation set    
                y_pred_validation = model.predict(x_validation)
                pred.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold, 
                    "Vorhersage": y_pred_validation
                 })

                # this is needed to check for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting
                y_pred_train = model.predict(x_train)

                # calculate the evaluation metrics for the validation set forecast in the cross validation
                rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
                mae_validation = mean_absolute_error(y_validation, y_pred_validation)
                nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

                # calculate the evaluation metrics for the training set forecast in the cross validation to compare them with the claculated metrics in the validation set forecast.
                rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
                mae_train = mean_absolute_error(y_train, y_pred_train)
                nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)

                # store information about the respective hyperparameter, station and fold with the corresponding metrics
                scores.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold,
                    "rmse validation": rmse_validation,
                    "mae validation": mae_validation,
                    "nse validation": nse_validation,
                    "rmse train": rmse_train,
                    "mae train": mae_train,
                    "nse train": nse_train,
                })
                print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
                print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
                print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station and hyperparameter combination
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby(["Stationsname"] + params_columns)[["rmse validation", "mae validation", "nse validation", "rmse train", "mae train", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "rmse train": "mean_rmse_train", "mae train": "mean_mae_train", "nse train": "mean_nse_train"})

    # calculate the mean evaluation metrics of all stations with the same hyperparameter configurations to find the best hyper parameter combination for all stations. We also want to calculate the evaluation metrics in the train set to identify if the model realy learns to regularize ore just to memorize if the metrics in the train set are much betterthan the metrics in the validation set.
    mean_per_hyper_parameter = mean_per_station.groupby(params_columns)[["mean_rmse_validation", "mean_mae_validation", "mean_nse_validation", "mean_rmse_train", "mean_mae_train", "mean_nse_train"]].mean()
    mean_per_hyper_parameter = mean_per_hyper_parameter.reset_index()
    mean_per_hyper_parameter["nse gap"] = mean_per_hyper_parameter["mean_nse_train"] - mean_per_hyper_parameter["mean_nse_validation"]

    # sort the evaluation metrics to show the best hyperparameter for the best metric
    sorted_rmse = mean_per_hyper_parameter.sort_values("mean_rmse_validation")
    sorted_mae = mean_per_hyper_parameter.sort_values("mean_mae_validation")
    sorted_nse = mean_per_hyper_parameter.sort_values("mean_nse_validation", ascending=False)

    # define the best hyperparameters per evaluation metric
    best_hp_rmse = sorted_rmse[params_columns].iloc[0]
    best_hp_mae = sorted_mae[params_columns].iloc[0]
    best_hp_nse = sorted_nse[params_columns].iloc[0]

    print(f"Best Hyperparameter combination with lowest mean rmse for all stations are {best_hp_rmse} with mean rmse {sorted_rmse['mean_rmse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_rmse['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean mae for all stations are {best_hp_mae} with mean mae {sorted_mae['mean_mae_validation'].iloc[0]} with nse gap between train and validation of: {sorted_mae['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean nse for all stations are {best_hp_nse} with mean nse {sorted_nse['mean_nse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_nse['nse gap'].iloc[0]}.")

    return best_hp_rmse, best_hp_mae, best_hp_nse

hyper_parameter_tuning_cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# [0]	validation_0-rmse:11.11598
# [99]	validation_0-rmse:3.05927
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.0592663283874817.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.575067166973485.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8304915257947089.
# [0]	validation_0-rmse:24.86411
# [99]	validation_0-rmse:5.91384
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 5.913841657947517.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.9663174773322214.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9300689871448121.
# [0]	validation_0-rmse:3.67231
# [99]	validation_0-rmse:1.66691
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.666908778345019.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6240319259206454.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.3935980636667612.
# [0]	validation_0-rmse:1.30827
# [99]	validation_0-rmse:0.46739
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.46738531713222226.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3391064079218441.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.34937747158561594.
# [0]	validation_0-rmse:2.04590
# [99]	validation_0-rmse:0.70019
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7001913762514097.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4955165337655279.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7438336894151363.
# [0]	validation_0-rmse:2.51791
# [99]	validation_0-rmse:0.78887
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7888664955647148.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5175201590286361.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7468930012790134.
# [0]	validation_0-rmse:20.88036
# [99]	validation_0-rmse:3.65132
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.651321000896527.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.6978207391341527.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9469188300374796.
# [0]	validation_0-rmse:0.48807
# [99]	validation_0-rmse:0.14542
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.14541585673847512.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06104838573071692.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9079385104486765.
# [0]	validation_0-rmse:1.60220
# [99]	validation_0-rmse:0.33954
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.3395397331043366.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14837177578873104.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8915309467653472.
# [0]	validation_0-rmse:0.42156
# [99]	validation_0-rmse:0.11987
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11986759813462725.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05343822293347782.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8756729083529152.
# [0]	validation_0-rmse:0.21113
# [99]	validation_0-rmse:0.04343
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04342898093733172.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.025983755484885643.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9428424362853063.
# [0]	validation_0-rmse:0.27438
# [99]	validation_0-rmse:0.03625
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.036254798829947074.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.022096894981794887.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7207054297475616.
# [0]	validation_0-rmse:0.34251
# [99]	validation_0-rmse:0.01660
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01660292298694575.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.01254945688255959.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7792435369684525.
# [0]	validation_0-rmse:0.38329
# [99]	validation_0-rmse:0.05910
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.059097776215296986.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03769332746532228.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9712287023561819.
# [0]	validation_0-rmse:517.42170
# [99]	validation_0-rmse:6.72010
# Calculated CV RMSE for Konstanz Rhein with RMSE: 6.720099105072417.
# Calculated CV MAE for Konstanz Rhein with MAE: 6.068122072686091.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9765201801062816.
# [0]	validation_0-rmse:647.59984
# [99]	validation_0-rmse:11.58494
# Calculated CV RMSE for Konstanz Rhein with RMSE: 11.584937673675151.
# Calculated CV MAE for Konstanz Rhein with MAE: 9.205902328830295.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9647275207139658.
# [0]	validation_0-rmse:611.28761
# [99]	validation_0-rmse:6.68375
# Calculated CV RMSE for Konstanz Rhein with RMSE: 6.683746809804263.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.2300423597547745.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9872124911873322.
# [0]	validation_0-rmse:417.42644
# [99]	validation_0-rmse:1.52428
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.5242856097946305.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.1934546234130852.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.99968896195177.
# [0]	validation_0-rmse:240.35114
# [99]	validation_0-rmse:1.63464
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.634642817065001.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.3295872767130534.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9959560079982902.
# [0]	validation_0-rmse:195.83854
# [99]	validation_0-rmse:1.28314
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.2831374594910416.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.0522464318169478.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9622606566810638.
# [0]	validation_0-rmse:202.93144
# [99]	validation_0-rmse:2.47792
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.4779197008192604.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.9445327472262919.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.940405393930546.
# [0]	validation_0-rmse:11.11598
# [99]	validation_0-rmse:3.04642
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.046421347271433.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.541677925423781.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8319119723452959.
# [0]	validation_0-rmse:24.86411
# [99]	validation_0-rmse:5.84255
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 5

# Calculated CV NSE for Konstanz Rhein with NSE: 0.9869707576584733.
# [0]	validation_0-rmse:417.42655
# [99]	validation_0-rmse:1.62503
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.6250294451267295.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.2988343573676215.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9996464887101216.
# [0]	validation_0-rmse:240.34140
# [99]	validation_0-rmse:1.65274
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.652742825311007.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.351548590257433.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9958659558715601.
# [0]	validation_0-rmse:195.75476
# [99]	validation_0-rmse:1.24898
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.2489851813939736.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.0205881513807498.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.964242879110725.
# [0]	validation_0-rmse:202.97650
# [99]	validation_0-rmse:2.60765
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.6076506164631024.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.0203754845513244.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9340019200384664.
# [0]	validation_0-rmse:11.11608
# [99]	validation_0-rmse:2.75014
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.750141140320682.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4926256318979794.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8630169577996564.
# [0]	validation_0-rmse:24.85164
# [99]	validation_0-rmse:5.64773
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 5.647726947213889.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.888261840742164.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.936220983613831.
# [0]	validation_0-rmse:3.67034
# [99]	validation_0-rmse:1.30357
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.3035702457596143.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6088122750785615.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.6291435898181814.
# [0]	validation_0-rmse:1.31006
# [99]	validation_0-rmse:0.44870
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.44870401854590375.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3265127235862944.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4003485540292726.
# [0]	validation_0-rmse:2.04535
# [99]	validation_0-rmse:0.70762
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7076177914789064.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4943666942450735.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7383709370308327.
# [0]	validation_0-rmse:2.51791
# [99]	validation_0-rmse:0.74015
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7401542648905923.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.49647060997088754.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7771864369885316.
# [0]	validation_0-rmse:20.87881
# [99]	validation_0-rmse:3.52806
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.5280566181760937.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.6711391620424059.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.950442253634531.
# [0]	validation_0-rmse:0.48799
# [99]	validation_0-rmse:0.14149
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.14149100328204842.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.059472850052184535.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9128410244565052.
# [0]	validation_0-rmse:1.61146
# [99]	validation_0-rmse:0.33647
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.3364713558351631.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1411661290499899.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8934825306368684.
# [0]	validation_0-rmse:0.42082
# [99]	validation_0-rmse:0.11714
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11713568777881976.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05222560764816071.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.881275422731306.
# [0]	validation_0-rmse:0.21079
# [99]	validation_0-rmse:0.04409
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.044089512329335785.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.026345258525013925.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9410905426845348.
# [0]	validation_0-rmse:0.27446
# [99]	validation_0-rmse:0.03593
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.035934898081746686.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.022054617610408198.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7256124965199069.
# [0]	validation_0-rmse:0.34251
# [99]	validation_0-rmse:0.01754
# ...
# [100]	validation_0-rmse:2.75921
# [200]	validation_0-rmse:2.80632
# [300]	validation_0-rmse:2.80478
# [400]	validation_0-rmse:2.82266
# [499]	validation_0-rmse:2.81482
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.814817836366693.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.6905175801701016.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9684542363492628.
# [0]	validation_0-rmse:0.46294
# [100]	validation_0-rmse:0.17015
# [200]	validation_0-rmse:0.16697
# [300]	validation_0-rmse:0.16660
# [400]	validation_0-rmse:0.16669
# [499]	validation_0-rmse:0.16649
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.16649399793797853.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06577008799678749.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.879315462993786.
# [0]	validation_0-rmse:1.51641
# [100]	validation_0-rmse:0.52955
# [200]	validation_0-rmse:0.52759
# [300]	validation_0-rmse:0.52756
# [400]	validation_0-rmse:0.52695
# [499]	validation_0-rmse:0.52627
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.526271112905207.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.16078425011568598.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7394184230514793.
# [0]	validation_0-rmse:0.39916
# [100]	validation_0-rmse:0.12865
# [200]	validation_0-rmse:0.13931
# [300]	validation_0-rmse:0.14293
# [400]	validation_0-rmse:0.14838
# [499]	validation_0-rmse:0.14882
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.14881516655951468.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.10167831358578469.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8083730630874447.
# [0]	validation_0-rmse:0.19987
# [100]	validation_0-rmse:0.04594
# [200]	validation_0-rmse:0.05474
# [300]	validation_0-rmse:0.06506
# [400]	validation_0-rmse:0.06708
# [499]	validation_0-rmse:0.06854
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06853819569886321.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03749974184963438.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8576426922362971.
# [0]	validation_0-rmse:0.25972
# [100]	validation_0-rmse:0.04973
# [200]	validation_0-rmse:0.05874
# [300]	validation_0-rmse:0.06860
# [400]	validation_0-rmse:0.08738
# [499]	validation_0-rmse:0.09390
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.09390476263260253.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07395918732533853.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.8737287987488072.
# [0]	validation_0-rmse:0.32189
# [100]	validation_0-rmse:0.01277
# [200]	validation_0-rmse:0.01182
# [300]	validation_0-rmse:0.01158
# [400]	validation_0-rmse:0.01194
# [499]	validation_0-rmse:0.01190
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01189507347814493.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.00896557856839564.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8866873024675745.
# [0]	validation_0-rmse:0.36120
# [100]	validation_0-rmse:0.06345
# [200]	validation_0-rmse:0.06335
# [300]	validation_0-rmse:0.06398
# [400]	validation_0-rmse:0.06399
# [499]	validation_0-rmse:0.06405
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06404808657736533.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03787097262077862.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9662067865713676.
# [0]	validation_0-rmse:490.09496
# [100]	validation_0-rmse:2.71586
# [200]	validation_0-rmse:2.70195
# [300]	validation_0-rmse:2.68603
# [400]	validation_0-rmse:2.66483
# [499]	validation_0-rmse:2.66703
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.6670268284312826.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.085420199584962.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9963017337490687.
# [0]	validation_0-rmse:613.98304
# [100]	validation_0-rmse:7.14529
# [200]	validation_0-rmse:7.31707
# [300]	validation_0-rmse:7.51993
# [400]	validation_0-rmse:7.64107
# [499]	validation_0-rmse:7.75497
# Calculated CV RMSE for Konstanz Rhein with RMSE: 7.754966373985166.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.280102473280165.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9841944933495528.
# [0]	validation_0-rmse:579.88809
# [100]	validation_0-rmse:3.52471
# [200]	validation_0-rmse:3.67690
# [300]	validation_0-rmse:3.87491
# [400]	validation_0-rmse:4.03297
# [499]	validation_0-rmse:4.10174
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.101742207131722.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.183631418863932.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9951840420120501.
# [0]	validation_0-rmse:395.47633
# [100]	validation_0-rmse:1.86695
# [200]	validation_0-rmse:1.92087
# [300]	validation_0-rmse:1.94638
# [400]	validation_0-rmse:2.06668
# [499]	validation_0-rmse:2.08574
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.0857360543341392.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.6272818118625227.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9994176293014363.
# [0]	validation_0-rmse:227.44580
# [100]	validation_0-rmse:1.10049
# [200]	validation_0-rmse:1.16120
# [300]	validation_0-rmse:1.17436
# [400]	validation_0-rmse:1.16845
# [499]	validation_0-rmse:1.18839
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.188394195966329.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.9332650017632388.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9978626010523206.
# [0]	validation_0-rmse:185.96392
# [100]	validation_0-rmse:0.79967
# [200]	validation_0-rmse:0.81753
# [300]	validation_0-rmse:0.82194
# [400]	validation_0-rmse:0.82065
# [499]	validation_0-rmse:0.82473
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8247289228567122.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6425336076524528.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9844091274256893.
# [0]	validation_0-rmse:192.30358
# [100]	validation_0-rmse:1.24510
# [200]	validation_0-rmse:1.25365
# [300]	validation_0-rmse:1.31660
# [400]	validation_0-rmse:1.34172
# [499]	validation_0-rmse:1.35272
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.352715618949588.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.0077919620090068.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9822398959683908.
# [0]	validation_0-rmse:10.56834
# [100]	validation_0-rmse:2.74864
# [200]	validation_0-rmse:2.77132
# [300]	validation_0-rmse:2.77744
# [400]	validation_0-rmse:2.77843
# [499]	validation_0-rmse:2.78016
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.780155640844629.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4622657836344508.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8600106295345783.
# [0]	validation_0-rmse:23.67581
# [100]	validation_0-rmse:4.90602
# [200]	validation_0-rmse:4.87409
# [300]	validation_0-rmse:4.86323
# [400]	validation_0-rmse:4.87025
# [499]	validation_0-rmse:4.86468
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.864675750226679.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.6458223336868818.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9526807088359454.
# [0]	validation_0-rmse:3.45833
# [100]	validation_0-rmse:3.41908
# [200]	validation_0-rmse:3.30999
# [300]	validation_0-rmse:3.28382
# [400]	validation_0-rmse:3.27583
# [499]	validation_0-rmse:3.27621
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.2762073482015985.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.647100827659501.
# Calculated CV NSE for Elpershofen Jagst with NSE: -1.3425003914460167.
# [0]	validation_0-rmse:1.24871
# [100]	validation_0-rmse:0.51638
# [200]	validation_0-rmse:0.51495
# [300]	validation_0-rmse:0.52897
# [400]	validation_0-rmse:0.53779
# [499]	validation_0-rmse:0.54774
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.5477371317926464.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3602428188946512.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.10644079356370995.
# [0]	validation_0-rmse:1.92105
# [100]	validation_0-rmse:0.68659
# [200]	validation_0-rmse:0.67486
# [300]	validation_0-rmse:0.66623
# [400]	validation_0-rmse:0.65574
# [499]	validation_0-rmse:0.65017
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6501723126665323.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.40744572106599813.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7791255704486242.
# [0]	validation_0-rmse:2.38498
# [100]	validation_0-rmse:0.64237
# [200]	validation_0-rmse:0.63575
# [300]	validation_0-rmse:0.63692
# [400]	validation_0-rmse:0.63299
# [499]	validation_0-rmse:0.63198
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.631975394000606.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.38025004279083674.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8375583208054811.
# [0]	validation_0-rmse:19.71831
# [100]	validation_0-rmse:2.81502
# [200]	validation_0-rmse:2.87136
# [300]	validation_0-rmse:2.89044
# [400]	validation_0-rmse:2.90483
# [499]	validation_0-rmse:2.90936
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.9093579884853753.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.7438576218393116.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9662996211535293.
# [0]	validation_0-rmse:0.46339
# [100]	validation_0-rmse:0.17078
# [200]	validation_0-rmse:0.16854
# [300]	validation_0-rmse:0.16789
# [400]	validation_0-rmse:0.16704
# [499]	validation_0-rmse:0.16664
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.16663585322729096.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06598318660590383.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8791097254506023.
# [0]	validation_0-rmse:1.51596
# [100]	validation_0-rmse:0.60157
# [200]	validation_0-rmse:0.59963
# [300]	validation_0-rmse:0.59981
# [400]	validation_0-rmse:0.59820
# [499]	validation_0-rmse:0.59862
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.5986190499028969.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.16120688252449034.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6628480233436083.
# [0]	validation_0-rmse:0.39843
# [100]	validation_0-rmse:0.12371
# [200]	validation_0-rmse:0.14942
# [300]	validation_0-rmse:0.15623
# [400]	validation_0-rmse:0.16858
# [499]	validation_0-rmse:0.16919
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.16919352990565412.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12315447008675999.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7522979102248428.
# [0]	validation_0-rmse:0.19960
# [100]	validation_0-rmse:0.04615
# [200]	validation_0-rmse:0.05805
# [300]	validation_0-rmse:0.05811
# [400]	validation_0-rmse:0.06047
# [499]	validation_0-rmse:0.06169
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.061686763606650166.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03364878871705797.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8846816544967243.
# [0]	validation_0-rmse:0.25962
# [100]	validation_0-rmse:0.05339
# [200]	validation_0-rmse:0.06077
# [300]	validation_0-rmse:0.06287
# [400]	validation_0-rmse:0.06467
# [499]	validation_0-rmse:0.06874
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06874388853824823.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06003904262698359.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: -0.0041525202443502.
# [0]	validation_0-rmse:0.32183
# [100]	validation_0-rmse:0.01863
# [200]	validation_0-rmse:0.01886
# [300]	validation_0-rmse:0.01896
# [400]	validation_0-rmse:0.01880
# [499]	validation_0-rmse:0.01896
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01895665994789234.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.01491396100314127.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7122151287221987.
# [0]	validation_0-rmse:0.36134
# [100]	validation_0-rmse:0.06392
# [200]	validation_0-rmse:0.06403
# [300]	validation_0-rmse:0.06436
# [400]	validation_0-rmse:0.06474
# [499]	validation_0-rmse:0.06493
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0649309448031327.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03745705614992314.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.965268733844082.
# [0]	validation_0-rmse:490.09496
# [100]	validation_0-rmse:2.52638
# [200]	validation_0-rmse:2.53827
# [300]	validation_0-rmse:2.53604
# [400]	validation_0-rmse:2.50850
# [499]	validation_0-rmse:2.48287
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.482864928500459.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.9295360829671226.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9967948408915304.
# [0]	validation_0-rmse:613.98304
# [100]	validation_0-rmse:7.38809
# [200]	validation_0-rmse:7.99926
# [300]	validation_0-rmse:8.08905
# [400]	validation_0-rmse:8.04636
# [499]	validation_0-rmse:8.14659
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.146590326135637.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.573470768229166.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9825578371052339.
# [0]	validation_0-rmse:579.88809
# [100]	validation_0-rmse:3.57414
# [200]	validation_0-rmse:3.63823
# [300]	validation_0-rmse:3.74532
# [400]	validation_0-rmse:3.74644
# [499]	validation_0-rmse:3.77247
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.7724730661168286.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.9348855780707455.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9959262135254054.
# [0]	validation_0-rmse:395.47633
# [100]	validation_0-rmse:1.72015
# [200]	validation_0-rmse:1.72464
# [300]	validation_0-rmse:1.80780
# [400]	validation_0-rmse:1.85616
# [499]	validation_0-rmse:1.94631
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.946307593159258.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.5243631083170575.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9994928881341096.
# [0]	validation_0-rmse:227.44580
# [100]	validation_0-rmse:1.30219
# [200]	validation_0-rmse:1.29302
# [300]	validation_0-rmse:1.29904
# [400]	validation_0-rmse:1.29591
# [499]	validation_0-rmse:1.29425
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.2942535882105206.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.0241154471503366.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9974648520916357.
# [0]	validation_0-rmse:185.96392
# [100]	validation_0-rmse:0.80111
# [200]	validation_0-rmse:0.80577
# [300]	validation_0-rmse:0.80727
# [400]	validation_0-rmse:0.82606
# [499]	validation_0-rmse:0.83223
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8322267191961267.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6480512176513674.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9841243585679783.
# [0]	validation_0-rmse:192.30358
# [100]	validation_0-rmse:1.11172
# [200]	validation_0-rmse:1.16654
# [300]	validation_0-rmse:1.21769
# [400]	validation_0-rmse:1.21791
# [499]	validation_0-rmse:1.22760
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.2276008302561376.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.9355293289184573.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9853732835217249.
# Best Hyperparameter combination with lowest mean rmse for all stations are n_estimators        200.00
# max_depth             6.00
# learning_rate         0.05
# subsample             0.50
# colsample_bytree      1.00
# Name: 74, dtype: float64 with mean rmse 1.5595119033411962 with nse gap between train and validation of: 0.13727881724354085.
# Best Hyperparameter combination with lowest mean mae for all stations are n_estimators        200.00
# max_depth             8.00
# learning_rate         0.05
# subsample             0.50
# colsample_bytree      1.00
# Name: 92, dtype: float64 with mean mae 0.9469791730821805 with nse gap between train and validation of: 0.144046656466979.
# Best Hyperparameter combination with lowest mean nse for all stations are n_estimators        100.0
# max_depth             8.0
# learning_rate         0.1
# subsample             0.5
# colsample_bytree      0.5
# Name: 45, dtype: float64 with mean nse 0.8797866266962465 with nse gap between train and validation of: 0.11645032742942762.
# (n_estimators        200.00
#  max_depth             6.00
#  learning_rate         0.05
#  subsample             0.50
#  colsample_bytree      1.00
#  Name: 74, dtype: float64,
#  n_estimators        200.00
#  max_depth             8.00
#  learning_rate         0.05
#  subsample             0.50
#  colsample_bytree      1.00
#  Name: 92, dtype: float64,
#  n_estimators        100.0
#  max_depth             8.0
#  learning_rate         0.1
#  subsample             0.5
#  colsample_bytree      0.5
#  Name: 45, dtype: float64)

# %% [markdown]
# ### Hyperparameter-Tuning mit min_child_weight
# Mit der nun in der vorherigen Optimierung ausgewählten Kombination wird hier zusätzlich der Hyperparameter "min_child_weight" in einer erneuten Cross-Validation variiert. Ziel ist es, zu überprüfen, ob sich dadurch die Validierungsleistung verbessern oder die Differenz zwischen Trainings- und Validierungs-NSE reduzieren lässt. Es wird min_child_weight=20 gewählt.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
from itertools import product
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


def hyper_parameter_tuning_cross_validation():
    train_test = train_and_test_nan()

    # define possible parameters
    params = {
        "n_estimators": [100, 200, 300],
        "min_child_weight": [1, 3, 5, 10, 20],
        "learning_rate": [0.05, 0.1],
        "colsample_bytree": [0.5, 1.0]
            }
    keys = params.keys()
    values = params.values()
    params_columns = list(keys)

    # create all hyperparameter combinations a list of dictionaries. Each of them containing one hyper parameter combination.
    dict_all_combination = []
    all_combination = list(product(*values))
    for c in all_combination:
        dict_combination = dict(zip(keys, c))
        dict_all_combination.append(dict_combination)
            
    pred = []
    scores = []

    # try every hyperparameter combination of the grid.
    for d in dict_all_combination:
        selected_stations = ["Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein"]
        selected_train_test = [t for t in train_test if t["Stationsname"] in selected_stations]

        
        for t in selected_train_test:
            train_water = t["Trainingsset"].copy()
            train_water = train_water.sort_index()
            # define forecast horizon to forecast six hours in the future: Q(t) --> Q(t+6).
            train_water["y"] = train_water["Abfluss in m^3/s"].shift(-6)
    
            # the last six rows of y are NaN due to the shift by six hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
            train_water = train_water.dropna(subset=["y"])
    
            # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast. We keep "Abfluss in m^3/s" as current value and the last knon runoff which is important for the prediction. 
            x = train_water.drop(columns=["y"])
            y = train_water["y"]
            
            station = t["Stationsname"]
    
            # define Time Series Spliit for the Cross validation. We evaluate the model on 720 hour validation windows using six hour forecasts. 
            # To avoid leakage between train and validation I use a gap of six hours.
            tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=6)
            fold = 0

            # split the train set into seven folds for the cross validation and use XGBoostRegressor with the respective hyperparameter combination.
            for train_idx, validation_idx in tss.split(x):
                fold += 1
                x_train = x.iloc[train_idx]
                x_validation = x.iloc[validation_idx]
                y_train = y.iloc[train_idx]
                y_validation = y.iloc[validation_idx]
                
                model = xgb.XGBRegressor(
                    **d,
                    max_depth=8,
                    subsample=0.5,
                    base_score=0.5, 
                    tree_method="hist", 
                    n_jobs = -1, 
                    random_state=42,
                    eval_metric="rmse"
                )
                    
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_validation, y_validation)],
                    verbose=100
                )
                
                
                # this is needed to predict the validation set    
                y_pred_validation = model.predict(x_validation)
                pred.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold, 
                    "Vorhersage": y_pred_validation
                 })

                # this is needed to check for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting
                y_pred_train = model.predict(x_train)

                # calculate the evaluation metrics for the validation set forecast in the cross validation
                rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
                mae_validation = mean_absolute_error(y_validation, y_pred_validation)
                nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

                # calculate the evaluation metrics for the training set forecast in the cross validation to compare them with the claculated metrics in the validation set forecast.
                rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
                mae_train = mean_absolute_error(y_train, y_pred_train)
                nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)

                # store information about the respective hyperparameter, station and fold with the corresponding metrics
                scores.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold,
                    "rmse validation": rmse_validation,
                    "mae validation": mae_validation,
                    "nse validation": nse_validation,
                    "rmse train": rmse_train,
                    "mae train": mae_train,
                    "nse train": nse_train,
                })
                print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
                print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
                print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station and hyperparameter combination
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby(["Stationsname"] + params_columns)[["rmse validation", "mae validation", "nse validation", "rmse train", "mae train", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "rmse train": "mean_rmse_train", "mae train": "mean_mae_train", "nse train": "mean_nse_train"})

    # calculate the mean evaluation metrics of all stations with the same hyperparameter configurations to find the best hyper parameter combination for all stations. We also want to calculate the evaluation metrics in the train set to identify if the model realy learns to regularize ore just to memorize if the metrics in the train set are much betterthan the metrics in the validation set.
    mean_per_hyper_parameter = mean_per_station.groupby(params_columns)[["mean_rmse_validation", "mean_mae_validation", "mean_nse_validation", "mean_rmse_train", "mean_mae_train", "mean_nse_train"]].mean()
    mean_per_hyper_parameter = mean_per_hyper_parameter.reset_index()
    mean_per_hyper_parameter["nse gap"] = mean_per_hyper_parameter["mean_nse_train"] - mean_per_hyper_parameter["mean_nse_validation"]

    # sort the evaluation metrics to show the best hyperparameter for the best metric
    sorted_rmse = mean_per_hyper_parameter.sort_values("mean_rmse_validation")
    sorted_mae = mean_per_hyper_parameter.sort_values("mean_mae_validation")
    sorted_nse = mean_per_hyper_parameter.sort_values("mean_nse_validation", ascending=False)

    # define the best hyperparameters per evaluation metric
    best_hp_rmse = sorted_rmse[params_columns].iloc[0]
    best_hp_mae = sorted_mae[params_columns].iloc[0]
    best_hp_nse = sorted_nse[params_columns].iloc[0]

    print(f"Best Hyperparameter combination with lowest mean rmse for all stations are {best_hp_rmse} with mean rmse {sorted_rmse['mean_rmse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_rmse['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean mae for all stations are {best_hp_mae} with mean mae {sorted_mae['mean_mae_validation'].iloc[0]} with nse gap between train and validation of: {sorted_mae['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean nse for all stations are {best_hp_nse} with mean nse {sorted_nse['mean_nse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_nse['nse gap'].iloc[0]}.")

    return best_hp_rmse, best_hp_mae, best_hp_nse

hyper_parameter_tuning_cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# [0]	validation_0-rmse:11.09484
# [99]	validation_0-rmse:2.94912
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.9491246755228366.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4165164455188646.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8424773145183061.
# [0]	validation_0-rmse:24.80944
# [99]	validation_0-rmse:5.05814
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 5.058137145429453.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.682192314089669.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9488422264509638.
# [0]	validation_0-rmse:3.65568
# [99]	validation_0-rmse:1.34618
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.3461791329864354.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6525530497497982.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.604503521744558.
# [0]	validation_0-rmse:1.31679
# [99]	validation_0-rmse:0.41764
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.41764430274072323.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3124706284893884.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.48049217917000286.
# [0]	validation_0-rmse:2.04305
# [99]	validation_0-rmse:0.72188
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7218752562949593.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.48956509888701966.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7277218382796411.
# [0]	validation_0-rmse:2.50549
# [99]	validation_0-rmse:0.75000
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7499966389298918.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4724730773422453.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.

# Calculated CV MAE for Elpershofen Jagst with MAE: 0.32138833892610336.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.45868129019772275.
# [0]	validation_0-rmse:1.92912
# [99]	validation_0-rmse:0.71049
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7104908354778255.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.47614462109804156.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7362421104986691.
# [0]	validation_0-rmse:2.38938
# [99]	validation_0-rmse:0.69048
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6904764961327398.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4400841446797053.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8060923553676381.
# [0]	validation_0-rmse:19.72643
# [99]	validation_0-rmse:2.86603
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.8660296899056728.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4872711344454022.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9672959282734616.
# [0]	validation_0-rmse:0.46218
# [99]	validation_0-rmse:0.14123
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.14122763121670995.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06033103206488821.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9131651987767184.
# [0]	validation_0-rmse:1.52832
# [99]	validation_0-rmse:0.43471
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.4347085468291946.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.15175251653525565.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8222044030916045.
# [0]	validation_0-rmse:0.39742
# [99]	validation_0-rmse:0.12516
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1251577564615302.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05256055220862229.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8644568085649317.
# [0]	validation_0-rmse:0.19997
# [99]	validation_0-rmse:0.04406
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0440644799163084.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02472696665525436.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9411574169665965.
# [0]	validation_0-rmse:0.25939
# [99]	validation_0-rmse:0.03420
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03420265812099857.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.021158224049541687.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7514285692631805.
# [0]	validation_0-rmse:0.32216
# [99]	validation_0-rmse:0.01312
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01312034941850145.
# ...
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9839507026510261.
# [0]	validation_0-rmse:202.92794
# [100]	validation_0-rmse:1.70927
# [200]	validation_0-rmse:1.16430
# [299]	validation_0-rmse:1.18021
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.1802114363104566.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.8716754360622833.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.986480764494411.
# [0]	validation_0-rmse:10.53365
# [100]	validation_0-rmse:2.61229
# [200]	validation_0-rmse:2.69251
# [299]	validation_0-rmse:2.75485
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.7548475850830196.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4225488999095228.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8625477056821642.
# [0]	validation_0-rmse:23.55259
# [100]	validation_0-rmse:5.03475
# [200]	validation_0-rmse:4.96174
# [299]	validation_0-rmse:4.94054
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 4.940540272440673.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.7225717623578176.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9511933138013888.
# [0]	validation_0-rmse:3.46666
# [100]	validation_0-rmse:1.25074
# [200]	validation_0-rmse:1.44249
# [299]	validation_0-rmse:1.57380
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5737950989883447.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6913845906244384.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.459453214492096.
# [0]	validation_0-rmse:1.25066
# [100]	validation_0-rmse:0.43960
# [200]	validation_0-rmse:0.45267
# [299]	validation_0-rmse:0.46839
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.46838689236531006.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.3478455855382813.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.34658600336923495.
# [0]	validation_0-rmse:1.93047
# [100]	validation_0-rmse:0.69001
# [200]	validation_0-rmse:0.67700
# [299]	validation_0-rmse:0.66778
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6677848259149244.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4563169646396716.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7669969580340047.
# [0]	validation_0-rmse:2.38607
# [100]	validation_0-rmse:0.72549
# [200]	validation_0-rmse:0.71549
# [299]	validation_0-rmse:0.70907
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.7090741225395781.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4458873725917604.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7955060781758112.
# [0]	validation_0-rmse:19.72935
# [100]	validation_0-rmse:2.98165
# [200]	validation_0-rmse:2.99880
# [299]	validation_0-rmse:2.97794
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.9779442126680116.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4906356658723623.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.964691963100325.
# [0]	validation_0-rmse:0.46278
# [100]	validation_0-rmse:0.14670
# [200]	validation_0-rmse:0.14614
# [299]	validation_0-rmse:0.14695
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1469455635135512.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06412685907350646.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9059914352811749.
# [0]	validation_0-rmse:1.52376
# [100]	validation_0-rmse:0.39221
# [200]	validation_0-rmse:0.40094
# [299]	validation_0-rmse:0.41132
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.4113181461362966.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.16813381359974544.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8408229751900362.
# [0]	validation_0-rmse:0.39846
# [100]	validation_0-rmse:0.12446
# [200]	validation_0-rmse:0.12584
# [299]	validation_0-rmse:0.12622
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12621857697758854.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05635973775221242.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.862149378931865.
# [0]	validation_0-rmse:0.19979
# [100]	validation_0-rmse:0.04254
# [200]	validation_0-rmse:0.04333
# [299]	validation_0-rmse:0.04339
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04338733304860795.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02487388615343306.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9429520106004261.
# [0]	validation_0-rmse:0.25965
# [100]	validation_0-rmse:0.03372
# [200]	validation_0-rmse:0.03369
# [299]	validation_0-rmse:0.03376
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03376180629664838.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.020506997036271624.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7577951468289617.
# [0]	validation_0-rmse:0.32205
# [100]	validation_0-rmse:0.01290
# [200]	validation_0-rmse:0.01295
# [299]	validation_0-rmse:0.01330
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01329632660585709.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.010549976513203647.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8584181218507727.
# [0]	validation_0-rmse:0.36157
# [100]	validation_0-rmse:0.06191
# [200]	validation_0-rmse:0.06376
# [299]	validation_0-rmse:0.06438
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06438313132961357.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.040473277134944995.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9658523075054873.
# [0]	validation_0-rmse:490.16369
# [100]	validation_0-rmse:2.67758
# [200]	validation_0-rmse:2.63496
# [299]	validation_0-rmse:2.66859
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.668586176960682.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.14427590637207.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9962974079043789.
# [0]	validation_0-rmse:614.19481
# [100]	validation_0-rmse:7.38398
# [200]	validation_0-rmse:7.73567
# [299]	validation_0-rmse:7.83084
# Calculated CV RMSE for Konstanz Rhein with RMSE: 7.830840834598509.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.295489215087891.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9838836987238173.
# [0]	validation_0-rmse:579.10760
# [100]	validation_0-rmse:3.67672
# [200]	validation_0-rmse:3.67230
# [299]	validation_0-rmse:3.76030
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.7602961105715265.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.873252922905816.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9959524701773161.
# [0]	validation_0-rmse:395.38394
# [100]	validation_0-rmse:1.85204
# [200]	validation_0-rmse:1.90056
# [299]	validation_0-rmse:1.90898
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.9089760612469286.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.5323862236870671.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.999512155083983.
# [0]	validation_0-rmse:227.46657
# [100]	validation_0-rmse:1.32063
# [200]	validation_0-rmse:1.33944
# [299]	validation_0-rmse:1.30796
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.3079617014718863.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.009228362528484.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9974108655564776.
# [0]	validation_0-rmse:185.52377
# [100]	validation_0-rmse:0.88073
# [200]	validation_0-rmse:0.88769
# [299]	validation_0-rmse:0.88577
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8857728518124746.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6817252027723528.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9820157346340155.
# [0]	validation_0-rmse:192.22936
# [100]	validation_0-rmse:1.25193
# [200]	validation_0-rmse:1.27351
# [299]	validation_0-rmse:1.26869
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.2686948350908.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.9400083589341909.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9843776328604747.
# [0]	validation_0-rmse:10.50596
# [100]	validation_0-rmse:2.68391
# [200]	validation_0-rmse:2.78021
# [299]	validation_0-rmse:2.82763
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.8276284960675917.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4530082920849323.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.8551890039611814.
# [0]	validation_0-rmse:23.54167
# [100]	validation_0-rmse:5.26762
# [200]	validation_0-rmse:5.18414
# [299]	validation_0-rmse:5.11737
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 5.117366147766676.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.7824407431787916.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9476371329324959.
# [0]	validation_0-rmse:3.46697
# [100]	validation_0-rmse:1.24322
# [200]	validation_0-rmse:1.50409
# [299]	validation_0-rmse:1.67411
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.674111799959593.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.6479418475813336.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.3883459903432156.
# [0]	validation_0-rmse:1.25053
# [100]	validation_0-rmse:0.43395
# [200]	validation_0-rmse:0.43645
# [299]	validation_0-rmse:0.43244
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.4324372699472829.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.32412009500794936.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.44303846742629516.
# [0]	validation_0-rmse:1.92878
# [100]	validation_0-rmse:0.73404
# [200]	validation_0-rmse:0.73880
# [299]	validation_0-rmse:0.72125
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.721245240467369.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4822959379699495.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7281968918139446.
# [0]	validation_0-rmse:2.38735
# [100]	validation_0-rmse:0.68521
# [200]	validation_0-rmse:0.68090
# [299]	validation_0-rmse:0.67870
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.678700596190538.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4343847176419364.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.812650045069972.
# [0]	validation_0-rmse:19.68751
# [100]	validation_0-rmse:3.27722
# [200]	validation_0-rmse:3.20135
# [299]	validation_0-rmse:3.23661
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 3.236613868870931.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.6029544013102848.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9582917240734606.
# [0]	validation_0-rmse:0.46286
# [100]	validation_0-rmse:0.15483
# [200]	validation_0-rmse:0.15404
# [299]	validation_0-rmse:0.15249
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1524895608906655.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06469325763881206.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8987640663637937.
# [0]	validation_0-rmse:1.50915
# [100]	validation_0-rmse:0.46033
# [200]	validation_0-rmse:0.47136
# [299]	validation_0-rmse:0.47505
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.4750463587794931.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.17420064739121333.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7876772010069862.
# [0]	validation_0-rmse:0.39864
# [100]	validation_0-rmse:0.12041
# [200]	validation_0-rmse:0.12004
# [299]	validation_0-rmse:0.12074
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.12073764865004367.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05336826584835848.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8738615193352917.
# [0]	validation_0-rmse:0.19986
# [100]	validation_0-rmse:0.04405
# [200]	validation_0-rmse:0.04410
# [299]	validation_0-rmse:0.04428
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04427883333730558.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.02502066983613703.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9405835403438153.
# [0]	validation_0-rmse:0.25955
# [100]	validation_0-rmse:0.03365
# [200]	validation_0-rmse:0.03370
# [299]	validation_0-rmse:0.03378
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.03378368997892184.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.020146882574260238.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7574810610370462.
# [0]	validation_0-rmse:0.32218
# [100]	validation_0-rmse:0.01344
# [200]	validation_0-rmse:0.01388
# [299]	validation_0-rmse:0.01404
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.014044154052731858.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.010802718231578665.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8420442319296978.
# [0]	validation_0-rmse:0.36165
# [100]	validation_0-rmse:0.06345
# [200]	validation_0-rmse:0.06399
# [299]	validation_0-rmse:0.06512
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.06512147155266129.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.040224438199980395.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9650646110259625.
# [0]	validation_0-rmse:490.16369
# [100]	validation_0-rmse:2.61050
# [200]	validation_0-rmse:2.51395
# [299]	validation_0-rmse:2.52543
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.525428040610129.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.0093596991644973.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9966840085505928.
# [0]	validation_0-rmse:614.19481
# [100]	validation_0-rmse:7.39866
# [200]	validation_0-rmse:7.51258
# [299]	validation_0-rmse:7.71192
# Calculated CV RMSE for Konstanz Rhein with RMSE: 7.711920365167178.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.2318667677137585.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9843694717247211.
# [0]	validation_0-rmse:579.10760
# [100]	validation_0-rmse:3.27856
# [200]	validation_0-rmse:3.29362
# [299]	validation_0-rmse:3.38757
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.3875682531848823.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.684910478379992.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9967151005929.
# [0]	validation_0-rmse:395.38394
# [100]	validation_0-rmse:1.76483
# [200]	validation_0-rmse:1.81843
# [299]	validation_0-rmse:1.94101
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.9410069788265651.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.555987880113391.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9994956465307275.
# [0]	validation_0-rmse:227.46657
# [100]	validation_0-rmse:1.02806
# [200]	validation_0-rmse:1.03457
# [299]	validation_0-rmse:1.03765
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.037654647178722.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.8245976542154957.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9983704405169956.
# [0]	validation_0-rmse:185.52377
# [100]	validation_0-rmse:0.82546
# [200]	validation_0-rmse:0.82331
# [299]	validation_0-rmse:0.82519
# Calculated CV RMSE for Konstanz Rhein with RMSE: 0.8251937572499581.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.6455477127075196.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9843915477921361.
# [0]	validation_0-rmse:192.22936
# [100]	validation_0-rmse:1.11160
# [200]	validation_0-rmse:1.12108
# [299]	validation_0-rmse:1.14189
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.1418852833497504.
# Calculated CV MAE for Konstanz Rhein with MAE: 0.8735115061442063.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9873445542114986.
# Best Hyperparameter combination with lowest mean rmse for all stations are n_estimators        200.00
# min_child_weight      3.00
# learning_rate         0.05
# colsample_bytree      1.00
# Name: 25, dtype: float64 with mean rmse 1.5253419745251906 with nse gap between train and validation of: 0.12362915852721212.
# Best Hyperparameter combination with lowest mean mae for all stations are n_estimators        200.00
# min_child_weight      1.00
# learning_rate         0.05
# colsample_bytree      1.00
# Name: 21, dtype: float64 with mean mae 0.9469791730821805 with nse gap between train and validation of: 0.144046656466979.
# Best Hyperparameter combination with lowest mean nse for all stations are n_estimators        100.00
# min_child_weight     20.00
# learning_rate         0.05
# colsample_bytree      1.00
# Name: 17, dtype: float64 with mean nse 0.8887568242801546 with nse gap between train and validation of: 0.09959975148488565.
# (n_estimators        200.00
#  min_child_weight      3.00
#  learning_rate         0.05
#  colsample_bytree      1.00
#  Name: 25, dtype: float64,
#  n_estimators        200.00
#  min_child_weight      1.00
#  learning_rate         0.05
#  colsample_bytree      1.00
#  Name: 21, dtype: float64,
#  n_estimators        100.00
#  min_child_weight     20.00
#  learning_rate         0.05
#  colsample_bytree      1.00
#  Name: 17, dtype: float64)

# %% [markdown]
# ### Cross Validation mit optimierten Hyperparametern
# In den folgenden zwei Blöcken wird eine zeitbasierte Cross-Validation mit der ermittelten Hyperparameter-Kombination für alle 25 Zeitreihen durchgeführt. Ziel ist es, die Validierungsleistung pro Station und über alle Stationen im Mittel zu quantifizieren. Zusätzlich soll ermöglicht werden, eine mögliche Überanpassung über die Differenz zwischen Trainings- und Validierungs-NSE zu beurteilen.
# Im ersten Block wird der Niederschlag als exogene Variable verwendet, im zweiten Block werden alle Niederschlagsdaten entfernt. Durch den Vergleich der Metriken soll die Bedeutung der Niederschlagsdaten für die Vorhersageleistung bewertet werden.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


# cross validation with exogene features
def cross_validation():
    train_test = train_and_test_nan()
    
    pred = []
    scores = []
    # Cross Validation for every of the 25 stations in Baden-Württemberg with the best hyper parameter from the hyper parameter tuning.
    for t in train_test:
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()

        # defining forecast horizon to forecast six hours in the future.
        train_water["y"] = train_water["Abfluss in m^3/s"].shift(-6)

        # the last six rows of y is NaN due to the shift by six hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train_water = train_water.dropna(subset=["y"])

        # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast.
        # We keep "Abfluss in m^3/s" as current value and the last known runoff which is important for the prediction.
        x = train_water.drop(columns=["y"])
        y = train_water["y"]
        
        station = t["Stationsname"]

        # define Time Series Spliit for the Cross validation. I evaluate the model on 720 hour validation windows using one hour forecasts. 
        # To avoid leakage between train and validation I use a gap of six hours.
        tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=6)
        fold = 0

        # split the train set into seven folds for the cross validation and use XGBoostRegressor with the respective hyperparameter combination.
        for train_idx, validation_idx in tss.split(x):
            fold += 1
            x_train = x.iloc[train_idx]
            x_validation = x.iloc[validation_idx]
            y_train = y.iloc[train_idx]
            y_validation = y.iloc[validation_idx]

            # Define XGBoost model with the best hyperparameter combination identified in the hyperparameter tuning
            model = xgb.XGBRegressor(
                n_estimators=100, 
                max_depth=8, 
                min_child_weight=20,
                learning_rate=0.05, 
                subsample=0.5, 
                colsample_bytree=1.0, 
                base_score=0.5,
                tree_method="hist", 
                n_jobs = -1, 
                random_state=42,
                eval_metric="rmse")
            
            model.fit(x_train, y_train, eval_set=[(x_validation, y_validation)], verbose=100)

        
            # Predict the respective validation set per fold
            y_pred_validation = model.predict(x_validation)
            pred.append({
                "Stationsname": station,
                "Fold": fold, 
                "Vorhersage": y_pred_validation
            })

            # Predict the respective validation set per fold to ceck for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting.
            y_pred_train = model.predict(x_train)

            # Calculate the evaluation metrics "RMSE", "MAE" and "NSE" for the prediction of the validation set per fold.
            rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
            mae_validation = mean_absolute_error(y_validation, y_pred_validation)
            nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

            # Calculate "NSE" and "NSE gap" per fold to identify potential model overfitting.
            nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)
            nse_gap = nse_train - nse_validation

            # store evaluation metrics for this station and fold in score
            scores.append({
                "Stationsname": station,
                "Fold": fold,
                "rmse validation": rmse_validation,
                "mae validation": mae_validation,
                "nse validation": nse_validation,
                "nse train": nse_train,
                "nse gap": nse_gap
            })
            print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
            print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
            print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

         
    # calculate the mean evaluation metrics over the folds with the same station. This enables to compare the scores with the other cv, to identify the importance of the exogene features.
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby("Stationsname")[["rmse validation", "mae validation", "nse validation", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "nse train": "mean_nse_train"})

    overall_mean_nse = mean_per_station["mean_nse_validation"].mean()
    overall_mean_nse_train = mean_per_station["mean_nse_train"].mean()
    overall_nse_gap = overall_mean_nse_train - overall_mean_nse
    
    return scores_df, mean_per_station, overall_mean_nse, overall_mean_nse_train, overall_nse_gap
    
cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# [0]	validation_0-rmse:17.40908
# [99]	validation_0-rmse:4.59802
# Calculated CV RMSE for Gießen Argen with RMSE: 4.598022760118519.
# Calculated CV MAE for Gießen Argen with MAE: 1.6496540490256415.
# Calculated CV NSE for Gießen Argen with NSE: 0.8817155199775415.
# [0]	validation_0-rmse:35.13979
# [99]	validation_0-rmse:10.39101
# Calculated CV RMSE for Gießen Argen with RMSE: 10.391007284139832.
# Calculated CV MAE for Gießen Argen with MAE: 3.8443982610384624.
# Calculated CV NSE for Gießen Argen with NSE: 0.8522221621558133.
# [0]	validation_0-rmse:36.60947
# [99]	validation_0-rmse:8.19558
# Calculated CV RMSE for Gießen Argen with RMSE: 8.195584567779362.
# Calculated CV MAE for Gießen Argen with MAE: 2.8090097808043164.
# Calculated CV NSE for Gießen Argen with NSE: 0.9243999473800742.
# [0]	validation_0-rmse:10.28687
# [99]	validation_0-rmse:2.31775
# Calculated CV RMSE for Gießen Argen with RMSE: 2.3177483360764164.
# Calculated CV MAE for Gießen Argen with MAE: 0.7081302538606856.
# Calculated CV NSE for Gießen Argen with NSE: 0.807484181401812.
# [0]	validation_0-rmse:4.86557
# [99]	validation_0-rmse:0.53541
# Calculated CV RMSE for Gießen Argen with RMSE: 0.5354096565964158.
# Calculated CV MAE for Gießen Argen with MAE: 0.2838269201013777.
# Calculated CV NSE for Gießen Argen with NSE: 0.743223864936698.
# [0]	validation_0-rmse:9.30011
# [99]	validation_0-rmse:1.22092
# Calculated CV RMSE for Gießen Argen with RMSE: 1.2209214897898222.
# Calculated CV MAE for Gießen Argen with MAE: 0.5574147797425588.
# Calculated CV NSE for Gießen Argen with NSE: 0.9539854282145542.
# [0]	validation_0-rmse:35.52320
# [99]	validation_0-rmse:4.57199
# Calculated CV RMSE for Gießen Argen with RMSE: 4.571986529857516.
# Calculated CV MAE for Gießen Argen with MAE: 2.3184631785498726.
# Calculated CV NSE for Gießen Argen with NSE: 0.9609351886170758.
# [0]	validation_0-rmse:1.40223
# [99]	validation_0-rmse:0.19526
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.19525819334812491.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.11518636944558887.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.7120235749082422.
# [0]	validation_0-rmse:7.76439
# [99]	validation_0-rmse:1.63383
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 1.6338319411689741.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.5467293038553662.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.8953855092460521.
# [0]	validation_0-rmse:2.24364
# [99]	validation_0-rmse:0.13246
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.1324569565627562.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.09137187299463487.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.8707464386660483.
# [0]	validation_0-rmse:1.58216
# [99]	validation_0-rmse:0.10040
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.10040041259696797.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.08035161873499552.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9202886045885821.
# [0]	validation_0-rmse:0.89967
# [99]	validation_0-rmse:0.07607
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.07606946702665371.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.061094613550768964.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.78652887892397.
# [0]	validation_0-rmse:0.63061
# [99]	validation_0-rmse:0.06310
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.06310034737147319.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.04663574431472354.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.6448604871853403.
# [0]	validation_0-rmse:1.75378
# [99]	validation_0-rmse:0.12999
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.12998565089282085.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.09573458969195682.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9805835275904486.
# [0]	validation_0-rmse:3.11061
# [99]	validation_0-rmse:0.60106
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.6010584126126247.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.2780421283112632.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.240201696927675.
# [0]	validation_0-rmse:4.25492
# [99]	validation_0-rmse:0.91299
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.912988247104608.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.38203687146769627.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.6428277846953012.
# [0]	validation_0-rmse:3.04185
# [99]	validation_0-rmse:0.49583
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.4958252440562526.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.20838627027405632.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.2839031395255396.
# [0]	validation_0-rmse:2.45209
# [99]	validation_0-rmse:0.17027
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.17027223660985902.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.11398967087268828.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.4169930785966326.
# [0]	validation_0-rmse:2.15763
# [99]	validation_0-rmse:0.28590
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.28589858684227715.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.15040433353053198.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.36137976930141047.
# [0]	validation_0-rmse:1.79872
# [99]	validation_0-rmse:0.23879
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.23879280436962488.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.11302141525745392.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.4877465845840031.
# [0]	validation_0-rmse:2.65796
# [99]	validation_0-rmse:0.32812
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.32811669392938314.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.18851280602084267.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.8615940181448227.
# [0]	validation_0-rmse:19.60851
# [99]	validation_0-rmse:2.53940
# Calculated CV RMSE for Beuron Donau with RMSE: 2.539404053749912.
# Calculated CV MAE for Beuron Donau with MAE: 1.224668362903595.
# Calculated CV NSE for Beuron Donau with NSE: 0.9627752199506096.
# [0]	validation_0-rmse:23.47564
# [99]	validation_0-rmse:1.68512
# Calculated CV RMSE for Beuron Donau with RMSE: 1.6851182564484875.
# Calculated CV MAE for Beuron Donau with MAE: 1.0137203191598256.
# Calculated CV NSE for Beuron Donau with NSE: 0.9785404907809387.
# [0]	validation_0-rmse:5.71271
# [99]	validation_0-rmse:0.51329
# Calculated CV RMSE for Beuron Donau with RMSE: 0.513293951523394.
# Calculated CV MAE for Beuron Donau with MAE: 0.3449123030980428.
# Calculated CV NSE for Beuron Donau with NSE: 0.9626854863728475.
# [0]	validation_0-rmse:2.20170
# [99]	validation_0-rmse:0.24012
# Calculated CV RMSE for Beuron Donau with RMSE: 0.24012155883575445.
# Calculated CV MAE for Beuron Donau with MAE: 0.11251306842697992.
# Calculated CV NSE for Beuron Donau with NSE: 0.8551166983583487.
# [0]	validation_0-rmse:1.03176
# [99]	validation_0-rmse:0.08698
# Calculated CV RMSE for Beuron Donau with RMSE: 0.08697554053799926.
# Calculated CV MAE for Beuron Donau with MAE: 0.06050378226041793.
# Calculated CV NSE for Beuron Donau with NSE: 0.9259273535760449.
# [0]	validation_0-rmse:0.66145
# [99]	validation_0-rmse:0.07383
# Calculated CV RMSE for Beuron Donau with RMSE: 0.07382732936111303.
# Calculated CV MAE for Beuron Donau with MAE: 0.04727108715706401.
# Calculated CV NSE for Beuron Donau with NSE: 0.9012081813647435.
# [0]	validation_0-rmse:13.50297
# [99]	validation_0-rmse:1.70812
# Calculated CV RMSE for Beuron Donau with RMSE: 1.708120747662178.
# Calculated CV MAE for Beuron Donau with MAE: 0.6684573930309878.
# Calculated CV NSE for Beuron Donau with NSE: 0.9673555400981513.
# [0]	validation_0-rmse:37.56868
# [99]	validation_0-rmse:3.44819
# Calculated CV RMSE for Hundersingen Donau with RMSE: 3.44819242308564.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.7667361562940809.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9749098275972345.
# [0]	validation_0-rmse:54.81462
# [99]	validation_0-rmse:4.04297
# Calculated CV RMSE for Hundersingen Donau with RMSE: 4.042969034503385.
# Calculated CV MAE for Hundersingen Donau with MAE: 2.2755729518466525.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9676053473492879.
# [0]	validation_0-rmse:19.90953
# [99]	validation_0-rmse:0.67155
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.67155288205694.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.47309609545601744.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9849192430631338.
# [0]	validation_0-rmse:11.70574
# [99]	validation_0-rmse:0.48898
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.488983354739428.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.3504138742764791.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9187314030182511.
# [0]	validation_0-rmse:7.90096
# [99]	validation_0-rmse:0.62675
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.6267519554699683.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.4994736895773146.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.6680207647903642.
# [0]	validation_0-rmse:6.20436
# [99]	validation_0-rmse:0.66616
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.6661550965688989.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.5317502286646101.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.4107743177671639.
# [0]	validation_0-rmse:20.94679
# [99]	validation_0-rmse:2.17238
# Calculated CV RMSE for Hundersingen Donau with RMSE: 2.1723846172464514.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.9178894178920323.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9597386258222597.
# [0]	validation_0-rmse:7.93294
# [99]	validation_0-rmse:6.99634
# Calculated CV RMSE for Wannweil Echaz with RMSE: 6.996335519339139.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.3821272707396084.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.07785697656636115.
# [0]	validation_0-rmse:5.09081
# [99]	validation_0-rmse:1.66020
# Calculated CV RMSE for Wannweil Echaz with RMSE: 1.6601989106830912.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.7142796080032985.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.5246853157913641.
# [0]	validation_0-rmse:2.06058
# [99]	validation_0-rmse:0.92521
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.9252139387806525.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.6445347469925881.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.22229900124457314.
# [0]	validation_0-rmse:1.24175
# [99]	validation_0-rmse:0.29415
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.29415257731209393.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.17692386918465297.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.5748799614143051.
# [0]	validation_0-rmse:0.71933
# [99]	validation_0-rmse:0.32934
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.3293362862370104.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.16448919146259625.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.11011632033592333.
# [0]	validation_0-rmse:0.50347
# [99]	validation_0-rmse:0.19289
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.19289170180487128.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.11890665667520628.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.07939522160240631.
# [0]	validation_0-rmse:1.51307
# [99]	validation_0-rmse:0.52538
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.5253768833560217.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.26246430799298814.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.5327302098782485.
# [0]	validation_0-rmse:17.62331
# [99]	validation_0-rmse:7.08576
# Calculated CV RMSE for Eutingen Enz with RMSE: 7.08575959003341.
# Calculated CV MAE for Eutingen Enz with MAE: 2.806091358513302.
# Calculated CV NSE for Eutingen Enz with NSE: 0.4973871458862157.
# [0]	validation_0-rmse:21.76088
# [99]	validation_0-rmse:3.45872
# Calculated CV RMSE for Eutingen Enz with RMSE: 3.4587186972182344.
# Calculated CV MAE for Eutingen Enz with MAE: 1.6650936397764418.
# Calculated CV NSE for Eutingen Enz with NSE: 0.9143218675700167.
# [0]	validation_0-rmse:10.58832
# [99]	validation_0-rmse:1.63454
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.63454397301893.
# Calculated CV MAE for Eutingen Enz with MAE: 1.0032798714319866.
# Calculated CV NSE for Eutingen Enz with NSE: 0.7087473173826291.
# [0]	validation_0-rmse:7.53095
# [99]	validation_0-rmse:1.00540
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.0053950406837855.
# Calculated CV MAE for Eutingen Enz with MAE: 0.49676107121043733.
# Calculated CV NSE for Eutingen Enz with NSE: 0.6072635081546085.
# [0]	validation_0-rmse:7.53550
# [99]	validation_0-rmse:1.18567
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.185670185832321.
# Calculated CV MAE for Eutingen Enz with MAE: 0.5445795500914257.
# Calculated CV NSE for Eutingen Enz with NSE: 0.5093390321953959.
# [0]	validation_0-rmse:6.44016
# [99]	validation_0-rmse:0.69889
# Calculated CV RMSE for Eutingen Enz with RMSE: 0.6988943728508107.
# Calculated CV MAE for Eutingen Enz with MAE: 0.5488423816257053.
# Calculated CV NSE for Eutingen Enz with NSE: 0.4741134506258782.
# [0]	validation_0-rmse:13.36823
# [99]	validation_0-rmse:1.90963
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.9096256324852303.
# Calculated CV MAE for Eutingen Enz with MAE: 0.9227274773332808.
# Calculated CV NSE for Eutingen Enz with NSE: 0.9328602399499093.
# [0]	validation_0-rmse:11.08218
# [99]	validation_0-rmse:2.58128
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.5812816570261043.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.362075406785806.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.879322131209542.
# [0]	validation_0-rmse:24.82000
# [99]	validation_0-rmse:5.14991
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 5.14991032559042.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.7064320260100891.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.946969005974889.
# [0]	validation_0-rmse:3.65627
# [99]	validation_0-rmse:0.97895
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.9789484592542754.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5999206096874343.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7908506272735454.
# [0]	validation_0-rmse:1.31697
# [99]	validation_0-rmse:0.43032
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.43032195586869915.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.32386133108139037.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4484740167261916.
# [0]	validation_0-rmse:2.03949
# [99]	validation_0-rmse:0.66522
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6652204294591957.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.47284145498275765.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.7687830570363035.
# [0]	validation_0-rmse:2.50547
# [99]	validation_0-rmse:0.68631
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6863063371521179.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4412399328152339.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.808427507533959.
# [0]	validation_0-rmse:20.80165
# [99]	validation_0-rmse:2.85742
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.85741811488111.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4782968112283281.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.9674921652177718.
# [0]	validation_0-rmse:13.48019
# [99]	validation_0-rmse:2.73901
# Calculated CV RMSE for Hausach Kinzig with RMSE: 2.7390143916483383.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.3988698311858707.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.8110762659186135.
# [0]	validation_0-rmse:17.68533
# [99]	validation_0-rmse:3.39420
# Calculated CV RMSE for Hausach Kinzig with RMSE: 3.394204029868525.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.3040229606681402.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.8918065297313598.
# [0]	validation_0-rmse:5.63336
# [99]	validation_0-rmse:0.63581
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.6358062094637768.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.3533441111299727.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.8396985294092948.
# [0]	validation_0-rmse:3.43973
# [99]	validation_0-rmse:0.42515
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.42514926090182525.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.22510143520567152.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.5674752575186408.
# [0]	validation_0-rmse:3.76217
# [99]	validation_0-rmse:0.59092
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.5909228760356314.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.2697194338003794.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.7338314732673339.
# [0]	validation_0-rmse:5.30902
# [99]	validation_0-rmse:1.06477
# Calculated CV RMSE for Hausach Kinzig with RMSE: 1.0647685806915732.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.3628855565256543.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.7922787645888532.
# [0]	validation_0-rmse:27.33859
# [99]	validation_0-rmse:4.35679
# Calculated CV RMSE for Hausach Kinzig with RMSE: 4.356790645634205.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.7938277078204685.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.9328419866104773.
# [0]	validation_0-rmse:1.65993
# [99]	validation_0-rmse:1.32867
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 1.3286677670060836.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.39226208850012884.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.028863311645415002.
# [0]	validation_0-rmse:3.81426
# [99]	validation_0-rmse:2.39383
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 2.393825646144355.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.5997283531679047.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.4402930497616315.
# [0]	validation_0-rmse:0.83656
# [99]	validation_0-rmse:0.37651
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.3765132747153451.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.19647578827606307.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.3233039532491462.
# [0]	validation_0-rmse:0.33874
# [99]	validation_0-rmse:0.12784
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.12784197069580097.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.061726405249039336.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.22062075815025195.
# [0]	validation_0-rmse:0.27149
# [99]	validation_0-rmse:0.23243
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.23243032920803056.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.11003066081007325.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.2004931673709207.
# [0]	validation_0-rmse:0.22399
# [99]	validation_0-rmse:0.12938
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0

# Calculated CV MAE for Bad Rotenfels Murg with MAE: 3.3081306593736017.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.5538325615977291.
# [0]	validation_0-rmse:22.82652
# [99]	validation_0-rmse:3.64788
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 3.6478827591737084.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 2.026102318053775.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.8414273218333939.
# [0]	validation_0-rmse:10.36966
# [99]	validation_0-rmse:2.76562
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 2.765616289733334.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.4779845186021596.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.3003772946312371.
# [0]	validation_0-rmse:4.89087
# [99]	validation_0-rmse:0.98604
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 0.9860372852507511.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.6277793200625313.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.6894740485212332.
# [0]	validation_0-rmse:3.97258
# [99]	validation_0-rmse:1.49798
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.4979839713550613.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.6339069119215012.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.00590104344336273.
# [0]	validation_0-rmse:5.72725
# [99]	validation_0-rmse:1.14191
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.1419112838825252.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.7892772630002765.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.7440756744699204.
# [0]	validation_0-rmse:33.96264
# [99]	validation_0-rmse:9.91055
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 9.910553819647914.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 3.7383612340238366.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.8652681123358326.
# [0]	validation_0-rmse:3.51405
# [99]	validation_0-rmse:1.43620
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.436202973910511.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.5750200130807029.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.7687575167071155.
# [0]	validation_0-rmse:3.11023
# [99]	validation_0-rmse:0.86868
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.8686754096487291.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.31008521358569463.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.854349932489223.
# [0]	validation_0-rmse:0.64760
# [99]	validation_0-rmse:0.23360
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.23359907934214572.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.1096267272286945.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.5468251691901822.
# [0]	validation_0-rmse:0.21786
# [99]	validation_0-rmse:0.11429
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.11428984135969131.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.053700696810748835.
# Calculated CV NSE for Baiersbronn Murg with NSE: -0.9988374075752913.
# [0]	validation_0-rmse:0.47921
# [99]	validation_0-rmse:0.28203
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.28202857319647523.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.11277662144568232.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.2928017587349945.
# [0]	validation_0-rmse:1.32366
# [99]	validation_0-rmse:0.43642
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.43641578216201654.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.16658423426217503.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.812584396590075.
# [0]	validation_0-rmse:10.48123
# [99]	validation_0-rmse:3.61382
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 3.613824463572038.
# Calculated CV MAE for Baiersbronn Murg with MAE: 1.3070044593400425.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.8335882066589316.
# [0]	validation_0-rmse:20.17651
# [99]	validation_0-rmse:4.73087
# Calculated CV RMSE for Horb Neckar with RMSE: 4.730871104458329.
# Calculated CV MAE for Horb Neckar with MAE: 2.2383895434591508.
# Calculated CV NSE for Horb Neckar with NSE: 0.8753796475258133.
# [0]	validation_0-rmse:23.09251
# [99]	validation_0-rmse:4.11372
# Calculated CV RMSE for Horb Neckar with RMSE: 4.113722605170415.
# Calculated CV MAE for Horb Neckar with MAE: 2.0445451033062403.
# Calculated CV NSE for Horb Neckar with NSE: 0.9021143703364861.
# [0]	validation_0-rmse:10.81356
# [99]	validation_0-rmse:3.45357
# Calculated CV RMSE for Horb Neckar with RMSE: 3.453566790261698.
# Calculated CV MAE for Horb Neckar with MAE: 1.177425936047236.
# Calculated CV NSE for Horb Neckar with NSE: 0.46348254619551843.
# [0]	validation_0-rmse:7.22190
# [99]	validation_0-rmse:1.56085
# Calculated CV RMSE for Horb Neckar with RMSE: 1.5608476676525451.
# Calculated CV MAE for Horb Neckar with MAE: 0.6394766048643324.
# Calculated CV NSE for Horb Neckar with NSE: 0.7257614984810121.
# [0]	validation_0-rmse:4.96507
# [99]	validation_0-rmse:0.45948
# Calculated CV RMSE for Horb Neckar with RMSE: 0.4594805344850652.
# Calculated CV MAE for Horb Neckar with MAE: 0.31435615449481535.
# Calculated CV NSE for Horb Neckar with NSE: 0.8507718752394363.
# [0]	validation_0-rmse:4.32272
# [99]	validation_0-rmse:0.98113
# Calculated CV RMSE for Horb Neckar with RMSE: 0.9811314042100893.
# Calculated CV MAE for Horb Neckar with MAE: 0.3483808168040381.
# Calculated CV NSE for Horb Neckar with NSE: 0.4351536989607666.
# [0]	validation_0-rmse:18.36753
# [99]	validation_0-rmse:2.83143
# Calculated CV RMSE for Horb Neckar with RMSE: 2.8314329884772533.
# Calculated CV MAE for Horb Neckar with MAE: 1.212505104637146.
# Calculated CV NSE for Horb Neckar with NSE: 0.9257447282931095.
# [0]	validation_0-rmse:12.85140
# [99]	validation_0-rmse:0.91633
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.9163253071641773.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.4251337578455608.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8920467423593438.
# [0]	validation_0-rmse:18.13600
# [99]	validation_0-rmse:1.82379
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 1.8237860785136835.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.9008852426952785.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.7765299813693765.
# [0]	validation_0-rmse:11.70622
# [99]	validation_0-rmse:0.31872
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.31871776654403855.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.23356118507385248.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9915964644268814.
# [0]	validation_0-rmse:6.53091
# [99]	validation_0-rmse:0.36325
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.36324501466961684.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.2370017298327552.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.594682001657172.
# [0]	validation_0-rmse:4.98989
# [99]	validation_0-rmse:0.20795
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.20794681527262437.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.13225299914148117.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9047847716437458.
# [0]	validation_0-rmse:4.78952
# [99]	validation_0-rmse:0.32053
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.3205322569756039.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.19073320899009708.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8277890478546662.
# [0]	validation_0-rmse:8.24316
# [99]	validation_0-rmse:0.41325
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.41325368958171077.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.26898497404522365.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9576975678039109.
# [0]	validation_0-rmse:517.09760
# [99]	validation_0-rmse:4.87756
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.877558926608597.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.356231026882596.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9876306050884528.
# [0]	validation_0-rmse:647.88172
# [99]	validation_0-rmse:9.69045
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.690453250536196.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.503533547634548.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9753204767862385.
# [0]	validation_0-rmse:611.57882
# [99]	validation_0-rmse:5.89959
# Calculated CV RMSE for Konstanz Rhein with RMSE: 5.8995918322869105.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.920298471408419.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9900370053348952.
# [0]	validation_0-rmse:417.48359
# [99]	validation_0-rmse:2.39817
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.3981669818782065.
# Calculated CV MAE for Konstanz Rhein with MAE: 2.0055613555908196.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9992300905374426.
# [0]	validation_0-rmse:240.11324
# [99]	validation_0-rmse:1.73989
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7398867532745748.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.4707413950602213.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9954185124546153.
# [0]	validation_0-rmse:195.99536
# [99]	validation_0-rmse:1.37118
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.3711800475169598.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.1705680162217873.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9569040020885611.
# [0]	validation_0-rmse:202.92794
# [99]	validation_0-rmse:1.75679
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7567878235348409.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.459786773003473.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9700448760136791.
# [0]	validation_0-rmse:4.91311
# [99]	validation_0-rmse:2.78807
# Calculated CV RMSE for Binnrot Rot with RMSE: 2.788066672640495.
# Calculated CV MAE for Binnrot Rot with MAE: 0.6456760189798144.
# Calculated CV NSE for Binnrot Rot with NSE: 0.48932255541150527.
# [0]	validation_0-rmse:4.46348
# [99]	validation_0-rmse:1.40283
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.402826659983664.
# Calculated CV MAE for Binnrot Rot with MAE: 0.3951556711157163.
# Calculated CV NSE for Binnrot Rot with NSE: 0.817655044463437.
# [0]	validation_0-rmse:2.26642
# [99]	validation_0-rmse:0.56460
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.5646029161055784.
# Calculated CV MAE for Binnrot Rot with MAE: 0.20357229997979268.
# Calculated CV NSE for Binnrot Rot with NSE: 0.8264805768476519.
# [0]	validation_0-rmse:1.08401
# [99]	validation_0-rmse:0.10081
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.10080792201405277.
# Calculated CV MAE for Binnrot Rot with MAE: 0.05014204798407026.
# Calculated CV NSE for Binnrot Rot with NSE: 0.628654890488366.
# [0]	validation_0-rmse:0.94516
# [99]	validation_0-rmse:0.18666
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.18666060299946752.
# Calculated CV MAE for Binnrot Rot with MAE: 0.09240388930771085.
# Calculated CV NSE for Binnrot Rot with NSE: -1.4350736014638237.
# [0]	validation_0-rmse:0.88923
# [99]	validation_0-rmse:0.07921
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.07921251680001984.
# Calculated CV MAE for Binnrot Rot with MAE: 0.045173388459947374.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7565040294431441.
# [0]	validation_0-rmse:1.99762
# [99]	validation_0-rmse:0.41061
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.4106141694429486.
# Calculated CV MAE for Binnrot Rot with MAE: 0.17561492360168035.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7704623732708871.
# [0]	validation_0-rmse:6.23280
# [99]	validation_0-rmse:1.90776
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.9077550549299815.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.9633025495025846.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.6147009335096505.
# [0]	validation_0-rmse:22.12168
# [99]	validation_0-rmse:11.74196
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 11.741957376314607.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 3.199159706873364.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.6095127820538498.
# [0]	validation_0-rmse:4.88645
# [99]	validation_0-rmse:0.57944
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.5794374935913088.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.3629200466447407.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.8489762459818783.
# [0]	validation_0-rmse:3.08326
# [99]	validation_0-rmse:0.24515
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.24515441482033734.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.16941896042029064.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.658563260330151.
# [0]	validation_0-rmse:3.07911
# [99]	validation_0-rmse:0.34715
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.3471494978606995.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.21950196783277723.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.8223830078749834.
# [0]	validation_0-rmse:2.85681
# [99]	validation_0-rmse:0.37731
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.37731394571386295.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.19452539297209848.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.6861923147801634.
# [0]	validation_0-rmse:14.17292
# [99]	validation_0-rmse:1.87581
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.8758102895507893.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.0128490528292127.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.9631511512099916.
# [0]	validation_0-rmse:4.61533
# [99]	validation_0-rmse:1.58706
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.5870552614104094.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.5550166470044189.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.8408331234244752.
# [0]	validation_0-rmse:9.36790
# [99]	validation_0-rmse:4.58750
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 4.5874992748184376.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.297829098844528.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.6945978375746977.
# [0]	validation_0-rmse:10.61470
# [99]	validation_0-rmse:3.17944
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 3.17944429928989.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.0734546918484902.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.8818596689602473.
# [0]	validation_0-rmse:2.88575
# [99]	validation_0-rmse:1.41525
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.4152526814668347.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.3177371644152535.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.5649091865524407.
# [0]	validation_0-rmse:0.48916
# [99]	validation_0-rmse:0.34714
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.347135180014716.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.09863226680755616.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.3153537550047003.
# [0]	validation_0-rmse:1.37762
# [99]	validation_0-rmse:0.33278
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.33278010656943985.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.1471917664806048.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.9183912715602032.
# [0]	validation_0-rmse:10.37387
# [99]	validation_0-rmse:2.35610
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.3561008390011247.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.0181712128718694.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.9244216996221117.
# [0]	validation_0-rmse:5.78727
# [99]	validation_0-rmse:1.46687
# Calculated CV RMSE for Zell Wiese with RMSE: 1.46686526333667.
# Calculated CV MAE for Zell Wiese with MAE: 0.6809779724968805.
# Calculated CV NSE for Zell Wiese with NSE: 0.6149653445834009.
# [0]	validation_0-rmse:13.67080
# [99]	validation_0-rmse:2.65917
# Calculated CV RMSE for Zell Wiese with RMSE: 2.659168976550259.
# Calculated CV MAE for Zell Wiese with MAE: 0.9873757618082895.
# Calculated CV NSE for Zell Wiese with NSE: 0.9285336975381937.
# [0]	validation_0-rmse:2.70026
# [99]	validation_0-rmse:0.31925
# Calculated CV RMSE for Zell Wiese with RMSE: 0.3192499155835983.
# Calculated CV MAE for Zell Wiese with MAE: 0.1657183815545506.
# Calculated CV NSE for Zell Wiese with NSE: 0.930617713382178.
# [0]	validation_0-rmse:1.18930
# [99]	validation_0-rmse:0.34202
# Calculated CV RMSE for Zell Wiese with RMSE: 0.3420210284938112.
# Calculated CV MAE for Zell Wiese with MAE: 0.14875989101197984.
# Calculated CV NSE for Zell Wiese with NSE: 0.39037387772651266.
# [0]	validation_0-rmse:1.19274
# [99]	validation_0-rmse:0.36426
# Calculated CV RMSE for Zell Wiese with RMSE: 0.3642622993616678.
# Calculated CV MAE for Zell Wiese with MAE: 0.14688230487902962.
# Calculated CV NSE for Zell Wiese with NSE: 0.5255535053006922.
# [0]	validation_0-rmse:2.39996
# [99]	validation_0-rmse:0.95636
# Calculated CV RMSE for Zell Wiese with RMSE: 0.9563578493719282.
# Calculated CV MAE for Zell Wiese with MAE: 0.5399910478115082.
# Calculated CV NSE for Zell Wiese with NSE: 0.2761590519390976.
# [0]	validation_0-rmse:17.59716
# [99]	validation_0-rmse:2.99176
# Calculated CV RMSE for Zell Wiese with RMSE: 2.991760070706216.
# Calculated CV MAE for Zell Wiese with MAE: 1.2830951781749727.
# Calculated CV NSE for Zell Wiese with NSE: 0.9463989235931728.
# [0]	validation_0-rmse:8.57755
# [99]	validation_0-rmse:2.45613
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 2.456127294020641.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.8566075566715663.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.5838726931825443.
# [0]	validation_0-rmse:9.08907
# [99]	validation_0-rmse:1.26289
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 1.2628872816638002.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.5103767103248172.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.926591111494526.
# [0]	validation_0-rmse:3.07746
# [99]	validation_0-rmse:0.16421
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.16420785658101003.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.11234198635684119.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.9775636298139325.
# [0]	validation_0-rmse:1.61970
# [99]	validation_0-rmse:0.13450
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.13449916951200497.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.08000092369582917.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.7567955677012265.
# [0]	validation_0-rmse:1.27466
# [99]	validation_0-rmse:0.10478
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.10477875508181667.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.05028237462043764.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.8149178653494707.
# [0]	validation_0-rmse:1.28425
# [99]	validation_0-rmse:0.13437
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.13436689380707342.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.0637757787042194.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.8158892834520396.
# [0]	validation_0-rmse:8.54862
# [99]	validation_0-rmse:1.09125
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 1.091249056530996.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.49720236153602604.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.9651319455896599.
# [0]	validation_0-rmse:13.62054
# [99]	validation_0-rmse:3.17040
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 3.1704035357094207.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 1.3943774034341174.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.603394086258114.
# [0]	validation_0-rmse:19.06344
# [99]	validation_0-rmse:7.12888
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 7.128881947809604.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 2.0821177953826053.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.5776016635943152.
# [0]	validation_0-rmse:6.47150
# [99]	validation_0-rmse:0.41005
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.4100462221405261.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.23829996338420445.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.963911184136356.
# [0]	validation_0-rmse:3.58643
# [99]	validation_0-rmse:0.30538
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.30537554177567167.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.18260691978136695.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.5674897169856488.
# [0]	validation_0-rmse:2.93594
# [99]	validation_0-rmse:0.24332
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.24331614778236213.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.167165859108501.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.47743776326862675.
# [0]	validation_0-rmse:2.80842
# [99]	validation_0-rmse:0.20498
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.20497821352382212.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.14041070973873138.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.7662076289552915.
# [0]	validation_0-rmse:11.30427
# [99]	validation_0-rmse:1.57203
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 1.5720342933797462.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.6910265767309401.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.9476411020106864.
# [0]	validation_0-rmse:0.38299
# [99]	validation_0-rmse:0.30539
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.30539290473205366.
# Calculated CV MAE for Hausen Zaber with MAE: 0.10677399669008124.
# Calculated CV NSE for Hausen Zaber with NSE: 0.3358977602225456.
# [0]	validation_0-rmse:0.49176
# [99]	validation_0-rmse:0.35897
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.35896918687577817.
# Calculated CV MAE for Hausen Zaber with MAE: 0.11721907718413406.
# Calculated CV NSE for Hausen Zaber with NSE: 0.49138701306846255.
# [0]	validation_0-rmse:0.32985
# [99]	validation_0-rmse:0.22758
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.227583086546039.
# Calculated CV MAE for Hausen Zaber with MAE: 0.07141989020307858.
# Calculated CV NSE for Hausen Zaber with NSE: 0.3866007706777653.
# [0]	validation_0-rmse:0.25779
# [99]	validation_0-rmse:0.06302
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.06301727351075641.
# Calculated CV MAE for Hausen Zaber with MAE: 0.023925833249092105.
# Calculated CV NSE for Hausen Zaber with NSE: 0.30992570729607494.
# [0]	validation_0-rmse:0.31328
# [99]	validation_0-rmse:0.19082
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.19082405592407561.
# Calculated CV MAE for Hausen Zaber with MAE: 0.04880881833020183.
# Calculated CV NSE for Hausen Zaber with NSE: 0.44906673725130086.
# [0]	validation_0-rmse:0.21504
# [99]	validation_0-rmse:0.06062
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.06062425662376743.
# Calculated CV MAE for Hausen Zaber with MAE: 0.027695379154715274.
# Calculated CV NSE for Hausen Zaber with NSE: 0.7168301928795802.
# [0]	validation_0-rmse:0.20399
# [99]	validation_0-rmse:0.14363
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.14363302962400631.
# Calculated CV MAE for Hausen Zaber with MAE: 0.05650935526258415.
# Calculated CV NSE for Hausen Zaber with NSE: 0.5289682906305774.
# (     Stationsname  Fold  rmse validation  mae validation  nse validation  \
#  0    Gießen Argen     1         4.598023        1.649654        0.881716
#  1    Gießen Argen     2        10.391007        3.844398        0.852222
#  2    Gießen Argen     3         8.195585        2.809010        0.924400
#  3    Gießen Argen     4         2.317748        0.708130        0.807484
#  4    Gießen Argen     5         0.535410        0.283827        0.743224
#  ..            ...   ...              ...             ...             ...
#  170  Hausen Zaber     3         0.227583        0.071420        0.386601
#  171  Hausen Zaber     4         0.063017        0.023926        0.309926
#  172  Hausen Zaber     5         0.190824        0.048809        0.449067
#  173  Hausen Zaber     6         0.060624        0.027695        0.716830
#  174  Hausen Zaber     7         0.143633        0.056509        0.528968
#
#       nse train   nse gap
#  0     0.971699  0.089984
#  1     0.971478  0.119256
#  2     0.971254  0.046854
#  3     0.970964  0.163479
#  4     0.970488  0.227265
#  ..         ...       ...
#  170   0.872535  0.485934
#  171   0.871879  0.561953
#  172   0.871415  0.422348
#  173   0.871795  0.154964
#  174   0.873727  0.344759
#
#  [175 rows x 7 columns],
#                       Stationsname  mean_rmse_validation  mean_mae_validation  \
#  0              Bad Rotenfels Murg              3.850704             1.800220
#  1                Baiersbronn Murg              0.997862             0.376400
#  2                    Beuron Donau              0.978123             0.496007
#  3                     Binnrot Rot              0.790399             0.229677
#  4                 Blaubeuren Blau              0.333015             0.148158
#  5                   Bolheim Brenz              0.433279             0.204913
#  6               Elpershofen Jagst              1.907058             0.912095
#  7                    Eutingen Enz              2.425515             1.141054
#  8               Ewattingen Wutach              0.764017             0.310084
#  9                    Gießen Argen              4.547240             1.738700
#  10                 Hausach Kinzig              1.886665             0.815396
#  11                   Hausen Zaber              0.192863             0.064622
#  12                    Horb Neckar              2.590150             1.139297
#  13             Hundersingen Donau              1.730998             0.973562
#  14              Hüttlingen Kocher              0.729475             0.238404
#  15                 Konstanz Rhein              3.961947             3.269532
#  16           Mägerkingen Lauchert              0.118492             0.050950
#  17         Oberlauchringen Wutach              1.862148             0.699429
#  18           Rengers Untere Argen              1.972181             0.644005
#  19           Riegel Leopoldskanal              2.127766             0.995062
#  20  Rielasingen Radolfzeller Aach              0.623401             0.341222
#  21      Tauberbischofsheim Tauber              2.439225             0.874525
#  22                 Wannweil Echaz              1.560501             0.494818
#  23              Wiesloch Leimbach              0.175292             0.069668
#  24                     Zell Wiese              1.299955             0.564686
#
#      mean_nse_validation  mean_nse_train
#  0              0.571479        0.954766
#  1              0.444296        0.920986
#  2              0.936230        0.996024
#  3              0.407715        0.942842
#  4              0.830060        0.996108
#  5              0.470664        0.958953
#  6              0.801474        0.984210
#  7              0.663433        0.980668
#  8              0.834395        0.982712
#  9              0.874852        0.971171
#  10             0.795573        0.979786
#  11             0.459811        0.872859
#  12             0.739773        0.981194
#  13             0.840671        0.996983
#  14             0.296235        0.880905
#  15             0.982084        0.999512
#  16             0.882713        0.981348
#  17             0.700526        0.981166
#  18             0.644237        0.951693
#  19             0.898283        0.986515
#  20             0.849304        0.990833
#  21             0.743354        0.987402
#  22             0.280453        0.808935
#  23             0.399302        0.811238
#  24             0.658943        0.982323  ,
#  np.float64(0.6802343585454683),
#  np.float64(0.9552452255251075),
#  np.float64(0.27501086697963917))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


# cross validation without exogene features
def cross_validation():
    train_test = train_and_test_nan()
    
    pred = []
    scores = []
    # Cross Validation for every of the 25 stations in Baden-Württemberg with the best hyper parameter from the hyper parameter tuning.
    for t in train_test:
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()

        exogene_features = train_water.filter(regex=r"^Niederschlag").columns

        # defining forecast horizon to forecast six hours in the future (Q(t) --> Q(t+6)).
        train_water["y"] = train_water["Abfluss in m^3/s"].shift(-6)

        # the last six rows of y is NaN due to the shift by six hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train_water = train_water.dropna(subset=["y"])

        # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast.
        # We keep "Abfluss in m^3/s" as current value and the last known runoff which is important for the prediction.
        x = train_water.drop(columns=["y", *exogene_features])
        y = train_water["y"]
        
        station = t["Stationsname"]

        # define Time Series Spliit for the Cross validation. I evaluate the model on 720 hour validation windows using one hour forecasts. 
        # To avoid leakage between train and validation I use a gap of six hours.
        tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=6)
        fold = 0

        # split the train set into seven folds for the cross validation and use XGBoostRegressor with the respective hyperparameter combination.
        for train_idx, validation_idx in tss.split(x):
            fold += 1
            x_train = x.iloc[train_idx]
            x_validation = x.iloc[validation_idx]
            y_train = y.iloc[train_idx]
            y_validation = y.iloc[validation_idx]

            # Define XGBoost model with the best hyperparameter combination identified in the hyperparameter tuning
            model = xgb.XGBRegressor(
                n_estimators=100, 
                max_depth=8, 
                min_child_weight=20,
                learning_rate=0.05, 
                subsample=0.5, 
                colsample_bytree=1.0, 
                base_score=0.5, 
                tree_method="hist", 
                n_jobs = -1, 
                random_state=42,
                eval_metric="rmse")
            
            model.fit(x_train, y_train, eval_set=[(x_validation, y_validation)], verbose=100)

        
            # Predict the respective validation set per fold
            y_pred_validation = model.predict(x_validation)
            pred.append({
                "Stationsname": station,
                "Fold": fold, 
                "Vorhersage": y_pred_validation
            })

            # Predict the respective validation set per fold to ceck for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting.
            y_pred_train = model.predict(x_train)

            # Calculate the evaluation metrics "RMSE", "MAE" and "NSE" for the prediction of the validation set per fold.
            rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
            mae_validation = mean_absolute_error(y_validation, y_pred_validation)
            nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

            # Calculate "NSE" and "NSE gap" per fold to identify potential model overfitting.
            nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)
            nse_gap = nse_train - nse_validation

            # store evaluation metrics for this station and fold in score
            scores.append({
                "Stationsname": station,
                "Fold": fold,
                "rmse validation": rmse_validation,
                "mae validation": mae_validation,
                "nse validation": nse_validation,
                "nse train": nse_train,
                "nse gap": nse_gap
            })
            print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
            print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
            print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

         

    # calculate the mean evaluation metrics over the folds with the same station. This enables to compare the scores with the other cv, to identify the importance of the exogene features.
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby("Stationsname")[["rmse validation", "mae validation", "nse validation", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "nse train": "mean_nse_train"})

    overall_mean_nse = mean_per_station["mean_nse_validation"].mean()
    overall_mean_nse_train = mean_per_station["mean_nse_train"].mean()
    overall_nse_gap = overall_mean_nse_train - overall_mean_nse
    
    return scores_df, mean_per_station, overall_mean_nse, overall_mean_nse_train, overall_nse_gap

cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# [0]	validation_0-rmse:17.45148
# [99]	validation_0-rmse:5.12920
# Calculated CV RMSE for Gießen Argen with RMSE: 5.12919545289305.
# Calculated CV MAE for Gießen Argen with MAE: 1.9452561429659523.
# Calculated CV NSE for Gießen Argen with NSE: 0.8528080601717009.
# [0]	validation_0-rmse:35.01958
# [99]	validation_0-rmse:11.64013
# Calculated CV RMSE for Gießen Argen with RMSE: 11.640127666375378.
# Calculated CV MAE for Gießen Argen with MAE: 4.104903002124363.
# Calculated CV NSE for Gießen Argen with NSE: 0.8145574046948592.
# [0]	validation_0-rmse:36.63524
# [99]	validation_0-rmse:9.99004
# Calculated CV RMSE for Gießen Argen with RMSE: 9.990035535953643.
# Calculated CV MAE for Gießen Argen with MAE: 3.6194329516092933.
# Calculated CV NSE for Gießen Argen with NSE: 0.8876698621289278.
# [0]	validation_0-rmse:10.25818
# [99]	validation_0-rmse:2.76808
# Calculated CV RMSE for Gießen Argen with RMSE: 2.768075955726366.
# Calculated CV MAE for Gießen Argen with MAE: 0.8955575670030381.
# Calculated CV NSE for Gießen Argen with NSE: 0.7254067417819605.
# [0]	validation_0-rmse:4.86501
# [99]	validation_0-rmse:0.71427
# Calculated CV RMSE for Gießen Argen with RMSE: 0.714267500275813.
# Calculated CV MAE for Gießen Argen with MAE: 0.34847779445118376.
# Calculated CV NSE for Gießen Argen with NSE: 0.5430127980383626.
# [0]	validation_0-rmse:9.27183
# [99]	validation_0-rmse:1.71832
# Calculated CV RMSE for Gießen Argen with RMSE: 1.7183239476789265.
# Calculated CV MAE for Gießen Argen with MAE: 0.7471933068275453.
# Calculated CV NSE for Gießen Argen with NSE: 0.9088555991442191.
# [0]	validation_0-rmse:35.55425
# [99]	validation_0-rmse:6.20096
# Calculated CV RMSE for Gießen Argen with RMSE: 6.200963227410636.
# Calculated CV MAE for Gießen Argen with MAE: 2.5650044014930726.
# Calculated CV NSE for Gießen Argen with NSE: 0.9281388506227662.
# [0]	validation_0-rmse:1.40219
# [99]	validation_0-rmse:0.21340
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.21340228904408773.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.12360153376526303.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.6560173404735274.
# [0]	validation_0-rmse:7.76439
# [99]	validation_0-rmse:1.68064
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 1.6806420082332691.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.5654364425367778.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.8893051259923596.
# [0]	validation_0-rmse:2.24364
# [99]	validation_0-rmse:0.10845
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.10845296443460904.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.08708220833407508.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9133485511480598.
# [0]	validation_0-rmse:1.58210
# [99]	validation_0-rmse:0.10135
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.10135063093272298.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.08032234084208806.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9187726415490441.
# [0]	validation_0-rmse:0.89963
# [99]	validation_0-rmse:0.08111
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.081110823174611.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.06417669797870848.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.7572965208607289.
# [0]	validation_0-rmse:0.63052
# [99]	validation_0-rmse:0.06342
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.0634223793382859.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.046829273534483386.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.641226335738299.
# [0]	validation_0-rmse:1.75354
# [99]	validation_0-rmse:0.12940
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.12940490881100056.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.09361312213738758.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9807566355219365.
# [0]	validation_0-rmse:3.11111
# [99]	validation_0-rmse:0.62097
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.6209742796027429.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.30853082450760727.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.1890161909480964.
# [0]	validation_0-rmse:4.25508
# [99]	validation_0-rmse:0.95079
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.9507932180392183.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.3999401484330495.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.6126358328177648.
# [0]	validation_0-rmse:3.04299
# [99]	validation_0-rmse:0.49983
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.4998266286488185.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.2679482574674818.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.2722984824445981.
# [0]	validation_0-rmse:2.45210
# [99]	validation_0-rmse:0.16513
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.16512998015746772.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.12161544745763143.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.45167520283722984.
# [0]	validation_0-rmse:2.15806
# [99]	validation_0-rmse:0.30163
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.3016319314634975.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.15684820566177368.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.28915766457505254.
# [0]	validation_0-rmse:1.79894
# [99]	validation_0-rmse:0.26107
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.26107086251397466.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.12156207784016929.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.38770713473028195.
# [0]	validation_0-rmse:2.65818
# [99]	validation_0-rmse:0.35116
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.35115644042826527.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.19292986315621272.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.8414743718621405.
# [0]	validation_0-rmse:19.60994
# [99]	validation_0-rmse:2.84124
# Calculated CV RMSE for Beuron Donau with RMSE: 2.8412390565300263.
# Calculated CV MAE for Beuron Donau with MAE: 1.3451979734473758.
# Calculated CV NSE for Beuron Donau with NSE: 0.9534001975915386.
# [0]	validation_0-rmse:23.47712
# [99]	validation_0-rmse:1.92358
# Calculated CV RMSE for Beuron Donau with RMSE: 1.923584553739573.
# Calculated CV MAE for Beuron Donau with MAE: 1.1357062236520978.
# Calculated CV NSE for Beuron Donau with NSE: 0.9720371405349549.
# [0]	validation_0-rmse:5.71550
# [99]	validation_0-rmse:0.69080
# Calculated CV RMSE for Beuron Donau with RMSE: 0.6908025142721441.
# Calculated CV MAE for Beuron Donau with MAE: 0.41699938684569465.
# Calculated CV NSE for Beuron Donau with NSE: 0.9324145342576541.
# [0]	validation_0-rmse:2.20234
# [99]	validation_0-rmse:0.20991
# Calculated CV RMSE for Beuron Donau with RMSE: 0.20990994341651042.
# Calculated CV MAE for Beuron Donau with MAE: 0.12197985203133689.
# Calculated CV NSE for Beuron Donau with NSE: 0.8892810268737024.
# [0]	validation_0-rmse:1.03121
# [99]	validation_0-rmse:0.08862
# Calculated CV RMSE for Beuron Donau with RMSE: 0.08862080309842307.
# Calculated CV MAE for Beuron Donau with MAE: 0.056882463840643556.
# Calculated CV NSE for Beuron Donau with NSE: 0.9230984752274033.
# [0]	validation_0-rmse:0.66157
# [99]	validation_0-rmse:0.07640
# Calculated CV RMSE for Beuron Donau with RMSE: 0.07640071984543566.
# Calculated CV MAE for Beuron Donau with MAE: 0.042234312981367116.
# Calculated CV NSE for Beuron Donau with NSE: 0.894200999621384.
# [0]	validation_0-rmse:13.49883
# [99]	validation_0-rmse:1.60915
# Calculated CV RMSE for Beuron Donau with RMSE: 1.609154086140033.
# Calculated CV MAE for Beuron Donau with MAE: 0.6383135260575347.
# Calculated CV NSE for Beuron Donau with NSE: 0.9710287244559331.
# [0]	validation_0-rmse:37.56881
# [99]	validation_0-rmse:3.38159
# Calculated CV RMSE for Hundersingen Donau with RMSE: 3.381589490163524.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.781433002090454.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.975869716231472.
# [0]	validation_0-rmse:54.81462
# [99]	validation_0-rmse:4.41762
# Calculated CV RMSE for Hundersingen Donau with RMSE: 4.41761918863041.
# Calculated CV MAE for Hundersingen Donau with MAE: 2.436932606739468.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9613233323128232.
# [0]	validation_0-rmse:19.90909
# [99]	validation_0-rmse:0.74686
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.7468603952822493.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.5047645922660828.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9813473059811174.
# [0]	validation_0-rmse:11.70394
# [99]	validation_0-rmse:0.48534
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.4853419861843687.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.34555858627955116.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9199372806694108.
# [0]	validation_0-rmse:7.90028
# [99]	validation_0-rmse:0.70467
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.7046677470483349.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.5366239001909893.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.5803489510131654.
# [0]	validation_0-rmse:6.20347
# [99]	validation_0-rmse:0.68165
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.6816451618495336.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.5532656385898591.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.3830532636013462.
# [0]	validation_0-rmse:20.94590
# [99]	validation_0-rmse:2.22055
# Calculated CV RMSE for Hundersingen Donau with RMSE: 2.2205518002582725.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.9956009484185113.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.9579334424624585.
# [0]	validation_0-rmse:7.93323
# [99]	validation_0-rmse:7.00084
# Calculated CV RMSE for Wannweil Echaz with RMSE: 7.00083520626546.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.3881984514223202.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.0766704442103251.
# [0]	validation_0-rmse:5.07996
# [99]	validation_0-rmse:1.79560
# Calculated CV RMSE for Wannweil Echaz with RMSE: 1.7955980058244536.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.8140933753940793.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.4439943419106924.
# [0]	validation_0-rmse:2.06268
# [99]	validation_0-rmse:0.84734
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.8473424449776039.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.5635254184828864.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.34770170123174204.
# [0]	validation_0-rmse:1.24044
# [99]	validation_0-rmse:0.39735
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.39734668457615335.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.30903258300357395.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.2242791799575652.
# [0]	validation_0-rmse:0.71968
# [99]	validation_0-rmse:0.35290
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.3529015328060962.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.18245752048161296.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.02178886024074478.
# [0]	validation_0-rmse:0.50427
# [99]	validation_0-rmse:0.21832
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.2183151629397175.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.14137372149957553.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.3826784767794684.
# [0]	validation_0-rmse:1.51253
# [99]	validation_0-rmse:0.55790
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.557895465481582.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.27088098798592886.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.47309605853746894.
# [0]	validation_0-rmse:17.61352
# [99]	validation_0-rmse:8.38161
# Calculated CV RMSE for Eutingen Enz with RMSE: 8.38160675506218.
# Calculated CV MAE for Eutingen Enz with MAE: 3.183175905895233.
# Calculated CV NSE for Eutingen Enz with NSE: 0.29674095486646357.
# [0]	validation_0-rmse:21.77458
# [99]	validation_0-rmse:4.89712
# Calculated CV RMSE for Eutingen Enz with RMSE: 4.897115105271123.
# Calculated CV MAE for Eutingen Enz with MAE: 1.9887228280279374.
# Calculated CV NSE for Eutingen Enz with NSE: 0.8282407510729698.
# [0]	validation_0-rmse:10.58734
# [99]	validation_0-rmse:1.78520
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.7852022450420801.
# Calculated CV MAE for Eutingen Enz with MAE: 1.1633494317160713.
# Calculated CV NSE for Eutingen Enz with NSE: 0.6525826001293377.
# [0]	validation_0-rmse:7.52648
# [99]	validation_0-rmse:1.32476
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.3247593655821592.
# Calculated CV MAE for Eutingen Enz with MAE: 0.6046149864408706.
# Calculated CV NSE for Eutingen Enz with NSE: 0.3181296973242258.
# [0]	validation_0-rmse:7.53404
# [99]	validation_0-rmse:1.18960
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.1896023237849171.
# Calculated CV MAE for Eutingen Enz with MAE: 0.5769785888459948.
# Calculated CV NSE for Eutingen Enz with NSE: 0.506079195077396.
# [0]	validation_0-rmse:6.44038
# [99]	validation_0-rmse:0.54077
# Calculated CV RMSE for Eutingen Enz with RMSE: 0.5407693404911089.
# Calculated CV MAE for Eutingen Enz with MAE: 0.3965490272680918.
# Calculated CV NSE for Eutingen Enz with NSE: 0.

# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.7310511169936922.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.5885015916249811.
# [0]	validation_0-rmse:3.97740
# [99]	validation_0-rmse:1.43034
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.4303434752312498.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.621605423339208.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.09364994883101652.
# [0]	validation_0-rmse:5.72976
# [99]	validation_0-rmse:1.32274
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.322737344042964.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 0.8412868095821804.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.6566049202323174.
# [0]	validation_0-rmse:34.17663
# [99]	validation_0-rmse:13.61631
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 13.61631357588003.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 5.041007659037908.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.7456723170266779.
# [0]	validation_0-rmse:3.51420
# [99]	validation_0-rmse:1.54638
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.5463788879857852.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.6185608271453116.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.7319179073798519.
# [0]	validation_0-rmse:3.10720
# [99]	validation_0-rmse:1.05003
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.0500293784797567.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.3970389017250803.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.7871868131437477.
# [0]	validation_0-rmse:0.64678
# [99]	validation_0-rmse:0.24478
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.24478078382625124.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.16440452811320622.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.5024025226949629.
# [0]	validation_0-rmse:0.21784
# [99]	validation_0-rmse:0.06783
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.0678266498591771.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.04329997159043948.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.29601575153558346.
# [0]	validation_0-rmse:0.47858
# [99]	validation_0-rmse:0.24067
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.24066787859217778.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.09979236184623505.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.48501899429646167.
# [0]	validation_0-rmse:1.32282
# [99]	validation_0-rmse:0.48810
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.4881005593207916.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.1744212027748426.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.765564454447869.
# [0]	validation_0-rmse:10.53951
# [99]	validation_0-rmse:4.12286
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 4.122856796607712.
# Calculated CV MAE for Baiersbronn Murg with MAE: 1.595175454764896.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.783405963815117.
# [0]	validation_0-rmse:20.23915
# [99]	validation_0-rmse:5.62464
# Calculated CV RMSE for Horb Neckar with RMSE: 5.6246426757952435.
# Calculated CV MAE for Horb Neckar with MAE: 2.7260501625855764.
# Calculated CV NSE for Horb Neckar with NSE: 0.8238443329050493.
# [0]	validation_0-rmse:23.09236
# [99]	validation_0-rmse:5.61892
# Calculated CV RMSE for Horb Neckar with RMSE: 5.618922484255559.
# Calculated CV MAE for Horb Neckar with MAE: 2.687062474091848.
# Calculated CV NSE for Horb Neckar with NSE: 0.8173771928622827.
# [0]	validation_0-rmse:10.80572
# [99]	validation_0-rmse:4.17226
# Calculated CV RMSE for Horb Neckar with RMSE: 4.172264362160104.
# Calculated CV MAE for Horb Neckar with MAE: 1.4066433208359612.
# Calculated CV NSE for Horb Neckar with NSE: 0.2169458915136756.
# [0]	validation_0-rmse:7.23220
# [99]	validation_0-rmse:1.68634
# Calculated CV RMSE for Horb Neckar with RMSE: 1.6863375208233682.
# Calculated CV MAE for Horb Neckar with MAE: 0.7543625627570681.
# Calculated CV NSE for Horb Neckar with NSE: 0.6798920988147741.
# [0]	validation_0-rmse:4.96660
# [99]	validation_0-rmse:0.53945
# Calculated CV RMSE for Horb Neckar with RMSE: 0.539450809686847.
# Calculated CV MAE for Horb Neckar with MAE: 0.34988005560768975.
# Calculated CV NSE for Horb Neckar with NSE: 0.7943067003704273.
# [0]	validation_0-rmse:4.32485
# [99]	validation_0-rmse:0.74419
# Calculated CV RMSE for Horb Neckar with RMSE: 0.7441930727446837.
# Calculated CV MAE for Horb Neckar with MAE: 0.2672201131608751.
# Calculated CV NSE for Horb Neckar with NSE: 0.6750270734336552.
# [0]	validation_0-rmse:18.36534
# [99]	validation_0-rmse:3.64762
# Calculated CV RMSE for Horb Neckar with RMSE: 3.6476168314315593.
# Calculated CV MAE for Horb Neckar with MAE: 1.4791445982403224.
# Calculated CV NSE for Horb Neckar with NSE: 0.8767652642009381.
# [0]	validation_0-rmse:12.85140
# [99]	validation_0-rmse:0.93901
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.9390108320454135.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.42850502976311583.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8866353649253851.
# [0]	validation_0-rmse:18.13600
# [99]	validation_0-rmse:2.04001
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 2.04001124562367.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 1.0292003946092394.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.720400367910182.
# [0]	validation_0-rmse:11.70622
# [99]	validation_0-rmse:0.34196
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.3419600285289667.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.2513950394365522.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9903261313715959.
# [0]	validation_0-rmse:6.53091
# [99]	validation_0-rmse:0.37153
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.37153500951059365.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.24406884714762372.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.5759705205522722.
# [0]	validation_0-rmse:4.98989
# [99]	validation_0-rmse:0.20691
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.20690689271618606.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.13031101316346064.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9057347152869974.
# [0]	validation_0-rmse:4.78952
# [99]	validation_0-rmse:0.32536
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.3253614489448836.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.19406873318354287.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8225608404599992.
# [0]	validation_0-rmse:8.24316
# [99]	validation_0-rmse:0.39720
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.39719550214344845.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.2482958123948839.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.960921264506377.
# [0]	validation_0-rmse:517.09760
# [99]	validation_0-rmse:4.58964
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.589641055385322.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.9769776048448344.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.989047813036198.
# [0]	validation_0-rmse:647.88172
# [99]	validation_0-rmse:9.94768
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.947682015237927.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.823472427707247.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9739928733647883.
# [0]	validation_0-rmse:611.57882
# [99]	validation_0-rmse:5.84296
# Calculated CV RMSE for Konstanz Rhein with RMSE: 5.84296174219354.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.772760719129773.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9902273566007366.
# [0]	validation_0-rmse:417.48359
# [99]	validation_0-rmse:2.23306
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.2330582661046035.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8643848937988279.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9993324544135284.
# [0]	validation_0-rmse:240.11324
# [99]	validation_0-rmse:1.51141
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.5114145622348918.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.2197760476006403.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9965427423075743.
# [0]	validation_0-rmse:195.99536
# [99]	validation_0-rmse:1.37249
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.3724932459177244.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.1754031650119348.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9568214152745537.
# [0]	validation_0-rmse:202.92794
# [99]	validation_0-rmse:1.72898
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.7289758644458266.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.4188905907524962.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9709858162053215.
# [0]	validation_0-rmse:4.91757
# [99]	validation_0-rmse:3.01287
# Calculated CV RMSE for Binnrot Rot with RMSE: 3.012872858064759.
# Calculated CV MAE for Binnrot Rot with MAE: 0.6846893287433519.
# Calculated CV NSE for Binnrot Rot with NSE: 0.40364896628721425.
# [0]	validation_0-rmse:4.46523
# [99]	validation_0-rmse:1.72646
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.726458832870363.
# Calculated CV MAE for Binnrot Rot with MAE: 0.5454237572458055.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7238162094327512.
# [0]	validation_0-rmse:2.26367
# [99]	validation_0-rmse:0.67567
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.6756690523292828.
# Calculated CV MAE for Binnrot Rot with MAE: 0.2848344429996279.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7514979840660778.
# [0]	validation_0-rmse:1.08292
# [99]	validation_0-rmse:0.15965
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.15965286042104657.
# Calculated CV MAE for Binnrot Rot with MAE: 0.08154473352564706.
# Calculated CV NSE for Binnrot Rot with NSE: 0.06858808011985273.
# [0]	validation_0-rmse:0.94553
# [99]	validation_0-rmse:0.15212
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.1521222457278409.
# Calculated CV MAE for Binnrot Rot with MAE: 0.08005862265825271.
# Calculated CV NSE for Binnrot Rot with NSE: -0.6173060824290042.
# [0]	validation_0-rmse:0.88790
# [99]	validation_0-rmse:0.09061
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.0906148998687635.
# Calculated CV MAE for Binnrot Rot with MAE: 0.052078699897395234.
# Calculated CV NSE for Binnrot Rot with NSE: 0.6813577323917281.
# [0]	validation_0-rmse:1.99776
# [99]	validation_0-rmse:0.39563
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.3956303986108398.
# Calculated CV MAE for Binnrot Rot with MAE: 0.18958634916014144.
# Calculated CV NSE for Binnrot Rot with NSE: 0.7869088906016641.
# [0]	validation_0-rmse:6.23394
# [99]	validation_0-rmse:2.12155
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 2.1215506951718264.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.058533112311363.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.5235036716282755.
# [0]	validation_0-rmse:22.12336
# [99]	validation_0-rmse:13.76026
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 13.760260347182196.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 3.8393408283127686.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.46373540492659937.
# [0]	validation_0-rmse:4.88806
# [99]	validation_0-rmse:0.60841
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.6084075970033739.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.4051788942946328.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.8334972806808925.
# [0]	validation_0-rmse:3.08223
# [99]	validation_0-rmse:0.34222
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.34222434375567184.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.27045733238855996.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.33464624479288396.
# [0]	validation_0-rmse:3.08004
# [99]	validation_0-rmse:0.39990
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.3998963778041491.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.24624738667805993.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.7643071710488235.
# [0]	validation_0-rmse:2.85492
# [99]	validation_0-rmse:0.40581
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.40581145559024767.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.2151306937562095.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.637000133032996.
# [0]	validation_0-rmse:14.16514
# [99]	validation_0-rmse:2.12779
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 2.127792985459745.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.1036564178201886.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.9525861913656573.
# [0]	validation_0-rmse:4.62171
# [99]	validation_0-rmse:2.52898
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.5289813802939265.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.77505114131901.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.5958339226935067.
# [0]	validation_0-rmse:9.37015
# [99]	validation_0-rmse:5.06383
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 5.063833528864916.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.6420570456842578.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.6278834973178771.
# [0]	validation_0-rmse:10.62286
# [99]	validation_0-rmse:3.50760
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 3.5075951740877924.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.2318420987844467.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.856214639949887.
# [0]	validation_0-rmse:2.87152
# [99]	validation_0-rmse:1.47003
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.4700286054314033.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.4409045173883438.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.53057792109649.
# [0]	validation_0-rmse:0.48835
# [99]	validation_0-rmse:0.27216
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.2721604171202334.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.09309617128372191.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.19147168302222606.
# [0]	validation_0-rmse:1.37072
# [99]	validation_0-rmse:0.50353
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.5035263826192419.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.2140938590672281.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.8131615054001342.
# [0]	validation_0-rmse:10.36123
# [99]	validation_0-rmse:3.02110
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 3.02109669623482.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.1034002694381608.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.8757379181897534.
# [0]	validation_0-rmse:5.79478
# [99]	validation_0-rmse:1.46483
# Calculated CV RMSE for Zell Wiese with RMSE: 1.4648324938847763.
# Calculated CV MAE for Zell Wiese with MAE: 0.7324465717421638.
# Calculated CV NSE for Zell Wiese with NSE: 0.6160317606813376.
# [0]	validation_0-rmse:13.67230
# [99]	validation_0-rmse:3.18062
# Calculated CV RMSE for Zell Wiese with RMSE: 3.1806209111136465.
# Calculated CV MAE for Zell Wiese with MAE: 1.268375435143047.
# Calculated CV NSE for Zell Wiese with NSE: 0.8977570757885897.
# [0]	validation_0-rmse:2.70087
# [99]	validation_0-rmse:0.47044
# Calculated CV RMSE for Zell Wiese with RMSE: 0.4704400278285256.
# Calculated CV MAE for Zell Wiese with MAE: 0.27447349202897814.
# Calculated CV NSE for Zell Wiese with NSE: 0.8493408334829493.
# [0]	validation_0-rmse:1.18986
# [99]	validation_0-rmse:0.46843
# Calculated CV RMSE for Zell Wiese with RMSE: 0.46842643073579837.
# Calculated CV MAE for Zell Wiese with MAE: 0.24043509152332945.
# Calculated CV NSE for Zell Wiese with NSE: -0.14351202186758139.
# [0]	validation_0-rmse:1.19517
# [99]	validation_0-rmse:0.51389
# Calculated CV RMSE for Zell Wiese with RMSE: 0.5138927139314061.
# Calculated CV MAE for Zell Wiese with MAE: 0.22760214538441764.
# Calculated CV NSE for Zell Wiese with NSE: 0.05571364667285561.
# [0]	validation_0-rmse:2.40112
# [99]	validation_0-rmse:0.60656
# Calculated CV RMSE for Zell Wiese with RMSE: 0.6065552192308292.
# Calculated CV MAE for Zell Wiese with MAE: 0.27552486468288634.
# Calculated CV NSE for Zell Wiese with NSE: 0.7088324431203528.
# [0]	validation_0-rmse:17.62610
# [99]	validation_0-rmse:2.90929
# Calculated CV RMSE for Zell Wiese with RMSE: 2.909293409427555.
# Calculated CV MAE for Zell Wiese with MAE: 1.3092799465974172.
# Calculated CV NSE for Zell Wiese with NSE: 0.9493131812807544.
# [0]	validation_0-rmse:8.58285
# [99]	validation_0-rmse:2.85982
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 2.859820169162568.
# Calculated CV MAE for Ewattingen Wutach with MAE: 1.0651194573031533.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.4358404780640627.
# [0]	validation_0-rmse:9.11387
# [99]	validation_0-rmse:2.26624
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 2.2662399797477444.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.9131213115427229.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.7636088230089234.
# [0]	validation_0-rmse:3.07789
# [99]	validation_0-rmse:0.27333
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.2733339269020217.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.1595510611746046.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.9378341588954342.
# [0]	validation_0-rmse:1.61947
# [99]	validation_0-rmse:0.18606
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.18605799840001866.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.09440287540356315.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.5345972242931356.
# [0]	validation_0-rmse:1.27590
# [99]	validation_0-rmse:0.13192
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.13191854081894963.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.049426993978023526.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.7066205370485441.
# [0]	validation_0-rmse:1.28546
# [99]	validation_0-rmse:0.13136
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.13136184572143603.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.06514537272188396.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.8240322840440657.
# [0]	validation_0-rmse:8.54260
# [99]	validation_0-rmse:2.08463
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 2.0846254374004283.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.8823769602510664.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.8727563793206577.
# [0]	validation_0-rmse:13.63201
# [99]	validation_0-rmse:3.33450
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 3.3345003975923397.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 1.5458424584070842.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.5612757447836214.
# [0]	validation_0-rmse:19.10057
# [99]	validation_0-rmse:7.42471
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 7.4247086125846256.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 2.1893723179923166.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.541817833510258.
# [0]	validation_0-rmse:6.47237
# [99]	validation_0-rmse:0.54353
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.5435320196162085.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.35240127727190657.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.9365900706173532.
# [0]	validation_0-rmse:3.58558
# [99]	validation_0-rmse:0.33555
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.33554846528453575.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.19768412599033777.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.4777980971582134.
# [0]	validation_0-rmse:2.93659
# [99]	validation_0-rmse:0.25382
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.25382492026426046.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.1631047588798735.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.43132429489166846.
# [0]	validation_0-rmse:2.81007
# [99]	validation_0-rmse:0.20848
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.20848106958076373.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.14170166024896835.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.7581488365878084.
# [0]	validation_0-rmse:11.29869
# [99]	validation_0-rmse:2.07695
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 2.076950063345281.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.8691210809707641.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.9086058127084499.
# [0]	validation_0-rmse:0.38515
# [99]	validation_0-rmse:0.35485
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.3548535216815962.
# Calculated CV MAE for Hausen Zaber with MAE: 0.12758696574403178.
# Calculated CV NSE for Hausen Zaber with NSE: 0.10336580253950323.
# [0]	validation_0-rmse:0.49659
# [99]	validation_0-rmse:0.44302
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.4430160690519652.
# Calculated CV MAE for Hausen Zaber with MAE: 0.1448945612958736.
# Calculated CV NSE for Hausen Zaber with NSE: 0.2253383418783168.
# [0]	validation_0-rmse:0.33079
# [99]	validation_0-rmse:0.24863
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.24863145188482078.
# Calculated CV MAE for Hausen Zaber with MAE: 0.09801078018529549.
# Calculated CV NSE for Hausen Zaber with NSE: 0.2678915967441057.
# [0]	validation_0-rmse:0.25823
# [99]	validation_0-rmse:0.08935
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.08935225381638374.
# Calculated CV MAE for Hausen Zaber with MAE: 0.05696259531113837.
# Calculated CV NSE for Hausen Zaber with NSE: -0.3873551601316494.
# [0]	validation_0-rmse:0.31470
# [99]	validation_0-rmse:0.22195
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.22194902240599038.
# Calculated CV MAE for Hausen Zaber with MAE: 0.06441402011960745.
# Calculated CV NSE for Hausen Zaber with NSE: 0.2546860982159721.
# [0]	validation_0-rmse:0.21542
# [99]	validation_0-rmse:0.07776
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.07776121238831489.
# Calculated CV MAE for Hausen Zaber with MAE: 0.0415739381780227.
# Calculated CV NSE for Hausen Zaber with NSE: 0.5341134865320631.
# [0]	validation_0-rmse:0.20575
# [99]	validation_0-rmse:0.15507
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.15507112105901724.
# Calculated CV MAE for Hausen Zaber with MAE: 0.08159737298323048.
# Calculated CV NSE for Hausen Zaber with NSE: 0.4509607971231564.
# (     Stationsname  Fold  rmse validation  mae validation  nse validation  \
#  0    Gießen Argen     1         5.129195        1.945256        0.852808
#  1    Gießen Argen     2        11.640128        4.104903        0.814557
#  2    Gießen Argen     3         9.990036        3.619433        0.887670
#  3    Gießen Argen     4         2.768076        0.895558        0.725407
#  4    Gießen Argen     5         0.714268        0.348478        0.543013
#  ..            ...   ...              ...             ...             ...
#  170  Hausen Zaber     3         0.248631        0.098011        0.267892
#  171  Hausen Zaber     4         0.089352        0.056963       -0.387355
#  172  Hausen Zaber     5         0.221949        0.064414        0.254686
#  173  Hausen Zaber     6         0.077761        0.041574        0.534113
#  174  Hausen Zaber     7         0.155071        0.081597        0.450961
#
#       nse train   nse gap
#  0     0.957328  0.104520
#  1     0.957843  0.143285
#  2     0.957346  0.069676
#  3     0.957653  0.232246
#  4     0.957784  0.414772
#  ..         ...       ...
#  170   0.846059  0.578167
#  171   0.844537  1.231892
#  172   0.846495  0.591809
#  173   0.846070  0.311956
#  174   0.846578  0.395617
#
#  [175 rows x 7 columns],
#                       Stationsname  mean_rmse_validation  mean_mae_validation  \
#  0              Bad Rotenfels Murg              4.572807             2.065660
#  1                Baiersbronn Murg              1.108663             0.441813
#  2                    Beuron Donau              1.062816             0.536759
#  3                     Binnrot Rot              0.887574             0.274031
#  4                 Blaubeuren Blau              0.339684             0.151580
#  5                   Bolheim Brenz              0.450083             0.224196
#  6               Elpershofen Jagst              2.509369             1.155475
#  7                    Eutingen Enz              2.882417             1.276945
#  8               Ewattingen Wutach              1.133337             0.461306
#  9                    Gießen Argen              5.451570             2.032261
#  10                 Hausach Kinzig              2.229669             0.996323
#  11                   Hausen Zaber              0.227234             0.087863
#  12                    Horb Neckar              3.147633             1.381480
#  13             Hundersingen Donau              1.805468             1.022026
#  14              Hüttlingen Kocher              0.758492             0.274476
#  15                 Konstanz Rhein              3.889461             3.178809
#  16           Mägerkingen Lauchert              0.177314             0.063734
#  17         Oberlauchringen Wutach              2.025364             0.779890
#  18           Rengers Untere Argen              2.338175             0.785778
#  19           Riegel Leopoldskanal              3.277496             1.446611
#  20  Rielasingen Radolfzeller Aach              0.660283             0.360835
#  21      Tauberbischofsheim Tauber              2.823706             1.019792
#  22                 Wannweil Echaz              1.595748             0.524223
#  23              Wiesloch Leimbach              0.206806             0.090770
#  24                     Zell Wiese              1.373437             0.618305
#
#      mean_nse_validation  mean_nse_train
#  0              0.524801        0.927560
#  1              0.621645        0.896072
#  2              0.933637        0.995377
#  3              0.399787        0.929915
#  4              0.822389        0.995510
#  5              0.434852        0.954201
#  6              0.716642        0.979017
#  7              0.601280        0.974013
#  8              0.725041        0.971197
#  9              0.808636        0.957704
#  10             0.713744        0.971174
#  11             0.207000        0.846836
#  12             0.697737        0.971369
#  13             0.822830        0.996581
#  14             0.271338        0.875785
#  15             0.982421        0.999504
#  16             0.793480        0.981599
#  17             0.659366        0.974464
#  18             0.641554        0.922673
#  19             0.803646        0.974999
#  20             0.837507        0.990067
#  21             0.644182        0.986576
#  22             0.165896        0.804353
#  23             0.061367        0.777830
#  24             0.561925        0.975721  ,
#  np.float64(0.6181082666051779),
#  np.float64(0.9452039743157803),
#  np.float64(0.32709570771060237))

# %% [markdown]
# ### Final model fitting und Evaluation
# In diesem Abschnitt wird schließlich das finale Modell mit der gewählten Hyperparameter-Kombination für jede Station separat trainiert und auf dem Testzeitraum evaluiert. Die Zielvariable wird als 6-Stunden-Vorhersage definiert (Lead Time 6h), das heißt es wird Q(t+6) auf Basis der Merkmale zu Zeitpunkt t vorhergesagt (y = Abfluss.shift(-6)).
# Die Vorhersage erfolgt als Expanding-Window. Das Modell wird zunächst auf dem Trainingsset trainiert und sagt anschließend den Testdatensatz blockweise in Fenster von 720 Stunden voraus. Nach jeder Blockvorhersage werden die tatsächlichen Beobachtungen dieses Blocks an den Trainingssatz angehängt und das Modell wird für den nächsten Block erneut trainiert. Die vorhersagen werden zeitlich korrekt um plus 6 Stunden verschoben, sodass der Vorhersagezeitpunkt dem tatsächlichen Zielzeitpunkt am Abfluss Q(t+6) entspricht.
#
# Die Vorhersagegüte wird auf mehreren Ebenen ausgewertet:
# - Es wird der stündliche absoute Fehler berechnet
# - Pro Block (720 Stunden) werden RMSE, MAE und NSE berechnet
# - Die Vorhersagegüte der Wochen um die zehn höchsten Abflussspitzen pro Station werden berechnet (RMSE, MAE und NSE), wobei die Peaks mindestens 7 Tage auseinanderliegen.
# - Die Gesamtmetriken werden über den gesamten vorhergesagten Testzeitraum pro Station berechnet (RMSE, MAE und NSE)
#
# Alle Auswertungen und Ergebnisse werden als CSV-Dateien im Ordner "Evaluation" gespeichert.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error


def final_model_fitting():
    
    train_test = train_and_test_nan()

    results = []
    all_forecasts = {}
    all_hourly_eval_list = []
    all_evaluate_max_week_list = []
    overall_max_week_metrics = []
    all_monthly_eval_list = []
    week = 168
    month = 720
    horizon = 6
    
    
    for t in train_test:
        
        station = t["Stationsname"]
        
        
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()
        
        test_water = t["Testset"].copy()
        test_water = test_water.sort_index()

        train = train_water.copy()
        test = test_water.copy()
        train["y"] = train_water["Abfluss in m^3/s"].shift(-horizon)
        test["y"] = test_water["Abfluss in m^3/s"].shift(-horizon)
        
        
        # the last six rows of y are NaNs due to the shift by six hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train = train.dropna(subset=["y"])
        test = test.dropna(subset=["y"])

        # define current_train to enrich it later in the expanding window forecast.
        current_train = train.copy()

        
        
        forecast_blocks = []
        # expanding window forecast: predicting a window of one month and cancatenate the actual runoff of this month to the train data.
        for i in range(0, len(test), month):
            end = i + month
            # defining x and y for final evaluation
            x_train = current_train.drop(columns=["y"])
            y_train = current_train["y"]
        
            x_test = test.drop(columns=["y"])
            y_test = test["y"]

            # defining the test block (one month). if the block is empty, the time series is at the end
            x_test_block = x_test.iloc[i:end]
            if len(x_test_block) == 0:
                break

            # defining the model with the best hyperparamters due to hyperparameter tuning.
            model = xgb.XGBRegressor(
                n_estimators=100, 
                max_depth=8,
                min_child_weight=20,
                learning_rate=0.05, 
                subsample=0.5,
                colsample_bytree=1.0,
                tree_method="hist",
                base_score=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # predicting the respective month and store the forecast in forecast_blocks but shift the forecast six hours ahead because that is the actual date for the forecast due to the horizon (shift(-6)). 
            y_block_pred = model.predict(x_test_block)
            forecast_blocks.append(pd.Series(y_block_pred, index=test.index[i:i + len(x_test_block)] + pd.Timedelta(hours=horizon)))

            # enriching the train set by the actual values of the month which was forecasted in this loop.
            current_train = pd.concat([current_train, test.iloc[i:i + len(x_test_block)]])

            
        # concatenate the forecast on forecast_series with the corresponding station and store every forecast as a data frame in all_forecasts[station]   
        forecast_series = pd.concat(forecast_blocks).sort_index()
        all_forecasts[station] = pd.DataFrame({
            "Forecast": forecast_series
        })

        # defining the actual surface runoff to calculate the absolute error per hour.
        all_truth = test_water["Abfluss in m^3/s"].reindex(forecast_series.index) 

        # calculate the absolute error per hour.
        absolute_error_hourly = abs(all_truth - forecast_series)

        # store the information in the data frame evaluate_hourly_df.
        evaluate_hourly_df = pd.DataFrame({
            "Stationsname": station,
            "Datum / Uhrzeit": forecast_series.index,
            "Abfluss in m^3/s": all_truth.values,
            "Forecast": forecast_series.values,
            "Absolutfehler pro Stunde": absolute_error_hourly.values,
            
        })
        # append the respective data frame to a list.
        all_hourly_eval_list.append(evaluate_hourly_df)

        # calculate the 10 highest peaks which are minimum 7 days apart from each Peak
        true_runoff = evaluate_hourly_df["Abfluss in m^3/s"]
        forecast_runoff = evaluate_hourly_df["Forecast"]
        maximum_runoff = (true_runoff > true_runoff.shift(1)) & (true_runoff > true_runoff.shift(-1))
        local_maxima = true_runoff[maximum_runoff]
        local_maxima = local_maxima.sort_values(ascending=False)
        maximum_times = local_maxima.index

        # check if the sorted local maxima are more than a week apart.
        all_selected_maxima = []
        for maxima in maximum_times:
            if len(all_selected_maxima) >= 10:
                break
                
            distance_ok = True
            for selected in all_selected_maxima:
                if abs(maxima - selected) <= week:
                    distance_ok = False
                    break
            if distance_ok:
                all_selected_maxima.append(maxima)
                
        # define the week around the selected local maxima
        evaluate_maximum_weeks = []
        for selected_maxima in all_selected_maxima:
            start = selected_maxima - (week // 2)
            end = selected_maxima + (week // 2)
            
            start = max(start, true_runoff.index.min())
            end = min(end, true_runoff.index.max())

            # define the actual week around the local maxima and the forecast week to calculate the evaluation metrics of the forecast of this week.
            true_max_week = true_runoff.iloc[start:end]
            forecast_max_week = forecast_runoff.iloc[start:end]

            mae_max_week = mean_absolute_error(true_max_week, forecast_max_week)
            rmse_max_week = np.sqrt(mean_squared_error(true_max_week, forecast_max_week))

            squared_diff = (true_max_week - forecast_max_week)**2
            sum_squared_diff = np.sum(squared_diff)
            squared_diff2 = (true_max_week - true_max_week.mean())**2
            sum_squared_diff2 = np.sum(squared_diff2)

            if sum_squared_diff2 == 0:
                nse_max_week = np.nan
            else:
                nse_max_week = 1 - (sum_squared_diff / sum_squared_diff2)

            # store all maximum weeks of a time series and station in evaluate_maximum_weeks
            evaluate_maximum_weeks.append({
                "Stationsname": station,
                "Wochenstart": true_max_week.index[0],
                "Wochenende": true_max_week.index[-1],
                "Peak": selected_maxima,
                "MAE_MAX_WEEK": mae_max_week,
                "RMSE_MAX_WEEK": rmse_max_week,
                "NSE_MAX_WEEK": nse_max_week
            })
        evaluate_max_week_df = pd.DataFrame(evaluate_maximum_weeks)
        all_evaluate_max_week_list.append(evaluate_max_week_df)

        # calculate the evaluation metrics per station to identify how good the model is forecasting weeks with maximum peaks.
        all_mae_max_week = evaluate_max_week_df["MAE_MAX_WEEK"].mean()
        all_rmse_max_week = evaluate_max_week_df["RMSE_MAX_WEEK"].mean()
        all_nse_max_week = evaluate_max_week_df["NSE_MAX_WEEK"].mean()

        # store them in overall_max_week_metrics
        overall_max_week_metrics.append({
            "Stationsname": station,
            "All_MAE": all_mae_max_week,
            "All_RMSE": all_rmse_max_week,
            "All_NSE": all_nse_max_week
        })
                
        # Calculate the evaluation metrics per month block
        evaluate_monthly = []
        for i in range(0, len(forecast_series), month):
            end = i + month
            pred_block = forecast_series.iloc[i:end]
            truth_block = all_truth.iloc[i:end]

            if len(pred_block) == 0:
                break
          
            mae_block = mean_absolute_error(truth_block, pred_block)
            rmse_block = np.sqrt(mean_squared_error(truth_block, pred_block))

            squared_diff = (truth_block - pred_block)**2
            sum_squared_diff = np.sum(squared_diff)
            squared_diff2 = (truth_block - truth_block.mean())**2
            sum_squared_diff2 = np.sum(squared_diff2)

            if sum_squared_diff2 == 0:
                nse_block = np.nan
            else:
                nse_block = 1 - (sum_squared_diff / sum_squared_diff2)

            evaluate_monthly.append({
                "Stationsname": station,
                "Block Index": i // month,
                "Block Start": pred_block.index[0],
                "Block Ende": pred_block.index[-1],
                "MAE Block": mae_block,
                "RMSE Block": rmse_block,
                "NSE Block": nse_block
            })

        evaluate_monthly_df = pd.DataFrame(evaluate_monthly)
        all_monthly_eval_list.append(evaluate_monthly_df)

        
        # Calculate evaluation metrics for the whole test set per station    
        rmse = np.sqrt(mean_squared_error(test_water["Abfluss in m^3/s"].reindex(forecast_series.index), forecast_series))
        mae = mean_absolute_error(test_water["Abfluss in m^3/s"].reindex(forecast_series.index), forecast_series)
        nse = 1 - np.sum((test_water["Abfluss in m^3/s"].reindex(forecast_series.index) - forecast_series)**2) / np.sum((test_water["Abfluss in m^3/s"].reindex(forecast_series.index) - np.mean(test_water["Abfluss in m^3/s"].reindex(forecast_series.index)))**2)
        results.append({
            "Stationsname": station,
            "RMSE": rmse,
            "MAE": mae,
            "NSE": nse
        })

            
        print(f"{station}: Finished forecasting. Forecasting months {i // 720 + 1}")
        print(forecast_series.describe())

    # create a data frame for every evaluation metric an sort them.
    results_rmse_df = pd.DataFrame(results).sort_values(by="RMSE")
    results_mae_df = pd.DataFrame(results).sort_values(by="MAE")
    results_nse_df = pd.DataFrame(results).sort_values(by="NSE", ascending=False)

    # concatenate hourly and monthly evaluation metrics and for every station and the metrics for every maximum week individually and overall.  
    all_hourly_eval_df = pd.concat(all_hourly_eval_list, ignore_index=True)
    all_monthly_eval_df = pd.concat(all_monthly_eval_list, ignore_index=True)
    all_evaluate_max_week_df = pd.concat(all_evaluate_max_week_list, ignore_index=True)
    overall_max_week_metrics_df = pd.DataFrame(overall_max_week_metrics)

    

    # store the different evaluation metrics and times as csv file.
    results_rmse_df.to_csv("Evaluation/XGBoost_Gesamtmetriken_RMSE_6h.csv", index=False)
    results_mae_df.to_csv("Evaluation/XGBoost_Gesamtmetriken_MAE_6h.csv", index=False)
    results_nse_df.to_csv("Evaluation/XGBoost_Gesamtmetriken_NSE_6h.csv", index=False)
    all_hourly_eval_df.to_csv("Evaluation/XGBoost_Metriken_stündlich_6h.csv", index=False)
    all_monthly_eval_df.to_csv("Evaluation/XGBoost_Metriken_monatlich_6h.csv", index=False)
    all_evaluate_max_week_df.to_csv("Evaluation/XGBoost_Metriken_maximum_wochen_6h.csv", index=False)
    overall_max_week_metrics_df.to_csv("Evaluation/XGBoost_Metriken_durchschnittlich_über_maximum_wochen_6h.csv", index=False)
    
    return results_rmse_df, results_mae_df, results_nse_df, all_forecasts, all_hourly_eval_df, all_monthly_eval_df

final_model_fitting()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Gießen Argen: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        19.790443
# std         20.800394
# min          3.141180
# 25%          8.131659
# 50%         13.737583
# 75%         24.671147
# max        310.389343
# dtype: float64
# Blaubeuren Blau: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         2.426470
# std          1.730387
# min          0.649608
# 25%          1.314590
# 50%          2.022917
# 75%          2.932079
# max         18.594938
# dtype: float64
# Bolheim Brenz: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         4.401547
# std          1.793126
# min          1.990790
# 25%          3.175257
# 50%          4.000606
# 75%          5.132578
# max         12.081343
# dtype: float64
# Beuron Donau: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        11.666118
# std         16.075621
# min          0.580022
# 25%          2.162234
# 50%          5.303260
# 75%         16.129326
# max        155.742599
# dtype: float64
# Hundersingen Donau: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        23.878370
# std         22.699884
# min          4.489158
# 25%          9.677046
# 50%         16.222607
# 75%         30.853158
# max        182.273117
# dtype: float64
# Wannweil Echaz: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         2.654524
# std          2.016090
# min          0.552362
# 25%          1.480782
# 50%          2.150907
# 75%          3.170557
# max         39.199860
# dtype: float64
# Eutingen Enz: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        16.100773
# std         12.245642
# min          4.245686
# 25%          8.053955
# 50%         12.813517
# 75%         20.424634
# max        187.236984
# dtype: float64
# Elpershofen Jagst: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         7.861784
# std         11.662455
# min         -0.984449
# 25%          2.215017
# 50%          4.329961
# 75%          8.431564
# max        133.311081
# dtype: float64
# Hausach Kinzig: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        15.706275
# std         17.742241
# min          2.131216
# 25%          5.096466
# 50%         10.471779
# 75%         19.851056
# max        221.233047
# dtype: float64
# Hüttlingen Kocher: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         2.007732
# std          1.664995
# min          0.545383
# 25%          0.935577
# 50%          1.463182
# 75%          2.474774
# max         22.215090
# dtype: float64
# Mägerkingen Lauchert: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         0.677986
# std          0.757194
# min          0.058851
# 25%          0.247538
# 50%          0.500949
# 75%          0.877301
# max         15.603844
# dtype: float64
# Wiesloch Leimbach: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         0.611707
# std          0.326895
# min          0.251335
# 25%          0.425720
# 50%          0.548541
# 75%          0.707913
# max          6.741082
# dtype: float64
# Riegel Leopoldskanal: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        11.755589
# std         17.192202
# min          0.334671
# 25%          0.652748
# 50%          4.810938
# 75%         17.586869
# max        181.633408
# dtype: float64
# Bad Rotenfels Murg: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        15.917538
# std         16.198500
# min          2.008658
# 25%          5.774236
# 50%         11.702757
# 75%         19.847669
# max        277.694824
# dtype: float64
# Baiersbronn Murg: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         2.893078
# std          3.541295
# min          0.366981
# 25%          0.910928
# 50%          1.850548
# 75%          3.283726
# max         45.035389
# dtype: float64
# Horb Neckar: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean        13.753130
# std         13.709795
# min          2.728740
# 25%          5.646985
# 50%          9.633617
# 75%         17.102199
# max        153.653763
# dtype: float64
# Rielasingen Radolfzeller Aach: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         9.203194
# std          4.293703
# min          2.442379
# 25%          6.156232
# 50%          9.046999
# 75%         11.691911
# max         26.532101
# dtype: float64
# Konstanz Rhein: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean       319.279968
# std        131.590012
# min        168.046875
# 25%        225.322170
# 50%        289.596619
# 75%        362.419296
# max        821.375488
# dtype: float64
# Binnrot Rot: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         1.897245
# std          1.465509
# min          0.788300
# 25%          1.140630
# 50%          1.497643
# 75%          2.011056
# max         20.766613
# dtype: float64
# Tauberbischofsheim Tauber: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         8.666966
# std          8.554667
# min          2.291372
# 25%          3.903814
# 50%          6.321675
# 75%         10.147164
# max         98.096504
# dtype: float64
# Rengers Untere Argen: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         4.557810
# std          6.235873
# min          0.282807
# 25%          1.340088
# 50%          2.681152
# 75%          5.345822
# max         95.827217
# dtype: float64
# Zell Wiese: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         7.300245
# std          7.895181
# min          0.803255
# 25%          2.534075
# 50%          5.039993
# 75%          8.879337
# max         94.133553
# dtype: float64
# Ewattingen Wutach: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         5.739822
# std          5.930192
# min          0.658743
# 25%          2.129107
# 50%          4.010749
# 75%          7.491504
# max         85.272720
# dtype: float64
# Oberlauchringen Wutach: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean         8.932229
# std          8.268680
# min          1.664050
# 25%          3.738043
# 50%          6.302528
# 75%         11.949493
# max        116.811058
# dtype: float64
# Hausen Zaber: Finished forecasting. Forecasting months 37
# count    26298.000000
# mean