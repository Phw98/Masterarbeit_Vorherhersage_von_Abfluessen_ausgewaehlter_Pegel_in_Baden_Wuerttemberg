# %% [markdown]
# # Random Forest - Anwendung (Lead Time 24 Stunde)

# %% [markdown]
# ### Feature Creation
# In diesem Block wird die Attributmatrix für die Modellierung erstellt. Dazu werden Zeitmerkmale aus dem Zeitindex abgeleitet ("Stunde", "Tage in einer Woche", "Monat", "Viertel Jahr", "Jahr", "Tage im Jahr"). Zusätzlich werden zyklische Zeitinformationen über Sinus und Cosinus ("Sinus Tag", "Cosinus Tag", "Sinus Jahr", "Cosinus Jahr") abgebildet, damit die Modelle periodische Muster lernen können.
# Darüber hinaus werden Lag-Features erzeugt (1, 3, 6, 12, 24, 48, 72, 168, 720, 8760 Stunden), um Informationen aus der Vergangenheit in die Vorhersage einzubeziehen (Von Bedeutung wegen Autokorrelation in Abflusszeitreihen). Diese gehen als Spalten "Abfluss in m^3/s_lag{lag}" in die Attributmatrix ein.
# Da Niederschlag häufig zeitverzögert auf den Abfluss wirkt, werden auch die zugeordneten Niederschlagszeitreihen um 0, 1, 3, 6, 12, 24, 36, 48 Stunden verschoben. Diese Merkmale werden als "{column}_lag{lag}" ergänzt. Die konstanten Spalten "Stationsname", "Gewässer", "Interpoliert" werden abschließend entfernt.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import glob

# Create new time series for all 25 stations which is enriched by feauters an which based on datetime index.
def feature_creation_nan():
    all_merged_files_nan=glob.glob("Datensätze/UDO-LUBW/Endgültige Auswahl Landespegel Hydrologie/Gewässer/*/*/*_merged_nan.csv")

    
    all_water_stations = []
    for a in all_merged_files_nan:
        p = Path(a)
        
        # read the respective file as a data frame.
        df_water_station = pd.read_csv(p, sep=",", index_col="Datum / Uhrzeit", parse_dates=["Datum / Uhrzeit"], encoding="utf-8")

        df_water_station = df_water_station.sort_index()
        
        # save "Stationsname" and "Gewässer" separately. I will drop them later on in the features.
        station_and_water = df_water_station[["Stationsname", "Gewässer"]]
        
        # defining time features by creating them from the datetime index
        df_water_station["Stunde"] = df_water_station.index.hour
        df_water_station["Tage in einer Woche"] = df_water_station.index.dayofweek
        df_water_station["Monat"] = df_water_station.index.month
        df_water_station["Viertel Jahr"] = df_water_station.index.quarter
        df_water_station["Jahr"] = df_water_station.index.year
        df_water_station["Tage im Jahr"] = df_water_station.index.dayofyear


        # defining cyclic features by calculating daily and yearly cycles (as sinus and cosinus).
        df_water_station["Sinus Tag"] = np.sin(2 * np.pi * df_water_station["Stunde"] / 24)
        df_water_station["Cosinus Tag"] = np.cos(2 * np.pi * df_water_station["Stunde"] / 24)
        df_water_station["Sinus Jahr"] = np.sin(2 * np.pi * df_water_station["Tage im Jahr"] / 365)
        df_water_station["Cosinus Jahr"] = np.cos(2 * np.pi * df_water_station["Tage im Jahr"] / 365)

        # defining lag features by shifting the original "Abfluss in m^3/s" to enable connecting with past surface runoff.
        # store them in a separate data frame to avoid warnings
        lags_water = {}
        for lag in [1, 3, 6, 12, 24, 48, 72, 168, 720, 8760]:
            lags_water[f"Abfluss in m^3/s_lag{lag}"] = df_water_station["Abfluss in m^3/s"].shift(lag)
        df_lags_water = pd.DataFrame(lags_water, index=df_water_station.index)

        # defining lag features for exogenous variables by shifting the original precipitation columns to capture their delayed impact on the surface runoff. 
        # store them in a separate data frame to avoid warnings
        lags_exogene = {}
        for column in df_water_station.filter(regex=r"^Niederschlag").columns:
            for lag in [0, 1, 3, 6, 12, 24, 36, 48]:
                lags_exogene[f"{column}_lag{lag}"] = df_water_station[column].shift(lag)
        df_lags_exogene = pd.DataFrame(lags_exogene, index=df_water_station.index)

        # Concatenate the data frames to one
        df_water_station = pd.concat([df_water_station, df_lags_water, df_lags_exogene], axis=1)
        

        # remove static columns or columns that are not used as features for the model
        df_water_station = df_water_station.drop(columns=["Stationsname", "Gewässer", "Interpoliert"])
                
        all_water_stations.append({
            "Stationsname": station_and_water["Stationsname"].iloc[0],
            "Gewässer": station_and_water["Gewässer"].iloc[0],
            "df": df_water_station
        })
        print(f"Create features for {p.name}.")

    return all_water_stations

feature_creation_nan()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# [{'Stationsname': 'Gießen Argen',
#   'Gewässer': 'Argen',
#   'df':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            78.308                      0.0
#   2010-01-01 01:00:00            75.247                      0.0
#   2010-01-01 02:00:00            73.206                      0.0
#   2010-01-01 03:00:00            69.861                      0.0
#   2010-01-01 04:00:00            67.697                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            11.832                      0.0
#   2024-12-31 20:00:00            11.037                      0.0
#   2024-12-31 21:00:00            10.951                      0.0
#   2024-12-31 22:00:00            10.797                      0.0
#   2024-12-31 23:00:00            10.783                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Blaubeuren Blau',
#   'Gewässer': 'Blau',
#   'df':                      Abfluss in m^3/s  Niederschlag 2814 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             5.580                      0.0
#   2010-01-01 01:00:00             5.555                      0.0
#   2010-01-01 02:00:00             5.562                      0.0
#   2010-01-01 03:00:00             5.568                      0.0
#   2010-01-01 04:00:00             5.597                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             2.573                      0.0
#   2024-12-31 20:00:00             2.635                      0.0
#   2024-12-31 21:00:00             2.450                      0.0
#   2024-12-31 22:00:00             2.488                      0.0
#   2024-12-31 23:00:00             2.428                      0.0
#
#                        Niederschlag 5511 in mm  Niederschlag 3418 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3418 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3418 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 57 columns]},
#  {'Stationsname': 'Bolheim Brenz',
#   'Gewässer': 'Brenz',
#   'df':                      Abfluss in m^3/s  Niederschlag 3440 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             4.161                      0.0
#   2010-01-01 01:00:00             4.161                      0.0
#   2010-01-01 02:00:00             3.967                      0.0
#   2010-01-01 03:00:00             3.967                      0.0
#   2010-01-01 04:00:00             3.967                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             4.098                      0.0
#   2024-12-31 20:00:00             4.040                      0.0
#   2024-12-31 21:00:00             3.962                      0.0
#   2024-12-31 22:00:00             3.871                      0.0
#   2024-12-31 23:00:00             3.982                      0.0
#
#                        Niederschlag 7331 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 7331 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 7331 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Beuron Donau',
#   'Gewässer': 'Donau',
#   'df':                      Abfluss in m^3/s  Niederschlag 2638 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            74.509                      0.0
#   2010-01-01 01:00:00            74.509                      0.0
#   2010-01-01 02:00:00            75.483                      0.0
#   2010-01-01 03:00:00            75.483                      0.0
#   2010-01-01 04:00:00            75.483                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            14.078                      0.0
#   2024-12-31 20:00:00            14.012                      0.0
#   2024-12-31 21:00:00            13.903                      0.0
#   2024-12-31 22:00:00            13.838                      0.0
#   2024-12-31 23:00:00            13.765                      0.0
#
#                        Niederschlag 4703 in mm  Niederschlag 3519 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3519 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3519 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
# ...
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 48 columns]},
#  {'Stationsname': 'Hausen Zaber',
#   'Gewässer': 'Zaber',
#   'df':                      Abfluss in m^3/s  Niederschlag 4349 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             1.417                      0.0
#   2010-01-01 01:00:00             1.417                      0.0
#   2010-01-01 02:00:00             1.334                      0.0
#   2010-01-01 03:00:00             1.334                      0.0
#   2010-01-01 04:00:00             1.334                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             0.486                      0.0
#   2024-12-31 20:00:00             0.487                      0.0
#   2024-12-31 21:00:00             0.487                      0.0
#   2024-12-31 22:00:00             0.486                      0.0
#   2024-12-31 23:00:00             0.485                      0.0
#
#                        Niederschlag 3734 in mm  Niederschlag 7238 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag 7498 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  ...  \
#   Datum / Uhrzeit                                                        ...
#   2010-01-01 00:00:00       0                    4      1             1  ...
#   2010-01-01 01:00:00       1                    4      1             1  ...
#   2010-01-01 02:00:00       2                    4      1             1  ...
#   2010-01-01 03:00:00       3                    4      1             1  ...
#   2010-01-01 04:00:00       4                    4      1             1  ...
#   ...                     ...                  ...    ...           ...  ...
#   2024-12-31 19:00:00      19                    1     12             4  ...
#   2024-12-31 20:00:00      20                    1     12             4  ...
#   2024-12-31 21:00:00      21                    1     12             4  ...
#   2024-12-31 22:00:00      22                    1     12             4  ...
#   2024-12-31 23:00:00      23                    1     12             4  ...
#
#                        Niederschlag 7498 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 7498 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#   [131496 rows x 66 columns]}]

# %% [markdown]
# ## Hyperparameter Tuning mit Cross Validation

# %% [markdown]
# ### Teilung in Trainings- und Testset
# In diesem Block werden alle Zeitreihen zeitbasiert in Trainings- und Testsets aufgeteilt. Das Trainingsset umfasst alle Einträge von 2010 bis einschließlich 2021 (Zeitstempel vor dem 0.01.2022). Die späteren Einträge werden dem Testset zugeordnet.

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import glob

# split the stations time series in train and test sets
def train_and_test_nan():
    # create the features for every station
    water_stations = feature_creation_nan()
    train_test_nan = []

    # defining the timestamp separating the train and test data
    split_train_test = pd.Timestamp("2022-01-01")
    for a in water_stations:
        
        # defining important information to identify the correct train and test set for the respective station
        water = a["Gewässer"]
        station = a["Stationsname"]
        df_water_station = a["df"]

        # splitting the respective time series into train and test data (ratio: 80% train set, 20% test set)
        # (train set until 2021-12-31, test set from 2022-01-01)
        train_data = df_water_station[df_water_station.index < split_train_test]
        test_data = df_water_station[df_water_station.index >= split_train_test]

        # store the respective split with the meta data in train_test_nan
        train_test_nan.append({
            "Gewässer": water, "Stationsname": station, "Trainingsset": train_data, "Testset": test_data
        })

        print(f"Created train ({len(train_data)} rows) and test data ({len(test_data)} rows) for {station}.")

    return train_test_nan



train_and_test_nan()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# [{'Gewässer': 'Argen',
#   'Stationsname': 'Gießen Argen',
#   'Trainingsset':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00            78.308                      0.0
#   2010-01-01 01:00:00            75.247                      0.0
#   2010-01-01 02:00:00            73.206                      0.0
#   2010-01-01 03:00:00            69.861                      0.0
#   2010-01-01 04:00:00            67.697                      0.0
#   ...                               ...                      ...
#   2021-12-31 19:00:00            49.543                      0.0
#   2021-12-31 20:00:00            48.711                      0.0
#   2021-12-31 21:00:00            47.784                      0.0
#   2021-12-31 22:00:00            47.063                      0.0
#   2021-12-31 23:00:00            46.322                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                              0.0
#   2010-01-01 01:00:00                      0.0                              0.0
#   2010-01-01 02:00:00                      0.0                              0.0
#   2010-01-01 03:00:00                      0.0                              0.0
#   2010-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2021-12-31 19:00:00                      0.0                              0.0
#   2021-12-31 20:00:00                      0.0                              0.0
#   2021-12-31 21:00:00                      0.0                              0.0
#   2021-12-31 22:00:00                      0.0                              0.0
#   2021-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00       0                    4      1             1  2010
#   2010-01-01 01:00:00       1                    4      1             1  2010
#   2010-01-01 02:00:00       2                    4      1             1  2010
#   2010-01-01 03:00:00       3                    4      1             1  2010
#   2010-01-01 04:00:00       4                    4      1             1  2010
#   ...                     ...                  ...    ...           ...   ...
#   2021-12-31 19:00:00      19                    4     12             4  2021
#   2021-12-31 20:00:00      20                    4     12             4  2021
#   2021-12-31 21:00:00      21                    4     12             4  2021
#   2021-12-31 22:00:00      22                    4     12             4  2021
#   2021-12-31 23:00:00      23                    4     12             4  2021
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2010-01-01 00:00:00             1  ...                            NaN
#   2010-01-01 01:00:00             1  ...                            NaN
#   2010-01-01 02:00:00             1  ...                            NaN
#   2010-01-01 03:00:00             1  ...                            NaN
#   2010-01-01 04:00:00             1  ...                            NaN
#   ...                           ...  ...                            ...
#   2021-12-31 19:00:00           365  ...                            0.1
#   2021-12-31 20:00:00           365  ...                            0.0
#   2021-12-31 21:00:00           365  ...                            0.0
#   2021-12-31 22:00:00           365  ...                            0.0
#   2021-12-31 23:00:00           365  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2021-12-31 19:00:00                            3.1
#   2021-12-31 20:00:00                            0.3
#   2021-12-31 21:00:00                            0.1
#   2021-12-31 22:00:00                            0.1
#   2021-12-31 23:00:00                            0.4
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                   0.05
#   2021-12-31 20:00:00                                   0.05
#   2021-12-31 21:00:00                                   0.00
#   2021-12-31 22:00:00                                   0.00
#   2021-12-31 23:00:00                                   0.00
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                   2.45
#   2021-12-31 20:00:00                                   0.50
#   2021-12-31 21:00:00                                   0.40
#   2021-12-31 22:00:00                                   0.65
#   2021-12-31 23:00:00                                   0.90
#
#   [105192 rows x 48 columns],
#   'Testset':                      Abfluss in m^3/s  Niederschlag 6258 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00            45.612                      0.0
#   2022-01-01 01:00:00            44.763                      0.0
#   2022-01-01 02:00:00            44.163                      0.0
#   2022-01-01 03:00:00            43.402                      0.0
#   2022-01-01 04:00:00            42.720                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00            11.832                      0.0
#   2024-12-31 20:00:00            11.037                      0.0
#   2024-12-31 21:00:00            10.951                      0.0
#   2024-12-31 22:00:00            10.797                      0.0
#   2024-12-31 23:00:00            10.783                      0.0
#
#                        Niederschlag 4094 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.0                              0.0
#   2022-01-01 01:00:00                      0.0                              0.0
#   2022-01-01 02:00:00                      0.0                              0.0
#   2022-01-01 03:00:00                      0.0                              0.0
#   2022-01-01 04:00:00                      0.0                              0.0
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                              0.0
#   2024-12-31 20:00:00                      0.0                              0.0
#   2024-12-31 21:00:00                      0.0                              0.0
#   2024-12-31 22:00:00                      0.0                              0.0
#   2024-12-31 23:00:00                      0.0                              0.0
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  Jahr  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00       0                    5      1             1  2022
#   2022-01-01 01:00:00       1                    5      1             1  2022
#   2022-01-01 02:00:00       2                    5      1             1  2022
#   2022-01-01 03:00:00       3                    5      1             1  2022
#   2022-01-01 04:00:00       4                    5      1             1  2022
#   ...                     ...                  ...    ...           ...   ...
#   2024-12-31 19:00:00      19                    1     12             4  2024
#   2024-12-31 20:00:00      20                    1     12             4  2024
#   2024-12-31 21:00:00      21                    1     12             4  2024
#   2024-12-31 22:00:00      22                    1     12             4  2024
#   2024-12-31 23:00:00      23                    1     12             4  2024
#
#                        Tage im Jahr  ...  Niederschlag 4094 in mm_lag36  \
#   Datum / Uhrzeit                    ...
#   2022-01-01 00:00:00             1  ...                            0.0
#   2022-01-01 01:00:00             1  ...                            0.0
#   2022-01-01 02:00:00             1  ...                            0.0
#   2022-01-01 03:00:00             1  ...                            0.0
#   2022-01-01 04:00:00             1  ...                            0.0
#   ...                           ...  ...                            ...
#   2024-12-31 19:00:00           366  ...                            0.0
#   2024-12-31 20:00:00           366  ...                            0.0
#   2024-12-31 21:00:00           366  ...                            0.0
#   2024-12-31 22:00:00           366  ...                            0.0
#   2024-12-31 23:00:00           366  ...                            0.0
#
#                        Niederschlag 4094 in mm_lag48  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.3
#   2022-01-01 01:00:00                            0.2
#   2022-01-01 02:00:00                            0.1
#   2022-01-01 03:00:00                            0.2
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.45
#   2022-01-01 01:00:00                                   0.15
#   2022-01-01 02:00:00                                   0.05
#   2022-01-01 03:00:00                                   0.10
#   2022-01-01 04:00:00                                   0.00
#   ...                                                    ...
#   2024-12-31 19:00:00                                   0.00
#   2024-12-31 20:00:00                                   0.00
#   2024-12-31 21:00:00                                   0.00
#   2024-12-31 22:00:00                                   0.00
#   2024-12-31 23:00:00                                   0.00
#
#   [26304 rows x 48 columns]},
#  {'Gewässer': 'Blau',
#   'Stationsname': 'Blaubeuren Blau',
#   'Trainingsset':                      Abfluss in m^3/s  Niederschlag 2814 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00             5.580                      0.0
#   2010-01-01 01:00:00             5.555                      0.0
#   2010-01-01 02:00:00             5.562                      0.0
#   2010-01-01 03:00:00             5.568                      0.0
#   2010-01-01 04:00:00             5.597                      0.0
#   ...                               ...                      ...
#   2021-12-31 19:00:00             5.165                      0.0
#   2021-12-31 20:00:00             5.158                      0.0
#   2021-12-31 21:00:00             5.068                      0.0
#   2021-12-31 22:00:00             5.168                      0.0
#   2021-12-31 23:00:00             5.085                      0.0
#
#                        Niederschlag 5511 in mm  Niederschlag 3418 in mm  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                      0.0                      0.0
#   2010-01-01 01:00:00                      0.0                      0.0
#   2010-01-01 02:00:00                      0.0                      0.0
#   2010-01-01 03:00:00                      0.0                      0.0
#   2010-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2021-12-31 19:00:00                      0.0                      0.0
#   2021-12-31 20:00:00                      0.0                      0.0
#   2021-12-31 21:00:00                      0.0                      0.0
#   2021-12-31 22:00:00                      0.0                      0.0
#   2021-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                              0.0       0
#   2010-01-01 01:00:00                              0.0       1
#   2010-01-01 02:00:00                              0.0       2
#   2010-01-01 03:00:00                              0.0       3
#   2010-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2021-12-31 19:00:00                              0.0      19
#   2021-12-31 20:00:00                              0.0      20
#   2021-12-31 21:00:00                              0.0      21
#   2021-12-31 22:00:00                              0.0      22
#   2021-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2010-01-01 00:00:00                    4      1             1  2010  ...
#   2010-01-01 01:00:00                    4      1             1  2010  ...
#   2010-01-01 02:00:00                    4      1             1  2010  ...
#   2010-01-01 03:00:00                    4      1             1  2010  ...
#   2010-01-01 04:00:00                    4      1             1  2010  ...
#   ...                                  ...    ...           ...   ...  ...
#   2021-12-31 19:00:00                    4     12             4  2021  ...
#   2021-12-31 20:00:00                    4     12             4  2021  ...
#   2021-12-31 21:00:00                    4     12             4  2021  ...
#   2021-12-31 22:00:00                    4     12             4  2021  ...
#   2021-12-31 23:00:00                    4     12             4  2021  ...
#
#                        Niederschlag 3418 in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2021-12-31 19:00:00                            0.0
#   2021-12-31 20:00:00                            0.0
#   2021-12-31 21:00:00                            0.1
#   2021-12-31 22:00:00                            0.0
#   2021-12-31 23:00:00                            0.0
#
#                        Niederschlag 3418 in mm_lag48  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                            NaN
#   2010-01-01 01:00:00                            NaN
#   2010-01-01 02:00:00                            NaN
#   2010-01-01 03:00:00                            NaN
#   2010-01-01 04:00:00                            NaN
#   ...                                            ...
#   2021-12-31 19:00:00                            4.0
#   2021-12-31 20:00:00                            0.2
#   2021-12-31 21:00:00                            0.2
#   2021-12-31 22:00:00                            0.0
#   2021-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   0.0
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   0.0
#   2010-01-01 02:00:00                                   0.0
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   0.0
#   2010-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                   NaN
#   2010-01-01 01:00:00                                   NaN
#   2010-01-01 02:00:00                                   NaN
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                               0.333333
#   2021-12-31 20:00:00                               0.033333
#   2021-12-31 21:00:00                               0.000000
#   2021-12-31 22:00:00                               0.000000
#   2021-12-31 23:00:00                               0.000000
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                               0.100000
#   2021-12-31 20:00:00                               0.900000
#   2021-12-31 21:00:00                               0.533333
#   2021-12-31 22:00:00                               0.000000
#   2021-12-31 23:00:00                               0.000000
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                               3.433333
#   2021-12-31 20:00:00                               1.700000
#   2021-12-31 21:00:00                               0.333333
#   2021-12-31 22:00:00                               0.000000
#   2021-12-31 23:00:00                               0.000000
#
#   [105192 rows x 57 columns],
#   'Testset':                      Abfluss in m^3/s  Niederschlag 2814 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00             5.010                      0.0
#   2022-01-01 01:00:00             5.038                      0.0
#   2022-01-01 02:00:00             5.068                      0.0
#   2022-01-01 03:00:00             4.945                      0.0
#   2022-01-01 04:00:00             4.870                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             2.573                      0.0
#   2024-12-31 20:00:00             2.635                      0.0
#   2024-12-31 21:00:00             2.450                      0.0
#   2024-12-31 22:00:00             2.488                      0.0
#   2024-12-31 23:00:00             2.428                      0.0
#
#                        Niederschlag 5511 in mm  Niederschlag 3418 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.0                      0.0
#   2022-01-01 01:00:00                      0.0                      0.0
#   2022-01-01 02:00:00                      0.0                      0.0
#   2022-01-01 03:00:00                      0.0                      0.0
#   2022-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag Durchschnitt in mm  Stunde  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                              0.0       0
#   2022-01-01 01:00:00                              0.0       1
#   2022-01-01 02:00:00                              0.0       2
#   2022-01-01 03:00:00                              0.0       3
#   2022-01-01 04:00:00                              0.0       4
#   ...                                              ...     ...
#   2024-12-31 19:00:00                              0.0      19
#   2024-12-31 20:00:00                              0.0      20
#   2024-12-31 21:00:00                              0.0      21
#   2024-12-31 22:00:00                              0.0      22
#   2024-12-31 23:00:00                              0.0      23
#
#                        Tage in einer Woche  Monat  Viertel Jahr  Jahr  ...  \
#   Datum / Uhrzeit                                                      ...
#   2022-01-01 00:00:00                    5      1             1  2022  ...
#   2022-01-01 01:00:00                    5      1             1  2022  ...
#   2022-01-01 02:00:00                    5      1             1  2022  ...
#   2022-01-01 03:00:00                    5      1             1  2022  ...
#   2022-01-01 04:00:00                    5      1             1  2022  ...
#   ...                                  ...    ...           ...   ...  ...
#   2024-12-31 19:00:00                    1     12             4  2024  ...
#   2024-12-31 20:00:00                    1     12             4  2024  ...
#   2024-12-31 21:00:00                    1     12             4  2024  ...
#   2024-12-31 22:00:00                    1     12             4  2024  ...
#   2024-12-31 23:00:00                    1     12             4  2024  ...
#
#                        Niederschlag 3418 in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.0
#   2022-01-01 01:00:00                            0.0
#   2022-01-01 02:00:00                            0.0
#   2022-01-01 03:00:00                            0.0
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 3418 in mm_lag48  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.5
#   2022-01-01 01:00:00                            0.8
#   2022-01-01 02:00:00                            0.9
#   2022-01-01 03:00:00                            0.1
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
# ...
#   2010-01-01 03:00:00                                   NaN
#   2010-01-01 04:00:00                                   NaN
#   ...                                                   ...
#   2021-12-31 19:00:00                                   0.0
#   2021-12-31 20:00:00                                   0.0
#   2021-12-31 21:00:00                                   0.0
#   2021-12-31 22:00:00                                   0.0
#   2021-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                    0.0
#   2021-12-31 20:00:00                                    0.0
#   2021-12-31 21:00:00                                    0.0
#   2021-12-31 22:00:00                                    0.0
#   2021-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                   0.25
#   2021-12-31 20:00:00                                   0.00
#   2021-12-31 21:00:00                                   0.00
#   2021-12-31 22:00:00                                   0.00
#   2021-12-31 23:00:00                                   0.00
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2010-01-01 00:00:00                                    NaN
#   2010-01-01 01:00:00                                    NaN
#   2010-01-01 02:00:00                                    NaN
#   2010-01-01 03:00:00                                    NaN
#   2010-01-01 04:00:00                                    NaN
#   ...                                                    ...
#   2021-12-31 19:00:00                                  1.125
#   2021-12-31 20:00:00                                  0.350
#   2021-12-31 21:00:00                                  0.025
#   2021-12-31 22:00:00                                  0.000
#   2021-12-31 23:00:00                                  0.000
#
#   [105192 rows x 66 columns],
#   'Testset':                      Abfluss in m^3/s  Niederschlag 4349 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00             0.541                      0.0
#   2022-01-01 01:00:00             0.536                      0.0
#   2022-01-01 02:00:00             0.524                      0.0
#   2022-01-01 03:00:00             0.531                      0.0
#   2022-01-01 04:00:00             0.520                      0.0
#   ...                               ...                      ...
#   2024-12-31 19:00:00             0.486                      0.0
#   2024-12-31 20:00:00             0.487                      0.0
#   2024-12-31 21:00:00             0.487                      0.0
#   2024-12-31 22:00:00             0.486                      0.0
#   2024-12-31 23:00:00             0.485                      0.0
#
#                        Niederschlag 3734 in mm  Niederschlag 7238 in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.1                      0.0
#   2022-01-01 01:00:00                      0.0                      0.0
#   2022-01-01 02:00:00                      0.1                      0.0
#   2022-01-01 03:00:00                      0.0                      0.0
#   2022-01-01 04:00:00                      0.0                      0.0
#   ...                                      ...                      ...
#   2024-12-31 19:00:00                      0.0                      0.0
#   2024-12-31 20:00:00                      0.0                      0.0
#   2024-12-31 21:00:00                      0.0                      0.0
#   2024-12-31 22:00:00                      0.0                      0.0
#   2024-12-31 23:00:00                      0.0                      0.0
#
#                        Niederschlag 7498 in mm  Niederschlag Durchschnitt in mm  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                      0.0                            0.025
#   2022-01-01 01:00:00                      0.1                            0.025
#   2022-01-01 02:00:00                      0.1                            0.050
#   2022-01-01 03:00:00                      0.0                            0.000
#   2022-01-01 04:00:00                      0.0                            0.000
#   ...                                      ...                              ...
#   2024-12-31 19:00:00                      0.0                            0.000
#   2024-12-31 20:00:00                      0.0                            0.000
#   2024-12-31 21:00:00                      0.0                            0.000
#   2024-12-31 22:00:00                      0.0                            0.000
#   2024-12-31 23:00:00                      0.0                            0.000
#
#                        Stunde  Tage in einer Woche  Monat  Viertel Jahr  ...  \
#   Datum / Uhrzeit                                                        ...
#   2022-01-01 00:00:00       0                    5      1             1  ...
#   2022-01-01 01:00:00       1                    5      1             1  ...
#   2022-01-01 02:00:00       2                    5      1             1  ...
#   2022-01-01 03:00:00       3                    5      1             1  ...
#   2022-01-01 04:00:00       4                    5      1             1  ...
#   ...                     ...                  ...    ...           ...  ...
#   2024-12-31 19:00:00      19                    1     12             4  ...
#   2024-12-31 20:00:00      20                    1     12             4  ...
#   2024-12-31 21:00:00      21                    1     12             4  ...
#   2024-12-31 22:00:00      22                    1     12             4  ...
#   2024-12-31 23:00:00      23                    1     12             4  ...
#
#                        Niederschlag 7498 in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.0
#   2022-01-01 01:00:00                            0.0
#   2022-01-01 02:00:00                            0.1
#   2022-01-01 03:00:00                            0.4
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag 7498 in mm_lag48  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                            0.0
#   2022-01-01 01:00:00                            0.0
#   2022-01-01 02:00:00                            0.0
#   2022-01-01 03:00:00                            0.0
#   2022-01-01 04:00:00                            0.0
#   ...                                            ...
#   2024-12-31 19:00:00                            0.0
#   2024-12-31 20:00:00                            0.0
#   2024-12-31 21:00:00                            0.0
#   2024-12-31 22:00:00                            0.0
#   2024-12-31 23:00:00                            0.0
#
#                        Niederschlag Durchschnitt in mm_lag0  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                 0.025
#   2022-01-01 01:00:00                                 0.025
#   2022-01-01 02:00:00                                 0.050
#   2022-01-01 03:00:00                                 0.000
#   2022-01-01 04:00:00                                 0.000
#   ...                                                   ...
#   2024-12-31 19:00:00                                 0.000
#   2024-12-31 20:00:00                                 0.000
#   2024-12-31 21:00:00                                 0.000
#   2024-12-31 22:00:00                                 0.000
#   2024-12-31 23:00:00                                 0.000
#
#                        Niederschlag Durchschnitt in mm_lag1  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                 0.000
#   2022-01-01 01:00:00                                 0.025
#   2022-01-01 02:00:00                                 0.025
#   2022-01-01 03:00:00                                 0.050
#   2022-01-01 04:00:00                                 0.000
#   ...                                                   ...
#   2024-12-31 19:00:00                                 0.000
#   2024-12-31 20:00:00                                 0.000
#   2024-12-31 21:00:00                                 0.000
#   2024-12-31 22:00:00                                 0.000
#   2024-12-31 23:00:00                                 0.000
#
#                        Niederschlag Durchschnitt in mm_lag3  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                 0.000
#   2022-01-01 01:00:00                                 0.000
#   2022-01-01 02:00:00                                 0.000
#   2022-01-01 03:00:00                                 0.025
#   2022-01-01 04:00:00                                 0.025
#   ...                                                   ...
#   2024-12-31 19:00:00                                 0.000
#   2024-12-31 20:00:00                                 0.000
#   2024-12-31 21:00:00                                 0.000
#   2024-12-31 22:00:00                                 0.000
#   2024-12-31 23:00:00                                 0.000
#
#                        Niederschlag Durchschnitt in mm_lag6  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                   0.0
#   2022-01-01 01:00:00                                   0.0
#   2022-01-01 02:00:00                                   0.0
#   2022-01-01 03:00:00                                   0.0
#   2022-01-01 04:00:00                                   0.0
#   ...                                                   ...
#   2024-12-31 19:00:00                                   0.0
#   2024-12-31 20:00:00                                   0.0
#   2024-12-31 21:00:00                                   0.0
#   2024-12-31 22:00:00                                   0.0
#   2024-12-31 23:00:00                                   0.0
#
#                        Niederschlag Durchschnitt in mm_lag12  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag24  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                    0.0
#   2022-01-01 01:00:00                                    0.0
#   2022-01-01 02:00:00                                    0.0
#   2022-01-01 03:00:00                                    0.0
#   2022-01-01 04:00:00                                    0.0
#   ...                                                    ...
#   2024-12-31 19:00:00                                    0.0
#   2024-12-31 20:00:00                                    0.0
#   2024-12-31 21:00:00                                    0.0
#   2024-12-31 22:00:00                                    0.0
#   2024-12-31 23:00:00                                    0.0
#
#                        Niederschlag Durchschnitt in mm_lag36  \
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                  0.000
#   2022-01-01 01:00:00                                  0.000
#   2022-01-01 02:00:00                                  0.025
#   2022-01-01 03:00:00                                  0.100
#   2022-01-01 04:00:00                                  0.050
#   ...                                                    ...
#   2024-12-31 19:00:00                                  0.000
#   2024-12-31 20:00:00                                  0.000
#   2024-12-31 21:00:00                                  0.000
#   2024-12-31 22:00:00                                  0.000
#   2024-12-31 23:00:00                                  0.000
#
#                        Niederschlag Durchschnitt in mm_lag48
#   Datum / Uhrzeit
#   2022-01-01 00:00:00                                  0.025
#   2022-01-01 01:00:00                                  0.000
#   2022-01-01 02:00:00                                  0.000
#   2022-01-01 03:00:00                                  0.000
#   2022-01-01 04:00:00                                  0.000
#   ...                                                    ...
#   2024-12-31 19:00:00                                  0.000
#   2024-12-31 20:00:00                                  0.000
#   2024-12-31 21:00:00                                  0.000
#   2024-12-31 22:00:00                                  0.000
#   2024-12-31 23:00:00                                  0.000
#
#   [26304 rows x 66 columns]}]

# %% [markdown]
# ### Hyperparameter-Optimierung
# In diesem Abschnitt werden die Hyperparameter des Random Forest für die spätere Vorhersage der Testsets aller 25 Zeitreihen optimiert. Für das Tuning werden drei repräsentative Zeitreihen verwendet, die anhand des Variationskoeffizienten (hoch, mittel, niedrig) ausgewählt wurden ("Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein").
# Es wird eine Grid-Search mit TimeSeriesSplit-Cross-Validation durchgeführt. Pro Station werden 7 Folds verwendet. Das Validierungsset umfasst dabei jeweils 720 Stunden. Zur Vermeidung von Leakage wird eine Lücke von 24 Stunde ("gap=24") zwischen trainingsset und Validierungsset gesetzt. Die Zielgröße ist dabei eine 24-Stunden-Vorhersage (y=Abfluss(t+24)).
# Bewertet werden hier RMSE, MAE und NSE. Der Output zeigt dabei die Hyperparameterkombination mit dem niedrigsten mittleren RMSE und MAE sowie der höchsten mittleren NSE über alle Folds und repräsentativen Stationen.
# Als primäres Auswahlkriterium wurde die NSE verwendet. Darüber hinaus wurde die Diferenz zwischen Trainings-NSE und Validierungs-NSE ("nse gap") betrachtet, um ggfs. ein mögliches Overfitting zu erkennen und diesem später entgegenwirken zu können.
# Randbemerkung: Mit horizon ist die Lead Time der Vorhersage gemeint, also t --> Q(t+24)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from itertools import product
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


def hyper_parameter_tuning_cross_validation():
    train_test = train_and_test_nan()

    # define possible parameters
    params = {
                "n_estimators": [100, 200, 300, 500],
                "max_features": ["sqrt", "log2", 1.0],
                "max_depth": [10, 20],
                "min_samples_split": [5, 10],
                "min_samples_leaf": [1, 4],
                "max_samples": np.linspace(0.5, 1.0, 3),
            }
    keys = params.keys()
    values = params.values()
    params_columns = list(keys)

    # create all hyperparameter combinations a list of dictionaries. Each of them containing one hyper parameter combination.
    dict_all_combination = []
    all_combination = list(product(*values))
    for c in all_combination:
        dict_combination = dict(zip(keys, c))
        dict_all_combination.append(dict_combination)
            
    pred = []
    scores = []

    # try every hyperparameter combination of the grid.
    for d in dict_all_combination:
        selected_stations = ["Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein"]
        selected_train_test = [t for t in train_test if t["Stationsname"] in selected_stations]

       
        for t in selected_train_test:
            train_water = t["Trainingsset"].copy()
            train_water = train_water.sort_index()
            # define forecast horizon to forecast 24 hours in the future.
            train_water["y"] = train_water["Abfluss in m^3/s"].shift(-24)
    
            # the last 24 rows of y are NaN due to the shift by 24 hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
            train_water = train_water.dropna(subset=["y"])
    
            # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast. We keep "Abfluss in m^3/s" as current value and the last knon runoff which is important for the prediction. 
            x = train_water.drop(columns=["y"])
            y = train_water["y"]
            
            station = t["Stationsname"]
    
            # define Time Series Split for the Cross validation. We evaluate the model on 720 hour validation windows using 24 hour forecasts. 
            # To avoid leakage between train and validation I use a gap of 24 hours.
            tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=24)
            fold = 0

            # split the train set into seven folds for the cross validation and use RandomForestRegressor with the respective hyperparameter combination.
            for train_idx, validation_idx in tss.split(x):
                fold += 1
                x_train = x.iloc[train_idx]
                x_validation = x.iloc[validation_idx]
                y_train = y.iloc[train_idx]
                y_validation = y.iloc[validation_idx]
                
                model = RandomForestRegressor(
                    **d,
                    n_jobs = -1, 
                    random_state=42
                )
                    
                model.fit(x_train, y_train)
                
                
                # this is needed to predict the validation set    
                y_pred_validation = model.predict(x_validation)
                pred.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold, 
                    "Vorhersage": y_pred_validation
                 })

                # this is needed to check for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting
                y_pred_train = model.predict(x_train)

                # calculate the evaluation metrics for the validation set forecast in the cross validation
                rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
                mae_validation = mean_absolute_error(y_validation, y_pred_validation)
                nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

                # calculate the evaluation metrics for the training set forecast in the cross validation to compare them with the claculated metrics in the validation set forecast.
                rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
                mae_train = mean_absolute_error(y_train, y_pred_train)
                nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)

                # store information about the respective hyperparameter, station and fold with the corresponding metrics
                scores.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold,
                    "rmse validation": rmse_validation,
                    "mae validation": mae_validation,
                    "nse validation": nse_validation,
                    "rmse train": rmse_train,
                    "mae train": mae_train,
                    "nse train": nse_train,
                })
                print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
                print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
                print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station and hyperparameter combination
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby(["Stationsname"] + params_columns)[["rmse validation", "mae validation", "nse validation", "rmse train", "mae train", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "rmse train": "mean_rmse_train", "mae train": "mean_mae_train", "nse train": "mean_nse_train"})

    # calculate the mean evaluation metrics of all stations with the same hyperparameter configurations to find the best hyper parameter combination for all stations. We also want to calculate the evaluation metrics in the train set to identify if the model realy learns to regularize ore just to memorize if the metrics in the train set are much betterthan the metrics in the validation set.
    mean_per_hyper_parameter = mean_per_station.groupby(params_columns)[["mean_rmse_validation", "mean_mae_validation", "mean_nse_validation", "mean_rmse_train", "mean_mae_train", "mean_nse_train"]].mean()
    mean_per_hyper_parameter = mean_per_hyper_parameter.reset_index()
    mean_per_hyper_parameter["nse gap"] = mean_per_hyper_parameter["mean_nse_train"] - mean_per_hyper_parameter["mean_nse_validation"]

    # sort the evaluation metrics to show the best hyperparameter for the best metric
    sorted_rmse = mean_per_hyper_parameter.sort_values("mean_rmse_validation")
    sorted_mae = mean_per_hyper_parameter.sort_values("mean_mae_validation")
    sorted_nse = mean_per_hyper_parameter.sort_values("mean_nse_validation", ascending=False)

    # define the best hyperparameters per evaluation metric
    best_hp_rmse = sorted_rmse[params_columns].iloc[0]
    best_hp_mae = sorted_mae[params_columns].iloc[0]
    best_hp_nse = sorted_nse[params_columns].iloc[0]

    print(f"Best Hyperparameter combination with lowest mean rmse for all stations are {best_hp_rmse} with mean rmse {sorted_rmse['mean_rmse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_rmse['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean mae for all stations are {best_hp_mae} with mean mae {sorted_mae['mean_mae_validation'].iloc[0]} with nse gap between train and validation of: {sorted_mae['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean nse for all stations are {best_hp_nse} with mean nse {sorted_nse['mean_nse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_nse['nse gap'].iloc[0]}.")

    return best_hp_rmse, best_hp_mae, best_hp_nse

hyper_parameter_tuning_cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 7.006823878258022.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.291961823237532.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.11080043018962593.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 17.145164326285162.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.919255353454251.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.41222144356607926.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.1642986222133334.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.436957353722487.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.022283327607509618.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6465628012137934.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.500649452623973.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.24508900066040296.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.6815980136539634.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8727271422796427.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.4775183035909296.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.4857254716801098.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8606470995787745.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.1022110211727133.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 11.0550877000491.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.839140655964538.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5134081384574121.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.30142287738572143.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14075749507874688.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6044449919671521.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6765206725577734.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3175094928629987.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5693873463933543.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.236116931986751.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13111666386101603.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5175898563637094.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07790468376421986.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05597723061456086.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8160746591159734.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04675971195559689.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.032930469738883576.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5354043408261823.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.015283259796439234.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.01201544500688521.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8129419892365262.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11050445286557366.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0709234428217321.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.899404922674349.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.977529759409721.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.301219848802408.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9482405718993357.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.09334084780096.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.021882210835553.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9139628307406052.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.071743385347572.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.5476337177306645.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9709627642637766.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.93653645642615.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.348457751012676.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.989308976564047.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.875973596967251.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.6531507916089767.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9640178393976911.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.194622735803668.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8599073656458693.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.889600344161027.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.653919120218092.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.8099549003929543.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.7897818745129069.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 7.001310313986734.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.265104655000208.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.11219927512964778.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 17.074745719730046.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.913860485146463.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.417039775605222.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.31830255751229.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.5071352365562516.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.1729436289342119.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6136622564671016.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.48756854992397247.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.12159946244341735.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.6288472922331192.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.842515549704914.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.3862745130815768.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.4556468328974654.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8472261359377784.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.138194679027425.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 11.008466298395827.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.761479466373473.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.517503584916954.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2933020913176966.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14110171219969483.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6254715751981683.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6604664985705123.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.30528829593601636.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.589582159995194.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.23691157604956384.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13218391838952104.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.514337320258816.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07535351046380233.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05314723958323142.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8279235608261647.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04600564490833581.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0312150383366124.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5502680526105521.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01602276984773033.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.013169135506564632.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7944017047534904.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10885521396371961.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07247443554078392.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.90238520577151.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 11.8031042957601.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.225339445700762.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9275670964216866.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.50658949245017.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.644465663595227.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9099878019322973.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.386115915915884.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.772194944500514.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9691217771661993.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 11.485832952307044.
# Calculated CV MAE for Konstanz Rhein with MAE: 11.097199796004556.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9823393855239453.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 6.074111535190411.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.807382896428491.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.944161972049703.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.065148694356936.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7557126073290237.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9022423786919507.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.77389933757552.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.9569301382037514.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.778803112985849.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 7.055787394277708.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.27646419709363.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.0983295987358257.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 17.12333890874436.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.898955375865254.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.413716949466691.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.040715569786528.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.374840211730962.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.09112979177891778.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6280312353499191.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5073374013947723.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.17473918449744574.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.6384239779539302.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8535813915591728.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.4026234277689591.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.4440940701170804.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8411750027948276.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.15181985694614497.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 10.870679663633956.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.730012461640046.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.529506256286315.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2992282829086286.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14266149061403713.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6101839238110842.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6556452200395321.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3008711991463984.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.595552232720427.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2458187909649768.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13281533030124146.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.4771316854426403.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.08090170646676442.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05998756031835206.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8016511000130435.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.05155960675742946.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03667640676324741.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.4351271698709558.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.016248669250184627.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.012930847727487947.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7885635213362981.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10047097092142745.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07118245560947883.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9168430848765698.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 11.520572660427051.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.099259991326576.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9309932553636696.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 19.27313042712989.
# Calculated CV MAE for Konstanz Rhein with MAE: 13.461308487979114.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9023767853234124.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.350070584733317.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.843565865605764.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9693357328739596.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.618909570317085.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.863874387254496.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9876139593081221.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 5.942808891730791.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.444481112538342.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9465499548923699.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.255746694514528.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8991825903897337.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8833650706471654.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.584675281152998.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.7954381588881247.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.7959908441403245.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.8907342501793.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.20098634181275.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.14002100536694562.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.95429705359836.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.698943256183467.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.42523540217388744.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.1450624712776816.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.432780174827664.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.00419210262859937.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6069187039115251.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4859359362432289.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.09708432655713395.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.6108093773106245.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8333231239923369.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.35574120781583307.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.463130766262356.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.849288467155447.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.12931028016021484.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 10.95489643619178.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.8113352299444285.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5221880479916179.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2960983834117396.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13628972842821277.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6182961526514946.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6590941506208513.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3053487225766892.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.591285958517648.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2375933376831235.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12909381376198542.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5115381105250363.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.08193431338035079.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.055510692767371646.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7965554459274844.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04491136156138849.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03091634447826411.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5714081221304979.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.015896065550980016.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.012293176666785586.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.79764049408645.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1132115166205741.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07556982037500283.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8944159325751875.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.611139408060835.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.909990229990907.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9519721485357739.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.656698616635243.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.921684188996975.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9085216809569912.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.65722108394162.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.570968849420802.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9733037467130191.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.857934090287953.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.210757438562629.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9894962178042465.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.82594580282201.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.8483008098527067.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9647524100334495.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.0360818152985307.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7292651811792594.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9049748811070406.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.493739948591703.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.6059478477743414.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8040034761615945.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.830258245496945.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.145415053761084.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.1550498453390604.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.98278231480971.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.789605101194785.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4233024322150748.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.0587563757685645.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4067254492836088.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.07498915120193839.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6004615826772991.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.47401724244211907.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.07386433869897124.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5968239206526829.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8300015544694617.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.33230162578751976.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5020994995973413.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8611807579986572.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.08231309520359098.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 11.10139256748183.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.812085293922893.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5093233659718814.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2920379939995376.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1369101343970534.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6286929647166192.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6516189178850453.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.29946568589896727.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6005043891457941.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.23733380896745848.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.129821523109168.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5126046442184289.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07729374459695537.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.052707465485483676.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8189480831451598.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.05283142004302155.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.04290209766829549.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.4069161998044545.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01538095269842859.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.012221918783068898.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8105429400801232.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10848292402448843.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07089512816249886.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9030517583511776.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.422623936828115.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.907038864060668.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9435196288874906.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.94975659133144.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.996194899491188.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9056252410244787.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.069306161215016.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.791182569514863.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9709768157911548.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.026794195491595.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.34778907132066.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9890919303908026.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.81265509883405.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.859925006937965.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9649462871404711.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.108015977298448.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7992813642228829.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.898141853815044.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.599443122144773.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.7519100302795754.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.7946744468554169.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.913839299901287.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.247627307922441.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.13424421319166324.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.99917536612016.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.7527568743966055.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.42218855164861235.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.112223035379496.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4021448145229536.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.026319525082339146.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6401362387683629.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5187138395457093.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.22046068700560606.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.6072920201352727.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8352051587291801.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.3498268895165504.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.443367297884585.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8468391489631841.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.15267337289350968.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 11.088234495942169.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.747611792341675.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5104858385125818.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28361510347943647.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1353535515307232.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.649802392766383.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6648948858803818.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3104067389967929.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.584060056345888.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.24546404661800858.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13967262740128703.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.47863971288388285.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07815098669372826.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.053995743562544704.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8149098263921389.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.047072202035860135.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03322953412782859.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5291739067643131.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.015124611204611713.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.012056352728264781.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8168053614877282.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1128919365052292.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07684146030203125.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8950111890331958.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 11.105316377935727.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.033911871120369.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9358782632604926.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.77228723318187.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.908712296122786.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9073846515172147.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.684788949513045.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.391056725058131.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9731511129142983.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.000486317341414.
# Calculated CV MAE for Konstanz Rhein with MAE: 9.433975440949313.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9866117732640413.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 6.023471663892413.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.810818828360918.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9450891343363624.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.177751046592328.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8384007856356106.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8912912671150971.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.639238002849889.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.8899545905217248.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.7911060784868404.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.876862892385758.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.224512979952503.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.1434798731779443.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.993989084670453.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.852384712867709.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.42254106706194383.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.15237911314053.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4467717106048281.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.011054228682537248.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6334333981524682.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5045429377007549.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.19503571073269255.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.6777904624809528.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8882801545803442.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.4708349494354058.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5183347121218862.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8763115764322792.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.06236853379385299.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 10.977254469462894.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.765140051149086.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5202357087660583.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.30960725080140633.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.15346969197595584.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5826727814225396.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6720230450308415.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3147692314777695.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5750938902591873.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2421106784990037.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13257800027784492.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.49278737189293287.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.08114708497763491.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05552328602776319.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8004460730776511.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04487439328496882.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.030555551914866353.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5721134127933853.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01585612819625291.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.012400011803723047.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7986560348299337.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10950868679442023.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.0700952488272521.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.901209697874494.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 12.177570200694337.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.928049130758978.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9228981694497136.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.829891815493987.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.773885892151894.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9068153810829908.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.11855849611502.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.204134711743509.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9706921972588771.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.386664346162465.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.714394349111013.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9882048519737944.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 6.301473647414536.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.779315627706732.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9399035530960318.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.0658330111908425.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.759566792486643.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9021775811596852.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.72767485060329.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.9300397296387435.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.7830659640517812.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 7.0323122062703565.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.332068376843253.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.10431948165773863.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 17.20062588614236.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.94403539345677.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4084125746463019.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.1009510328309884.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4390662519631912.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.0366840020976088.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6418087101303108.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5227769390894884.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.22684636526060165.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.6478593334581828.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8592663167683976.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.41882479879083023.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5007688636721626.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8633052310463626.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.0839382422788475.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 10.848849028185613.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.805701890619925.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5313940617158742.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.3040164960048259.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14495719186226871.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.597608532536479.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6725671217948087.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.31641829388840126.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5744055950396597.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.24516854956738493.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13476472660697983.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.4798942159198534.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.08030583876385283.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05512252986729891.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8045621498663712.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0501837919095514.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03649544178288275.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.46487105712945165.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.01572009144395612.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.012425150096841857.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8020960527882692.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10588566683782419.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07440237041316264.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9076383838524982.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 12.196572153902165.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.693046747584864.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9226573614040736.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 19.00392081320364.
# Calculated CV MAE for Konstanz Rhein with MAE: 13.278756581501423.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9050849659223555.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.737182984435115.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.451706972847473.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9728598258934301.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.774415337384642.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.893358377785505.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9872102399332314.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 5.284444900936771.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.13929943703686.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9577367106516194.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.0686824564987774.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7576207421304781.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9019075381634949.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.840557584581452.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.015127841259192.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.7725828156848771.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 7.104195268298656.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.318376253071158.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.0859149175094478.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 17.142827368500154.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.978954426137663.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4123816660092743.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.2193169983444507.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4753291879847956.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.07491863285284506.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6334640181456012.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.5058245424296804.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.19515124890856428.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.6532669812231546.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8581865296862149.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.4281521651717646.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5066916795898906.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8790785860599095.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.07669346056363457.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 10.988363586168648.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.781921247740762.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5192641626645227.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.29651598873550367.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14220264867217808.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6172187137022557.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6757049425062109.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3119419637358442.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5704251621595782.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.24103085278248987.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13259108940038483.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.49730166969688683.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07859572155617502.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.053424511190444036.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8127972421517535.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04579419417986407.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03144843256348978.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5543926598431952.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.015320468664329831.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.012267662936263607.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8120300516485268.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10274269330591684.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06787296154051876.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9130400935422345.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 12.01162194100697.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.416972354263905.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.924985241643734.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.399060220875096.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.386428774870001.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9110307631101126.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.945479418631269.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.706062408048046.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9716862487427677.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.459390507590648.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.907878194133325.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9880213706202671.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 6.986553613610585.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.494922996735915.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9261261829908002.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.10876259034458.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.790992576665316.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8980696891929607.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.942485471354232.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.123203077085413.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.762904506737625.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.8952124129343355.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.1888227042423.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.13890287276965696.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.974868837825305.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.817131376022291.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.42383975520185657.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.219105161788363.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.5161294242815548.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.07471343801680597.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6072888916584918.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.48227911098312465.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.0984230595054596.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.6146479506761353.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8514088287314747.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.362210393912475.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5006845067447725.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8598982143556605.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.08404122147203064.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 11.007854777311385.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.738285191155357.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5175571888482887.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2932839873601688.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14283413956562624.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6255178090139919.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6659750544306298.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.30792212465132296.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.582707511144439.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.23513720072691.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13056482368354522.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5215849255519813.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07747667229035969.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.054109914212477093.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8180900939034201.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04638591625496153.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03284100630584985.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5428025783652466.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.014644524615675723.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.01148042842292631.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.828250739004569.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11111318427278985.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07421209521863611.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8982935820210972.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.647269918832448.
# Calculated CV MAE for Konstanz Rhein with MAE: 9.028034302620345.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9410586697166596.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.818995175954004.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.861503466060665.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9069231995891296.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.550967680869377.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.6088450812776385.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9681337798732191.
# ...
# Calculated CV MAE for Konstanz Rhein with MAE: 7.850149012767994.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9636363728673532.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.013956798170376.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.733044959358611.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9891229340114231.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 15.083502214712995.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.788361156437263.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.6556747036969731.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.7858906401490953.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7728011626285505.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8220999378389752.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.00207334292376.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.469097926117597.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.378505125442933.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 7.946694701294311.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.595044581700384.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.14374681640967335.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 17.811079920984465.
# Calculated CV MAE for Elpershofen Jagst with MAE: 6.8741972509388445.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.36567629886628406.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.336653527371406.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.501479569635156.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.1915864453150451.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.989303320663866.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.6970001763541613.
# Calculated CV NSE for Elpershofen Jagst with NSE: -10.786394748149311.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.8500652945895821.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8695054701357119.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.7883915568211646.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.7556920403439453.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.9955875421708912.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.25370053731879305.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 11.603437708707972.
# Calculated CV MAE for Elpershofen Jagst with MAE: 7.228199759308119.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.46393950034805786.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.30513736488516313.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14353310051318505.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5946359338771452.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6927511393242121.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.32499244588771586.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5484777658335751.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.27840615441185645.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1508566828162933.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.32931308857757013.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11020650779467432.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06931608050853254.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6319312780643358.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.05210438475732892.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03469493417694852.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.4231272324481091.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.016277373069025925.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.009475107008731313.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7878158422663631.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1694873884652975.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.10965569935789929.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7633579344425043.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 13.892848195136489.
# Calculated CV MAE for Konstanz Rhein with MAE: 11.897928741152242.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8996480106985517.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 15.662414061586297.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.115854589956045.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9355287655389679.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.974368590258772.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.6975116366429095.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9655249383536171.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.622348734493746.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.394508147848677.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.990047504567173.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.222998556219368.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.446576096672377.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8418310811654997.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.6412829849455193.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.6971022856838558.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8400891842708469.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 6.735348963235568.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.665712971688941.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.5596959302153484.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 8.244901773439675.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.652907794092395.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.23119775034710588.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 18.094820205626963.
# Calculated CV MAE for Elpershofen Jagst with MAE: 7.129752071112288.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.3453050688420307.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.3065926766127167.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.460253724507939.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.16112434164178469.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.2026421254856143.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.8570608072220134.
# Calculated CV NSE for Elpershofen Jagst with NSE: -13.44996678592321.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.8402708644473487.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8638700751118471.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.7695058345009569.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.758530907956995.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.0197412003477557.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.25775815927818235.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 11.99173915768176.
# Calculated CV MAE for Elpershofen Jagst with MAE: 7.761385289026141.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.42746135875335667.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.309267649423495.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14637914517745443.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5835877933974951.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.7125720295771725.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3293310845063422.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.52227036164251.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28425859841124756.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1520710712076209.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.30081936904457895.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11513657967999483.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06987518228105823.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5982636962780429.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.051457790953282706.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03454173131421185.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.4373558988712931.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.018276443032891894.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.010011346051214388.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.732497605116963.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.1823374660557389.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.10976296658533226.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7261145244190006.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 14.402481690171062.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.227634071253442.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8921505166307891.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 15.860258964086661.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.244596824180658.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9338896993709744.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 11.087891802882714.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.67245079621173.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9648080019295687.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.407963384110326.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.300419558695934.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9905362678032317.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 12.30457880874763.
# Calculated CV MAE for Konstanz Rhein with MAE: 6.461242821180286.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.770861507532376.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.6108443890162003.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.6724085225072596.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8437536261411985.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 7.461141862072952.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.142294379320255.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.45968989333017174.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 8.406227452085353.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.697371404840416.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.27985012397796893.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 18.11771237232049.
# Calculated CV MAE for Elpershofen Jagst with MAE: 7.154328818748647.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.34364748222139563.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.311097593432273.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4517017242424666.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.1656642646503872.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.4068050351638117.
# Calculated CV MAE for Elpershofen Jagst with MAE: 2.023618126845755.
# Calculated CV NSE for Elpershofen Jagst with NSE: -16.252847753649625.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.797517809764002.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8443248182082032.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.6882427851285284.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.7937063134507074.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.0448874899841687.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.30857857399752575.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 12.03419680387945.
# Calculated CV MAE for Elpershofen Jagst with MAE: 7.815736826187443.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4233999501410506.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.3168034947239845.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.14949451571170283.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.563047335223749.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.7239264099472409.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.33239014376000675.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5069244306454682.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28821808977720187.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.151631511135485.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.2812056759750624.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11702477792121685.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.07060639069383452.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5849789900481254.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.05109806668528576.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.034283419627550396.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.44519491759378815.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.018595825837697547.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.009980732081177219.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7230666492436574.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.19724210172814077.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11599727009164423.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6795085746076857.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 14.828398464699042.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.517218024170905.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.885677450517827.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 16.0379506584068.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.370060663986388.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9324000569889902.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 11.091636560816035.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.732089823037451.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9647842268476089.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.59902049080275.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.365811042247017.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9901012857736116.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 13.543265030551488.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.055334458235265.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.7224052158202768.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.7097164598976464.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7125663897290553.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8316955223902263.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 7.9019103618653705.
# Calculated CV MAE for Konstanz Rhein with MAE: 5.3890366706892365.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.3939664130847753.
# Best Hyperparameter combination with lowest mean rmse for all stations are n_estimators          100
# max_features         sqrt
# max_depth              10
# min_samples_split       5
# min_samples_leaf        4
# max_samples           0.5
# Name: 51, dtype: object with mean rmse 4.772064235866597 with nse gap between train and validation of: 0.34365125383739736.
# Best Hyperparameter combination with lowest mean mae for all stations are n_estimators          100
# max_features         sqrt
# max_depth              10
# min_samples_split       5
# min_samples_leaf        4
# max_samples           0.5
# Name: 51, dtype: object with mean mae 3.135929970237679 with nse gap between train and validation of: 0.34365125383739736.
# Best Hyperparameter combination with lowest mean nse for all stations are n_estimators          500
# max_features         sqrt
# max_depth              10
# min_samples_split       5
# min_samples_leaf        4
# max_samples           0.5
# Name: 267, dtype: object with mean nse 0.5747757741494537 with nse gap between train and validation of: 0.34209104854913763.
# (n_estimators          100
#  max_features         sqrt
#  max_depth              10
#  min_samples_split       5
#  min_samples_leaf        4
#  max_samples           0.5
#  Name: 51, dtype: object,
#  n_estimators          100
#  max_features         sqrt
#  max_depth              10
#  min_samples_split       5
#  min_samples_leaf        4
#  max_samples           0.5
#  Name: 51, dtype: object,
#  n_estimators          500
#  max_features         sqrt
#  max_depth              10
#  min_samples_split       5
#  min_samples_leaf        4
#  max_samples           0.5
#  Name: 267, dtype: object)

# %% [markdown]
# ### Hyperparameter-Tuning mit höherem min_samples_leaf
# Mit der nun in der vorherigen Optimierung ausgewählten Kombination wird hier zusätzlich der Hyperparameter "min_samples_leaf" mit etwas höheren Werten in einer erneuten Cross-Validation variiert, während die übrigen Hyperparameter fixiert bleiben. Ziel ist es, zu überprüfen, ob sich dadurch die Validierungsleistung verbessern oder die Differenz zwischen Trainings- und Validierungs-NSE reduzieren lässt. Tatsächlich wird min_samples_leaf=12 gewählt, da die NSE-Leistung damit am besten ist.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from itertools import product
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


def hyper_parameter_tuning_cross_validation():
    train_test = train_and_test_nan()

    # define possible parameters
    params = {
                "min_samples_leaf": [6, 8, 10, 12]
            }
    keys = params.keys()
    values = params.values()
    params_columns = list(keys)

    # create all hyperparameter combinations a list of dictionaries. Each of them containing one hyper parameter combination.
    dict_all_combination = []
    all_combination = list(product(*values))
    for c in all_combination:
        dict_combination = dict(zip(keys, c))
        dict_all_combination.append(dict_combination)
            
    pred = []
    scores = []

    # try every hyperparameter combination of the grid.
    for d in dict_all_combination:
        selected_stations = ["Elpershofen Jagst", "Mägerkingen Lauchert", "Konstanz Rhein"]
        selected_train_test = [t for t in train_test if t["Stationsname"] in selected_stations]

        
        for t in selected_train_test:
            train_water = t["Trainingsset"].copy()
            train_water = train_water.sort_index()
            # define forecast horizon to forecast one hour in the future.
            train_water["y"] = train_water["Abfluss in m^3/s"].shift(-24)
    
            # the last 6 rows of y are NaNs due to the shift by 24 hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
            train_water = train_water.dropna(subset=["y"])
    
            # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast. We keep "Abfluss in m^3/s" as current value and the last knon runoff which is important for the prediction. 
            x = train_water.drop(columns=["y"])
            y = train_water["y"]
            
            station = t["Stationsname"]
    
            # define Time Series Spliit for the Cross validation. We evaluate the model on 720 hour validation windows using 24 hour forecasts. 
            # To avoid leakage between train and validation I use a gap of 24 hours.
            tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=24)
            fold = 0

            # split the train set into seven folds for the cross validation and use XGBoostRegressor with the respective hyperparameter combination.
            for train_idx, validation_idx in tss.split(x):
                fold += 1
                x_train = x.iloc[train_idx]
                x_validation = x.iloc[validation_idx]
                y_train = y.iloc[train_idx]
                y_validation = y.iloc[validation_idx]
                
                model = RandomForestRegressor(
                    **d,
                    n_estimators=500,
                    max_depth=10,
                    min_samples_split=5,
                    max_features="sqrt",
                    max_samples=0.5,
                    n_jobs = -1, 
                    random_state=42
                )
                    
                model.fit(x_train, y_train)
                
                
                # this is needed to predict the validation set    
                y_pred_validation = model.predict(x_validation)
                pred.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold, 
                    "Vorhersage": y_pred_validation
                 })

                # this is needed to check for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting
                y_pred_train = model.predict(x_train)

                # calculate the evaluation metrics for the validation set forecast in the cross validation
                rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
                mae_validation = mean_absolute_error(y_validation, y_pred_validation)
                nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

                # calculate the evaluation metrics for the training set forecast in the cross validation to compare them with the claculated metrics in the validation set forecast.
                rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
                mae_train = mean_absolute_error(y_train, y_pred_train)
                nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)

                # store information about the respective hyperparameter, station and fold with the corresponding metrics
                scores.append({
                    **d,
                    "Stationsname": station,
                    "Fold": fold,
                    "rmse validation": rmse_validation,
                    "mae validation": mae_validation,
                    "nse validation": nse_validation,
                    "rmse train": rmse_train,
                    "mae train": mae_train,
                    "nse train": nse_train,
                })
                print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
                print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
                print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station and hyperparameter combination
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby(["Stationsname"] + params_columns)[["rmse validation", "mae validation", "nse validation", "rmse train", "mae train", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "rmse train": "mean_rmse_train", "mae train": "mean_mae_train", "nse train": "mean_nse_train"})

    # calculate the mean evaluation metrics of all stations with the same hyperparameter configurations to find the best hyper parameter combination for all stations. We also want to calculate the evaluation metrics in the train set to identify if the model realy learns to regularize ore just to memorize if the metrics in the train set are much betterthan the metrics in the validation set.
    mean_per_hyper_parameter = mean_per_station.groupby(params_columns)[["mean_rmse_validation", "mean_mae_validation", "mean_nse_validation", "mean_rmse_train", "mean_mae_train", "mean_nse_train"]].mean()
    mean_per_hyper_parameter = mean_per_hyper_parameter.reset_index()
    mean_per_hyper_parameter["nse gap"] = mean_per_hyper_parameter["mean_nse_train"] - mean_per_hyper_parameter["mean_nse_validation"]

    # sort the evaluation metrics to show the best hyperparameter for the best metric
    sorted_rmse = mean_per_hyper_parameter.sort_values("mean_rmse_validation")
    sorted_mae = mean_per_hyper_parameter.sort_values("mean_mae_validation")
    sorted_nse = mean_per_hyper_parameter.sort_values("mean_nse_validation", ascending=False)

    # define the best hyperparameters per evaluation metric
    best_hp_rmse = sorted_rmse[params_columns].iloc[0]
    best_hp_mae = sorted_mae[params_columns].iloc[0]
    best_hp_nse = sorted_nse[params_columns].iloc[0]

    print(f"Best Hyperparameter combination with lowest mean rmse for all stations are {best_hp_rmse} with mean rmse {sorted_rmse['mean_rmse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_rmse['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean mae for all stations are {best_hp_mae} with mean mae {sorted_mae['mean_mae_validation'].iloc[0]} with nse gap between train and validation of: {sorted_mae['nse gap'].iloc[0]}.")
    print(f"Best Hyperparameter combination with lowest mean nse for all stations are {best_hp_nse} with mean nse {sorted_nse['mean_nse_validation'].iloc[0]} with nse gap between train and validation of: {sorted_nse['nse gap'].iloc[0]}.")

    return best_hp_rmse, best_hp_mae, best_hp_nse

hyper_parameter_tuning_cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.844257230985885.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.157173768078985.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.15158275345210903.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.932197450042043.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.6728804320137876.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4267328150429598.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.1015605766317127.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4190596962234163.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.036124951967918206.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.613358740885053.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4930912755407804.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.12049025709801264.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5948428102766847.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8225558767054072.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.32899781849444376.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.4769362442536171.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.852498998881625.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.11280184879136479.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 10.925901841355675.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.745282965865218.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5247139742242781.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28542826488477274.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.133101246886799.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6453104284524341.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.660832316883719.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3019834558187267.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5891273907026273.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.23493090473410735.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.12961834947081335.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5224240255983678.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07730854675895646.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05512162415372628.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8188787317007156.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.047295519959112846.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03458693644492055.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5246959639275278.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.016161665056471822.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.01294018370825232.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7908217505309519.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10407958695893346.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06985627143757765.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.910762315746496.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.439592615903637.
# Calculated CV MAE for Konstanz Rhein with MAE: 9.071412101655275.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9433355720775272.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.954114973414917.
# Calculated CV MAE for Konstanz Rhein with MAE: 13.032567604878336.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9055818242599476.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.802222290237308.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.414215843333649.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9724960505960513.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.716693580245531.
# Calculated CV MAE for Konstanz Rhein with MAE: 9.09795824602149.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9873608510089232.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 5.355170483583903.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.555897351566761.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9565978593833527.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.1329877508718686.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8045252241533205.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.895714315943393.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.56454042430263.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.7859359759457414.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.79777883341505.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.8333412480084865.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.149055396689101.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.15428689575019083.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.958352519912253.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.671986152902805.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.42496040200871776.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.0503642522341234.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.384881459742013.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.08251503781505487.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.607580835993038.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4840230484905.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.09947941167670393.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.608257561803127.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8224359129150198.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.3514491281104628.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.461280439773949.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.843407812881861.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.1315110971852903.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 10.971194294056644.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.712107819254731.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5207652862140495.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28256723885467716.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1345840041311815.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6523853425604382.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6602347866179797.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3049723060719679.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5898700838716975.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.23604571199319624.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.130434814571246.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5178808313940899.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07583436127824916.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05340739456964022.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8257204226239395.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.045990022545402486.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03240442112669622.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5505734361265643.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.015382076175964444.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.01214200670170552.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8105152618824619.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10376661052723019.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06992806657822503.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9112981998692646.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.26939332456522.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.7946780411984.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9451681396028155.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 18.56107701241551.
# Calculated CV MAE for Konstanz Rhein with MAE: 12.673443880532675.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.909456989761601.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.053191376986167.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.481111271372852.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9710696380951652.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.422181672444493.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.795594576947327.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9881154219729635.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 5.045954911791032.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.35742001583617.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9614653624719544.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.2084331382770035.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8486933376806753.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8882065183477106.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.44543124475194.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.5718965690403612.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8081948378165758.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.838308483312082.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.15048265598069.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.15305693147321875.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.99354711377242.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.6955653478524635.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4225711031791948.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.0589296184901116.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4013392499302275.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.07483346678846703.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6024514473285384.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4763589939001305.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.08099347197071549.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5975162964654988.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8170124628573395.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.33345723649074865.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.4723479281202756.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8497990724596352.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.118305705070061.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 11.020940725493775.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.749675763972031.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5164094676473712.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.27729218066468897.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13124302616714498.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.66524296619595.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.6578502839674053.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3051006087728651.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.592827183073758.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.23848648594375524.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.1312910080467442.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5078588079768219.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07598217935792465.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.05293493918623112.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8250403409395499.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04656535124095489.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03353597690685948.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5392585765575879.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.015236496288660395.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.011903532242527498.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8140849529936032.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10242681284734155.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06884584156699716.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.913573984720039.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 11.21321663034043.
# Calculated CV MAE for Konstanz Rhein with MAE: 10.102768245123832.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9346261848957852.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 19.101124264400653.
# Calculated CV MAE for Konstanz Rhein with MAE: 13.085070875321152.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.904111517942266.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.899265011035972.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.330341112261259.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9719487726545806.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.333451133466435.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.759822659512112.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9883382068258917.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.804211702841891.
# Calculated CV MAE for Konstanz Rhein with MAE: 4.033620826671498.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9650691767900941.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.2302367965986973.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.8463470485982492.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8859881677214011.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.395275024013046.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.5491715876103664.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8124985603368691.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.793996332213783.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.113522642936602.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.16399772853739114.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.952058085698404.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.620556328799323.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4253871978524073.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.0805041416410566.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4024043722772326.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.05534314296128795.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6044898253264251.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.47835503875466856.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.08832087076693451.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.573900586596201.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8046637140828403.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.2943242640756918.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.4647132925103172.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8427623958316872.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.12742578079528166.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 10.9862870818314.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.738219517868571.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5194458377105482.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.28144368320664415.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13243187937753492.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.6551442464165839.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.658400588466866.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3066802697522363.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5921456822590043.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.23443692696375937.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13126841884821971.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5244302656460702.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07547130715076118.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.052487988964390137.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8273851419012574.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.04708806421352506.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03352087942243227.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5288565396075338.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.015993560757103065.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.012587072476520777.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7951506221388679.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10066008100625987.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06853468499286558.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9165297483780054.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.146835012099432.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.829769706817752.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9464690928581223.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 19.537667889713948.
# Calculated CV MAE for Konstanz Rhein with MAE: 13.462484802684314.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8996784970661986.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.32545533954888.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.5365695106927095.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.969481415143276.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.467908282873323.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.822886956465522.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9879997884241285.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.9380592869116904.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.340240671405884.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9765291376047696.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.120965276784281.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.7560809533791895.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8968866044609842.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.428445951801596.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.502828307451035.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8096577523424494.
# Best Hyperparameter combination with lowest mean rmse for all stations are min_samples_leaf    12
# Name: 3, dtype: int64 with mean rmse 4.84927526653884 with nse gap between train and validation of: 0.30334408675409197.
# Best Hyperparameter combination with lowest mean mae for all stations are min_samples_leaf    12
# Name: 3, dtype: int64 with mean mae 3.1899455292038827 with nse gap between train and validation of: 0.30334408675409197.
# Best Hyperparameter combination with lowest mean nse for all stations are min_samples_leaf    12
# Name: 3, dtype: int64 with mean nse 0.5826332898695972 with nse gap between train and validation of: 0.30334408675409197.
# (min_samples_leaf    12
#  Name: 3, dtype: int64,
#  min_samples_leaf    12
#  Name: 3, dtype: int64,
#  min_samples_leaf    12
#  Name: 3, dtype: int64)

# %% [markdown]
# ### Cross Validation mit optimierten Hyperparametern
# In den folgenden zwei Blöcken wird eine zeitbasierte Cross-Validation mit der ermittelten Hyperparameter-Kombination für alle 25 Zeitreihen durchgeführt. Ziel ist es, die Validierungsleistung pro Station und über alle Stationen im Mittel zu quantifizieren. Zusätzlich soll ermöglicht werden, eine mögliche Überanpassung über die Differenz zwischen Trainings- und Validierungs-NSE zu beurteilen.
# Im ersten Block wird der Niederschlag als exogene Variable verwendet, im zweiten Block werden alle Niderschlagsdaten entfernt. Durch den Vergleich der Metriken soll die Bedeutung der Niederschlagsdaten für die Vorhersageleistung bewertet werden.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Cross Validation with exogene features
def cross_validation():
    train_test = train_and_test_nan()
    
    pred = []
    scores = []

    # Cross Validation for every of the 25 stations in Baden-Württemberg with the best hyper parameter from the hyper parameter tuning.
    for t in train_test:
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()

        # defining forecast horizon to forecast 24 hours in the future (Q(t)--> Q(t+24)).
        train_water["y"] = train_water["Abfluss in m^3/s"].shift(-24)

        # the last 24 rows of y are NaN due to the shift by 24 hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train_water = train_water.dropna(subset=["y"])

        # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast.
        # We keep "Abfluss in m^3/s" as current value and the last known runoff which is important for the prediction.
        x = train_water.drop(columns=["y"])
        y = train_water["y"]
        
        station = t["Stationsname"]

        # define Time Series Spliit for the Cross validation. I evaluate the model on 720 hour validation windows using 24 hour ahead forecasts. 
        # To avoid leakage between train and validation I use a gap of 24 hours.
        tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=24)
        fold = 0

        # split the train set into seven folds for the cross validation and use RandomForestRegressor with the respective hyperparameter combination.
        for train_idx, validation_idx in tss.split(x):
            fold += 1
            x_train = x.iloc[train_idx]
            x_validation = x.iloc[validation_idx]
            y_train = y.iloc[train_idx]
            y_validation = y.iloc[validation_idx]

            # Define Random Forest model with the best hyperparameter combination identified in the hyperparameter tuning
            model = RandomForestRegressor(
                n_estimators=500, 
                max_features="sqrt",
                max_depth=10, 
                min_samples_split=5,
                min_samples_leaf=12,
                max_samples=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # Predict the respective validation set per fold
            y_pred_validation = model.predict(x_validation)
            pred.append({
                "Stationsname": station,
                "Fold": fold, 
                "Vorhersage": y_pred_validation
            })

            # Predict the respective validation set per fold to ceck for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting.
            y_pred_train = model.predict(x_train)

            # Calculate the evaluation metrics "RMSE", "MAE" and "NSE" for the prediction of the validation set per fold.
            rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
            mae_validation = mean_absolute_error(y_validation, y_pred_validation)
            nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

            # Calculate "NSE" and "NSE gap" per fold to identify potential model overfitting.
            nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)
            nse_gap = nse_train - nse_validation

            # store evaluation metrics for this station and fold in score
            scores.append({
                "Stationsname": station,
                "Fold": fold,
                "rmse validation": rmse_validation,
                "mae validation": mae_validation,
                "nse validation": nse_validation,
                "nse train": nse_train,
                "nse gap": nse_gap
            })
            print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
            print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
            print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")

    # calculate the mean evaluation metrics over the folds with the same station. This enables to compare the scores with the other cv, to identify the importance of the exogene features.
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby("Stationsname")[["rmse validation", "mae validation", "nse validation", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "nse train": "mean_nse_train"})

    overall_mean_nse = mean_per_station["mean_nse_validation"].mean()
    overall_mean_nse_train = mean_per_station["mean_nse_train"].mean()
    overall_nse_gap = overall_mean_nse_train - overall_mean_nse
    
    return scores_df, mean_per_station, overall_mean_nse, overall_mean_nse_train, overall_nse_gap

cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Gießen Argen with RMSE: 7.804497659093685.
# Calculated CV MAE for Gießen Argen with MAE: 4.1641305626284.
# Calculated CV NSE for Gießen Argen with NSE: 0.6592189465872749.
# Calculated CV RMSE for Gießen Argen with RMSE: 22.491439677340573.
# Calculated CV MAE for Gießen Argen with MAE: 11.780506203743997.
# Calculated CV NSE for Gießen Argen with NSE: 0.30764549793886087.
# Calculated CV RMSE for Gießen Argen with RMSE: 24.133087637658672.
# Calculated CV MAE for Gießen Argen with MAE: 10.255857151208364.
# Calculated CV NSE for Gießen Argen with NSE: 0.3444768918840959.
# Calculated CV RMSE for Gießen Argen with RMSE: 4.653704181491915.
# Calculated CV MAE for Gießen Argen with MAE: 2.975189484425739.
# Calculated CV NSE for Gießen Argen with NSE: 0.22387546776267642.
# Calculated CV RMSE for Gießen Argen with RMSE: 1.8815335592167692.
# Calculated CV MAE for Gießen Argen with MAE: 1.2972479302153004.
# Calculated CV NSE for Gießen Argen with NSE: -2.1710726777443203.
# Calculated CV RMSE for Gießen Argen with RMSE: 4.271924517353037.
# Calculated CV MAE for Gießen Argen with MAE: 2.5441230664260046.
# Calculated CV NSE for Gießen Argen with NSE: 0.4366645916599281.
# Calculated CV RMSE for Gießen Argen with RMSE: 17.286046857234656.
# Calculated CV MAE for Gießen Argen with MAE: 9.566191498362306.
# Calculated CV NSE for Gießen Argen with NSE: 0.4415719573651904.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.3343033114067403.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.20466754008292867.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.1558497375837291.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 3.784153363148608.
# Calculated CV MAE for Blaubeuren Blau with MAE: 1.1893943953265274.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.4388040359729456.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.23316326554811498.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.1606654665973126.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.5994901216726631.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.09784558944284852.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.07989065926367635.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.9242937168904144.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.10014427531179282.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.07781012150913928.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.6300264810569607.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.07272318794473027.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.053157540277294045.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.5282832347111464.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.34092807737912306.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.2201681030246605.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.8664311944617828.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.6731233836092188.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.38704531526720654.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.04708466788760035.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 1.329282494081213.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.6276761391668904.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.24285010862553236.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.5673720186135615.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.32665846206742694.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.06232933709891819.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.20064428618274283.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.1599907184123694.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.19045755783497398.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.35285745486246334.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.22573624664809944.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.02721413958110197.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.31398745875059214.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.18010634309487636.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.11434007330390539.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.5195740374469993.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.31829627253284115.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.6529491678981691.
# Calculated CV RMSE for Beuron Donau with RMSE: 9.110770917604029.
# Calculated CV MAE for Beuron Donau with MAE: 5.046744926270685.
# Calculated CV NSE for Beuron Donau with NSE: 0.5208419631815059.
# Calculated CV RMSE for Beuron Donau with RMSE: 6.286152733541656.
# Calculated CV MAE for Beuron Donau with MAE: 3.809555505324478.
# Calculated CV NSE for Beuron Donau with NSE: 0.7013731346947232.
# Calculated CV RMSE for Beuron Donau with RMSE: 1.6524858276267655.
# Calculated CV MAE for Beuron Donau with MAE: 0.9984332640562101.
# Calculated CV NSE for Beuron Donau with NSE: 0.6132583206189832.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.5152099708655205.
# Calculated CV MAE for Beuron Donau with MAE: 0.4034510822341156.
# Calculated CV NSE for Beuron Donau with NSE: 0.3330019798847563.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.24121283345602598.
# Calculated CV MAE for Beuron Donau with MAE: 0.15040202628490082.
# Calculated CV NSE for Beuron Donau with NSE: 0.43027613927132347.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.17489377268141085.
# Calculated CV MAE for Beuron Donau with MAE: 0.10964014546288132.
# Calculated CV NSE for Beuron Donau with NSE: 0.4455845100451372.
# Calculated CV RMSE for Beuron Donau with RMSE: 5.281555797769251.
# Calculated CV MAE for Beuron Donau with MAE: 2.7969245785379666.
# Calculated CV NSE for Beuron Donau with NSE: 0.6878983270893044.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 13.307494755694698.
# Calculated CV MAE for Hundersingen Donau with MAE: 7.1154356752380865.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.6263084595805664.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 11.271895716271173.
# Calculated CV MAE for Hundersingen Donau with MAE: 7.617926223858935.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.7481937984158754.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 2.0631371726560155.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.3073293167670204.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.8576626375922154.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.8129827495806317.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.6169210200336385.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.7753547336387434.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.9207142518943223.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.6718932124530758.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.2835774349809943.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.6937711554859413.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.5706498377830804.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.3609079177904634.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 5.829913603456587.
# Calculated CV MAE for Hundersingen Donau with MAE: 3.141575435786004.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.7100391303048358.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 7.2728740544118295.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.7567176976626013.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.0035186804936427896.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 2.0633878955521547.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.0558771251705978.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.26578586820785977.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.9236521358279526.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.6510841792912873.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.22492237407152327.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.3530395880451168.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.30321144324424987.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.38763117109107725.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.3826565005125348.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.26127433586889565.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.20135750312074263.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.2143606369551958.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.17557893079887535.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.33304091500854316.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.5731718182331303.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.38395307956848324.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.44384551753026036.
# Calculated CV RMSE for Eutingen Enz with RMSE: 9.651425863972314.
# Calculated CV MAE for Eutingen Enz with MAE: 4.496174997770997.
# Calculated CV NSE for Eutingen Enz with NSE: 0.06751098814053269.
# Calculated CV RMSE for Eutingen Enz with RMSE: 11.410221536030935.
# Calculated CV MAE for Eutingen Enz with MAE: 4.482054762257803.
# Calculated CV NSE for Eutingen Enz with NSE: 0.06754547402243538.
# Calculated CV RMSE for Eutingen Enz with RMSE: 2.9991592353604135.
# Calculated CV MAE for Eutingen Enz with MAE: 2.299891027628856.
# Calculated CV NSE for Eutingen Enz with NSE: 0.01943640348909781.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.4348558291516162.
# Calculated CV MAE for Eutingen Enz with MAE: 0.8843300356114535.
# Calculated CV NSE for Eutingen Enz with NSE: 0.2000841321500041.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.6790601999526178.
# Calculated CV MAE for Eutingen Enz with MAE: 1.0259529255599802.
# Calculated CV NSE for Eutingen Enz with NSE: 0.016020055286163903.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.1620750039746617.
# Calculated CV MAE for Eutingen Enz with MAE: 0.8968086248443234.
# Calculated CV NSE for Eutingen Enz with NSE: -0.4539092340199591.
# Calculated CV RMSE for Eutingen Enz with RMSE: 4.627455200093658.
# Calculated CV MAE for Eutingen Enz with MAE: 2.3866810944685506.
# Calculated CV NSE for Eutingen Enz with NSE: 0.6057535788379622.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 6.793996332213783.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.113522642936602.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.16399772853739114.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 16.952058085698404.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.620556328799323.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.4253871978524073.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 2.080504141641056.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4024043722772324.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.05534314296128817.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.6044898253264251.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.4783550387546685.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.08832087076693451.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.573900586596201.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8046637140828403.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.2943242640756918.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.4647132925103172.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8427623958316869.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.12742578079528166.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 10.986287081831398.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.738219517868568.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.5194458377105483.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 4.7565538388991255.
# Calculated CV MAE for Hausach Kinzig with MAE: 3.206437694141086.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.43025210913793055.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 8.64463196105132.
# Calculated CV MAE for Hausach Kinzig with MAE: 3.5629386585011917.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.29819222085203545.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 1.5510229560486568.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.2305240818690049.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.04605260187706717.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.7873918819266504.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.6321602430351828.
# Calculated CV NSE for Hausach Kinzig with NSE: -0.4835765672517194.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 1.446467701527148.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.9701158214545545.
# Calculated CV NSE for Hausach Kinzig with NSE: -0.5948233157484561.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 2.2075891940559087.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.5137193478653443.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.10709149200996826.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 12.364766548669555.
# Calculated CV MAE for Hausach Kinzig with MAE: 7.452603946853075.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.4590759388938649.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 1.3264633909707384.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.46018451408591543.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.03208303993243744.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 3.0224249582509177.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.8709405403871054.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.10774965890838817.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.4503578595622246.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.30848763322928296.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.03183685431074024.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.15493069938577264.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.14128092557384575.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.14466099395032495.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.23909848107931367.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.13655577118170184.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.2703626960602248.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.19776586018063144.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.12793623744073432.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.2354273234526738.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.8848255404271259.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.5346884011292646.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.3858466943159983.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2814436832066441.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13243187937753492.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.655144246416584.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.658400588466866.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.3066802697522363.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5921456822590044.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.23443692696375937.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13126841884821971.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5244302656460702.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.07547130715076117.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.052487988964390116.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8273851419012576.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.047088064213525065.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.03352087942243228.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5288565396075336.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.015993560757103058.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.01258707247652077.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7951506221388681.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.10066008100625988.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06853468499286558.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.9165297483780054.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.5778922365315468.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.26784142818929907.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.033935961090496125.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.45069703908518866.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.18013218611051465.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.01845421330393049.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.10137259996871818.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.08325060702796223.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -1.0437018219211787.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.10531042040701867.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.062233801902641765.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.20731557493875918.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.16898005609503666.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.0743155522172262.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.04689844147220512.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.09422840976573986.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.056156430463371584.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.07030270714668796.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.23358410304655963.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.13195433422891756.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.1742541569648478.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 7.722953723227692.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 5.173076066605195.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.5259853323599168.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 14.93744689098501.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 6.466072296107155.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.6714820860208134.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 2.5401772808737406.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.81251864688448.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.3008107184997697.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 1.3678913096997563.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.031549958043008.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.2381751578469079.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 2.5567333743064995.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.1904486801747136.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: -0.22628491579833976.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 2.488109484460422.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.6841877613513425.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.051839078135825334.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 13.274824403756288.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 7.30579641025824.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.3975088601155442.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 7.986140422157608.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 4.820067262398235.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.4200876076268576.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 7.588133119837596.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 4.110933621575846.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.31385405720238724.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 4.3529432277904325.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 2.7353829319181022.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -0.7331895122032184.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.847010504103462.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.227331752062486.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -0.08955700483852702.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 2.2102418205177528.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.3025226784498884.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -1.1641874251969053.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 2.66550335541451.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.926147952966972.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -0.3944575741503962.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 18.291150964302645.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 8.26895482802428.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.5410592572159407.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 2.5885871559894347.
# Calculated CV MAE for Baiersbronn Murg with MAE: 1.3015175074785108.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.24878964609706156.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 2.073434315959519.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.9797762218898762.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.1701947107712477.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.6302146126295544.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.4272919900299392.
# Calculated CV NSE for Baiersbronn Murg with NSE: -2.298378305673284.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.1857750894236295.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.1354368584569047.
# Calculated CV NSE for Baiersbronn Murg with NSE: -4.281255356701259.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.5690925306177186.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.4122797814972807.
# Calculated CV NSE for Baiersbronn Murg with NSE: -1.8795241312340742.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.042288834669833.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.697713396232849.
# Calculated CV NSE for Baiersbronn Murg with NSE: -0.06900816225474382.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 7.432553889175689.
# Calculated CV MAE for Baiersbronn Murg with MAE: 3.603228873069871.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.29607542510619933.
# Calculated CV RMSE for Horb Neckar with RMSE: 10.745908185684799.
# Calculated CV MAE for Horb Neckar with MAE: 5.84988143265444.
# Calculated CV NSE for Horb Neckar with NSE: 0.3570266164820307.
# Calculated CV RMSE for Horb Neckar with RMSE: 11.100021660789112.
# Calculated CV MAE for Horb Neckar with MAE: 5.019890585814244.
# Calculated CV NSE for Horb Neckar with NSE: 0.2873166954983434.
# Calculated CV RMSE for Horb Neckar with RMSE: 4.8504256976430895.
# Calculated CV MAE for Horb Neckar with MAE: 2.7221722507037214.
# Calculated CV NSE for Horb Neckar with NSE: -0.05829769005700913.
# Calculated CV RMSE for Horb Neckar with RMSE: 2.9986190451225276.
# Calculated CV MAE for Horb Neckar with MAE: 1.6249374183377734.
# Calculated CV NSE for Horb Neckar with NSE: -0.012161881784809037.
# Calculated CV RMSE for Horb Neckar with RMSE: 1.437993303176678.
# Calculated CV MAE for Horb Neckar with MAE: 1.1825247918566708.
# Calculated CV NSE for Horb Neckar with NSE: -0.46160551627570245.
# Calculated CV RMSE for Horb Neckar with RMSE: 1.4288611478635385.
# Calculated CV MAE for Horb Neckar with MAE: 1.0396402749295863.
# Calculated CV NSE for Horb Neckar with NSE: -0.19799771655412401.
# Calculated CV RMSE for Horb Neckar with RMSE: 8.660110640914006.
# Calculated CV MAE for Horb Neckar with MAE: 5.2967391282537974.
# Calculated CV NSE for Horb Neckar with NSE: 0.3053571059262812.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 1.555117237024809.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.9070480086781779.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.6890699760073185.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 3.07763869094786.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 1.6010233270655534.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.36363433566296843.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.5940254696877737.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.48590723227453936.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.970808283757969.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.4973018218538315.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.35883455430986017.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.240309554098031.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.35293164783965214.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.23644937483640258.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.7257269891369523.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.3444327772211278.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.24140952495730245.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.8011497086024035.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 1.1753238682424392.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.732844757234167.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.6578260287199618.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.14683501209948.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.829769706817792.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9464690928581219.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 19.537667889713973.
# Calculated CV MAE for Konstanz Rhein with MAE: 13.462484802684331.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8996784970661984.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.325455339548903.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.536569510692719.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9694814151432759.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.467908282873303.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.822886956465513.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9879997884241286.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.9380592869116584.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.3402406714058523.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.97652913760477.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 2.120965276784276.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.756080953379185.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8968866044609848.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.428445951801582.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.5028283074510163.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8096577523424505.
# Calculated CV RMSE for Binnrot Rot with RMSE: 3.570500148129144.
# Calculated CV MAE for Binnrot Rot with MAE: 1.0606805077549226.
# Calculated CV NSE for Binnrot Rot with NSE: 0.16247365453927798.
# Calculated CV RMSE for Binnrot Rot with RMSE: 2.876925737550672.
# Calculated CV MAE for Binnrot Rot with MAE: 0.9912578348290626.
# Calculated CV NSE for Binnrot Rot with NSE: 0.23309241214538046.
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.0570325268405678.
# Calculated CV MAE for Binnrot Rot with MAE: 0.4995804568908934.
# Calculated CV NSE for Binnrot Rot with NSE: 0.3918109950397828.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.2230495220463244.
# Calculated CV MAE for Binnrot Rot with MAE: 0.13262084993071305.
# Calculated CV NSE for Binnrot Rot with NSE: -0.8179878547350612.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.18726014274627065.
# Calculated CV MAE for Binnrot Rot with MAE: 0.12661468209050153.
# Calculated CV NSE for Binnrot Rot with NSE: -1.4507412674714253.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.17866570927905254.
# Calculated CV MAE for Binnrot Rot with MAE: 0.12017119450631783.
# Calculated CV NSE for Binnrot Rot with NSE: -0.23875827858937493.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.9915793166907587.
# Calculated CV MAE for Binnrot Rot with MAE: 0.5581680318953529.
# Calculated CV NSE for Binnrot Rot with NSE: -0.33856955110488474.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 2.9386240135690844.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 1.9635695941147813.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.085800925549951.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 14.20551717940292.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 4.689383864504284.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.42846882750474224.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.4452743031267055.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.9320215546662044.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.0604224394549836.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.4324741652382438.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.3116492462874995.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.06255434550815342.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.6904845057080158.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.4320696474371344.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.29731723180920255.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.5402179424916101.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.3421913420105179.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.3567261902871791.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 5.93356583664051.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 3.233102275657905.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.6312961879527654.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.8299231596208183.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.484817107949327.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.4939215058760166.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 7.823745849368578.
# Calculated CV MAE for Rengers Untere Argen with MAE: 3.1717123905206845.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.11172066473524.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 7.772556598215493.
# Calculated CV MAE for Rengers Untere Argen with MAE: 3.149290747149604.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.29396939402810374.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.8874740813994628.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.0248700399083928.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.22611944554864427.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.5926003658364569.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.3920799936431388.
# Calculated CV NSE for Rengers Untere Argen with NSE: -2.8332676275838753.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.2573127831812074.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.808715886889859.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.16495341887415038.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 6.259773755947813.
# Calculated CV MAE for Rengers Untere Argen with MAE: 3.2325595558339058.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.4665095527327967.
# Calculated CV RMSE for Zell Wiese with RMSE: 1.769221254501807.
# Calculated CV MAE for Zell Wiese with MAE: 1.202893726185472.
# Calculated CV NSE for Zell Wiese with NSE: 0.43987666216538657.
# Calculated CV RMSE for Zell Wiese with RMSE: 5.792716474397137.
# Calculated CV MAE for Zell Wiese with MAE: 2.731915999755164.
# Calculated CV NSE for Zell Wiese with NSE: 0.6608639269367973.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.7669703863298165.
# Calculated CV MAE for Zell Wiese with MAE: 0.5517222650421592.
# Calculated CV NSE for Zell Wiese with NSE: 0.599553762253359.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.5607562333105102.
# Calculated CV MAE for Zell Wiese with MAE: 0.3835967303911622.
# Calculated CV NSE for Zell Wiese with NSE: -0.6387253445484058.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.6436722670947299.
# Calculated CV MAE for Zell Wiese with MAE: 0.3942407057425462.
# Calculated CV NSE for Zell Wiese with NSE: -0.48145474203838234.
# Calculated CV RMSE for Zell Wiese with RMSE: 1.1258591603132344.
# Calculated CV MAE for Zell Wiese with MAE: 0.7946770096907698.
# Calculated CV NSE for Zell Wiese with NSE: -0.0031605057458705677.
# Calculated CV RMSE for Zell Wiese with RMSE: 7.199488254795026.
# Calculated CV MAE for Zell Wiese with MAE: 4.1681244898811185.
# Calculated CV NSE for Zell Wiese with NSE: 0.6895989061237946.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 3.5648251906299455.
# Calculated CV MAE for Ewattingen Wutach with MAE: 2.0961797262032458.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.12340104358347281.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 4.125912988694493.
# Calculated CV MAE for Ewattingen Wutach with MAE: 1.8436776685981435.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.21646283825011392.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.6953653514296015.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.44886840102970305.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.5976622097465099.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.28791532687770827.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.16728221624594977.
# Calculated CV NSE for Ewattingen Wutach with NSE: -0.1144532357296153.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.2567287014276272.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.14103414364317102.
# Calculated CV NSE for Ewattingen Wutach with NSE: -0.11113513291879595.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.3651939781000452.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.1984777286842786.
# Calculated CV NSE for Ewattingen Wutach with NSE: -0.36000883051410915.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 3.395663563233328.
# Calculated CV MAE for Ewattingen Wutach with MAE: 1.9174830388559434.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.6623791479299277.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 4.423513135745592.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 3.023463195390838.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.22791566538794827.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 9.25559768897239.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 3.8823544993865027.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.28798639674109094.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 1.1487124818287335.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.6944487146665915.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.7167762409639734.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.521095213212844.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.3361537400999871.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -0.25939540352916923.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.36445158598086824.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.22613284068664244.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -0.1724001002074651.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.46912386660022076.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.28614960416260254.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -0.22458795750960392.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 3.7697296947645915.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 2.180074901244922.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.6989165478471984.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.373640043750099.
# Calculated CV MAE for Hausen Zaber with MAE: 0.16452329310879152.
# Calculated CV NSE for Hausen Zaber with NSE: 0.005914159316914525.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.49920108733394847.
# Calculated CV MAE for Hausen Zaber with MAE: 0.21214960934361507.
# Calculated CV NSE for Hausen Zaber with NSE: 0.016387253790985268.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.30346497195428984.
# Calculated CV MAE for Hausen Zaber with MAE: 0.13472022975914186.
# Calculated CV NSE for Hausen Zaber with NSE: -0.09063742843818745.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.10697692966405022.
# Calculated CV MAE for Hausen Zaber with MAE: 0.09528213331537369.
# Calculated CV NSE for Hausen Zaber with NSE: -0.988643288295407.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.2593707702047168.
# Calculated CV MAE for Hausen Zaber with MAE: 0.09630903516093478.
# Calculated CV NSE for Hausen Zaber with NSE: -0.017828980407323503.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.12547040677813276.
# Calculated CV MAE for Hausen Zaber with MAE: 0.08338841141121978.
# Calculated CV NSE for Hausen Zaber with NSE: -0.21293269941888404.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.22094764525910127.
# Calculated CV MAE for Hausen Zaber with MAE: 0.1510820982330464.
# Calculated CV NSE for Hausen Zaber with NSE: -0.11460312702849507.
# (     Stationsname  Fold  rmse validation  mae validation  nse validation  \
#  0    Gießen Argen     1         7.804498        4.164131        0.659219
#  1    Gießen Argen     2        22.491440       11.780506        0.307645
#  2    Gießen Argen     3        24.133088       10.255857        0.344477
#  3    Gießen Argen     4         4.653704        2.975189        0.223875
#  4    Gießen Argen     5         1.881534        1.297248       -2.171073
#  ..            ...   ...              ...             ...             ...
#  170  Hausen Zaber     3         0.303465        0.134720       -0.090637
#  171  Hausen Zaber     4         0.106977        0.095282       -0.988643
#  172  Hausen Zaber     5         0.259371        0.096309       -0.017829
#  173  Hausen Zaber     6         0.125470        0.083388       -0.212933
#  174  Hausen Zaber     7         0.220948        0.151082       -0.114603
#
#       nse train   nse gap
#  0     0.641390 -0.017829
#  1     0.641193  0.333547
#  2     0.638508  0.294031
#  3     0.635717  0.411842
#  4     0.637027  2.808100
#  ..         ...       ...
#  170   0.584540  0.675178
#  171   0.584823  1.573466
#  172   0.586186  0.604015
#  173   0.587779  0.800712
#  174   0.588044  0.702647
#
#  [175 rows x 7 columns],
#                       Stationsname  mean_rmse_validation  mean_mae_validation  \
#  0              Bad Rotenfels Murg              6.420160             3.484477
#  1                Baiersbronn Murg              2.074564             1.079606
#  2                    Beuron Donau              3.323183             1.902165
#  3                     Binnrot Rot              1.297859             0.498442
#  4                 Blaubeuren Blau              0.709037             0.283679
#  5                   Bolheim Brenz              0.565263             0.317930
#  6               Elpershofen Jagst              5.779421             2.714355
#  7                    Eutingen Enz              4.709179             2.353128
#  8               Ewattingen Wutach              1.813086             0.973286
#  9                    Gießen Argen             11.788891             6.083321
#  10                 Hausach Kinzig              4.536918             2.652643
#  11                   Hausen Zaber              0.269867             0.133922
#  12                    Horb Neckar              5.888849             3.247969
#  13             Hundersingen Donau              4.985701             3.005962
#  14              Hüttlingen Kocher              0.896552             0.368582
#  15                 Konstanz Rhein              8.566477             6.750123
#  16           Mägerkingen Lauchert              0.201928             0.105359
#  17         Oberlauchringen Wutach              2.850318             1.518397
#  18           Rengers Untere Argen              4.060484             1.894864
#  19           Riegel Leopoldskanal              6.412591             3.523379
#  20  Rielasingen Radolfzeller Aach              1.085253             0.651931
#  21      Tauberbischofsheim Tauber              3.740880             1.700570
#  22                 Wannweil Echaz              1.683306             0.655385
#  23              Wiesloch Leimbach              0.247438             0.122269
#  24                     Zell Wiese              2.551241             1.461024
#
#      mean_nse_validation  mean_nse_train
#  0             -0.158056        0.703448
#  1             -1.116158        0.531453
#  2              0.533176        0.936833
#  3             -0.294097        0.623469
#  4              0.591883        0.956881
#  5              0.191032        0.917592
#  6              0.129851        0.786379
#  7              0.074634        0.843742
#  8              0.144901        0.839548
#  9              0.034626        0.638498
#  10             0.037466        0.800938
#  11            -0.200335        0.586632
#  12             0.031377        0.770362
#  13             0.623149        0.950266
#  14            -0.013276        0.709393
#  15             0.926672        0.998828
#  16             0.691377        0.872725
#  17             0.182173        0.840185
#  18            -0.200854        0.578311
#  19             0.279931        0.824806
#  20             0.635504        0.958210
#  21             0.256782        0.815456
#  22             0.113044        0.624913
#  23            -0.172778        0.487989
#  24             0.180936        0.842608  ,
#  np.float64(0.14011839485282032),
#  np.float64(0.7775785885691665),
#  np.float64(0.6374601937163462))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error


# Cross Validation without exogene features
def cross_validation():
    train_test = train_and_test_nan()
    
    pred = []
    scores = []

    # Cross Validation for every of the 25 stations in Baden-Württemberg with the best hyper parameter from the hyper parameter tuning.
    for t in train_test:
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()

        # define all exogene precipitation data
        exogene_features = train_water.filter(regex=r"^Niederschlag").columns

        # defining forecast horizon to forecast 24 hours in the future (Q(t)--> Q(t+24)).
        train_water["y"] = train_water["Abfluss in m^3/s"].shift(-24)

        # the last 24 rows of y are NaN due to the shift by 24 hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train_water = train_water.dropna(subset=["y"])

        # define x and y for cross validation before the split because this is more efficient. Drop "y" for x, because "y" is the part to forecast.
        # We keep "Abfluss in m^3/s" as current value and the last known runoff which is important for the prediction.
        x = train_water.drop(columns=["y", *exogene_features])
        y = train_water["y"]
        
        station = t["Stationsname"]

        # define Time Series Spliit for the Cross validation. I evaluate the model on 720 hour validation windows using 24 hour ahead forecasts. 
        # To avoid leakage between train and validation I use a gap of 24 hours.
        tss = TimeSeriesSplit(n_splits=7, test_size=720, gap=24)
        fold = 0

        # split the train set into seven folds for the cross validation and use RandomForestRegressor with the respective hyperparameter combination.
        for train_idx, validation_idx in tss.split(x):
            fold += 1
            x_train = x.iloc[train_idx]
            x_validation = x.iloc[validation_idx]
            y_train = y.iloc[train_idx]
            y_validation = y.iloc[validation_idx]

            # Define Random Forest model with the best hyperparameter combination identified in the hyperparameter tuning
            model = RandomForestRegressor(
                n_estimators=500, 
                max_features="sqrt",
                max_depth=10, 
                min_samples_split=5,
                min_samples_leaf=12,
                max_samples=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # Predict the respective validation set per fold
            y_pred_validation = model.predict(x_validation)
            pred.append({
                "Stationsname": station,
                "Fold": fold, 
                "Vorhersage": y_pred_validation
            })

            # Predict the respective validation set per fold to ceck for overfitting: If the training metrics are much better than the validation metrics, the model might be overfitting.
            y_pred_train = model.predict(x_train)

            # Calculate the evaluation metrics "RMSE", "MAE" and "NSE" for the prediction of the validation set per fold.
            rmse_validation = np.sqrt(mean_squared_error(y_validation, y_pred_validation))
            mae_validation = mean_absolute_error(y_validation, y_pred_validation)
            nse_validation = 1 - np.sum((y_validation - y_pred_validation)**2) / np.sum((y_validation - np.mean(y_validation))**2)

            # Calculate "NSE" and "NSE gap" per fold to identify potential model overfitting.
            nse_train = 1 - np.sum((y_train - y_pred_train)**2) / np.sum((y_train - np.mean(y_train))**2)
            nse_gap = nse_train - nse_validation

            # store evaluation metrics for this station and fold in score
            scores.append({
                "Stationsname": station,
                "Fold": fold,
                "rmse validation": rmse_validation,
                "mae validation": mae_validation,
                "nse validation": nse_validation,
                "nse train": nse_train,
                "nse gap": nse_gap
            })
            print(f"Calculated CV RMSE for {t['Stationsname']} with RMSE: {rmse_validation}.")
            print(f"Calculated CV MAE for {t['Stationsname']} with MAE: {mae_validation}.")
            print(f"Calculated CV NSE for {t['Stationsname']} with NSE: {nse_validation}.")
            

    # calculate the mean evaluation metrics over the folds with the same station. This enables to compare the scores with the other cv, to identify the importance of the exogene features.
    scores_df = pd.DataFrame(scores)
    mean_per_station = scores_df.groupby("Stationsname")[["rmse validation", "mae validation", "nse validation", "nse train"]].mean()
    mean_per_station = mean_per_station.reset_index()
    mean_per_station = mean_per_station.rename(columns={"rmse validation": "mean_rmse_validation", "mae validation": "mean_mae_validation", "nse validation": "mean_nse_validation", "nse train": "mean_nse_train"})

    overall_mean_nse = mean_per_station["mean_nse_validation"].mean()
    overall_mean_nse_train = mean_per_station["mean_nse_train"].mean()
    overall_nse_gap = overall_mean_nse_train - overall_mean_nse
    
    return scores_df, mean_per_station, overall_mean_nse, overall_mean_nse_train, overall_nse_gap

cross_validation()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Calculated CV RMSE for Gießen Argen with RMSE: 9.434152019178569.
# Calculated CV MAE for Gießen Argen with MAE: 4.898219269047336.
# Calculated CV NSE for Gießen Argen with NSE: 0.5020436535663861.
# Calculated CV RMSE for Gießen Argen with RMSE: 26.399656198430666.
# Calculated CV MAE for Gießen Argen with MAE: 13.149935234015983.
# Calculated CV NSE for Gießen Argen with NSE: 0.046127009291972665.
# Calculated CV RMSE for Gießen Argen with RMSE: 25.47065171963629.
# Calculated CV MAE for Gießen Argen with MAE: 11.480741334157786.
# Calculated CV NSE for Gießen Argen with NSE: 0.26979913909861064.
# Calculated CV RMSE for Gießen Argen with RMSE: 5.5993762165964975.
# Calculated CV MAE for Gießen Argen with MAE: 4.296110430213203.
# Calculated CV NSE for Gießen Argen with NSE: -0.12360370085712025.
# Calculated CV RMSE for Gießen Argen with RMSE: 1.7819559295719583.
# Calculated CV MAE for Gießen Argen with MAE: 1.405007701468476.
# Calculated CV NSE for Gießen Argen with NSE: -1.8443050750772696.
# Calculated CV RMSE for Gießen Argen with RMSE: 5.6767889550890045.
# Calculated CV MAE for Gießen Argen with MAE: 3.472104273155201.
# Calculated CV NSE for Gießen Argen with NSE: 0.005223753343785997.
# Calculated CV RMSE for Gießen Argen with RMSE: 17.141413344379636.
# Calculated CV MAE for Gießen Argen with MAE: 9.496456694514888.
# Calculated CV NSE for Gießen Argen with NSE: 0.4508776727762993.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.3919623300019607.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.2310854747569114.
# Calculated CV NSE for Blaubeuren Blau with NSE: -0.16045168684777478.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 3.7724147482887753.
# Calculated CV MAE for Blaubeuren Blau with MAE: 1.145330938800504.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.4422803462789465.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.8410504916746228.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.6530237373109968.
# Calculated CV NSE for Blaubeuren Blau with NSE: -4.211192448756231.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.15502673556181118.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.11938178933744688.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.8099522987409467.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.11764374054273452.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.09116692050501314.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.48942912962786245.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.08065963521947234.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.05708579230598341.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.4197061049299381.
# Calculated CV RMSE for Blaubeuren Blau with RMSE: 0.3706531903996879.
# Calculated CV MAE for Blaubeuren Blau with MAE: 0.27384645441262834.
# Calculated CV NSE for Blaubeuren Blau with NSE: 0.8421244091581837.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.676615715500781.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.38829655527131246.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.03717109286086817.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 1.3334430799852433.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.631604848264773.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.2381030106364742.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.5679419378171496.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.33755356790739643.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.0604446304242201.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.2168337981526934.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.1773695648178832.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.05454691444168336.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.3552551659398147.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.23398229464677872.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.013948816262944974.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.3194479040233932.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.18343104861692114.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.08326781956569784.
# Calculated CV RMSE for Bolheim Brenz with RMSE: 0.5356112209692235.
# Calculated CV MAE for Bolheim Brenz with MAE: 0.3350498086206422.
# Calculated CV NSE for Bolheim Brenz with NSE: 0.6311943716104615.
# Calculated CV RMSE for Beuron Donau with RMSE: 9.210064006575752.
# Calculated CV MAE for Beuron Donau with MAE: 5.235887026918499.
# Calculated CV NSE for Beuron Donau with NSE: 0.5103409112432795.
# Calculated CV RMSE for Beuron Donau with RMSE: 7.460450622305383.
# Calculated CV MAE for Beuron Donau with MAE: 4.441553465493873.
# Calculated CV NSE for Beuron Donau with NSE: 0.5793807559591004.
# Calculated CV RMSE for Beuron Donau with RMSE: 1.8364964467382214.
# Calculated CV MAE for Beuron Donau with MAE: 1.175569565504978.
# Calculated CV NSE for Beuron Donau with NSE: 0.5223325184154481.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.6168672300573006.
# Calculated CV MAE for Beuron Donau with MAE: 0.49962508352950474.
# Calculated CV NSE for Beuron Donau with NSE: 0.04382050615111133.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.22393300177991.
# Calculated CV MAE for Beuron Donau with MAE: 0.18121228878354895.
# Calculated CV NSE for Beuron Donau with NSE: 0.508979310616713.
# Calculated CV RMSE for Beuron Donau with RMSE: 0.168134370438812.
# Calculated CV MAE for Beuron Donau with MAE: 0.1335783366093115.
# Calculated CV NSE for Beuron Donau with NSE: 0.4876111536623098.
# Calculated CV RMSE for Beuron Donau with RMSE: 5.024863145676615.
# Calculated CV MAE for Beuron Donau with MAE: 2.843873329785723.
# Calculated CV NSE for Beuron Donau with NSE: 0.7174984545369445.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 12.923927321552831.
# Calculated CV MAE for Hundersingen Donau with MAE: 7.001541796515993.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.6475401328329466.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 12.55523263873386.
# Calculated CV MAE for Hundersingen Donau with MAE: 7.778555292303852.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.687592086682656.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 2.1500643408575573.
# Calculated CV MAE for Hundersingen Donau with MAE: 1.5093088905030836.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.8454156164026867.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.9300563055050124.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.7297216709191482.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.7059960984967737.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.9584015997243317.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.7148090314760026.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.22372681453559895.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 0.6679654691817203.
# Calculated CV MAE for Hundersingen Donau with MAE: 0.532359239954233.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.4075673543332907.
# Calculated CV RMSE for Hundersingen Donau with RMSE: 5.626763880812974.
# Calculated CV MAE for Hundersingen Donau with MAE: 3.374073856021615.
# Calculated CV NSE for Hundersingen Donau with NSE: 0.7298950531845947.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 7.288549204601298.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.7916937513804505.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.0007813601872110887.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 2.056081267337848.
# Calculated CV MAE for Wannweil Echaz with MAE: 1.0841728069169094.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.2709764883546578.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 1.1139526554440662.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.8673140391014971.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.12735783871582895.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.40401421777864477.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.35940362519243113.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.1980273490994311.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.3847342035961096.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.26362064290715126.
# Calculated CV NSE for Wannweil Echaz with NSE: -0.21443889911249725.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.18403879599704334.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.1507706799286659.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.01741038780459725.
# Calculated CV RMSE for Wannweil Echaz with RMSE: 0.6221788745286821.
# Calculated CV MAE for Wannweil Echaz with MAE: 0.42276469540352735.
# Calculated CV NSE for Wannweil Echaz with NSE: 0.34467564879866874.
# Calculated CV RMSE for Eutingen Enz with RMSE: 9.632553226181793.
# Calculated CV MAE for Eutingen Enz with MAE: 4.387048500318557.
# Calculated CV NSE for Eutingen Enz with NSE: 0.07115424693225025.
# Calculated CV RMSE for Eutingen Enz with RMSE: 11.723267281365272.
# Calculated CV MAE for Eutingen Enz with MAE: 4.864396726859049.
# Calculated CV NSE for Eutingen Enz with NSE: 0.01567879416043183.
# Calculated CV RMSE for Eutingen Enz with RMSE: 3.261169676894193.
# Calculated CV MAE for Eutingen Enz with MAE: 2.7382712544376284.
# Calculated CV NSE for Eutingen Enz with NSE: -0.15937386991622993.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.6770381366305058.
# Calculated CV MAE for Eutingen Enz with MAE: 1.2102398547274313.
# Calculated CV NSE for Eutingen Enz with NSE: -0.09273198834112795.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.6610587742234975.
# Calculated CV MAE for Eutingen Enz with MAE: 1.039447403575709.
# Calculated CV NSE for Eutingen Enz with NSE: 0.03700571138796782.
# Calculated CV RMSE for Eutingen Enz with RMSE: 1.1182155026206224.
# Calculated CV MAE for Eutingen Enz with MAE: 0.8725122814079476.
# Calculated CV NSE for Eutingen Enz with NSE: -0.3462322594793259.
# Calculated CV RMSE for Eutingen Enz with RMSE: 5.037019659736017.
# Calculated CV MAE for Eutingen Enz with MAE: 3.199110872857035.
# Calculated CV NSE for Eutingen Enz with NSE: 0.5328776945182787.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 7.343201681103299.
# Calculated CV MAE for Elpershofen Jagst with MAE: 4.649723404739514.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.023375187733088443.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 18.076630126171352.
# Calculated CV MAE for Elpershofen Jagst with MAE: 5.718187578900372.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.34662069031361675.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.8310845838397496.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.4340377494397138.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.2682651751770181.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 0.8515776017149701.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.7046325065550902.
# Calculated CV NSE for Elpershofen Jagst with NSE: -1.1598690799697793.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.5276867553817632.
# Calculated CV MAE for Elpershofen Jagst with MAE: 0.8817127424831922.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.21943070186278035.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 1.7298809582512724.
# Calculated CV MAE for Elpershofen Jagst with MAE: 1.0242002487978108.
# Calculated CV NSE for Elpershofen Jagst with NSE: -0.21710926368081318.
# Calculated CV RMSE for Elpershofen Jagst with RMSE: 12.585922974485081.
# Calculated CV MAE for Elpershofen Jagst with MAE: 7.440361581715903.
# Calculated CV NSE for Elpershofen Jagst with NSE: 0.3693177684592862.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 4.944259769577678.
# Calculated CV MAE for Hausach Kinzig with MAE: 3.3249247187748847.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.3843973889966459.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 8.923458710195076.
# Calculated CV MAE for Hausach Kinzig with MAE: 3.9385954388260815.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.25218943200588506.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 1.5349732820431772.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.2329680316221852.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.06569296822746085.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 0.9529155529006794.
# Calculated CV MAE for Hausach Kinzig with MAE: 0.7866869916995977.
# Calculated CV NSE for Hausach Kinzig with NSE: -1.1728859411210228.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 1.5431275449930655.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.1947718245951475.
# Calculated CV NSE for Hausach Kinzig with NSE: -0.8150924154825405.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 2.2928996693709744.
# Calculated CV MAE for Hausach Kinzig with MAE: 1.614991224678087.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.036746611701766185.
# Calculated CV RMSE for Hausach Kinzig with RMSE: 12.988765340135643.
# Calculated CV MAE for Hausach Kinzig with MAE: 8.448070884152337.
# Calculated CV NSE for Hausach Kinzig with NSE: 0.40310189632317683.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 1.3368658306453025.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.45483179422857206.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.016842244881856594.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 3.0396775839059655.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.8563748638449669.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.0975342878493336.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.4763199854660168.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.3663818807907318.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.0830054996218541.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.17384875670527705.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.1591482732242145.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.4412691785388534.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.23202702721364518.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.1278389007067592.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.1963307050663219.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.20251107642059507.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.12177524909207182.
# Calculated CV NSE for Hüttlingen Kocher with NSE: -0.29542454413067554.
# Calculated CV RMSE for Hüttlingen Kocher with RMSE: 0.9599812089518501.
# Calculated CV MAE for Hüttlingen Kocher with MAE: 0.6574364711921983.
# Calculated CV NSE for Hüttlingen Kocher with NSE: 0.2770854632064851.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.264142673293144.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.11546860349148194.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.696239287706074.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.657989227773172.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.2969914217692083.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5926551679005578.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.2637144918497296.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.13948952015816513.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.3982305164469323.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.08789998183302769.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.06304484168922211.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.7658511644776534.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.0447187933634534.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.031068827157367307.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.5750756228416778.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.017905750284904588.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.014183624794253046.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.743238817400884.
# Calculated CV RMSE for Mägerkingen Lauchert with RMSE: 0.11974711253251379.
# Calculated CV MAE for Mägerkingen Lauchert with MAE: 0.08946529967797984.
# Calculated CV NSE for Mägerkingen Lauchert with NSE: 0.8818735175881002.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.5844096016685417.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.2698234085528978.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.0573885557843854.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.45474318851781803.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.1840380617479776.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.0007513768490257089.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.09771792448131003.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.08054211384754689.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.8989994091781661.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.11571024553562938.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.07442953493236658.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.4575442233672682.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.1662833805294763.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.07396307825089213.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.013751111937143179.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.09241584497971034.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.05023897459143372.
# Calculated CV NSE for Wiesloch Leimbach with NSE: -0.02952234626972028.
# Calculated CV RMSE for Wiesloch Leimbach with RMSE: 0.23298323716658784.
# Calculated CV MAE for Wiesloch Leimbach with MAE: 0.12969332172535716.
# Calculated CV NSE for Wiesloch Leimbach with NSE: 0.17849694864600552.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 8.70782295865878.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 5.720246008470386.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.39737922893798827.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 16.622762071172296.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 7.458278289975367.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.5931702671929352.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 2.511152447831883.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.830576208013954.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.31669772801613716.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 1.3087521102642654.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 0.9952377206981832.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.30262441401357687.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 2.427288770773562.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.0035004657781623.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: -0.10525731667935423.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 2.905076516010525.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 1.8618336934598994.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: -0.2925823751822427.
# Calculated CV RMSE for Riegel Leopoldskanal with RMSE: 13.842761962124865.
# Calculated CV MAE for Riegel Leopoldskanal with MAE: 7.868766915014532.
# Calculated CV NSE for Riegel Leopoldskanal with NSE: 0.34485324183770527.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 9.26840217002516.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 5.60772253700409.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.21891509392100927.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 7.3396825990433205.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 3.633013412948944.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.3580500398015596.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 3.5499001259785716.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 2.504968482733743.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -0.152689442996796.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 1.9960192019753817.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.520070626589218.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -0.27244979592473406.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 2.012673862133827.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.4410942047143862.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -0.7945770043309572.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 2.4764149752454974.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 1.9157605216332725.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: -0.20363187847019426.
# Calculated CV RMSE for Bad Rotenfels Murg with RMSE: 19.66460299207532.
# Calculated CV MAE for Bad Rotenfels Murg with MAE: 9.977367613965828.
# Calculated CV NSE for Bad Rotenfels Murg with NSE: 0.4695494407382458.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 2.657768969473195.
# Calculated CV MAE for Baiersbronn Murg with MAE: 1.3331328751700284.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.20809983339742522.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 2.021329099622901.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.9887566158744783.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.21137654182898502.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.6122082582322316.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.417450992784245.
# Calculated CV NSE for Baiersbronn Murg with NSE: -2.112589835500917.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.2081004825513429.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.17865268827990846.
# Calculated CV NSE for Baiersbronn Murg with NSE: -5.6268689655480575.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 0.7177432329182346.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.549298021416512.
# Calculated CV NSE for Baiersbronn Murg with NSE: -3.580291986400142.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 1.221875663147889.
# Calculated CV MAE for Baiersbronn Murg with MAE: 0.8205114765186272.
# Calculated CV NSE for Baiersbronn Murg with NSE: -0.46912544190250105.
# Calculated CV RMSE for Baiersbronn Murg with RMSE: 7.6628607888773.
# Calculated CV MAE for Baiersbronn Murg with MAE: 3.725235120861041.
# Calculated CV NSE for Baiersbronn Murg with NSE: 0.251775602138815.
# Calculated CV RMSE for Horb Neckar with RMSE: 10.822552170607224.
# Calculated CV MAE for Horb Neckar with MAE: 5.6491618025369705.
# Calculated CV NSE for Horb Neckar with NSE: 0.34782203672112466.
# Calculated CV RMSE for Horb Neckar with RMSE: 12.637246611777444.
# Calculated CV MAE for Horb Neckar with MAE: 6.60270040725574.
# Calculated CV NSE for Horb Neckar with NSE: 0.07625127100778839.
# Calculated CV RMSE for Horb Neckar with RMSE: 4.949258006441148.
# Calculated CV MAE for Horb Neckar with MAE: 3.1153267511575513.
# Calculated CV NSE for Horb Neckar with NSE: -0.10186483850097616.
# Calculated CV RMSE for Horb Neckar with RMSE: 3.3054425788491315.
# Calculated CV MAE for Horb Neckar with MAE: 1.978969092982818.
# Calculated CV NSE for Horb Neckar with NSE: -0.22989099561470616.
# Calculated CV RMSE for Horb Neckar with RMSE: 1.288954072366021.
# Calculated CV MAE for Horb Neckar with MAE: 1.0482433878995965.
# Calculated CV NSE for Horb Neckar with NSE: -0.17433318159975109.
# Calculated CV RMSE for Horb Neckar with RMSE: 1.2269699371271783.
# Calculated CV MAE for Horb Neckar with MAE: 0.7861316437468326.
# Calculated CV NSE for Horb Neckar with NSE: 0.11662769564024833.
# Calculated CV RMSE for Horb Neckar with RMSE: 8.995543412733081.
# Calculated CV MAE for Horb Neckar with MAE: 6.681665587715045.
# Calculated CV NSE for Horb Neckar with NSE: 0.25050364705794625.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 1.541484072153753.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.869343606419498.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.6944977076848836.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 3.107284559357861.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 1.5882456647744418.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.3513154914248555.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.7243228080191219.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.5773570275799954.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.9565975927496522.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.6025263860489048.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.4437117674300623.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: -0.11518958544650504.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.39947838427238064.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.29478455869086.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.6486107786238502.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 0.41506671752885366.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.3098341329160779.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.711229313165693.
# Calculated CV RMSE for Rielasingen Radolfzeller Aach with RMSE: 1.1724747813939933.
# Calculated CV MAE for Rielasingen Radolfzeller Aach with MAE: 0.745477265372779.
# Calculated CV NSE for Rielasingen Radolfzeller Aach with NSE: 0.6594829367210906.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 10.021011884967116.
# Calculated CV MAE for Konstanz Rhein with MAE: 8.84212376660092.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9477884531704197.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 17.988379384508193.
# Calculated CV MAE for Konstanz Rhein with MAE: 11.463961055607133.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9149581575343997.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 9.870016479359435.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.465285353012666.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9721142890121001.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 8.84837063846326.
# Calculated CV MAE for Konstanz Rhein with MAE: 7.546985797118091.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.989518886337869.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 3.955828910564969.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.1243717948186553.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9763168455463342.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 1.9448412503366515.
# Calculated CV MAE for Konstanz Rhein with MAE: 1.6374790420126715.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.9133005612428694.
# Calculated CV RMSE for Konstanz Rhein with RMSE: 4.258992384609145.
# Calculated CV MAE for Konstanz Rhein with MAE: 3.4307290258210363.
# Calculated CV NSE for Konstanz Rhein with NSE: 0.8239458676656228.
# Calculated CV RMSE for Binnrot Rot with RMSE: 3.69633378762631.
# Calculated CV MAE for Binnrot Rot with MAE: 1.27131240080816.
# Calculated CV NSE for Binnrot Rot with NSE: 0.10240023415877197.
# Calculated CV RMSE for Binnrot Rot with RMSE: 3.041472622654476.
# Calculated CV MAE for Binnrot Rot with MAE: 1.0194966387081612.
# Calculated CV NSE for Binnrot Rot with NSE: 0.1428564630108362.
# Calculated CV RMSE for Binnrot Rot with RMSE: 1.2146053079030315.
# Calculated CV MAE for Binnrot Rot with MAE: 0.6635556352544938.
# Calculated CV NSE for Binnrot Rot with NSE: 0.1969691852228176.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.2367675989711464.
# Calculated CV MAE for Binnrot Rot with MAE: 0.18621370676057733.
# Calculated CV NSE for Binnrot Rot with NSE: -1.0484856392402468.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.18043650779906228.
# Calculated CV MAE for Binnrot Rot with MAE: 0.14377333353343044.
# Calculated CV NSE for Binnrot Rot with NSE: -1.2753886624286306.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.1916394724238582.
# Calculated CV MAE for Binnrot Rot with MAE: 0.15049891234760546.
# Calculated CV NSE for Binnrot Rot with NSE: -0.42519433522832695.
# Calculated CV RMSE for Binnrot Rot with RMSE: 0.920722067086079.
# Calculated CV MAE for Binnrot Rot with MAE: 0.6133997481518871.
# Calculated CV NSE for Binnrot Rot with NSE: -0.15409916648794364.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 3.3014337184760727.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 2.3046198910933975.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.1538726937610142.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 15.43613085720544.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 5.370925037815535.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.3251570325005889.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 1.1604125894239061.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.884136031184788.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.39430088673323194.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.47332082407375353.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.3887921860584672.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.2727468696522364.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.7413162861104056.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.4670361422166924.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.1900494381463601.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 0.7064413080300311.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 0.4373693563728381.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: -0.10004393986134441.
# Calculated CV RMSE for Tauberbischofsheim Tauber with RMSE: 6.684911006093422.
# Calculated CV MAE for Tauberbischofsheim Tauber with MAE: 3.9291174459460447.
# Calculated CV NSE for Tauberbischofsheim Tauber with NSE: 0.5320091554984729.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 3.1877461572216594.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.7377059335325908.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.35785063514882376.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 8.604216650425766.
# Calculated CV MAE for Rengers Untere Argen with MAE: 3.511454364441007.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.07434252129971597.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 8.15674299133817.
# Calculated CV MAE for Rengers Untere Argen with MAE: 3.41668593627464.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.22244825850302075.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 2.2426690109266367.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.7283903826849414.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.09255247428150115.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 0.7400366270417794.
# Calculated CV MAE for Rengers Untere Argen with MAE: 0.5903210670363106.
# Calculated CV NSE for Rengers Untere Argen with NSE: -4.9779426058111405.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 1.3972259827243145.
# Calculated CV MAE for Rengers Untere Argen with MAE: 1.03669143470935.
# Calculated CV NSE for Rengers Untere Argen with NSE: -0.4386501801323668.
# Calculated CV RMSE for Rengers Untere Argen with RMSE: 6.268063952548173.
# Calculated CV MAE for Rengers Untere Argen with MAE: 3.0487385400682854.
# Calculated CV NSE for Rengers Untere Argen with NSE: 0.4650955497620297.
# Calculated CV RMSE for Zell Wiese with RMSE: 1.9185422183877285.
# Calculated CV MAE for Zell Wiese with MAE: 1.3771322809749797.
# Calculated CV NSE for Zell Wiese with NSE: 0.34133878203637624.
# Calculated CV RMSE for Zell Wiese with RMSE: 6.065886149535475.
# Calculated CV MAE for Zell Wiese with MAE: 2.773861477219472.
# Calculated CV NSE for Zell Wiese with NSE: 0.6281241704580586.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.8700099738331648.
# Calculated CV MAE for Zell Wiese with MAE: 0.6251914796813315.
# Calculated CV NSE for Zell Wiese with NSE: 0.4847292506480555.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.5928717548587907.
# Calculated CV MAE for Zell Wiese with MAE: 0.44183047593477587.
# Calculated CV NSE for Zell Wiese with NSE: -0.8318059775800732.
# Calculated CV RMSE for Zell Wiese with RMSE: 0.6492421966385767.
# Calculated CV MAE for Zell Wiese with MAE: 0.45166688564764323.
# Calculated CV NSE for Zell Wiese with NSE: -0.5072048045979247.
# Calculated CV RMSE for Zell Wiese with RMSE: 1.3651369679573802.
# Calculated CV MAE for Zell Wiese with MAE: 0.9906805243647684.
# Calculated CV NSE for Zell Wiese with NSE: -0.47487342155778367.
# Calculated CV RMSE for Zell Wiese with RMSE: 7.336507586321096.
# Calculated CV MAE for Zell Wiese with MAE: 4.520432212336574.
# Calculated CV NSE for Zell Wiese with NSE: 0.6776714830995757.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 3.6044930013194474.
# Calculated CV MAE for Ewattingen Wutach with MAE: 2.16888805462006.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.10378368362861201.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 4.248075807585513.
# Calculated CV MAE for Ewattingen Wutach with MAE: 1.8946293778600856.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.16937693669967058.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.8019242141482879.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.5980783224944559.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.46490439128876215.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.3377108926207145.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.21370289801102335.
# Calculated CV NSE for Ewattingen Wutach with NSE: -0.5332833423072523.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.260313527633224.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.18594550184857475.
# Calculated CV NSE for Ewattingen Wutach with NSE: -0.14238240812986303.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 0.30606034952787803.
# Calculated CV MAE for Ewattingen Wutach with MAE: 0.26051574208756234.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.04476846169808857.
# Calculated CV RMSE for Ewattingen Wutach with RMSE: 3.6167895240127437.
# Calculated CV MAE for Ewattingen Wutach with MAE: 2.3424075789284795.
# Calculated CV NSE for Ewattingen Wutach with NSE: 0.6169756142751404.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 4.38698447349141.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 3.055515746712806.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.24061451277210155.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 10.173242850137633.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 4.336885226732177.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.13980249838102143.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 1.4517729620622424.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 1.006465484218723.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.5476189440497543.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.5987777357757817.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.4410231771527413.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -0.6628735438636861.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.37080304808015024.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.2394283948824429.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -0.21362006715561965.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 0.4677574323930569.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 0.3125248680550481.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: -0.2174645428837252.
# Calculated CV RMSE for Oberlauchringen Wutach with RMSE: 4.104618628943859.
# Calculated CV MAE for Oberlauchringen Wutach with MAE: 2.676675364380694.
# Calculated CV NSE for Oberlauchringen Wutach with NSE: 0.6430461344298501.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.3791341420756776.
# Calculated CV MAE for Hausen Zaber with MAE: 0.15879491117945185.
# Calculated CV NSE for Hausen Zaber with NSE: -0.023535359612200546.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.49753144322825643.
# Calculated CV MAE for Hausen Zaber with MAE: 0.21256241992295702.
# Calculated CV NSE for Hausen Zaber with NSE: 0.02295589656357422.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.3001011213026301.
# Calculated CV MAE for Hausen Zaber with MAE: 0.13183054961928836.
# Calculated CV NSE for Hausen Zaber with NSE: -0.06659242742517568.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.1316381671982394.
# Calculated CV MAE for Hausen Zaber with MAE: 0.12091073068030382.
# Calculated CV NSE for Hausen Zaber with NSE: -2.0112047343272628.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.25984926060309843.
# Calculated CV MAE for Hausen Zaber with MAE: 0.09853729654185839.
# Calculated CV NSE for Hausen Zaber with NSE: -0.02158785135083474.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.13492113717112575.
# Calculated CV MAE for Hausen Zaber with MAE: 0.08328119636933216.
# Calculated CV NSE for Hausen Zaber with NSE: -0.40253619637731197.
# Calculated CV RMSE for Hausen Zaber with RMSE: 0.257603510439885.
# Calculated CV MAE for Hausen Zaber with MAE: 0.19328713874567.
# Calculated CV NSE for Hausen Zaber with NSE: -0.5151131104890971.
# (     Stationsname  Fold  rmse validation  mae validation  nse validation  \
#  0    Gießen Argen     1         9.434152        4.898219        0.502044
#  1    Gießen Argen     2        26.399656       13.149935        0.046127
#  2    Gießen Argen     3        25.470652       11.480741        0.269799
#  3    Gießen Argen     4         5.599376        4.296110       -0.123604
#  4    Gießen Argen     5         1.781956        1.405008       -1.844305
#  ..            ...   ...              ...             ...             ...
#  170  Hausen Zaber     3         0.300101        0.131831       -0.066592
#  171  Hausen Zaber     4         0.131638        0.120911       -2.011205
#  172  Hausen Zaber     5         0.259849        0.098537       -0.021588
#  173  Hausen Zaber     6         0.134921        0.083281       -0.402536
#  174  Hausen Zaber     7         0.257604        0.193287       -0.515113
#
#       nse train   nse gap
#  0     0.666340  0.164296
#  1     0.666297  0.620170
#  2     0.661281  0.391482
#  3     0.656869  0.780472
#  4     0.658858  2.503163
#  ..         ...       ...
#  170   0.647697  0.714290
#  171   0.647766  2.658971
#  172   0.648896  0.670484
#  173   0.648907  1.051443
#  174   0.648322  1.163435
#
#  [175 rows x 7 columns],
#                       Stationsname  mean_rmse_validation  mean_mae_validation  \
#  0              Bad Rotenfels Murg              6.615385             3.800000
#  1                Baiersbronn Murg              2.157412             1.144720
#  2                    Beuron Donau              3.505830             2.073043
#  3                     Binnrot Rot              1.354568             0.578321
#  4                 Blaubeuren Blau              0.818487             0.367274
#  5                   Bolheim Brenz              0.572164             0.326755
#  6               Elpershofen Jagst              6.277998             3.121837
#  7                    Eutingen Enz              4.872903             2.615861
#  8               Ewattingen Wutach              1.882195             1.094881
#  9                    Gießen Argen             13.071999             6.885511
#  10                 Hausach Kinzig              4.740057             2.934430
#  11                   Hausen Zaber              0.280111             0.142743
#  12                    Horb Neckar              6.175138             3.694600
#  13             Hundersingen Donau              5.116059             3.091481
#  14              Hüttlingen Kocher              0.917319             0.391970
#  15                 Konstanz Rhein              8.126777             6.215848
#  16           Mägerkingen Lauchert              0.208017             0.107102
#  17         Oberlauchringen Wutach              3.079137             1.724074
#  18           Rengers Untere Argen              4.370957             2.152855
#  19           Riegel Leopoldskanal              6.903660             3.819777
#  20  Rielasingen Radolfzeller Aach              1.137520             0.689822
#  21      Tauberbischofsheim Tauber              4.071995             1.968857
#  22                 Wannweil Echaz              1.721936             0.705677
#  23              Wiesloch Leimbach              0.249180             0.123247
#  24                     Zell Wiese              2.685457             1.597256
#
#      mean_nse_validation  mean_nse_train
#  0             -0.053833        0.741725
#  1             -1.588232        0.642859
#  2              0.481423        0.947032
#  3             -0.351563        0.650032
#  4             -0.195450        0.958937
#  5              0.159811        0.919675
#  6             -0.084119        0.827482
#  7              0.008340        0.870564
#  8              0.103449        0.871343
#  9             -0.099120        0.661106
#  10            -0.120836        0.844639
#  11            -0.431088        0.648873
#  12             0.040731        0.807012
#  13             0.606819        0.963903
#  14            -0.089224        0.734312
#  15             0.933992        0.998933
#  16             0.664738        0.889405
#  17             0.068161        0.863168
#  18            -0.648299        0.633407
#  19             0.222412        0.855576
#  20             0.558078        0.961886
#  21             0.130693        0.850061
#  22             0.069787        0.654620
#  23            -0.182565        0.546999
#  24             0.045426        0.871007  ,
#  np.float64(0.009981221337486997),
#  np.float64(0.808582205009493),
#  np.float64(0.7986009836720059))

# %% [markdown]
# ### Final model fitting und Evaluation
# In diesem Abschnitt wird schließlich das finale Modell mit der gewählten Hyperparameter-Kombination für jede Station separat trainiert und auf dem Testzeitraum evaluiert. Die Zielvariable wird als 24-Stunden-Vorhersage definiert (Lead Time 24h), das heißt es wird Q(t+24) auf Basis der Merkmale zu Zeitpunkt t vorhergesagt (y = Abfluss.shift(-24)).
# Die Vorhersage erfolgt als Expanding-Window. Das Modell wird zunächst auf dem Trainingsset trainiert und sagt anschließend den Testdatensatz blockweise in Fenster von 720 Stunden voraus. Nach jeder Blockvorhersage werden die tatsächlichen Beobachtungen dieses Blocks an den Trainingssatz angehängt und das Modell wird für den nächsten Block erneut trainiert. Die vorhersagen werden zeitlich korrekt um plus 24 Stunden verschoben, sodass der Vorhersagezeitpunkt dem tatsächlichen Zielzeitpunkt am Abfluss Q(t+24) entspricht.
#
# Die Vorhersagegüte wird auf mehreren Ebenen ausgewertet:
# - Es wird der stündliche absoute Fehler berechnet
# - Pro Block (720 Stunden) werden RMSE, MAE und NSE berechnet
# - Die Vorhersagegüte der Wochen um die zehn höchsten Abflussspitzen pro Station werden berechnet (RMSE, MAE und NSE), wobei die Peaks mindestens 7 Tage auseinanderliegen.
# - Die Gesamtmetriken werden über den gesamten vorhergesagten Testzeitraum pro Station berechnet (RMSE, MAE und NSE)
#
# Alle Auswertungen und Ergebnisse werden als CSV-Dateien im Ordner "Evaluation" gespeichert.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error


def final_model_fitting():
    
    train_test = train_and_test_nan()

    results = []
    all_forecasts = {}
    all_hourly_eval_list = []
    all_evaluate_max_week_list = []
    overall_max_week_metrics = []
    all_monthly_eval_list = []
    week = 168
    month = 720
    horizon = 24
    
    
    for t in train_test:
        
        station = t["Stationsname"]
        
        
        train_water = t["Trainingsset"].copy()
        train_water = train_water.sort_index()
        
        test_water = t["Testset"].copy()
        test_water = test_water.sort_index()

        train = train_water.copy()
        test = test_water.copy()
        train["y"] = train_water["Abfluss in m^3/s"].shift(-horizon)
        test["y"] = test_water["Abfluss in m^3/s"].shift(-horizon)
        
        
        # the last 24 rows of y are NaNs due to the shift by 24 hours. Because it is the target and because it doesn't make sense to predict something which doesn't exist, we need to drop it.
        train = train.dropna(subset=["y"])
        test = test.dropna(subset=["y"])

        # define current_train to enrich it later in the expanding window forecast.
        current_train = train.copy()

        
        
        forecast_blocks = []
        # expanding window forecast: predicting a window of one month and cancatenate the actual runoff of this month to the train data.
        for i in range(0, len(test), month):
            end = i + month
            # defining x and y for final evaluation
            x_train = current_train.drop(columns=["y"])
            y_train = current_train["y"]
        
            x_test = test.drop(columns=["y"])
            y_test = test["y"]

            # defining the test block (one month). if the block is empty, the time series is at the end
            x_test_block = x_test.iloc[i:end]
            if len(x_test_block) == 0:
                break

            # defining the model with the best hyperparamters due to hyperparameter tuning.
            model = RandomForestRegressor(
                n_estimators=500, 
                max_features="sqrt",
                max_depth=10, 
                min_samples_split=5,
                min_samples_leaf=12,
                max_samples=0.5,
                n_jobs = -1, 
                random_state=42
            )
            
            model.fit(x_train, y_train)

            # predicting the respective month and store the forecast in forecast_blocks but shift the forecast 24 hours ahead because that is the actual date for the forecast due to the horizon (shift(-1)). 
            y_block_pred = model.predict(x_test_block)
            forecast_blocks.append(pd.Series(y_block_pred, index=test.index[i:i + len(x_test_block)] + pd.Timedelta(hours=horizon)))

            # enriching the train set by the actual values of the month which was forecasted in this loop.
            current_train = pd.concat([current_train, test.iloc[i:i + len(x_test_block)]])

            
        # concatenate the forecast on forecast_series with the corresponding station and store every forecast as a data frame in all_forecasts[station]   
        forecast_series = pd.concat(forecast_blocks).sort_index()
        all_forecasts[station] = pd.DataFrame({
            "Forecast": forecast_series
        })

        # defining the actual surface runoff to calculate the absolute error per hour.
        all_truth = test_water["Abfluss in m^3/s"].reindex(forecast_series.index) 

        # calculate the absolute error per hour.
        absolute_error_hourly = abs(all_truth - forecast_series)

        # store the information in the data frame evaluate_hourly_df.
        evaluate_hourly_df = pd.DataFrame({
            "Stationsname": station,
            "Datum / Uhrzeit": forecast_series.index,
            "Abfluss in m^3/s": all_truth.values,
            "Forecast": forecast_series.values,
            "Absolutfehler pro Stunde": absolute_error_hourly.values,
            
        })
        # append the respective data frame to a list.
        all_hourly_eval_list.append(evaluate_hourly_df)

        # calculate the 10 highest peaks which are minimum 7 days apart from each Peak
        true_runoff = evaluate_hourly_df["Abfluss in m^3/s"]
        forecast_runoff = evaluate_hourly_df["Forecast"]
        maximum_runoff = (true_runoff > true_runoff.shift(1)) & (true_runoff > true_runoff.shift(-1))
        local_maxima = true_runoff[maximum_runoff]
        local_maxima = local_maxima.sort_values(ascending=False)
        maximum_times = local_maxima.index

        # check if the sorted local maxima are more than a week apart.
        all_selected_maxima = []
        for maxima in maximum_times:
            if len(all_selected_maxima) >= 10:
                break
                
            distance_ok = True
            for selected in all_selected_maxima:
                if abs(maxima - selected) <= week:
                    distance_ok = False
                    break
            if distance_ok:
                all_selected_maxima.append(maxima)
                
        # define the week around the selected local maxima
        evaluate_maximum_weeks = []
        for selected_maxima in all_selected_maxima:
            start = selected_maxima - (week // 2)
            end = selected_maxima + (week // 2)
            
            start = max(start, true_runoff.index.min())
            end = min(end, true_runoff.index.max())

            # define the actual week around the local maxima and the forecast week to calculate the evaluation metrics of the forecast of this week.
            true_max_week = true_runoff.iloc[start:end]
            forecast_max_week = forecast_runoff.iloc[start:end]

            mae_max_week = mean_absolute_error(true_max_week, forecast_max_week)
            rmse_max_week = np.sqrt(mean_squared_error(true_max_week, forecast_max_week))

            squared_diff = (true_max_week - forecast_max_week)**2
            sum_squared_diff = np.sum(squared_diff)
            squared_diff2 = (true_max_week - true_max_week.mean())**2
            sum_squared_diff2 = np.sum(squared_diff2)

            if sum_squared_diff2 == 0:
                nse_max_week = np.nan
            else:
                nse_max_week = 1 - (sum_squared_diff / sum_squared_diff2)

            # store all maximum weeks of a time series and station in evaluate_maximum_weeks
            evaluate_maximum_weeks.append({
                "Stationsname": station,
                "Wochenstart": true_max_week.index[0],
                "Wochenende": true_max_week.index[-1],
                "Peak": selected_maxima,
                "MAE_MAX_WEEK": mae_max_week,
                "RMSE_MAX_WEEK": rmse_max_week,
                "NSE_MAX_WEEK": nse_max_week
            })
        evaluate_max_week_df = pd.DataFrame(evaluate_maximum_weeks)
        all_evaluate_max_week_list.append(evaluate_max_week_df)

        # calculate the evaluation metrics per station to identify how good the model is forecasting weeks with maximum peaks.
        all_mae_max_week = evaluate_max_week_df["MAE_MAX_WEEK"].mean()
        all_rmse_max_week = evaluate_max_week_df["RMSE_MAX_WEEK"].mean()
        all_nse_max_week = evaluate_max_week_df["NSE_MAX_WEEK"].mean()

        # store them in overall_max_week_metrics
        overall_max_week_metrics.append({
            "Stationsname": station,
            "All_MAE": all_mae_max_week,
            "All_RMSE": all_rmse_max_week,
            "All_NSE": all_nse_max_week
        })
                
        # Calculate the evaluation metrics per month block
        evaluate_monthly = []
        for i in range(0, len(forecast_series), month):
            end = i + month
            pred_block = forecast_series.iloc[i:end]
            truth_block = all_truth.iloc[i:end]

            if len(pred_block) == 0:
                break
          
            mae_block = mean_absolute_error(truth_block, pred_block)
            rmse_block = np.sqrt(mean_squared_error(truth_block, pred_block))

            squared_diff = (truth_block - pred_block)**2
            sum_squared_diff = np.sum(squared_diff)
            squared_diff2 = (truth_block - truth_block.mean())**2
            sum_squared_diff2 = np.sum(squared_diff2)

            if sum_squared_diff2 == 0:
                nse_block = np.nan
            else:
                nse_block = 1 - (sum_squared_diff / sum_squared_diff2)

            evaluate_monthly.append({
                "Stationsname": station,
                "Block Index": i // month,
                "Block Start": pred_block.index[0],
                "Block Ende": pred_block.index[-1],
                "MAE Block": mae_block,
                "RMSE Block": rmse_block,
                "NSE Block": nse_block
            })

        evaluate_monthly_df = pd.DataFrame(evaluate_monthly)
        all_monthly_eval_list.append(evaluate_monthly_df)

        
        # Calculate evaluation metrics for the whole test set per station    
        rmse = np.sqrt(mean_squared_error(test_water["Abfluss in m^3/s"].reindex(forecast_series.index), forecast_series))
        mae = mean_absolute_error(test_water["Abfluss in m^3/s"].reindex(forecast_series.index), forecast_series)
        nse = 1 - np.sum((test_water["Abfluss in m^3/s"].reindex(forecast_series.index) - forecast_series)**2) / np.sum((test_water["Abfluss in m^3/s"].reindex(forecast_series.index) - np.mean(test_water["Abfluss in m^3/s"].reindex(forecast_series.index)))**2)
        results.append({
            "Stationsname": station,
            "RMSE": rmse,
            "MAE": mae,
            "NSE": nse
        })

            
        print(f"{station}: Finished forecasting. Forecasting months {i // 720 + 1}")
        print(forecast_series.describe())

    # create a data frame for every evaluation metric an sort them.
    results_rmse_df = pd.DataFrame(results).sort_values(by="RMSE")
    results_mae_df = pd.DataFrame(results).sort_values(by="MAE")
    results_nse_df = pd.DataFrame(results).sort_values(by="NSE", ascending=False)

    # concatenate hourly and monthly evaluation metrics and for every station and the metrics for every maximum week individually and overall.  
    all_hourly_eval_df = pd.concat(all_hourly_eval_list, ignore_index=True)
    all_monthly_eval_df = pd.concat(all_monthly_eval_list, ignore_index=True)
    all_evaluate_max_week_df = pd.concat(all_evaluate_max_week_list, ignore_index=True)
    overall_max_week_metrics_df = pd.DataFrame(overall_max_week_metrics)

    

    # store the different evaluation metrics and times as csv file.
    results_rmse_df.to_csv("Evaluation/Random_Forest_Gesamtmetriken_RMSE_24h.csv", index=False)
    results_mae_df.to_csv("Evaluation/Random_Forest_Gesamtmetriken_MAE_24h.csv", index=False)
    results_nse_df.to_csv("Evaluation/Random_Forest_Gesamtmetriken_NSE_24h.csv", index=False)
    all_hourly_eval_df.to_csv("Evaluation/Random_Forest_Metriken_stündlich_24h.csv", index=False)
    all_monthly_eval_df.to_csv("Evaluation/Random_Forest_Metriken_monatlich_24h.csv", index=False)
    all_evaluate_max_week_df.to_csv("Evaluation/Random_Forest_Metriken_maximum_wochen_24h.csv", index=False)
    overall_max_week_metrics_df.to_csv("Evaluation/Random_Forest_Metriken_durchschnittlich_über_maximum_wochen_24h.csv", index=False)
    
    return results_rmse_df, results_mae_df, results_nse_df, all_forecasts, all_hourly_eval_df, all_monthly_eval_df

final_model_fitting()
# Out:
# Create features for Gießen Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Blaubeuren Blau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bolheim Brenz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Beuron Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hundersingen Donau-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wannweil Echaz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Eutingen Enz-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Elpershofen Jagst-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausach Kinzig-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hüttlingen Kocher-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Mägerkingen Lauchert-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Wiesloch Leimbach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Riegel Leopoldskanal-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Bad Rotenfels Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Baiersbronn Murg-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Horb Neckar-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Konstanz Rhein-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Binnrot Rot-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Rengers Untere Argen-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Zell Wiese-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Ewattingen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Oberlauchringen Wutach-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Create features for Hausen Zaber-Hydrologische Landespegel_interpolated_merged_nan.csv.
# Created train (105192 rows) and test data (26304 rows) for Gießen Argen.
# Created train (105192 rows) and test data (26304 rows) for Blaubeuren Blau.
# Created train (105192 rows) and test data (26304 rows) for Bolheim Brenz.
# Created train (105192 rows) and test data (26304 rows) for Beuron Donau.
# Created train (105192 rows) and test data (26304 rows) for Hundersingen Donau.
# Created train (105192 rows) and test data (26304 rows) for Wannweil Echaz.
# Created train (105192 rows) and test data (26304 rows) for Eutingen Enz.
# Created train (105192 rows) and test data (26304 rows) for Elpershofen Jagst.
# Created train (105192 rows) and test data (26304 rows) for Hausach Kinzig.
# Created train (105192 rows) and test data (26304 rows) for Hüttlingen Kocher.
# Created train (105192 rows) and test data (26304 rows) for Mägerkingen Lauchert.
# Created train (105192 rows) and test data (26304 rows) for Wiesloch Leimbach.
# Created train (105192 rows) and test data (26304 rows) for Riegel Leopoldskanal.
# Created train (105192 rows) and test data (26304 rows) for Bad Rotenfels Murg.
# Created train (105192 rows) and test data (26304 rows) for Baiersbronn Murg.
# Created train (105192 rows) and test data (26304 rows) for Horb Neckar.
# Created train (105192 rows) and test data (26304 rows) for Rielasingen Radolfzeller Aach.
# Created train (105192 rows) and test data (26304 rows) for Konstanz Rhein.
# Created train (105192 rows) and test data (26304 rows) for Binnrot Rot.
# Created train (105192 rows) and test data (26304 rows) for Tauberbischofsheim Tauber.
# Created train (105192 rows) and test data (26304 rows) for Rengers Untere Argen.
# Created train (105192 rows) and test data (26304 rows) for Zell Wiese.
# Created train (105192 rows) and test data (26304 rows) for Ewattingen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Oberlauchringen Wutach.
# Created train (105192 rows) and test data (26304 rows) for Hausen Zaber.
# Gießen Argen: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean        20.060693
# std         15.514935
# min          3.919893
# 25%          9.080331
# 50%         15.346407
# 75%         26.880325
# max        165.705038
# dtype: float64
# Blaubeuren Blau: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         2.456531
# std          1.648972
# min          0.705428
# 25%          1.329545
# 50%          2.059282
# 75%          2.968587
# max         15.170913
# dtype: float64
# Bolheim Brenz: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         4.411732
# std          1.718144
# min          2.091263
# 25%          3.227183
# 50%          4.055506
# 75%          5.111883
# max         12.247132
# dtype: float64
# Beuron Donau: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean        11.733688
# std         14.641829
# min          0.790248
# 25%          2.375183
# 50%          5.455153
# 75%         17.123532
# max        120.333059
# dtype: float64
# Hundersingen Donau: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean        24.123796
# std         21.010046
# min          5.572171
# 25%         10.068519
# 50%         16.884655
# 75%         31.572909
# max        161.935710
# dtype: float64
# Wannweil Echaz: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         2.639840
# std          1.820312
# min          0.674910
# 25%          1.537774
# 50%          2.189496
# 75%          3.202596
# max         27.818405
# dtype: float64
# Eutingen Enz: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean        16.261962
# std         10.595765
# min          4.574229
# 25%          8.559835
# 50%         13.389050
# 75%         21.112406
# max         91.224109
# dtype: float64
# Elpershofen Jagst: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         7.946600
# std          9.386610
# min          1.241318
# 25%          2.518086
# 50%          4.800781
# 75%          9.346253
# max         87.814331
# dtype: float64
# Hausach Kinzig: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean        15.725065
# std         14.669179
# min          2.379043
# 25%          5.589205
# 50%         11.016543
# 75%         20.760739
# max        115.387866
# dtype: float64
# Hüttlingen Kocher: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         2.003622
# std          1.352455
# min          0.617425
# 25%          1.002795
# 50%          1.517126
# 75%          2.539931
# max         10.321331
# dtype: float64
# Mägerkingen Lauchert: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         0.685005
# std          0.649523
# min          0.069131
# 25%          0.258531
# 50%          0.512113
# 75%          0.911187
# max          7.678721
# dtype: float64
# Wiesloch Leimbach: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         0.608562
# std          0.213419
# min          0.267269
# 25%          0.454975
# 50%          0.579158
# 75%          0.737567
# max          2.304696
# dtype: float64
# Riegel Leopoldskanal: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean        12.034053
# std         15.213176
# min          0.792196
# 25%          1.240625
# 50%          5.985036
# 75%         17.840861
# max        126.868125
# dtype: float64
# Bad Rotenfels Murg: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean        16.149162
# std         13.506004
# min          2.325257
# 25%          6.226268
# 50%         12.496583
# 75%         20.403601
# max        101.135554
# dtype: float64
# Baiersbronn Murg: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         2.957827
# std          2.561048
# min          0.538136
# 25%          1.082170
# 50%          2.079576
# 75%          3.849474
# max         21.740022
# dtype: float64
# Horb Neckar: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean        13.799565
# std         11.169083
# min          3.093393
# 25%          6.252663
# 50%         10.177566
# 75%         17.613783
# max         92.184260
# dtype: float64
# Rielasingen Radolfzeller Aach: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         9.240807
# std          4.129636
# min          2.671252
# 25%          6.233087
# 50%          9.154380
# 75%         11.666534
# max         23.238406
# dtype: float64
# Konstanz Rhein: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean       321.949726
# std        130.881773
# min        171.891139
# 25%        227.422795
# 50%        292.459972
# 75%        364.908373
# max        802.079389
# dtype: float64
# Binnrot Rot: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         1.910157
# std          1.063061
# min          0.847863
# 25%          1.222882
# 50%          1.626790
# 75%          2.178479
# max          9.982450
# dtype: float64
# Tauberbischofsheim Tauber: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         8.757487
# std          7.387341
# min          2.427854
# 25%          4.211549
# 50%          6.630589
# 75%         10.575080
# max         82.920610
# dtype: float64
# Rengers Untere Argen: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         4.510646
# std          4.132958
# min          0.421241
# 25%          1.690270
# 50%          3.028013
# 75%          6.016700
# max         43.201521
# dtype: float64
# Zell Wiese: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         7.352872
# std          6.755129
# min          0.979367
# 25%          2.781439
# 50%          5.330623
# 75%          9.230673
# max         53.513239
# dtype: float64
# Ewattingen Wutach: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         5.727077
# std          4.971170
# min          0.899637
# 25%          2.185019
# 50%          4.181441
# 75%          7.666124
# max         46.723297
# dtype: float64
# Oberlauchringen Wutach: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         8.987310
# std          7.142721
# min          1.776099
# 25%          3.859457
# 50%          6.513372
# 75%         12.418237
# max         62.644292
# dtype: float64
# Hausen Zaber: Finished forecasting. Forecasting months 37
# count    26280.000000
# mean         0.521457
# std          0.260188
# min          0.193212
# 25%          0.343199
# 50%          0.482081
# 75%          0.623857
# max          3.161621
# dtype: float64
# (                     Stationsname       RMSE       MAE       NSE
#  10           Mägerkingen Lauchert   0.235153  0.084215  0.886867
#  11              Wiesloch Leimbach   0.366819  0.135989  0.214972
#  1                 Blaubeuren Blau   0.381618  0.177078  0.950609
#  24                   Hausen Zaber   0.431233  0.161419  0.228557
#  2                   Bolheim Brenz   0.606771  0.345332  0.900218
#  16  Rielasingen Radolfzeller Aach   1.088658  0.644421  0.938661
#  18                    Binnrot Rot   1.323615  0.431983  0.493714
#  9               Hüttlingen Kocher   1.387094  0.492866  0.531489
#  5                  Wannweil Echaz   1.645439  0.577151  0.634820
#  14               Baiersbronn Murg   2.867735  1.183638  0.398623
#  22              Ewattingen Wutach   2.948256  1.095602  0.749586
#  21                     Zell Wiese   3.574921  1.482663  0.774218
#  23         Oberlauchringen Wutach   3.971488  1.471355  0.767644
#  19      Tauberbischofsheim Tauber   4.587277  1.489449  0.748120
#  20           Rengers Untere Argen   4.784272  2.070640  0.460252
#  3                    Beuron Donau   5.055257  1.945992  0.902300
#  6                    Eutingen Enz   5.758821  2.625524  0.765296
#  4              Hundersingen Donau   6.046907  2.843478  0.931044
#  7               Elpershofen Jagst   6.789189  2.367154  0.681991
#  12           Riegel Leopoldskanal   8.142982  3.581688  0.778265
#  17                 Konstanz Rhein   8.295312  5.046081  0.996076
#  15                    Horb Neckar   8.744526  3.245189  0.636837
#  13             Bad Rotenfels Murg   9.407793  4.319748  0.638892
#  8                  Hausach Kinzig   9.456982  3.764388  0.712632
#  0                    Gießen Argen  13.870791  5.939197  0.584176,
#                       Stationsname       RMSE       MAE       NSE
#  10           Mägerkingen Lauchert   0.235153  0.084215  0.886867
#  11              Wiesloch Leimbach   0.366819  0.135989  0.214972
#  24                   Hausen Zaber   0.431233  0.161419  0.228557
#  1                 Blaubeuren Blau   0.381618  0.177078  0.950609
#  2                   Bolheim Brenz   0.606771  0.345332  0.900218
#  18                    Binnrot Rot   1.323615  0.431983  0.493714
#  9               Hüttlingen Kocher   1.387094  0.492866  0.531489
#  5                  Wannweil Echaz   1.645439  0.577151  0.634820
#  16  Rielasingen Radolfzeller Aach   1.088658  0.644421  0.938661
#  22              Ewattingen Wutach   2.948256  1.095602  0.749586
#  14               Baiersbronn Murg   2.867735  1.183638  0.398623
#  23         Oberlauchringen Wutach   3.971488  1.471355  0.767644
#  21                     Zell Wiese   3.574921  1.482663  0.774218
#  19      Tauberbischofsheim Tauber   4.587277  1.489449  0.748120
#  3                    Beuron Donau   5.055257  1.945992  0.902300
#  20           Rengers Untere Argen   4.784272  2.070640  0.460252
#  7               Elpershofen Jagst   6.789189  2.367154  0.681991
#  6                    Eutingen Enz   5.758821  2.625524  0.765296
#  4              Hundersingen Donau   6.046907  2.843478  0.931044
#  15                    Horb Neckar   8.744526  3.245189  0.636837
#  12           Riegel Leopoldskanal   8.142982  3.581688  0.778265
#  8                  Hausach Kinzig   9.456982  3.764388  0.712632
#  13             Bad Rotenfels Murg   9.407793  4.319748  0.638892
#  17                 Konstanz Rhein   8.295312  5.046081  0.996076
#  0                    Gießen Argen  13.870791  5.939197  0.584176,
#                       Stationsname       RMSE       MAE       NSE
#  17                 Konstanz Rhein   8.295312  5.046081  0.996076
#  1                 Blaubeuren Blau   0.381618  0.177078  0.950609
#  16  Rielasingen Radolfzeller Aach   1.088658  0.644421  0.938661
#  4              Hundersingen Donau   6.046907  2.843478  0.931044
#  3                    Beuron Donau   5.055257  1.945992  0.902300
#  2                   Bolheim Brenz   0.606771  0.345332  0.900218
#  10           Mägerkingen Lauchert   0.235153  0.084215  0.886867
#  12           Riegel Leopoldskanal   8.142982  3.581688  0.778265
#  21                     Zell Wiese   3.574921  1.482663  0.774218
#  23         Oberlauchringen Wutach   3.971488  1.471355  0.767644
#  6                    Eutingen Enz   5.758821  2.625524  0.765296
#  22              Ewattingen Wutach   2.948256  1.095602  0.749586
#  19      Tauberbischofsheim Tauber   4.587277  1.489449  0.748120
#  8                  Hausach Kinzig   9.456982  3.764388  0.712632
#  7               Elpershofen Jagst   6.789189  2.367154  0.681991
#  13             Bad Rotenfels Murg   9.407793  4.319748  0.638892
#  15                    Horb Neckar   8.744526  3.245189  0.636837
#  5                  Wannweil Echaz   1.645439  0.577151  0.634820
#  0                    Gießen Argen  13.870791  5.939197  0.584176
#  9               Hüttlingen Kocher   1.387094  0.492866  0.531489
#  18                    Binnrot Rot   1.323615  0.431983  0.493714
#  20           Rengers Untere Argen   4.784272  2.070640  0.460252
#  14               Baiersbronn Murg   2.867735  1.183638  0.398623
#  24                   Hausen Zaber   0.431233  0.161419  0.228557
#  11              Wiesloch Leimbach   0.366819  0.135989  0.214972,
#  {'Gießen Argen':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  49.256554
#   2022-01-02 01:00:00  47.721084
#   2022-01-02 02:00:00  46.847619
#   2022-01-02 03:00:00  46.977145
#   2022-01-02 04:00:00  46.627544
#   ...                        ...
#   2024-12-31 19:00:00  12.444949
#   2024-12-31 20:00:00  12.435119
#   2024-12-31 21:00:00  12.458035
#   2024-12-31 22:00:00  12.441543
#   2024-12-31 23:00:00  12.456783
#
#   [26280 rows x 1 columns],
#   'Blaubeuren Blau':                      Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  5.291825
#   2022-01-02 01:00:00  5.307309
#   2022-01-02 02:00:00  5.268432
#   2022-01-02 03:00:00  5.225927
#   2022-01-02 04:00:00  5.243669
#   ...                       ...
#   2024-12-31 19:00:00  2.600692
#   2024-12-31 20:00:00  2.597528
#   2024-12-31 21:00:00  2.603067
#   2024-12-31 22:00:00  2.595564
#   2024-12-31 23:00:00  2.578221
#
#   [26280 rows x 1 columns],
#   'Bolheim Brenz':                      Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  5.057008
#   2022-01-02 01:00:00  5.001776
#   2022-01-02 02:00:00  4.987659
#   2022-01-02 03:00:00  4.947249
#   2022-01-02 04:00:00  4.934639
#   ...                       ...
#   2024-12-31 19:00:00  4.092369
#   2024-12-31 20:00:00  4.080469
#   2024-12-31 21:00:00  4.194346
#   2024-12-31 22:00:00  4.210537
#   2024-12-31 23:00:00  4.180136
#
#   [26280 rows x 1 columns],
#   'Beuron Donau':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  34.201927
#   2022-01-02 01:00:00  33.941148
#   2022-01-02 02:00:00  33.752203
#   2022-01-02 03:00:00  33.426680
#   2022-01-02 04:00:00  33.114541
#   ...                        ...
#   2024-12-31 19:00:00  15.488279
#   2024-12-31 20:00:00  15.439878
#   2024-12-31 21:00:00  15.399998
#   2024-12-31 22:00:00  15.352801
#   2024-12-31 23:00:00  15.249060
#
#   [26280 rows x 1 columns],
#   'Hundersingen Donau':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  51.926987
#   2022-01-02 01:00:00  52.043359
#   2022-01-02 02:00:00  51.435394
#   2022-01-02 03:00:00  51.039185
#   2022-01-02 04:00:00  50.973038
#   ...                        ...
#   2024-12-31 19:00:00  29.393792
#   2024-12-31 20:00:00  29.320728
#   2024-12-31 21:00:00  29.000108
#   2024-12-31 22:00:00  28.867534
#   2024-12-31 23:00:00  28.972449
#
#   [26280 rows x 1 columns],
#   'Wannweil Echaz':                      Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  3.620960
#   2022-01-02 01:00:00  3.344400
#   2022-01-02 02:00:00  3.274555
#   2022-01-02 03:00:00  3.266286
#   2022-01-02 04:00:00  3.325340
#   ...                       ...
#   2024-12-31 19:00:00  2.154944
#   2024-12-31 20:00:00  2.127366
#   2024-12-31 21:00:00  2.141301
#   2024-12-31 22:00:00  2.141085
#   2024-12-31 23:00:00  2.123387
#
#   [26280 rows x 1 columns],
#   'Eutingen Enz':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  23.936093
#   2022-01-02 01:00:00  24.626946
#   2022-01-02 02:00:00  25.031301
#   2022-01-02 03:00:00  24.188710
#   2022-01-02 04:00:00  24.424006
#   ...                        ...
#   2024-12-31 19:00:00  14.288050
#   2024-12-31 20:00:00  14.267383
#   2024-12-31 21:00:00  14.199940
#   2024-12-31 22:00:00  14.172902
#   2024-12-31 23:00:00  14.134472
#
#   [26280 rows x 1 columns],
#   'Elpershofen Jagst':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  29.955400
#   2022-01-02 01:00:00  26.225938
#   2022-01-02 02:00:00  26.952383
#   2022-01-02 03:00:00  27.216574
#   2022-01-02 04:00:00  25.435714
#   ...                        ...
#   2024-12-31 19:00:00   5.005785
#   2024-12-31 20:00:00   4.955162
#   2024-12-31 21:00:00   4.986954
#   2024-12-31 22:00:00   5.006228
#   2024-12-31 23:00:00   5.018953
#
#   [26280 rows x 1 columns],
#   'Hausach Kinzig':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  43.818562
#   2022-01-02 01:00:00  42.186752
#   2022-01-02 02:00:00  41.047569
#   2022-01-02 03:00:00  40.937262
#   2022-01-02 04:00:00  40.969506
#   ...                        ...
#   2024-12-31 19:00:00  18.390966
#   2024-12-31 20:00:00  18.180515
#   2024-12-31 21:00:00  18.013824
#   2024-12-31 22:00:00  18.151729
#   2024-12-31 23:00:00  17.938862
#
#   [26280 rows x 1 columns],
#   'Hüttlingen Kocher':                      Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  4.641931
#   2022-01-02 01:00:00  4.731534
#   2022-01-02 02:00:00  4.630841
#   2022-01-02 03:00:00  4.397417
#   2022-01-02 04:00:00  4.222715
#   ...                       ...
#   2024-12-31 19:00:00  1.323665
#   2024-12-31 20:00:00  1.322565
#   2024-12-31 21:00:00  1.307822
#   2024-12-31 22:00:00  1.320848
#   2024-12-31 23:00:00  1.328399
#
#   [26280 rows x 1 columns],
#   'Mägerkingen Lauchert':                      Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  1.399723
#   2022-01-02 01:00:00  1.400739
#   2022-01-02 02:00:00  1.416635
#   2022-01-02 03:00:00  1.403130
#   2022-01-02 04:00:00  1.395233
#   ...                       ...
#   2024-12-31 19:00:00  0.512146
#   2024-12-31 20:00:00  0.509727
#   2024-12-31 21:00:00  0.509640
#   2024-12-31 22:00:00  0.508470
#   2024-12-31 23:00:00  0.504588
#
#   [26280 rows x 1 columns],
#   'Wiesloch Leimbach':                      Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  0.747146
#   2022-01-02 01:00:00  0.760126
#   2022-01-02 02:00:00  0.758997
#   2022-01-02 03:00:00  0.728205
#   2022-01-02 04:00:00  0.719992
#   ...                       ...
#   2024-12-31 19:00:00  0.723312
#   2024-12-31 20:00:00  0.723594
#   2024-12-31 21:00:00  0.725031
#   2024-12-31 22:00:00  0.723938
#   2024-12-31 23:00:00  0.723679
#
#   [26280 rows x 1 columns],
#   'Riegel Leopoldskanal':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  42.101772
#   2022-01-02 01:00:00  41.429673
#   2022-01-02 02:00:00  40.854134
#   2022-01-02 03:00:00  40.757321
#   2022-01-02 04:00:00  40.302785
#   ...                        ...
#   2024-12-31 19:00:00  13.032116
#   2024-12-31 20:00:00  12.864449
#   2024-12-31 21:00:00  12.822949
#   2024-12-31 22:00:00  12.778087
#   2024-12-31 23:00:00  12.742879
#
#   [26280 rows x 1 columns],
#   'Bad Rotenfels Murg':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  53.879044
#   2022-01-02 01:00:00  56.182295
#   2022-01-02 02:00:00  57.416432
#   2022-01-02 03:00:00  50.922201
#   2022-01-02 04:00:00  48.875685
#   ...                        ...
#   2024-12-31 19:00:00  15.849101
#   2024-12-31 20:00:00  16.678833
#   2024-12-31 21:00:00  16.461403
#   2024-12-31 22:00:00  15.934934
#   2024-12-31 23:00:00  15.886843
#
#   [26280 rows x 1 columns],
#   'Baiersbronn Murg':                      Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  8.950136
#   2022-01-02 01:00:00  8.593349
#   2022-01-02 02:00:00  8.344926
#   2022-01-02 03:00:00  8.349480
#   2022-01-02 04:00:00  8.314671
#   ...                       ...
#   2024-12-31 19:00:00  2.351659
#   2024-12-31 20:00:00  2.342902
#   2024-12-31 21:00:00  2.327347
#   2024-12-31 22:00:00  2.331121
#   2024-12-31 23:00:00  2.327209
#
#   [26280 rows x 1 columns],
#   'Horb Neckar':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  22.912927
#   2022-01-02 01:00:00  21.949972
#   2022-01-02 02:00:00  21.668683
#   2022-01-02 03:00:00  21.494396
#   2022-01-02 04:00:00  21.092137
#   ...                        ...
#   2024-12-31 19:00:00  14.462069
#   2024-12-31 20:00:00  14.471092
#   2024-12-31 21:00:00  14.503620
#   2024-12-31 22:00:00  14.415683
#   2024-12-31 23:00:00  14.446853
#
#   [26280 rows x 1 columns],
#   'Rielasingen Radolfzeller Aach':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  12.446054
#   2022-01-02 01:00:00  12.440022
#   2022-01-02 02:00:00  12.406288
#   2022-01-02 03:00:00  12.414132
#   2022-01-02 04:00:00  12.407314
#   ...                        ...
#   2024-12-31 19:00:00   9.739047
#   2024-12-31 20:00:00   9.758735
#   2024-12-31 21:00:00   9.737671
#   2024-12-31 22:00:00   9.761780
#   2024-12-31 23:00:00   9.679950
#
#   [26280 rows x 1 columns],
#   'Konstanz Rhein':                        Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  260.214674
#   2022-01-02 01:00:00  260.327600
#   2022-01-02 02:00:00  260.330084
#   2022-01-02 03:00:00  260.247399
#   2022-01-02 04:00:00  260.418808
#   ...                         ...
#   2024-12-31 19:00:00  213.119548
#   2024-12-31 20:00:00  213.035890
#   2024-12-31 21:00:00  212.894836
#   2024-12-31 22:00:00  212.722574
#   2024-12-31 23:00:00  212.675241
#
#   [26280 rows x 1 columns],
#   'Binnrot Rot':                      Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  2.382875
#   2022-01-02 01:00:00  2.368943
#   2022-01-02 02:00:00  2.379510
#   2022-01-02 03:00:00  2.372386
#   2022-01-02 04:00:00  2.364842
#   ...                       ...
#   2024-12-31 19:00:00  1.435600
#   2024-12-31 20:00:00  1.435600
#   2024-12-31 21:00:00  1.435422
#   2024-12-31 22:00:00  1.435422
#   2024-12-31 23:00:00  1.435327
#
#   [26280 rows x 1 columns],
#   'Tauberbischofsheim Tauber':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  22.325193
#   2022-01-02 01:00:00  21.767088
#   2022-01-02 02:00:00  21.032184
#   2022-01-02 03:00:00  20.719796
#   2022-01-02 04:00:00  20.064536
#   ...                        ...
#   2024-12-31 19:00:00   6.951146
#   2024-12-31 20:00:00   6.969042
#   2024-12-31 21:00:00   7.083375
#   2024-12-31 22:00:00   6.891443
#   2024-12-31 23:00:00   6.797907
#
#   [26280 rows x 1 columns],
#   'Rengers Untere Argen':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  14.012078
#   2022-01-02 01:00:00  13.889174
#   2022-01-02 02:00:00  14.172461
#   2022-01-02 03:00:00  13.715635
#   2022-01-02 04:00:00  14.220898
#   ...                        ...
#   2024-12-31 19:00:00   2.391764
#   2024-12-31 20:00:00   2.379527
#   2024-12-31 21:00:00   2.378823
#   2024-12-31 22:00:00   2.388851
#   2024-12-31 23:00:00   2.386631
#
#   [26280 rows x 1 columns],
#   'Zell Wiese':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  30.060958
#   2022-01-02 01:00:00  29.205880
#   2022-01-02 02:00:00  28.966284
#   2022-01-02 03:00:00  28.743068
#   2022-01-02 04:00:00  28.355116
#   ...                        ...
#   2024-12-31 19:00:00   5.755508
#   2024-12-31 20:00:00   5.733001
#   2024-12-31 21:00:00   5.658712
#   2024-12-31 22:00:00   5.655963
#   2024-12-31 23:00:00   5.650552
#
#   [26280 rows x 1 columns],
#   'Ewattingen Wutach':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  16.036763
#   2022-01-02 01:00:00  15.597065
#   2022-01-02 02:00:00  15.341954
#   2022-01-02 03:00:00  14.976071
#   2022-01-02 04:00:00  14.690923
#   ...                        ...
#   2024-12-31 19:00:00   6.645725
#   2024-12-31 20:00:00   6.629576
#   2024-12-31 21:00:00   6.641420
#   2024-12-31 22:00:00   6.658972
#   2024-12-31 23:00:00   6.587779
#
#   [26280 rows x 1 columns],
#   'Oberlauchringen Wutach':                       Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  19.509266
#   2022-01-02 01:00:00  19.254033
#   2022-01-02 02:00:00  19.264681
#   2022-01-02 03:00:00  19.279799
#   2022-01-02 04:00:00  18.968425
#   ...                        ...
#   2024-12-31 19:00:00  10.087334
#   2024-12-31 20:00:00  10.079040
#   2024-12-31 21:00:00  10.066347
#   2024-12-31 22:00:00  10.083196
#   2024-12-31 23:00:00  10.087629
#
#   [26280 rows x 1 columns],
#   'Hausen Zaber':                      Forecast
#   Datum / Uhrzeit
#   2022-01-02 00:00:00  0.765478
#   2022-01-02 01:00:00  0.894429
#   2022-01-02 02:00:00  0.957800
#   2022-01-02 03:00:00  0.774932
#   2022-01-02 04:00:00  0.716383
#   ...                       ...
#   2024-12-31 19:00:00  0.548982
#   2024-12-31 20:00:00  0.549581
#   2024-12-31 21:00:00  0.551673
#   2024-12-31 22:00:00  0.551056
#   2024-12-31 23:00:00  0.550468
#
#   [26280 rows x 1 columns]},
#          Stationsname     Datum / Uhrzeit  Abfluss in m^3/s   Forecast  \
#  0       Gießen Argen 2022-01-02 00:00:00            33.649  49.256554
#  1       Gießen Argen 2022-01-02 01:00:00            33.353  47.721084
#  2       Gießen Argen 2022-01-02 02:00:00            33.142  46.847619
#  3       Gießen Argen 2022-01-02 03:00:00            32.827  46.977145
#  4       Gießen Argen 2022-01-02 04:00:00            32.490  46.627544
#  ...              ...                 ...               ...        ...
#  656995  Hausen Zaber 2024-12-31 19:00:00             0.486   0.548982
#  656996  Hausen Zaber 2024-12-31 20:00:00             0.487   0.549581
#  656997  Hausen Zaber 2024-12-31 21:00:00             0.487   0.551673
#  656998  Hausen Zaber 2024-12-31 22:00:00             0.486   0.551056
#  656999  Hausen Zaber 2024-12-31 23:00:00             0.485   0.550468
#
#          Absolutfehler pro Stunde
#  0                      15.607554
#  1                      14.368084
#  2                      13.705619
#  3                      14.150145
#  4                      14.137544
#  ...                          ...
#  656995                  0.062982
#  656996                  0.062581
#  656997                  0.064673
#  656998                  0.065056
#  656999                  0.065468
#
#  [657000 rows x 5 columns],
#       Stationsname  Block Index Block Start          Block Ende  MAE Block  \
#  0    Gießen Argen            0  2022-01-02 2022-01-31 23:00:00   4.513994
#  1    Gießen Argen            1  2022-02-01 2022-03-02 23:00:00   8.252997
#  2    Gießen Argen            2  2022-03-03 2022-04-01 23:00:00   1.282303
#  3    Gießen Argen            3  2022-04-02 2022-05-01 23:00:00   3.658546
#  4    Gießen Argen            4  2022-05-02 2022-05-31 23:00:00   3.826786
#  ..            ...          ...         ...                 ...        ...
#  920  Hausen Zaber           32  2024-08-19 2024-09-17 23:00:00   0.186956
#  921  Hausen Zaber           33  2024-09-18 2024-10-17 23:00:00   0.173952
#  922  Hausen Zaber           34  2024-10-18 2024-11-16 23:00:00   0.062640
#  923  Hausen Zaber           35  2024-11-17 2024-12-16 23:00:00   0.129662
#  924  Hausen Zaber           36  2024-12-17 2024-12-31 23:00:00   0.127668
#
#       RMSE Block  NSE Block
#  0      7.847867   0.041504
#  1     12.577595   0.046642
#  2      1.606488   0.414869
#  3      6.801524   0.156766
#  4      6.588292  -0.383171
#  ..          ...        ...
#  920    0.260079  -0.449952
#  921    0.386184  -0.000649
#  922    0.070502  -2.946242
#  923    0.325382  -0.064612
#  924    0.196199  -0.192902
#
#  [925 rows x 7 columns])
