# %% [markdown]
# # Umgang mit den Lücken
# ### Interpolation
#
# In dieser Datei werden die Lücken der Zeitreihen der endgültig ausgewählten Stationen mittels zeitbasierter linearer Interpolation geschlossen. Dazu wird "Datum / Uhrzeit" als datetime definiert, sodass fehlende Zeitpunkte als Zeilen mit NaN-Werten erscheinen. Anschließend werden fehlende Werte innerhalb der Zeitreihe zeitbasiert interpoliert (method="time"). Dabei werden ausschließlich fehlende Werte innerhalb der Datn interpoliert ("limit_area="inside"). Die Ränder der zeitreihen werden nicht gefüllt. Dies ist jedoch unproblematisch, da bereits bei der Auswahl der Stationen festgelegt wurde, dass alle gewählten Zeitreihen den definierten Zeitraum vollständig abdecken und somit an den Rändern gültige Einträge vorliegen.
#
# Interpolierte Werte werden in der zusätzlichen Spalte "Interpoliert" markiert. Das bedeutet, ein Eintrag ist "True", wenn der Wert zuvor gefehlt hat (NaN) und durch Interpolation ergänzt wurde. Werte die nicht interpoliert wurden, erhalten in dieser Spalte "False". Die interpolierten Dateien werden mit der Endung "interpolated.csv" gespeichert, wobei "_filtered_shortened" der Übersichtlichkeit wegen ersetzt wird.

# %%
from pathlib import Path
import pandas as pd
import glob

# glob all files in "Auswahl Landespegel Hydrologie" with the ending "_filtered_shortened.csv".
files=glob.glob("Datensätze/UDO-LUBW/Auswahl Landespegel Hydrologie/Gewässer/*/*/*_filtered_shortened.csv")
print(f"Found {len(files)} files")

# interpolate every gap in the respective csv file
def interpolate_gaps():
    interpolated = []
    for p in files:
        p = Path(p)

        # read the respective file as a data frame.
        df = pd.read_csv(p, sep=",", encoding="utf-8")

        # store the data frame as a copy of the data frame to work with it without missunderstandings.
        df = df.copy()
        # define the column "Datum / Uhrzeit" as a real date time.
        df["Datum / Uhrzeit"] = pd.to_datetime(df["Datum / Uhrzeit"], errors="coerce")

        # convert the column "Wert in m^3/s to a real numeric value.
        df["Wert in m^3/s"] = df["Wert in m^3/s"].astype(float)

        # maybe "Datum / Uhrzeit" is by any case not sorted.
        df = df.sort_values("Datum / Uhrzeit")
        
        # set the column "Datum / Uhrzeit" as index and in hourly frequence. Now the gaps are rows with NaNs but the Index is a real date time.
        df = df.set_index("Datum / Uhrzeit").asfreq("h")

        # set marker for the interpolation marker. True if respective df["Wert in m^3"] is nan false if not
        was_nan = df["Wert in m^3/s"].isna()

        # The interpolation of the NaNs in the column "Wert in m^3/s but just inside the data frame.
        df["Wert in m^3/s"] = df["Wert in m^3/s"].interpolate(method="time", limit_area="inside")

        # new column which marks interpolated values
        df["Interpoliert"] = was_nan & df["Wert in m^3/s"].notna()

        # fills the NaNs in "Stationsname" and "Gewässer" with the first entry of the respective column.
        for c in ("Stationsname", "Gewässer"):
            if c in df.columns and df[c].notna().any():
                df[c] = df[c].fillna(df[c].iloc[0])
                
        # reset the index and change the "index" back to "Datum / Uhrzeit" to avoid mistakes for repeated execution. 
        df = df.reset_index().rename(columns={"index": "Datum / Uhrzeit"})

        # create new data frame with the respective columns
        cols = [c for c in ("Stationsname", "Gewässer", "Datum / Uhrzeit", "Wert in m^3/s", "Interpoliert") if c in df.columns]

        # store those as a data frame
        df = df[cols]
        
        # replace old ending with new ending and store it as a csv file
        out_path = p.with_name(p.name.replace("_filtered_shortened", "_interpolated"))
        df.to_csv(out_path, index=False)

        print(f"interpolated: {p.name} to {out_path.name} ({len(df)} rows)")
        interpolated.append(out_path)

    print(f"\n Ready. interpolated {len(interpolated)} of {len(files)} files.")

interpolate_gaps()
# Out:
# Found 77 files
# interpolated: Oberensingen Aich-Hydrologische Landespegel_filtered_shortened.csv to Oberensingen Aich-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Lauben Aitrach-Hydrologische Landespegel_filtered_shortened.csv to Lauben Aitrach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Ettlingen Alb-Hydrologische Landespegel_filtered_shortened.csv to Ettlingen Alb-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Riegel-pumpwerksteg-Hydrologische Landespegel_filtered_shortened.csv to Riegel-pumpwerksteg-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Gießen Argen-Hydrologische Landespegel_filtered_shortened.csv to Gießen Argen-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Achstetten Baierzer Rot-Hydrologische Landespegel_filtered_shortened.csv to Achstetten Baierzer Rot-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Blaubeuren Blau-Hydrologische Landespegel_filtered_shortened.csv to Blaubeuren Blau-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Ulm Blau-Hydrologische Landespegel_filtered_shortened.csv to Ulm Blau-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Bolheim Brenz-Hydrologische Landespegel_filtered_shortened.csv to Bolheim Brenz-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Königsbronn Brenz-Hydrologische Landespegel_filtered_shortened.csv to Königsbronn Brenz-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Donaueschingen Brigach-Hydrologische Landespegel_filtered_shortened.csv to Donaueschingen Brigach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Villingen Brigach-Hydrologische Landespegel_filtered_shortened.csv to Villingen Brigach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Berg Donau-Hydrologische Landespegel_filtered_shortened.csv to Berg Donau-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Beuron Donau-Hydrologische Landespegel_filtered_shortened.csv to Beuron Donau-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Hundersingen Donau-Hydrologische Landespegel_filtered_shortened.csv to Hundersingen Donau-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Kirchen-Hausen Donau-Hydrologische Landespegel_filtered_shortened.csv to Kirchen-Hausen Donau-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Möhringen-Espenbrücke Donau-Hydrologische Landespegel_filtered_shortened.csv to Möhringen-Espenbrücke Donau-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Wannweil Echaz-Hydrologische Landespegel_filtered_shortened.csv to Wannweil Echaz-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Tuttlingen Elta-Hydrologische Landespegel_filtered_shortened.csv to Tuttlingen Elta-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Bleibach-WKA Elz-Hydrologische Landespegel_filtered_shortened.csv to Bleibach-WKA Elz-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Gutach Elz-Hydrologische Landespegel_filtered_shortened.csv to Gutach Elz-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Besigheim Enz-Hydrologische Landespegel_filtered_shortened.csv to Besigheim Enz-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Eutingen Enz-Hydrologische Landespegel_filtered_shortened.csv to Eutingen Enz-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Höfen Enz-Hydrologische Landespegel_filtered_shortened.csv to Höfen Enz-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Geislingen Fils-Hydrologische Landespegel_filtered_shortened.csv to Geislingen Fils-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Plochingen Fils-Hydrologische Landespegel_filtered_shortened.csv to Plochingen Fils-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Salach Fils-Hydrologische Landespegel_filtered_shortened.csv to Salach Fils-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Wiesensteig Fils-Hydrologische Landespegel_filtered_shortened.csv to Wiesensteig Fils-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Dörzbach Jagst-Hydrologische Landespegel_filtered_shortened.csv to Dörzbach Jagst-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Elpershofen Jagst-Hydrologische Landespegel_filtered_shortened.csv to Elpershofen Jagst-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Jagstzell Jagst-Hydrologische Landespegel_filtered_shortened.csv to Jagstzell Jagst-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Schwabsberg Jagst-Hydrologische Landespegel_filtered_shortened.csv to Schwabsberg Jagst-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Untergriesheim Jagst-Hydrologische Landespegel_filtered_shortened.csv to Untergriesheim Jagst-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Biberach Kinzig-Hydrologische Landespegel_filtered_shortened.csv to Biberach Kinzig-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Hausach Kinzig-Hydrologische Landespegel_filtered_shortened.csv to Hausach Kinzig-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Schenkenzell Kinzig-Hydrologische Landespegel_filtered_shortened.csv to Schenkenzell Kinzig-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Schwaibach Kinzig-Hydrologische Landespegel_filtered_shortened.csv to Schwaibach Kinzig-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Gaildorf Kocher-Hydrologische Landespegel_filtered_shortened.csv to Gaildorf Kocher-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Hüttlingen Kocher-Hydrologische Landespegel_filtered_shortened.csv to Hüttlingen Kocher-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Kocherstetten Kocher-Hydrologische Landespegel_filtered_shortened.csv to Kocherstetten Kocher-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Stein Kocher-Hydrologische Landespegel_filtered_shortened.csv to Stein Kocher-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Ubstadt Kraichbach-Hydrologische Landespegel_filtered_shortened.csv to Ubstadt Kraichbach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Gammertingen Lauchert-Hydrologische Landespegel_filtered_shortened.csv to Gammertingen Lauchert-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Laucherthal Lauchert-Hydrologische Landespegel_filtered_shortened.csv to Laucherthal Lauchert-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Mägerkingen Lauchert-Hydrologische Landespegel_filtered_shortened.csv to Mägerkingen Lauchert-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Königsbronn Leerausbach-Hydrologische Landespegel_filtered_shortened.csv to Königsbronn Leerausbach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Wiesloch Leimbach-Hydrologische Landespegel_filtered_shortened.csv to Wiesloch Leimbach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Riegel Leopoldskanal-Hydrologische Landespegel_filtered_shortened.csv to Riegel Leopoldskanal-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Bad Rotenfels Murg-Hydrologische Landespegel_filtered_shortened.csv to Bad Rotenfels Murg-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Baiersbronn Murg-Hydrologische Landespegel_filtered_shortened.csv to Baiersbronn Murg-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Schwarzenberg Murg-Hydrologische Landespegel_filtered_shortened.csv to Schwarzenberg Murg-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Horb Neckar-Hydrologische Landespegel_filtered_shortened.csv to Horb Neckar-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Oberndorf Neckar-Hydrologische Landespegel_filtered_shortened.csv to Oberndorf Neckar-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Rottweil Neckar-Hydrologische Landespegel_filtered_shortened.csv to Rottweil Neckar-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Wendlingen-Kläranlage Neckar-Hydrologische Landespegel_filtered_shortened.csv to Wendlingen-Kläranlage Neckar-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Untermünstertal Neumagen-Hydrologische Landespegel_filtered_shortened.csv to Untermünstertal Neumagen-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Epplings Obere Argen-Hydrologische Landespegel_filtered_shortened.csv to Epplings Obere Argen-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Jettkofen Ostrach-Hydrologische Landespegel_filtered_shortened.csv to Jettkofen Ostrach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Göllsdorf Prim-Hydrologische Landespegel_filtered_shortened.csv to Göllsdorf Prim-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Rielasingen Radolfzeller Aach-Hydrologische Landespegel_filtered_shortened.csv to Rielasingen Radolfzeller Aach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Hauenstein Rhein-Hydrologische Landespegel_filtered_shortened.csv to Hauenstein Rhein-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Konstanz Rhein-Hydrologische Landespegel_filtered_shortened.csv to Konstanz Rhein-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Binnrot Rot-Hydrologische Landespegel_filtered_shortened.csv to Binnrot Rot-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Gruol Stunzach-Hydrologische Landespegel_filtered_shortened.csv to Gruol Stunzach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Archshofen Tauber-Hydrologische Landespegel_filtered_shortened.csv to Archshofen Tauber-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Bad Mergentheim Tauber-Hydrologische Landespegel_filtered_shortened.csv to Bad Mergentheim Tauber-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Tauberbischofsheim Tauber-Hydrologische Landespegel_filtered_shortened.csv to Tauberbischofsheim Tauber-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Bad Teinach Teinach-Hydrologische Landespegel_filtered_shortened.csv to Bad Teinach Teinach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Sachsenflur Umpfer-Hydrologische Landespegel_filtered_shortened.csv to Sachsenflur Umpfer-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Beutelsau Untere Argen-Hydrologische Landespegel_filtered_shortened.csv to Beutelsau Untere Argen-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Rengers Untere Argen-Hydrologische Landespegel_filtered_shortened.csv to Rengers Untere Argen-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Unterkochen Weißer Kocher-Hydrologische Landespegel_filtered_shortened.csv to Unterkochen Weißer Kocher-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Zell Wiese-Hydrologische Landespegel_filtered_shortened.csv to Zell Wiese-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Simonswald Wilde Gutach-Hydrologische Landespegel_filtered_shortened.csv to Simonswald Wilde Gutach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Ewattingen Wutach-Hydrologische Landespegel_filtered_shortened.csv to Ewattingen Wutach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Oberlauchringen Wutach-Hydrologische Landespegel_filtered_shortened.csv to Oberlauchringen Wutach-Hydrologische Landespegel_interpolated.csv (131496 rows)
# interpolated: Hausen Zaber-Hydrologische Landespegel_filtered_shortened.csv to Hausen Zaber-Hydrologische Landespegel_interpolated.csv (131496 rows)
#
#  Ready. interpolated 77 of 77 files.
